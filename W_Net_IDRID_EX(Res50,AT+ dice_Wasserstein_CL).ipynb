# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:01<00:00, 674.79it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice
"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
"""def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1,axis=-1)
    m2  = tf.reduce_mean(feature_map2,axis=-1)
    return (tf.abs(m1-m2))"""

def complementary_loss(feature_map1,feature_map2):
    feature_map1 = tf.reduce_mean(feature_map1, axis=-1, keepdims=True)
    feature_map2  = tf.reduce_mean(feature_map2, axis=-1, keepdims=True)
    m1 = tf.reduce_mean(feature_map1)
    m2 = tf.reduce_mean(feature_map2)
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    #print(feature_map1.shape) #shapes are (none,H,W,1) so axis = 1 2 3 
    """intersection = tf.reduce_sum(feature_map1 * feature_map2, axis=[1, 2, 3])
    union = tf.reduce_sum(feature_map1 + feature_map2, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou"""
    return tf.abs(m1-m2) + dice_coeff(feature_map1,feature_map2)

    
clipping_layer = tf.keras.layers.Lambda(
    lambda x: tf.clip_by_value(x , clip_value_min=0, clip_value_max=2),
    name='output_2'
)

def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    
    #output_2 = (comp1+comp2+comp3+comp4)/4.0
    output_2 = tf.keras.layers.Add(name='output_2_sum')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])
    output_2 = clipping_layer(output_2)

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#  tf.math.reduce_mean_16 (TF  (None, 256, 256, 1)          0         ['encoder2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  (None, 256, 256, 1)          0         ['encoder1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  (None, 128, 128, 1)          0         ['encoder2[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  (None, 128, 128, 1)          0         ['encoder1[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_24 (TF  (None, 64, 64, 1)            0         ['encoder2[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_25 (TF  (None, 64, 64, 1)            0         ['encoder1[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_28 (TF  (None, 32, 32, 1)            0         ['encoder2[0][3]']
#  OpLambda)
#
#  tf.math.reduce_mean_29 (TF  (None, 32, 32, 1)            0         ['encoder1[0][3]']
#  OpLambda)
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  mbda)                                                              ']
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['tf.math.reduce_mean_17[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['tf.math.reduce_mean_21[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['tf.math.reduce_mean_24[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['tf.math.reduce_mean_25[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['tf.math.reduce_mean_28[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['tf.math.reduce_mean_29[0][0]
#  Lambda)                                                            ']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#  tchNormalization)
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_16[0][0]
#  a)                                                                 ',
#                                                                      'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_17[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_20[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_21[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_24[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_25[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_28[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_10 (TFOpLa  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_29[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_max_7[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.truediv[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_1[0][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_3[0][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_4[0][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_6[0][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_7[0][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_9[0][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_10[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.reshape[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.reshape_2[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.reshape_4[0][0]',
#  mbda)                                                               'tf.reshape_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.reshape_6[0][0]',
#  mbda)                                                               'tf.reshape_7[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.reduce_sum (TFOpLa  ()                           0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  ()                           0         ['tf.reshape[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_2 (TFOp  ()                           0         ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_3 (TFOp  ()                           0         ['tf.math.multiply_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_4 (TFOp  ()                           0         ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_5 (TFOp  ()                           0         ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_6 (TFOp  ()                           0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_7 (TFOp  ()                           0         ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_8 (TFOp  ()                           0         ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_9 (TFOp  ()                           0         ['tf.math.multiply_6[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_10 (TFO  ()                           0         ['tf.reshape_6[0][0]']
#  pLambda)
#
#  tf.math.reduce_sum_11 (TFO  ()                           0         ['tf.reshape_7[0][0]']
#  pLambda)
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_mean_18 (TF  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_mean_19 (TF  ()                           0         ['tf.math.reduce_mean_17[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_sum[0][0]']
#  mbda)
#
#  tf.__operators__.add_9 (TF  ()                           0         ['tf.math.reduce_sum_1[0][0]',
#  OpLambda)                                                           'tf.math.reduce_sum_2[0][0]']
#
#  tf.math.reduce_mean_22 (TF  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_mean_23 (TF  ()                           0         ['tf.math.reduce_mean_21[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.multiply_3 (TFOpLa  ()                           0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_13 (T  ()                           0         ['tf.math.reduce_sum_4[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_5[0][0]']
#
#  tf.math.reduce_mean_26 (TF  ()                           0         ['tf.math.reduce_mean_24[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_mean_27 (TF  ()                           0         ['tf.math.reduce_mean_25[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.multiply_5 (TFOpLa  ()                           0         ['tf.math.reduce_sum_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_17 (T  ()                           0         ['tf.math.reduce_sum_7[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_8[0][0]']
#
#  tf.math.reduce_mean_30 (TF  ()                           0         ['tf.math.reduce_mean_28[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_mean_31 (TF  ()                           0         ['tf.math.reduce_mean_29[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.multiply_7 (TFOpLa  ()                           0         ['tf.math.reduce_sum_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_21 (T  ()                           0         ['tf.math.reduce_sum_10[0][0]'
#  FOpLambda)                                                         , 'tf.math.reduce_sum_11[0][0]
#                                                                     ']
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.subtract (TFOpLamb  ()                           0         ['tf.math.reduce_mean_18[0][0]
#  da)                                                                ',
#                                                                      'tf.math.reduce_mean_19[0][0]
#                                                                     ']
#
#  tf.__operators__.add_8 (TF  ()                           0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.__operators__.add_10 (T  ()                           0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.math.subtract_1 (TFOpLa  ()                           0         ['tf.math.reduce_mean_22[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_23[0][0]
#                                                                     ']
#
#  tf.__operators__.add_12 (T  ()                           0         ['tf.math.multiply_3[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_14 (T  ()                           0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]']
#
#  tf.math.subtract_2 (TFOpLa  ()                           0         ['tf.math.reduce_mean_26[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_27[0][0]
#                                                                     ']
#
#  tf.__operators__.add_16 (T  ()                           0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_18 (T  ()                           0         ['tf.__operators__.add_17[0][0
#  FOpLambda)                                                         ]']
#
#  tf.math.subtract_3 (TFOpLa  ()                           0         ['tf.math.reduce_mean_30[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_31[0][0]
#                                                                     ']
#
#  tf.__operators__.add_20 (T  ()                           0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_22 (T  ()                           0         ['tf.__operators__.add_21[0][0
#  FOpLambda)                                                         ]']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.abs (TFOpLambda)    ()                           0         ['tf.math.subtract[0][0]']
#
#  tf.math.truediv_2 (TFOpLam  ()                           0         ['tf.__operators__.add_8[0][0]
#  bda)                                                               ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.abs_1 (TFOpLambda)  ()                           0         ['tf.math.subtract_1[0][0]']
#
#  tf.math.truediv_5 (TFOpLam  ()                           0         ['tf.__operators__.add_12[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  tf.math.abs_2 (TFOpLambda)  ()                           0         ['tf.math.subtract_2[0][0]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.__operators__.add_16[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_18[0][0
#                                                                     ]']
#
#  tf.math.abs_3 (TFOpLambda)  ()                           0         ['tf.math.subtract_3[0][0]']
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.__operators__.add_20[0][0
#  mbda)                                                              ]',
#                                                                      'tf.__operators__.add_22[0][0
#                                                                     ]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.__operators__.add_11 (T  ()                           0         ['tf.math.abs[0][0]',
#  FOpLambda)                                                          'tf.math.truediv_2[0][0]']
#
#  tf.__operators__.add_15 (T  ()                           0         ['tf.math.abs_1[0][0]',
#  FOpLambda)                                                          'tf.math.truediv_5[0][0]']
#
#  tf.__operators__.add_19 (T  ()                           0         ['tf.math.abs_2[0][0]',
#  FOpLambda)                                                          'tf.math.truediv_8[0][0]']
#
#  tf.__operators__.add_23 (T  ()                           0         ['tf.math.abs_3[0][0]',
#  FOpLambda)                                                          'tf.math.truediv_11[0][0]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.truediv_12 (TFOpLa  ()                           0         ['tf.__operators__.add_11[0][0
#  mbda)                                                              ]']
#
#  tf.math.truediv_13 (TFOpLa  ()                           0         ['tf.__operators__.add_15[0][0
#  mbda)                                                              ]']
#
#  tf.math.truediv_14 (TFOpLa  ()                           0         ['tf.__operators__.add_19[0][0
#  mbda)                                                              ]']
#
#  tf.math.truediv_15 (TFOpLa  ()                           0         ['tf.__operators__.add_23[0][0
#  mbda)                                                              ]']
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_2_sum (Add)          ()                           0         ['tf.math.truediv_12[0][0]',
#                                                                      'tf.math.truediv_13[0][0]',
#                                                                      'tf.math.truediv_14[0][0]',
#                                                                      'tf.math.truediv_15[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          20        ['multiply_15[0][0]']
#
#  output_2 (Lambda)           ()                           0         ['output_2_sum[0][0]']
#
# ==================================================================================================
# Total params: 25705415 (98.06 MB)
# Trainable params: 25676885 (97.95 MB)
# Non-trainable params: 28530 (111.45 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.03},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5", 
                               monitor="val_output_1_loss",
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
from keras import backend as K

batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
lr_reduction_factor = 0.5
lr_reduction_patience = 4  # Set the patience for validation loss reduction
best_val_loss = float('inf')  # Initialize the best validation loss
no_improvement_counter = 0
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=1,callbacks=callbacks)
    
    val_loss = history.history['val_output_1_loss'][-1]
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_counter = 0
    else:
        no_improvement_counter += 1

        # Apply learning rate reduction if validation loss does not improve for patience epochs
        if no_improvement_counter >= lr_reduction_patience:
            current_learning_rate = K.get_value(model.optimizer.learning_rate)
            new_learning_rate = current_learning_rate * lr_reduction_factor
            K.set_value(model.optimizer.learning_rate, new_learning_rate)
            no_improvement_counter = 0

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-25 08:04:55.539913: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.5292 - output_1_loss: 0.4787 - output_2_loss: 1.6849 - output_1_iou_score: 0.3148 - output_1_dice_coeff: 0.5445 - output_1_precision: 0.4616 - output_1_recall: 0.5711 - output_1_sensitivity: 0.6160 - output_1_specificity: 0.9803 - output_1_auc: 0.8738
# Epoch 1: val_output_1_loss improved from inf to 1.10012, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 111s 226ms/step - loss: 0.5292 - output_1_loss: 0.4787 - output_2_loss: 1.6849 - output_1_iou_score: 0.3148 - output_1_dice_coeff: 0.5445 - output_1_precision: 0.4616 - output_1_recall: 0.5711 - output_1_sensitivity: 0.6160 - output_1_specificity: 0.9803 - output_1_auc: 0.8738 - val_loss: 1.1601 - val_output_1_loss: 1.1001 - val_output_2_loss: 2.0000 - val_output_1_iou_score: 1.8445e-06 - val_output_1_dice_coeff: 3.0819e-06 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5000 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3923 - output_1_loss: 0.3386 - output_2_loss: 1.7906 - output_1_iou_score: 0.4216 - output_1_dice_coeff: 0.6836 - output_1_precision: 0.7947 - output_1_recall: 0.6655 - output_1_sensitivity: 0.6878 - output_1_specificity: 0.9948 - output_1_auc: 0.8967
# Epoch 1: val_output_1_loss improved from 1.10012 to 1.08888, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.3923 - output_1_loss: 0.3386 - output_2_loss: 1.7906 - output_1_iou_score: 0.4216 - output_1_dice_coeff: 0.6836 - output_1_precision: 0.7947 - output_1_recall: 0.6655 - output_1_sensitivity: 0.6878 - output_1_specificity: 0.9948 - output_1_auc: 0.8967 - val_loss: 1.1489 - val_output_1_loss: 1.0889 - val_output_2_loss: 2.0000 - val_output_1_iou_score: 4.4127e-04 - val_output_1_dice_coeff: 4.3565e-04 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5002 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3949 - output_1_loss: 0.3452 - output_2_loss: 1.6545 - output_1_iou_score: 0.4316 - output_1_dice_coeff: 0.6759 - output_1_precision: 0.7977 - output_1_recall: 0.6637 - output_1_sensitivity: 0.6875 - output_1_specificity: 0.9950 - output_1_auc: 0.8997
# Epoch 1: val_output_1_loss improved from 1.08888 to 0.99659, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 194ms/step - loss: 0.3949 - output_1_loss: 0.3452 - output_2_loss: 1.6545 - output_1_iou_score: 0.4316 - output_1_dice_coeff: 0.6759 - output_1_precision: 0.7977 - output_1_recall: 0.6637 - output_1_sensitivity: 0.6875 - output_1_specificity: 0.9950 - output_1_auc: 0.8997 - val_loss: 1.0566 - val_output_1_loss: 0.9966 - val_output_2_loss: 2.0000 - val_output_1_iou_score: 0.0167 - val_output_1_dice_coeff: 0.0469 - val_output_1_precision: 0.7852 - val_output_1_recall: 0.0181 - val_output_1_sensitivity: 0.0133 - val_output_1_specificity: 0.9999 - val_output_1_auc: 0.6577 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3616 - output_1_loss: 0.3137 - output_2_loss: 1.5981 - output_1_iou_score: 0.4568 - output_1_dice_coeff: 0.7038 - output_1_precision: 0.8048 - output_1_recall: 0.7164 - output_1_sensitivity: 0.7148 - output_1_specificity: 0.9948 - output_1_auc: 0.9237
# Epoch 1: val_output_1_loss improved from 0.99659 to 0.79486, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 195ms/step - loss: 0.3616 - output_1_loss: 0.3137 - output_2_loss: 1.5981 - output_1_iou_score: 0.4568 - output_1_dice_coeff: 0.7038 - output_1_precision: 0.8048 - output_1_recall: 0.7164 - output_1_sensitivity: 0.7148 - output_1_specificity: 0.9948 - output_1_auc: 0.9237 - val_loss: 0.8527 - val_output_1_loss: 0.7949 - val_output_2_loss: 1.9279 - val_output_1_iou_score: 0.1034 - val_output_1_dice_coeff: 0.2419 - val_output_1_precision: 0.9803 - val_output_1_recall: 0.1640 - val_output_1_sensitivity: 0.1428 - val_output_1_specificity: 0.9999 - val_output_1_auc: 0.7178 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3488 - output_1_loss: 0.3021 - output_2_loss: 1.5560 - output_1_iou_score: 0.4709 - output_1_dice_coeff: 0.7135 - output_1_precision: 0.8081 - output_1_recall: 0.7287 - output_1_sensitivity: 0.7259 - output_1_specificity: 0.9949 - output_1_auc: 0.9315
# Epoch 1: val_output_1_loss improved from 0.79486 to 0.34579, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 194ms/step - loss: 0.3488 - output_1_loss: 0.3021 - output_2_loss: 1.5560 - output_1_iou_score: 0.4709 - output_1_dice_coeff: 0.7135 - output_1_precision: 0.8081 - output_1_recall: 0.7287 - output_1_sensitivity: 0.7259 - output_1_specificity: 0.9949 - output_1_auc: 0.9315 - val_loss: 0.3967 - val_output_1_loss: 0.3458 - val_output_2_loss: 1.6967 - val_output_1_iou_score: 0.4048 - val_output_1_dice_coeff: 0.6683 - val_output_1_precision: 0.7664 - val_output_1_recall: 0.7586 - val_output_1_sensitivity: 0.6819 - val_output_1_specificity: 0.9935 - val_output_1_auc: 0.9398 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3370 - output_1_loss: 0.2915 - output_2_loss: 1.5139 - output_1_iou_score: 0.4781 - output_1_dice_coeff: 0.7252 - output_1_precision: 0.8141 - output_1_recall: 0.7353 - output_1_sensitivity: 0.7303 - output_1_specificity: 0.9950 - output_1_auc: 0.9277
# Epoch 1: val_output_1_loss improved from 0.34579 to 0.31600, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.3370 - output_1_loss: 0.2915 - output_2_loss: 1.5139 - output_1_iou_score: 0.4781 - output_1_dice_coeff: 0.7252 - output_1_precision: 0.8141 - output_1_recall: 0.7353 - output_1_sensitivity: 0.7303 - output_1_specificity: 0.9950 - output_1_auc: 0.9277 - val_loss: 0.3618 - val_output_1_loss: 0.3160 - val_output_2_loss: 1.5270 - val_output_1_iou_score: 0.4519 - val_output_1_dice_coeff: 0.7062 - val_output_1_precision: 0.7569 - val_output_1_recall: 0.7398 - val_output_1_sensitivity: 0.7333 - val_output_1_specificity: 0.9933 - val_output_1_auc: 0.9127 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3293 - output_1_loss: 0.2851 - output_2_loss: 1.4717 - output_1_iou_score: 0.4852 - output_1_dice_coeff: 0.7301 - output_1_precision: 0.8158 - output_1_recall: 0.7549 - output_1_sensitivity: 0.7354 - output_1_specificity: 0.9949 - output_1_auc: 0.9378
# Epoch 1: val_output_1_loss improved from 0.31600 to 0.28476, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.3293 - output_1_loss: 0.2851 - output_2_loss: 1.4717 - output_1_iou_score: 0.4852 - output_1_dice_coeff: 0.7301 - output_1_precision: 0.8158 - output_1_recall: 0.7549 - output_1_sensitivity: 0.7354 - output_1_specificity: 0.9949 - output_1_auc: 0.9378 - val_loss: 0.3294 - val_output_1_loss: 0.2848 - val_output_2_loss: 1.4873 - val_output_1_iou_score: 0.4613 - val_output_1_dice_coeff: 0.7279 - val_output_1_precision: 0.8388 - val_output_1_recall: 0.7722 - val_output_1_sensitivity: 0.6887 - val_output_1_specificity: 0.9958 - val_output_1_auc: 0.9413 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3148 - output_1_loss: 0.2713 - output_2_loss: 1.4503 - output_1_iou_score: 0.5026 - output_1_dice_coeff: 0.7430 - output_1_precision: 0.8187 - output_1_recall: 0.7691 - output_1_sensitivity: 0.7501 - output_1_specificity: 0.9949 - output_1_auc: 0.9428
# Epoch 1: val_output_1_loss did not improve from 0.28476
# 233/233 [==============================] - 44s 190ms/step - loss: 0.3148 - output_1_loss: 0.2713 - output_2_loss: 1.4503 - output_1_iou_score: 0.5026 - output_1_dice_coeff: 0.7430 - output_1_precision: 0.8187 - output_1_recall: 0.7691 - output_1_sensitivity: 0.7501 - output_1_specificity: 0.9949 - output_1_auc: 0.9428 - val_loss: 0.3660 - val_output_1_loss: 0.3221 - val_output_2_loss: 1.4651 - val_output_1_iou_score: 0.4429 - val_output_1_dice_coeff: 0.7001 - val_output_1_precision: 0.7737 - val_output_1_recall: 0.7260 - val_output_1_sensitivity: 0.7181 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9087 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3256 - output_1_loss: 0.2828 - output_2_loss: 1.4241 - output_1_iou_score: 0.4951 - output_1_dice_coeff: 0.7315 - output_1_precision: 0.8249 - output_1_recall: 0.7571 - output_1_sensitivity: 0.7351 - output_1_specificity: 0.9952 - output_1_auc: 0.9379
# Epoch 1: val_output_1_loss did not improve from 0.28476
# 233/233 [==============================] - 45s 191ms/step - loss: 0.3256 - output_1_loss: 0.2828 - output_2_loss: 1.4241 - output_1_iou_score: 0.4951 - output_1_dice_coeff: 0.7315 - output_1_precision: 0.8249 - output_1_recall: 0.7571 - output_1_sensitivity: 0.7351 - output_1_specificity: 0.9952 - output_1_auc: 0.9379 - val_loss: 0.3704 - val_output_1_loss: 0.3257 - val_output_2_loss: 1.4901 - val_output_1_iou_score: 0.4400 - val_output_1_dice_coeff: 0.6886 - val_output_1_precision: 0.7465 - val_output_1_recall: 0.7235 - val_output_1_sensitivity: 0.7339 - val_output_1_specificity: 0.9931 - val_output_1_auc: 0.9511 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3148 - output_1_loss: 0.2723 - output_2_loss: 1.4150 - output_1_iou_score: 0.5011 - output_1_dice_coeff: 0.7421 - output_1_precision: 0.8134 - output_1_recall: 0.7695 - output_1_sensitivity: 0.7502 - output_1_specificity: 0.9947 - output_1_auc: 0.9438
# Epoch 1: val_output_1_loss did not improve from 0.28476
# 233/233 [==============================] - 44s 190ms/step - loss: 0.3148 - output_1_loss: 0.2723 - output_2_loss: 1.4150 - output_1_iou_score: 0.5011 - output_1_dice_coeff: 0.7421 - output_1_precision: 0.8134 - output_1_recall: 0.7695 - output_1_sensitivity: 0.7502 - output_1_specificity: 0.9947 - output_1_auc: 0.9438 - val_loss: 0.3318 - val_output_1_loss: 0.2882 - val_output_2_loss: 1.4531 - val_output_1_iou_score: 0.4812 - val_output_1_dice_coeff: 0.7264 - val_output_1_precision: 0.8260 - val_output_1_recall: 0.7467 - val_output_1_sensitivity: 0.7017 - val_output_1_specificity: 0.9956 - val_output_1_auc: 0.9366 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2984 - output_1_loss: 0.2566 - output_2_loss: 1.3950 - output_1_iou_score: 0.5112 - output_1_dice_coeff: 0.7564 - output_1_precision: 0.8274 - output_1_recall: 0.7913 - output_1_sensitivity: 0.7582 - output_1_specificity: 0.9950 - output_1_auc: 0.9492
# Epoch 1: val_output_1_loss did not improve from 0.28476
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2984 - output_1_loss: 0.2566 - output_2_loss: 1.3950 - output_1_iou_score: 0.5112 - output_1_dice_coeff: 0.7564 - output_1_precision: 0.8274 - output_1_recall: 0.7913 - output_1_sensitivity: 0.7582 - output_1_specificity: 0.9950 - output_1_auc: 0.9492 - val_loss: 0.3775 - val_output_1_loss: 0.3329 - val_output_2_loss: 1.4851 - val_output_1_iou_score: 0.4172 - val_output_1_dice_coeff: 0.6826 - val_output_1_precision: 0.7766 - val_output_1_recall: 0.7218 - val_output_1_sensitivity: 0.6744 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9350 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2902 - output_1_loss: 0.2486 - output_2_loss: 1.3870 - output_1_iou_score: 0.5258 - output_1_dice_coeff: 0.7640 - output_1_precision: 0.8269 - output_1_recall: 0.7980 - output_1_sensitivity: 0.7654 - output_1_specificity: 0.9950 - output_1_auc: 0.9516
# Epoch 1: val_output_1_loss improved from 0.28476 to 0.27522, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 199ms/step - loss: 0.2902 - output_1_loss: 0.2486 - output_2_loss: 1.3870 - output_1_iou_score: 0.5258 - output_1_dice_coeff: 0.7640 - output_1_precision: 0.8269 - output_1_recall: 0.7980 - output_1_sensitivity: 0.7654 - output_1_specificity: 0.9950 - output_1_auc: 0.9516 - val_loss: 0.3175 - val_output_1_loss: 0.2752 - val_output_2_loss: 1.4109 - val_output_1_iou_score: 0.4806 - val_output_1_dice_coeff: 0.7376 - val_output_1_precision: 0.8614 - val_output_1_recall: 0.7585 - val_output_1_sensitivity: 0.6964 - val_output_1_specificity: 0.9966 - val_output_1_auc: 0.9346 - lr: 5.0000e-05
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2831 - output_1_loss: 0.2420 - output_2_loss: 1.3683 - output_1_iou_score: 0.5299 - output_1_dice_coeff: 0.7698 - output_1_precision: 0.8342 - output_1_recall: 0.8016 - output_1_sensitivity: 0.7701 - output_1_specificity: 0.9952 - output_1_auc: 0.9517
# Epoch 1: val_output_1_loss improved from 0.27522 to 0.25961, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2831 - output_1_loss: 0.2420 - output_2_loss: 1.3683 - output_1_iou_score: 0.5299 - output_1_dice_coeff: 0.7698 - output_1_precision: 0.8342 - output_1_recall: 0.8016 - output_1_sensitivity: 0.7701 - output_1_specificity: 0.9952 - output_1_auc: 0.9517 - val_loss: 0.3014 - val_output_1_loss: 0.2596 - val_output_2_loss: 1.3930 - val_output_1_iou_score: 0.5100 - val_output_1_dice_coeff: 0.7522 - val_output_1_precision: 0.8405 - val_output_1_recall: 0.7940 - val_output_1_sensitivity: 0.7453 - val_output_1_specificity: 0.9957 - val_output_1_auc: 0.9486 - lr: 5.0000e-05
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2783 - output_1_loss: 0.2374 - output_2_loss: 1.3610 - output_1_iou_score: 0.5384 - output_1_dice_coeff: 0.7745 - output_1_precision: 0.8342 - output_1_recall: 0.8073 - output_1_sensitivity: 0.7737 - output_1_specificity: 0.9952 - output_1_auc: 0.9538
# Epoch 1: val_output_1_loss did not improve from 0.25961
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2783 - output_1_loss: 0.2374 - output_2_loss: 1.3610 - output_1_iou_score: 0.5384 - output_1_dice_coeff: 0.7745 - output_1_precision: 0.8342 - output_1_recall: 0.8073 - output_1_sensitivity: 0.7737 - output_1_specificity: 0.9952 - output_1_auc: 0.9538 - val_loss: 0.3024 - val_output_1_loss: 0.2596 - val_output_2_loss: 1.4257 - val_output_1_iou_score: 0.5085 - val_output_1_dice_coeff: 0.7526 - val_output_1_precision: 0.8165 - val_output_1_recall: 0.8172 - val_output_1_sensitivity: 0.7649 - val_output_1_specificity: 0.9948 - val_output_1_auc: 0.9519 - lr: 5.0000e-05
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2753 - output_1_loss: 0.2347 - output_2_loss: 1.3535 - output_1_iou_score: 0.5491 - output_1_dice_coeff: 0.7774 - output_1_precision: 0.8389 - output_1_recall: 0.8078 - output_1_sensitivity: 0.7774 - output_1_specificity: 0.9953 - output_1_auc: 0.9538
# Epoch 1: val_output_1_loss did not improve from 0.25961
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2753 - output_1_loss: 0.2347 - output_2_loss: 1.3535 - output_1_iou_score: 0.5491 - output_1_dice_coeff: 0.7774 - output_1_precision: 0.8389 - output_1_recall: 0.8078 - output_1_sensitivity: 0.7774 - output_1_specificity: 0.9953 - output_1_auc: 0.9538 - val_loss: 0.3020 - val_output_1_loss: 0.2606 - val_output_2_loss: 1.3833 - val_output_1_iou_score: 0.4982 - val_output_1_dice_coeff: 0.7515 - val_output_1_precision: 0.7995 - val_output_1_recall: 0.8336 - val_output_1_sensitivity: 0.7813 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9580 - lr: 5.0000e-05
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2810 - output_1_loss: 0.2406 - output_2_loss: 1.3447 - output_1_iou_score: 0.5475 - output_1_dice_coeff: 0.7708 - output_1_precision: 0.8313 - output_1_recall: 0.8108 - output_1_sensitivity: 0.7710 - output_1_specificity: 0.9952 - output_1_auc: 0.9547
# Epoch 1: val_output_1_loss did not improve from 0.25961
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2810 - output_1_loss: 0.2406 - output_2_loss: 1.3447 - output_1_iou_score: 0.5475 - output_1_dice_coeff: 0.7708 - output_1_precision: 0.8313 - output_1_recall: 0.8108 - output_1_sensitivity: 0.7710 - output_1_specificity: 0.9952 - output_1_auc: 0.9547 - val_loss: 0.3066 - val_output_1_loss: 0.2650 - val_output_2_loss: 1.3866 - val_output_1_iou_score: 0.5011 - val_output_1_dice_coeff: 0.7478 - val_output_1_precision: 0.7644 - val_output_1_recall: 0.8617 - val_output_1_sensitivity: 0.8148 - val_output_1_specificity: 0.9925 - val_output_1_auc: 0.9655 - lr: 5.0000e-05
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2709 - output_1_loss: 0.2308 - output_2_loss: 1.3366 - output_1_iou_score: 0.5530 - output_1_dice_coeff: 0.7806 - output_1_precision: 0.8407 - output_1_recall: 0.8099 - output_1_sensitivity: 0.7839 - output_1_specificity: 0.9954 - output_1_auc: 0.9551
# Epoch 1: val_output_1_loss did not improve from 0.25961
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2709 - output_1_loss: 0.2308 - output_2_loss: 1.3366 - output_1_iou_score: 0.5530 - output_1_dice_coeff: 0.7806 - output_1_precision: 0.8407 - output_1_recall: 0.8099 - output_1_sensitivity: 0.7839 - output_1_specificity: 0.9954 - output_1_auc: 0.9551 - val_loss: 0.3049 - val_output_1_loss: 0.2647 - val_output_2_loss: 1.3410 - val_output_1_iou_score: 0.4955 - val_output_1_dice_coeff: 0.7485 - val_output_1_precision: 0.7710 - val_output_1_recall: 0.8566 - val_output_1_sensitivity: 0.8071 - val_output_1_specificity: 0.9928 - val_output_1_auc: 0.9619 - lr: 5.0000e-05
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2631 - output_1_loss: 0.2232 - output_2_loss: 1.3295 - output_1_iou_score: 0.5654 - output_1_dice_coeff: 0.7880 - output_1_precision: 0.8405 - output_1_recall: 0.8199 - output_1_sensitivity: 0.7904 - output_1_specificity: 0.9953 - output_1_auc: 0.9579
# Epoch 1: val_output_1_loss improved from 0.25961 to 0.25703, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2631 - output_1_loss: 0.2232 - output_2_loss: 1.3295 - output_1_iou_score: 0.5654 - output_1_dice_coeff: 0.7880 - output_1_precision: 0.8405 - output_1_recall: 0.8199 - output_1_sensitivity: 0.7904 - output_1_specificity: 0.9953 - output_1_auc: 0.9579 - val_loss: 0.2985 - val_output_1_loss: 0.2570 - val_output_2_loss: 1.3825 - val_output_1_iou_score: 0.5058 - val_output_1_dice_coeff: 0.7543 - val_output_1_precision: 0.8192 - val_output_1_recall: 0.8239 - val_output_1_sensitivity: 0.7660 - val_output_1_specificity: 0.9949 - val_output_1_auc: 0.9559 - lr: 2.5000e-05
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2666 - output_1_loss: 0.2268 - output_2_loss: 1.3273 - output_1_iou_score: 0.5685 - output_1_dice_coeff: 0.7841 - output_1_precision: 0.8432 - output_1_recall: 0.8204 - output_1_sensitivity: 0.7864 - output_1_specificity: 0.9954 - output_1_auc: 0.9578
# Epoch 1: val_output_1_loss did not improve from 0.25703
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2666 - output_1_loss: 0.2268 - output_2_loss: 1.3273 - output_1_iou_score: 0.5685 - output_1_dice_coeff: 0.7841 - output_1_precision: 0.8432 - output_1_recall: 0.8204 - output_1_sensitivity: 0.7864 - output_1_specificity: 0.9954 - output_1_auc: 0.9578 - val_loss: 0.2981 - val_output_1_loss: 0.2578 - val_output_2_loss: 1.3407 - val_output_1_iou_score: 0.5014 - val_output_1_dice_coeff: 0.7543 - val_output_1_precision: 0.8011 - val_output_1_recall: 0.8376 - val_output_1_sensitivity: 0.7768 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9582 - lr: 2.5000e-05
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2607 - output_1_loss: 0.2210 - output_2_loss: 1.3235 - output_1_iou_score: 0.5714 - output_1_dice_coeff: 0.7900 - output_1_precision: 0.8460 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7879 - output_1_specificity: 0.9955 - output_1_auc: 0.9581
# Epoch 1: val_output_1_loss did not improve from 0.25703
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2607 - output_1_loss: 0.2210 - output_2_loss: 1.3235 - output_1_iou_score: 0.5714 - output_1_dice_coeff: 0.7900 - output_1_precision: 0.8460 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7879 - output_1_specificity: 0.9955 - output_1_auc: 0.9581 - val_loss: 0.2991 - val_output_1_loss: 0.2589 - val_output_2_loss: 1.3409 - val_output_1_iou_score: 0.5065 - val_output_1_dice_coeff: 0.7541 - val_output_1_precision: 0.7843 - val_output_1_recall: 0.8530 - val_output_1_sensitivity: 0.8010 - val_output_1_specificity: 0.9934 - val_output_1_auc: 0.9611 - lr: 2.5000e-05
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2571 - output_1_loss: 0.2175 - output_2_loss: 1.3208 - output_1_iou_score: 0.5783 - output_1_dice_coeff: 0.7931 - output_1_precision: 0.8434 - output_1_recall: 0.8252 - output_1_sensitivity: 0.7951 - output_1_specificity: 0.9954 - output_1_auc: 0.9592
# Epoch 1: val_output_1_loss improved from 0.25703 to 0.24978, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2571 - output_1_loss: 0.2175 - output_2_loss: 1.3208 - output_1_iou_score: 0.5783 - output_1_dice_coeff: 0.7931 - output_1_precision: 0.8434 - output_1_recall: 0.8252 - output_1_sensitivity: 0.7951 - output_1_specificity: 0.9954 - output_1_auc: 0.9592 - val_loss: 0.2894 - val_output_1_loss: 0.2498 - val_output_2_loss: 1.3215 - val_output_1_iou_score: 0.5137 - val_output_1_dice_coeff: 0.7625 - val_output_1_precision: 0.8119 - val_output_1_recall: 0.8312 - val_output_1_sensitivity: 0.7812 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9547 - lr: 2.5000e-05
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2566 - output_1_loss: 0.2172 - output_2_loss: 1.3166 - output_1_iou_score: 0.5812 - output_1_dice_coeff: 0.7938 - output_1_precision: 0.8477 - output_1_recall: 0.8270 - output_1_sensitivity: 0.7959 - output_1_specificity: 0.9955 - output_1_auc: 0.9598
# Epoch 1: val_output_1_loss did not improve from 0.24978
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2566 - output_1_loss: 0.2172 - output_2_loss: 1.3166 - output_1_iou_score: 0.5812 - output_1_dice_coeff: 0.7938 - output_1_precision: 0.8477 - output_1_recall: 0.8270 - output_1_sensitivity: 0.7959 - output_1_specificity: 0.9955 - output_1_auc: 0.9598 - val_loss: 0.2933 - val_output_1_loss: 0.2532 - val_output_2_loss: 1.3382 - val_output_1_iou_score: 0.5105 - val_output_1_dice_coeff: 0.7591 - val_output_1_precision: 0.8277 - val_output_1_recall: 0.8159 - val_output_1_sensitivity: 0.7556 - val_output_1_specificity: 0.9952 - val_output_1_auc: 0.9500 - lr: 2.5000e-05
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2504 - output_1_loss: 0.2111 - output_2_loss: 1.3096 - output_1_iou_score: 0.5862 - output_1_dice_coeff: 0.7997 - output_1_precision: 0.8475 - output_1_recall: 0.8275 - output_1_sensitivity: 0.7991 - output_1_specificity: 0.9955 - output_1_auc: 0.9606
# Epoch 1: val_output_1_loss did not improve from 0.24978
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2504 - output_1_loss: 0.2111 - output_2_loss: 1.3096 - output_1_iou_score: 0.5862 - output_1_dice_coeff: 0.7997 - output_1_precision: 0.8475 - output_1_recall: 0.8275 - output_1_sensitivity: 0.7991 - output_1_specificity: 0.9955 - output_1_auc: 0.9606 - val_loss: 0.2954 - val_output_1_loss: 0.2559 - val_output_2_loss: 1.3175 - val_output_1_iou_score: 0.5094 - val_output_1_dice_coeff: 0.7563 - val_output_1_precision: 0.8086 - val_output_1_recall: 0.8342 - val_output_1_sensitivity: 0.7705 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9550 - lr: 2.5000e-05
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2570 - output_1_loss: 0.2177 - output_2_loss: 1.3096 - output_1_iou_score: 0.5821 - output_1_dice_coeff: 0.7930 - output_1_precision: 0.8455 - output_1_recall: 0.8290 - output_1_sensitivity: 0.7949 - output_1_specificity: 0.9954 - output_1_auc: 0.9600
# Epoch 1: val_output_1_loss did not improve from 0.24978
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2570 - output_1_loss: 0.2177 - output_2_loss: 1.3096 - output_1_iou_score: 0.5821 - output_1_dice_coeff: 0.7930 - output_1_precision: 0.8455 - output_1_recall: 0.8290 - output_1_sensitivity: 0.7949 - output_1_specificity: 0.9954 - output_1_auc: 0.9600 - val_loss: 0.2918 - val_output_1_loss: 0.2499 - val_output_2_loss: 1.3984 - val_output_1_iou_score: 0.5188 - val_output_1_dice_coeff: 0.7618 - val_output_1_precision: 0.8228 - val_output_1_recall: 0.8234 - val_output_1_sensitivity: 0.7693 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9540 - lr: 2.5000e-05
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2517 - output_1_loss: 0.2124 - output_2_loss: 1.3087 - output_1_iou_score: 0.5870 - output_1_dice_coeff: 0.7982 - output_1_precision: 0.8480 - output_1_recall: 0.8298 - output_1_sensitivity: 0.7968 - output_1_specificity: 0.9955 - output_1_auc: 0.9605
# Epoch 1: val_output_1_loss did not improve from 0.24978
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2517 - output_1_loss: 0.2124 - output_2_loss: 1.3087 - output_1_iou_score: 0.5870 - output_1_dice_coeff: 0.7982 - output_1_precision: 0.8480 - output_1_recall: 0.8298 - output_1_sensitivity: 0.7968 - output_1_specificity: 0.9955 - output_1_auc: 0.9605 - val_loss: 0.2903 - val_output_1_loss: 0.2507 - val_output_2_loss: 1.3204 - val_output_1_iou_score: 0.5226 - val_output_1_dice_coeff: 0.7615 - val_output_1_precision: 0.8415 - val_output_1_recall: 0.8021 - val_output_1_sensitivity: 0.7543 - val_output_1_specificity: 0.9957 - val_output_1_auc: 0.9457 - lr: 2.5000e-05
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2437 - output_1_loss: 0.2046 - output_2_loss: 1.3027 - output_1_iou_score: 0.6019 - output_1_dice_coeff: 0.8057 - output_1_precision: 0.8523 - output_1_recall: 0.8335 - output_1_sensitivity: 0.8043 - output_1_specificity: 0.9956 - output_1_auc: 0.9615
# Epoch 1: val_output_1_loss did not improve from 0.24978
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2437 - output_1_loss: 0.2046 - output_2_loss: 1.3027 - output_1_iou_score: 0.6019 - output_1_dice_coeff: 0.8057 - output_1_precision: 0.8523 - output_1_recall: 0.8335 - output_1_sensitivity: 0.8043 - output_1_specificity: 0.9956 - output_1_auc: 0.9615 - val_loss: 0.2925 - val_output_1_loss: 0.2530 - val_output_2_loss: 1.3169 - val_output_1_iou_score: 0.5135 - val_output_1_dice_coeff: 0.7595 - val_output_1_precision: 0.7998 - val_output_1_recall: 0.8411 - val_output_1_sensitivity: 0.7925 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9566 - lr: 1.2500e-05
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2449 - output_1_loss: 0.2060 - output_2_loss: 1.2977 - output_1_iou_score: 0.6015 - output_1_dice_coeff: 0.8044 - output_1_precision: 0.8547 - output_1_recall: 0.8328 - output_1_sensitivity: 0.8056 - output_1_specificity: 0.9957 - output_1_auc: 0.9615
# Epoch 1: val_output_1_loss improved from 0.24978 to 0.24758, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2449 - output_1_loss: 0.2060 - output_2_loss: 1.2977 - output_1_iou_score: 0.6015 - output_1_dice_coeff: 0.8044 - output_1_precision: 0.8547 - output_1_recall: 0.8328 - output_1_sensitivity: 0.8056 - output_1_specificity: 0.9957 - output_1_auc: 0.9615 - val_loss: 0.2868 - val_output_1_loss: 0.2476 - val_output_2_loss: 1.3070 - val_output_1_iou_score: 0.5216 - val_output_1_dice_coeff: 0.7650 - val_output_1_precision: 0.8086 - val_output_1_recall: 0.8344 - val_output_1_sensitivity: 0.7890 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9551 - lr: 1.2500e-05
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2447 - output_1_loss: 0.2056 - output_2_loss: 1.3034 - output_1_iou_score: 0.5995 - output_1_dice_coeff: 0.8047 - output_1_precision: 0.8508 - output_1_recall: 0.8360 - output_1_sensitivity: 0.8052 - output_1_specificity: 0.9956 - output_1_auc: 0.9624
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2447 - output_1_loss: 0.2056 - output_2_loss: 1.3034 - output_1_iou_score: 0.5995 - output_1_dice_coeff: 0.8047 - output_1_precision: 0.8508 - output_1_recall: 0.8360 - output_1_sensitivity: 0.8052 - output_1_specificity: 0.9956 - output_1_auc: 0.9624 - val_loss: 0.2914 - val_output_1_loss: 0.2520 - val_output_2_loss: 1.3133 - val_output_1_iou_score: 0.5130 - val_output_1_dice_coeff: 0.7604 - val_output_1_precision: 0.7980 - val_output_1_recall: 0.8436 - val_output_1_sensitivity: 0.7979 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9579 - lr: 1.2500e-05
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2479 - output_1_loss: 0.2089 - output_2_loss: 1.3009 - output_1_iou_score: 0.5973 - output_1_dice_coeff: 0.8015 - output_1_precision: 0.8517 - output_1_recall: 0.8368 - output_1_sensitivity: 0.7987 - output_1_specificity: 0.9956 - output_1_auc: 0.9623
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2479 - output_1_loss: 0.2089 - output_2_loss: 1.3009 - output_1_iou_score: 0.5973 - output_1_dice_coeff: 0.8015 - output_1_precision: 0.8517 - output_1_recall: 0.8368 - output_1_sensitivity: 0.7987 - output_1_specificity: 0.9956 - output_1_auc: 0.9623 - val_loss: 0.2940 - val_output_1_loss: 0.2547 - val_output_2_loss: 1.3105 - val_output_1_iou_score: 0.5185 - val_output_1_dice_coeff: 0.7579 - val_output_1_precision: 0.8058 - val_output_1_recall: 0.8375 - val_output_1_sensitivity: 0.7916 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9559 - lr: 1.2500e-05
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2413 - output_1_loss: 0.2023 - output_2_loss: 1.2984 - output_1_iou_score: 0.6023 - output_1_dice_coeff: 0.8079 - output_1_precision: 0.8527 - output_1_recall: 0.8372 - output_1_sensitivity: 0.8088 - output_1_specificity: 0.9956 - output_1_auc: 0.9622
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2413 - output_1_loss: 0.2023 - output_2_loss: 1.2984 - output_1_iou_score: 0.6023 - output_1_dice_coeff: 0.8079 - output_1_precision: 0.8527 - output_1_recall: 0.8372 - output_1_sensitivity: 0.8088 - output_1_specificity: 0.9956 - output_1_auc: 0.9622 - val_loss: 0.2886 - val_output_1_loss: 0.2494 - val_output_2_loss: 1.3057 - val_output_1_iou_score: 0.5204 - val_output_1_dice_coeff: 0.7628 - val_output_1_precision: 0.8055 - val_output_1_recall: 0.8414 - val_output_1_sensitivity: 0.7910 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9578 - lr: 1.2500e-05
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2452 - output_1_loss: 0.2063 - output_2_loss: 1.2974 - output_1_iou_score: 0.6066 - output_1_dice_coeff: 0.8039 - output_1_precision: 0.8566 - output_1_recall: 0.8382 - output_1_sensitivity: 0.8019 - output_1_specificity: 0.9958 - output_1_auc: 0.9627
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2452 - output_1_loss: 0.2063 - output_2_loss: 1.2974 - output_1_iou_score: 0.6066 - output_1_dice_coeff: 0.8039 - output_1_precision: 0.8566 - output_1_recall: 0.8382 - output_1_sensitivity: 0.8019 - output_1_specificity: 0.9958 - output_1_auc: 0.9627 - val_loss: 0.2933 - val_output_1_loss: 0.2541 - val_output_2_loss: 1.3053 - val_output_1_iou_score: 0.5137 - val_output_1_dice_coeff: 0.7594 - val_output_1_precision: 0.7880 - val_output_1_recall: 0.8494 - val_output_1_sensitivity: 0.7971 - val_output_1_specificity: 0.9935 - val_output_1_auc: 0.9571 - lr: 1.2500e-05
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2351 - output_1_loss: 0.1962 - output_2_loss: 1.2951 - output_1_iou_score: 0.6109 - output_1_dice_coeff: 0.8138 - output_1_precision: 0.8547 - output_1_recall: 0.8401 - output_1_sensitivity: 0.8143 - output_1_specificity: 0.9957 - output_1_auc: 0.9637
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2351 - output_1_loss: 0.1962 - output_2_loss: 1.2951 - output_1_iou_score: 0.6109 - output_1_dice_coeff: 0.8138 - output_1_precision: 0.8547 - output_1_recall: 0.8401 - output_1_sensitivity: 0.8143 - output_1_specificity: 0.9957 - output_1_auc: 0.9637 - val_loss: 0.2908 - val_output_1_loss: 0.2519 - val_output_2_loss: 1.2969 - val_output_1_iou_score: 0.5196 - val_output_1_dice_coeff: 0.7608 - val_output_1_precision: 0.8107 - val_output_1_recall: 0.8332 - val_output_1_sensitivity: 0.7807 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9540 - lr: 6.2500e-06
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2350 - output_1_loss: 0.1962 - output_2_loss: 1.2935 - output_1_iou_score: 0.6089 - output_1_dice_coeff: 0.8136 - output_1_precision: 0.8560 - output_1_recall: 0.8398 - output_1_sensitivity: 0.8098 - output_1_specificity: 0.9957 - output_1_auc: 0.9625
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2350 - output_1_loss: 0.1962 - output_2_loss: 1.2935 - output_1_iou_score: 0.6089 - output_1_dice_coeff: 0.8136 - output_1_precision: 0.8560 - output_1_recall: 0.8398 - output_1_sensitivity: 0.8098 - output_1_specificity: 0.9957 - output_1_auc: 0.9625 - val_loss: 0.2876 - val_output_1_loss: 0.2486 - val_output_2_loss: 1.2993 - val_output_1_iou_score: 0.5220 - val_output_1_dice_coeff: 0.7639 - val_output_1_precision: 0.8044 - val_output_1_recall: 0.8425 - val_output_1_sensitivity: 0.7907 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9570 - lr: 6.2500e-06
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2370 - output_1_loss: 0.1982 - output_2_loss: 1.2947 - output_1_iou_score: 0.6124 - output_1_dice_coeff: 0.8118 - output_1_precision: 0.8546 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8125 - output_1_specificity: 0.9957 - output_1_auc: 0.9640
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2370 - output_1_loss: 0.1982 - output_2_loss: 1.2947 - output_1_iou_score: 0.6124 - output_1_dice_coeff: 0.8118 - output_1_precision: 0.8546 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8125 - output_1_specificity: 0.9957 - output_1_auc: 0.9640 - val_loss: 0.2907 - val_output_1_loss: 0.2513 - val_output_2_loss: 1.3129 - val_output_1_iou_score: 0.5174 - val_output_1_dice_coeff: 0.7613 - val_output_1_precision: 0.8042 - val_output_1_recall: 0.8374 - val_output_1_sensitivity: 0.7878 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9550 - lr: 6.2500e-06
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2400 - output_1_loss: 0.2012 - output_2_loss: 1.2939 - output_1_iou_score: 0.6128 - output_1_dice_coeff: 0.8091 - output_1_precision: 0.8569 - output_1_recall: 0.8393 - output_1_sensitivity: 0.8082 - output_1_specificity: 0.9958 - output_1_auc: 0.9625
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2400 - output_1_loss: 0.2012 - output_2_loss: 1.2939 - output_1_iou_score: 0.6128 - output_1_dice_coeff: 0.8091 - output_1_precision: 0.8569 - output_1_recall: 0.8393 - output_1_sensitivity: 0.8082 - output_1_specificity: 0.9958 - output_1_auc: 0.9625 - val_loss: 0.2901 - val_output_1_loss: 0.2510 - val_output_2_loss: 1.3043 - val_output_1_iou_score: 0.5137 - val_output_1_dice_coeff: 0.7618 - val_output_1_precision: 0.8109 - val_output_1_recall: 0.8326 - val_output_1_sensitivity: 0.7854 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9531 - lr: 6.2500e-06
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2361 - output_1_loss: 0.1973 - output_2_loss: 1.2922 - output_1_iou_score: 0.6176 - output_1_dice_coeff: 0.8127 - output_1_precision: 0.8580 - output_1_recall: 0.8403 - output_1_sensitivity: 0.8102 - output_1_specificity: 0.9958 - output_1_auc: 0.9632
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2361 - output_1_loss: 0.1973 - output_2_loss: 1.2922 - output_1_iou_score: 0.6176 - output_1_dice_coeff: 0.8127 - output_1_precision: 0.8580 - output_1_recall: 0.8403 - output_1_sensitivity: 0.8102 - output_1_specificity: 0.9958 - output_1_auc: 0.9632 - val_loss: 0.2916 - val_output_1_loss: 0.2526 - val_output_2_loss: 1.3022 - val_output_1_iou_score: 0.5133 - val_output_1_dice_coeff: 0.7607 - val_output_1_precision: 0.7978 - val_output_1_recall: 0.8420 - val_output_1_sensitivity: 0.7951 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9555 - lr: 3.1250e-06
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2354 - output_1_loss: 0.1967 - output_2_loss: 1.2906 - output_1_iou_score: 0.6214 - output_1_dice_coeff: 0.8135 - output_1_precision: 0.8563 - output_1_recall: 0.8436 - output_1_sensitivity: 0.8135 - output_1_specificity: 0.9957 - output_1_auc: 0.9637
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2354 - output_1_loss: 0.1967 - output_2_loss: 1.2906 - output_1_iou_score: 0.6214 - output_1_dice_coeff: 0.8135 - output_1_precision: 0.8563 - output_1_recall: 0.8436 - output_1_sensitivity: 0.8135 - output_1_specificity: 0.9957 - output_1_auc: 0.9637 - val_loss: 0.2908 - val_output_1_loss: 0.2519 - val_output_2_loss: 1.2989 - val_output_1_iou_score: 0.5206 - val_output_1_dice_coeff: 0.7610 - val_output_1_precision: 0.8041 - val_output_1_recall: 0.8376 - val_output_1_sensitivity: 0.7890 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9541 - lr: 3.1250e-06
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2346 - output_1_loss: 0.1959 - output_2_loss: 1.2911 - output_1_iou_score: 0.6156 - output_1_dice_coeff: 0.8135 - output_1_precision: 0.8554 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9957 - output_1_auc: 0.9636
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2346 - output_1_loss: 0.1959 - output_2_loss: 1.2911 - output_1_iou_score: 0.6156 - output_1_dice_coeff: 0.8135 - output_1_precision: 0.8554 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9957 - output_1_auc: 0.9636 - val_loss: 0.2902 - val_output_1_loss: 0.2511 - val_output_2_loss: 1.3008 - val_output_1_iou_score: 0.5212 - val_output_1_dice_coeff: 0.7612 - val_output_1_precision: 0.8120 - val_output_1_recall: 0.8346 - val_output_1_sensitivity: 0.7842 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9545 - lr: 3.1250e-06
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2364 - output_1_loss: 0.1977 - output_2_loss: 1.2914 - output_1_iou_score: 0.6178 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8561 - output_1_recall: 0.8433 - output_1_sensitivity: 0.8096 - output_1_specificity: 0.9957 - output_1_auc: 0.9640
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2364 - output_1_loss: 0.1977 - output_2_loss: 1.2914 - output_1_iou_score: 0.6178 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8561 - output_1_recall: 0.8433 - output_1_sensitivity: 0.8096 - output_1_specificity: 0.9957 - output_1_auc: 0.9640 - val_loss: 0.2913 - val_output_1_loss: 0.2523 - val_output_2_loss: 1.2991 - val_output_1_iou_score: 0.5169 - val_output_1_dice_coeff: 0.7605 - val_output_1_precision: 0.8008 - val_output_1_recall: 0.8408 - val_output_1_sensitivity: 0.7918 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9562 - lr: 3.1250e-06
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2319 - output_1_loss: 0.1932 - output_2_loss: 1.2892 - output_1_iou_score: 0.6195 - output_1_dice_coeff: 0.8162 - output_1_precision: 0.8592 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8141 - output_1_specificity: 0.9958 - output_1_auc: 0.9642
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2319 - output_1_loss: 0.1932 - output_2_loss: 1.2892 - output_1_iou_score: 0.6195 - output_1_dice_coeff: 0.8162 - output_1_precision: 0.8592 - output_1_recall: 0.8431 - output_1_sensitivity: 0.8141 - output_1_specificity: 0.9958 - output_1_auc: 0.9642 - val_loss: 0.2901 - val_output_1_loss: 0.2509 - val_output_2_loss: 1.3084 - val_output_1_iou_score: 0.5202 - val_output_1_dice_coeff: 0.7618 - val_output_1_precision: 0.8069 - val_output_1_recall: 0.8378 - val_output_1_sensitivity: 0.7885 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9552 - lr: 1.5625e-06
# Epoch 41/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2353 - output_1_loss: 0.1966 - output_2_loss: 1.2910 - output_1_iou_score: 0.6235 - output_1_dice_coeff: 0.8134 - output_1_precision: 0.8579 - output_1_recall: 0.8436 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9958 - output_1_auc: 0.9638
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2353 - output_1_loss: 0.1966 - output_2_loss: 1.2910 - output_1_iou_score: 0.6235 - output_1_dice_coeff: 0.8134 - output_1_precision: 0.8579 - output_1_recall: 0.8436 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9958 - output_1_auc: 0.9638 - val_loss: 0.2910 - val_output_1_loss: 0.2518 - val_output_2_loss: 1.3083 - val_output_1_iou_score: 0.5208 - val_output_1_dice_coeff: 0.7609 - val_output_1_precision: 0.8071 - val_output_1_recall: 0.8378 - val_output_1_sensitivity: 0.7851 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9547 - lr: 1.5625e-06
# Epoch 42/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2328 - output_1_loss: 0.1941 - output_2_loss: 1.2912 - output_1_iou_score: 0.6189 - output_1_dice_coeff: 0.8156 - output_1_precision: 0.8559 - output_1_recall: 0.8435 - output_1_sensitivity: 0.8152 - output_1_specificity: 0.9957 - output_1_auc: 0.9635
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2328 - output_1_loss: 0.1941 - output_2_loss: 1.2912 - output_1_iou_score: 0.6189 - output_1_dice_coeff: 0.8156 - output_1_precision: 0.8559 - output_1_recall: 0.8435 - output_1_sensitivity: 0.8152 - output_1_specificity: 0.9957 - output_1_auc: 0.9635 - val_loss: 0.2873 - val_output_1_loss: 0.2484 - val_output_2_loss: 1.2970 - val_output_1_iou_score: 0.5159 - val_output_1_dice_coeff: 0.7646 - val_output_1_precision: 0.8020 - val_output_1_recall: 0.8427 - val_output_1_sensitivity: 0.7924 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9560 - lr: 1.5625e-06
# Epoch 43/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2355 - output_1_loss: 0.1968 - output_2_loss: 1.2903 - output_1_iou_score: 0.6181 - output_1_dice_coeff: 0.8132 - output_1_precision: 0.8568 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8125 - output_1_specificity: 0.9957 - output_1_auc: 0.9636
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2355 - output_1_loss: 0.1968 - output_2_loss: 1.2903 - output_1_iou_score: 0.6181 - output_1_dice_coeff: 0.8132 - output_1_precision: 0.8568 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8125 - output_1_specificity: 0.9957 - output_1_auc: 0.9636 - val_loss: 0.2909 - val_output_1_loss: 0.2520 - val_output_2_loss: 1.2981 - val_output_1_iou_score: 0.5193 - val_output_1_dice_coeff: 0.7609 - val_output_1_precision: 0.8096 - val_output_1_recall: 0.8328 - val_output_1_sensitivity: 0.7839 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9525 - lr: 1.5625e-06
# Epoch 44/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2334 - output_1_loss: 0.1947 - output_2_loss: 1.2895 - output_1_iou_score: 0.6202 - output_1_dice_coeff: 0.8153 - output_1_precision: 0.8589 - output_1_recall: 0.8432 - output_1_sensitivity: 0.8162 - output_1_specificity: 0.9958 - output_1_auc: 0.9635
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2334 - output_1_loss: 0.1947 - output_2_loss: 1.2895 - output_1_iou_score: 0.6202 - output_1_dice_coeff: 0.8153 - output_1_precision: 0.8589 - output_1_recall: 0.8432 - output_1_sensitivity: 0.8162 - output_1_specificity: 0.9958 - output_1_auc: 0.9635 - val_loss: 0.2894 - val_output_1_loss: 0.2505 - val_output_2_loss: 1.2985 - val_output_1_iou_score: 0.5178 - val_output_1_dice_coeff: 0.7623 - val_output_1_precision: 0.8047 - val_output_1_recall: 0.8399 - val_output_1_sensitivity: 0.7913 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9555 - lr: 7.8125e-07
# Epoch 45/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2311 - output_1_loss: 0.1924 - output_2_loss: 1.2898 - output_1_iou_score: 0.6228 - output_1_dice_coeff: 0.8172 - output_1_precision: 0.8602 - output_1_recall: 0.8383 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9959 - output_1_auc: 0.9633
# Epoch 1: val_output_1_loss did not improve from 0.24758
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2311 - output_1_loss: 0.1924 - output_2_loss: 1.2898 - output_1_iou_score: 0.6228 - output_1_dice_coeff: 0.8172 - output_1_precision: 0.8602 - output_1_recall: 0.8383 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9959 - output_1_auc: 0.9633 - val_loss: 0.2907 - val_output_1_loss: 0.2518 - val_output_2_loss: 1.2996 - val_output_1_iou_score: 0.5185 - val_output_1_dice_coeff: 0.7610 - val_output_1_precision: 0.8065 - val_output_1_recall: 0.8388 - val_output_1_sensitivity: 0.7853 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9545 - lr: 7.8125e-07
# Epoch 46/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2329 - output_1_loss: 0.1942 - output_2_loss: 1.2883 - output_1_iou_score: 0.6233 - output_1_dice_coeff: 0.8155 - output_1_precision: 0.8577 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8149 - output_1_specificity: 0.9958 - output_1_auc: 0.9639
# Epoch 1: val_output_1_loss improved from 0.24758 to 0.24710, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2329 - output_1_loss: 0.1942 - output_2_loss: 1.2883 - output_1_iou_score: 0.6233 - output_1_dice_coeff: 0.8155 - output_1_precision: 0.8577 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8149 - output_1_specificity: 0.9958 - output_1_auc: 0.9639 - val_loss: 0.2862 - val_output_1_loss: 0.2471 - val_output_2_loss: 1.3032 - val_output_1_iou_score: 0.5195 - val_output_1_dice_coeff: 0.7657 - val_output_1_precision: 0.8098 - val_output_1_recall: 0.8377 - val_output_1_sensitivity: 0.7869 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9542 - lr: 7.8125e-07
# Epoch 47/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2311 - output_1_loss: 0.1925 - output_2_loss: 1.2871 - output_1_iou_score: 0.6235 - output_1_dice_coeff: 0.8173 - output_1_precision: 0.8578 - output_1_recall: 0.8450 - output_1_sensitivity: 0.8169 - output_1_specificity: 0.9958 - output_1_auc: 0.9648
# Epoch 1: val_output_1_loss did not improve from 0.24710
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2311 - output_1_loss: 0.1925 - output_2_loss: 1.2871 - output_1_iou_score: 0.6235 - output_1_dice_coeff: 0.8173 - output_1_precision: 0.8578 - output_1_recall: 0.8450 - output_1_sensitivity: 0.8169 - output_1_specificity: 0.9958 - output_1_auc: 0.9648 - val_loss: 0.2926 - val_output_1_loss: 0.2533 - val_output_2_loss: 1.3092 - val_output_1_iou_score: 0.5125 - val_output_1_dice_coeff: 0.7597 - val_output_1_precision: 0.8030 - val_output_1_recall: 0.8375 - val_output_1_sensitivity: 0.7888 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9542 - lr: 7.8125e-07
# Epoch 48/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2279 - output_1_loss: 0.1893 - output_2_loss: 1.2878 - output_1_iou_score: 0.6180 - output_1_dice_coeff: 0.8205 - output_1_precision: 0.8587 - output_1_recall: 0.8414 - output_1_sensitivity: 0.8200 - output_1_specificity: 0.9958 - output_1_auc: 0.9639
# Epoch 1: val_output_1_loss did not improve from 0.24710
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2279 - output_1_loss: 0.1893 - output_2_loss: 1.2878 - output_1_iou_score: 0.6180 - output_1_dice_coeff: 0.8205 - output_1_precision: 0.8587 - output_1_recall: 0.8414 - output_1_sensitivity: 0.8200 - output_1_specificity: 0.9958 - output_1_auc: 0.9639 - val_loss: 0.2876 - val_output_1_loss: 0.2486 - val_output_2_loss: 1.2998 - val_output_1_iou_score: 0.5256 - val_output_1_dice_coeff: 0.7641 - val_output_1_precision: 0.8084 - val_output_1_recall: 0.8394 - val_output_1_sensitivity: 0.7868 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9550 - lr: 7.8125e-07
# Epoch 49/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2303 - output_1_loss: 0.1917 - output_2_loss: 1.2871 - output_1_iou_score: 0.6238 - output_1_dice_coeff: 0.8180 - output_1_precision: 0.8565 - output_1_recall: 0.8446 - output_1_sensitivity: 0.8163 - output_1_specificity: 0.9957 - output_1_auc: 0.9645
# Epoch 1: val_output_1_loss did not improve from 0.24710
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2303 - output_1_loss: 0.1917 - output_2_loss: 1.2871 - output_1_iou_score: 0.6238 - output_1_dice_coeff: 0.8180 - output_1_precision: 0.8565 - output_1_recall: 0.8446 - output_1_sensitivity: 0.8163 - output_1_specificity: 0.9957 - output_1_auc: 0.9645 - val_loss: 0.2884 - val_output_1_loss: 0.2493 - val_output_2_loss: 1.3025 - val_output_1_iou_score: 0.5169 - val_output_1_dice_coeff: 0.7634 - val_output_1_precision: 0.8074 - val_output_1_recall: 0.8377 - val_output_1_sensitivity: 0.7842 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9544 - lr: 7.8125e-07
# Epoch 50/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2305 - output_1_loss: 0.1919 - output_2_loss: 1.2870 - output_1_iou_score: 0.6231 - output_1_dice_coeff: 0.8175 - output_1_precision: 0.8554 - output_1_recall: 0.8457 - output_1_sensitivity: 0.8165 - output_1_specificity: 0.9956 - output_1_auc: 0.9653
# Epoch 1: val_output_1_loss did not improve from 0.24710
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2305 - output_1_loss: 0.1919 - output_2_loss: 1.2870 - output_1_iou_score: 0.6231 - output_1_dice_coeff: 0.8175 - output_1_precision: 0.8554 - output_1_recall: 0.8457 - output_1_sensitivity: 0.8165 - output_1_specificity: 0.9956 - output_1_auc: 0.9653 - val_loss: 0.2872 - val_output_1_loss: 0.2482 - val_output_2_loss: 1.2972 - val_output_1_iou_score: 0.5230 - val_output_1_dice_coeff: 0.7645 - val_output_1_precision: 0.8055 - val_output_1_recall: 0.8384 - val_output_1_sensitivity: 0.7914 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9550 - lr: 7.8125e-07
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_iou_score', 'output_1_dice_coeff', 'output_1_precision', 'output_1_recall', 'output_1_sensitivity', 'output_1_specificity', 'output_1_auc', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_iou_score', 'val_output_1_dice_coeff', 'val_output_1_precision', 'val_output_1_recall', 'val_output_1_sensitivity', 'val_output_1_specificity', 'val_output_1_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %%
"""from tensorflow.keras.models import load_model

custom_objects = {'total_loss': total_loss,
                  '<lambda>': lambda y_true, y_pred: y_pred,
                  'iou_score':iou_score,
                  'dice_coeff':dice_coeff,
                  'precision':tf.keras.metrics.Precision(),
                  'recall':tf.keras.metrics.Recall(),
                  'sensitivity':sensitivity,
                  'specificity':specificity
                 }

with tf.keras.utils.custom_object_scope(custom_objects):
    model = load_model('/kaggle/working/final_model.h5')"""
# Out:
# "from tensorflow.keras.models import load_model\n\ncustom_objects = {'total_loss': total_loss,\n                  '<lambda>': lambda y_true, y_pred: y_pred,\n                  'iou_score':iou_score,\n                  'dice_coeff':dice_coeff,\n                  'precision':tf.keras.metrics.Precision(),\n                  'recall':tf.keras.metrics.Recall(),\n                  'sensitivity':sensitivity,\n                  'specificity':specificity\n                 }\n\nwith tf.keras.utils.custom_object_scope(custom_objects):\n    model = load_model('/kaggle/working/final_model.h5')"

# %% [markdown]
# Im going for this method instead...more efficient

# %%
model = build_WNet((256,256,3))

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00005), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.01},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5",
                               monitor='val_output_1_loss',
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=2, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-25 08:44:32.645770: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.2209 - output_1_loss: 0.2080 - output_2_loss: 1.2903 - output_1_iou_score: 0.6000 - output_1_dice_coeff: 0.8024 - output_1_precision_1: 0.8507 - output_1_recall_1: 0.8364 - output_1_sensitivity: 0.8038 - output_1_specificity: 0.9956 - output_1_auc_1: 0.9614
# Epoch 1: val_output_1_loss improved from inf to 0.25078, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 98s 203ms/step - loss: 0.2209 - output_1_loss: 0.2080 - output_2_loss: 1.2903 - output_1_iou_score: 0.6000 - output_1_dice_coeff: 0.8024 - output_1_precision_1: 0.8507 - output_1_recall_1: 0.8364 - output_1_sensitivity: 0.8038 - output_1_specificity: 0.9956 - output_1_auc_1: 0.9614 - val_loss: 0.2639 - val_output_1_loss: 0.2508 - val_output_2_loss: 1.3128 - val_output_1_iou_score: 0.5063 - val_output_1_dice_coeff: 0.7620 - val_output_1_precision_1: 0.8115 - val_output_1_recall_1: 0.8308 - val_output_1_sensitivity: 0.7863 - val_output_1_specificity: 0.9945 - val_output_1_auc_1: 0.9523 - lr: 5.0000e-05
# Epoch 2/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2150 - output_1_loss: 0.2022 - output_2_loss: 1.2876 - output_1_iou_score: 0.6078 - output_1_dice_coeff: 0.8081 - output_1_precision_1: 0.8547 - output_1_recall_1: 0.8363 - output_1_sensitivity: 0.8062 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9624
# Epoch 2: val_output_1_loss did not improve from 0.25078
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2150 - output_1_loss: 0.2022 - output_2_loss: 1.2876 - output_1_iou_score: 0.6078 - output_1_dice_coeff: 0.8081 - output_1_precision_1: 0.8547 - output_1_recall_1: 0.8363 - output_1_sensitivity: 0.8062 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9624 - val_loss: 0.2722 - val_output_1_loss: 0.2590 - val_output_2_loss: 1.3220 - val_output_1_iou_score: 0.5030 - val_output_1_dice_coeff: 0.7542 - val_output_1_precision_1: 0.7925 - val_output_1_recall_1: 0.8420 - val_output_1_sensitivity: 0.7827 - val_output_1_specificity: 0.9938 - val_output_1_auc_1: 0.9543 - lr: 5.0000e-05
# Epoch 3/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2121 - output_1_loss: 0.1992 - output_2_loss: 1.2897 - output_1_iou_score: 0.6078 - output_1_dice_coeff: 0.8112 - output_1_precision_1: 0.8548 - output_1_recall_1: 0.8365 - output_1_sensitivity: 0.8118 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9615
# Epoch 3: val_output_1_loss improved from 0.25078 to 0.25044, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2121 - output_1_loss: 0.1992 - output_2_loss: 1.2897 - output_1_iou_score: 0.6078 - output_1_dice_coeff: 0.8112 - output_1_precision_1: 0.8548 - output_1_recall_1: 0.8365 - output_1_sensitivity: 0.8118 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9615 - val_loss: 0.2636 - val_output_1_loss: 0.2504 - val_output_2_loss: 1.3193 - val_output_1_iou_score: 0.5238 - val_output_1_dice_coeff: 0.7617 - val_output_1_precision_1: 0.8321 - val_output_1_recall_1: 0.8144 - val_output_1_sensitivity: 0.7574 - val_output_1_specificity: 0.9953 - val_output_1_auc_1: 0.9489 - lr: 5.0000e-05
# Epoch 4/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2108 - output_1_loss: 0.1979 - output_2_loss: 1.2954 - output_1_iou_score: 0.6052 - output_1_dice_coeff: 0.8122 - output_1_precision_1: 0.8557 - output_1_recall_1: 0.8374 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9958 - output_1_auc_1: 0.9616
# Epoch 4: val_output_1_loss did not improve from 0.25044
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2108 - output_1_loss: 0.1979 - output_2_loss: 1.2954 - output_1_iou_score: 0.6052 - output_1_dice_coeff: 0.8122 - output_1_precision_1: 0.8557 - output_1_recall_1: 0.8374 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9958 - output_1_auc_1: 0.9616 - val_loss: 0.2713 - val_output_1_loss: 0.2582 - val_output_2_loss: 1.3147 - val_output_1_iou_score: 0.5136 - val_output_1_dice_coeff: 0.7555 - val_output_1_precision_1: 0.8372 - val_output_1_recall_1: 0.8000 - val_output_1_sensitivity: 0.7425 - val_output_1_specificity: 0.9956 - val_output_1_auc_1: 0.9385 - lr: 5.0000e-05
# Epoch 5/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2140 - output_1_loss: 0.2011 - output_2_loss: 1.2926 - output_1_iou_score: 0.6121 - output_1_dice_coeff: 0.8088 - output_1_precision_1: 0.8560 - output_1_recall_1: 0.8386 - output_1_sensitivity: 0.8092 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9628
# Epoch 5: val_output_1_loss did not improve from 0.25044
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2140 - output_1_loss: 0.2011 - output_2_loss: 1.2926 - output_1_iou_score: 0.6121 - output_1_dice_coeff: 0.8088 - output_1_precision_1: 0.8560 - output_1_recall_1: 0.8386 - output_1_sensitivity: 0.8092 - output_1_specificity: 0.9957 - output_1_auc_1: 0.9628 - val_loss: 0.2655 - val_output_1_loss: 0.2522 - val_output_2_loss: 1.3374 - val_output_1_iou_score: 0.5122 - val_output_1_dice_coeff: 0.7609 - val_output_1_precision_1: 0.8091 - val_output_1_recall_1: 0.8328 - val_output_1_sensitivity: 0.7656 - val_output_1_specificity: 0.9944 - val_output_1_auc_1: 0.9521 - lr: 5.0000e-05
# Epoch 6/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2115 - output_1_loss: 0.1986 - output_2_loss: 1.2895 - output_1_iou_score: 0.6256 - output_1_dice_coeff: 0.8113 - output_1_precision_1: 0.8601 - output_1_recall_1: 0.8425 - output_1_sensitivity: 0.8102 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9638
# Epoch 6: val_output_1_loss improved from 0.25044 to 0.24906, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2115 - output_1_loss: 0.1986 - output_2_loss: 1.2895 - output_1_iou_score: 0.6256 - output_1_dice_coeff: 0.8113 - output_1_precision_1: 0.8601 - output_1_recall_1: 0.8425 - output_1_sensitivity: 0.8102 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9638 - val_loss: 0.2626 - val_output_1_loss: 0.2491 - val_output_2_loss: 1.3497 - val_output_1_iou_score: 0.5191 - val_output_1_dice_coeff: 0.7634 - val_output_1_precision_1: 0.8263 - val_output_1_recall_1: 0.8211 - val_output_1_sensitivity: 0.7668 - val_output_1_specificity: 0.9951 - val_output_1_auc_1: 0.9492 - lr: 1.5000e-05
# Epoch 7/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1989 - output_1_loss: 0.1860 - output_2_loss: 1.2879 - output_1_iou_score: 0.6295 - output_1_dice_coeff: 0.8237 - output_1_precision_1: 0.8592 - output_1_recall_1: 0.8459 - output_1_sensitivity: 0.8238 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9645
# Epoch 7: val_output_1_loss did not improve from 0.24906
# 233/233 [==============================] - 44s 190ms/step - loss: 0.1989 - output_1_loss: 0.1860 - output_2_loss: 1.2879 - output_1_iou_score: 0.6295 - output_1_dice_coeff: 0.8237 - output_1_precision_1: 0.8592 - output_1_recall_1: 0.8459 - output_1_sensitivity: 0.8238 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9645 - val_loss: 0.2638 - val_output_1_loss: 0.2503 - val_output_2_loss: 1.3516 - val_output_1_iou_score: 0.5216 - val_output_1_dice_coeff: 0.7622 - val_output_1_precision_1: 0.8237 - val_output_1_recall_1: 0.8231 - val_output_1_sensitivity: 0.7666 - val_output_1_specificity: 0.9950 - val_output_1_auc_1: 0.9495 - lr: 1.5000e-05
# Epoch 8/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2026 - output_1_loss: 0.1897 - output_2_loss: 1.2869 - output_1_iou_score: 0.6311 - output_1_dice_coeff: 0.8197 - output_1_precision_1: 0.8618 - output_1_recall_1: 0.8494 - output_1_sensitivity: 0.8193 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9656
# Epoch 8: val_output_1_loss did not improve from 0.24906
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.499999886320438e-06.
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2026 - output_1_loss: 0.1897 - output_2_loss: 1.2869 - output_1_iou_score: 0.6311 - output_1_dice_coeff: 0.8197 - output_1_precision_1: 0.8618 - output_1_recall_1: 0.8494 - output_1_sensitivity: 0.8193 - output_1_specificity: 0.9959 - output_1_auc_1: 0.9656 - val_loss: 0.2707 - val_output_1_loss: 0.2575 - val_output_2_loss: 1.3184 - val_output_1_iou_score: 0.5064 - val_output_1_dice_coeff: 0.7560 - val_output_1_precision_1: 0.7914 - val_output_1_recall_1: 0.8453 - val_output_1_sensitivity: 0.7889 - val_output_1_specificity: 0.9937 - val_output_1_auc_1: 0.9554 - lr: 1.5000e-05
# Epoch 9/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2011 - output_1_loss: 0.1883 - output_2_loss: 1.2856 - output_1_iou_score: 0.6410 - output_1_dice_coeff: 0.8212 - output_1_precision_1: 0.8648 - output_1_recall_1: 0.8492 - output_1_sensitivity: 0.8198 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9655
# Epoch 9: val_output_1_loss did not improve from 0.24906
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2011 - output_1_loss: 0.1883 - output_2_loss: 1.2856 - output_1_iou_score: 0.6410 - output_1_dice_coeff: 0.8212 - output_1_precision_1: 0.8648 - output_1_recall_1: 0.8492 - output_1_sensitivity: 0.8198 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9655 - val_loss: 0.2625 - val_output_1_loss: 0.2493 - val_output_2_loss: 1.3224 - val_output_1_iou_score: 0.5244 - val_output_1_dice_coeff: 0.7637 - val_output_1_precision_1: 0.8138 - val_output_1_recall_1: 0.8317 - val_output_1_sensitivity: 0.7799 - val_output_1_specificity: 0.9946 - val_output_1_auc_1: 0.9511 - lr: 4.5000e-06
# Epoch 10/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1967 - output_1_loss: 0.1838 - output_2_loss: 1.2869 - output_1_iou_score: 0.6385 - output_1_dice_coeff: 0.8254 - output_1_precision_1: 0.8655 - output_1_recall_1: 0.8498 - output_1_sensitivity: 0.8237 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9650
# Epoch 10: val_output_1_loss did not improve from 0.24906
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.3499999113264492e-06.
# 233/233 [==============================] - 44s 190ms/step - loss: 0.1967 - output_1_loss: 0.1838 - output_2_loss: 1.2869 - output_1_iou_score: 0.6385 - output_1_dice_coeff: 0.8254 - output_1_precision_1: 0.8655 - output_1_recall_1: 0.8498 - output_1_sensitivity: 0.8237 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9650 - val_loss: 0.2643 - val_output_1_loss: 0.2508 - val_output_2_loss: 1.3450 - val_output_1_iou_score: 0.5223 - val_output_1_dice_coeff: 0.7622 - val_output_1_precision_1: 0.8161 - val_output_1_recall_1: 0.8307 - val_output_1_sensitivity: 0.7728 - val_output_1_specificity: 0.9947 - val_output_1_auc_1: 0.9509 - lr: 4.5000e-06

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 286.81it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            #augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 21s 569ms/step - loss: 0.2507 - output_1_loss: 0.2382 - output_2_loss: 1.2582 - output_1_iou_score: 0.5121 - output_1_dice_coeff: 0.7821 - output_1_precision_1: 0.8030 - output_1_recall_1: 0.7928 - output_1_sensitivity: 0.7962 - output_1_specificity: 0.9934 - output_1_auc_1: 0.9311

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
