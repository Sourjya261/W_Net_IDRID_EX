# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:05<00:00, 201.05it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    """ comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2')([comp1,comp2,comp3,comp4,comp5])
    """
    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['encoder2[0][0]']
#  mbda)
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['encoder1[0][0]']
#  Lambda)
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['encoder2[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['encoder1[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['encoder2[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['encoder1[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['encoder2[0][3]']
#  Lambda)
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['encoder1[0][3]']
#  Lambda)
#
#  tf.math.reduce_max_8 (TFOp  ()                           0         ['encoder1[0][4]']
#  Lambda)
#
#  tf.math.reduce_max_9 (TFOp  ()                           0         ['encoder2[0][4]']
#  Lambda)
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 3)          0         ['encoder2[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 16)         0         ['encoder1[0][0]',
#  bda)                                                                'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_2 (TFOpLam  (None, 128, 128, 64)         0         ['encoder2[0][1]',
#  bda)                                                                'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 32)         0         ['encoder1[0][1]',
#  bda)                                                                'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 64, 64, 256)          0         ['encoder2[0][2]',
#  bda)                                                                'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_5 (TFOpLam  (None, 64, 64, 64)           0         ['encoder1[0][2]',
#  bda)                                                                'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 32, 32, 512)          0         ['encoder2[0][3]',
#  bda)                                                                'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 32, 32, 128)          0         ['encoder1[0][3]',
#  bda)                                                                'tf.math.reduce_max_7[0][0]']
#
#  tf.math.truediv_8 (TFOpLam  (None, 16, 16, 128)          0         ['encoder1[0][4]',
#  bda)                                                                'tf.math.reduce_max_8[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 16, 16, 128)          0         ['encoder2[0][4]',
#  bda)                                                                'tf.math.reduce_max_9[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_mean_16 (TF  ()                           0         ['tf.math.truediv[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  ()                           0         ['tf.math.truediv_1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  ()                           0         ['tf.math.truediv_2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  ()                           0         ['tf.math.truediv_3[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  ()                           0         ['tf.math.truediv_4[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  ()                           0         ['tf.math.truediv_5[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  ()                           0         ['tf.math.truediv_6[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  ()                           0         ['tf.math.truediv_7[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_24 (TF  ()                           0         ['tf.math.truediv_8[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_25 (TF  ()                           0         ['tf.math.truediv_9[0][0]']
#  OpLambda)
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.subtract (TFOpLamb  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  da)                                                                ',
#                                                                      'tf.math.reduce_mean_17[0][0]
#                                                                     ']
#
#  tf.math.subtract_1 (TFOpLa  ()                           0         ['tf.math.reduce_mean_18[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_19[0][0]
#                                                                     ']
#
#  tf.math.subtract_2 (TFOpLa  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_21[0][0]
#                                                                     ']
#
#  tf.math.subtract_3 (TFOpLa  ()                           0         ['tf.math.reduce_mean_22[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_23[0][0]
#                                                                     ']
#
#  tf.math.subtract_4 (TFOpLa  ()                           0         ['tf.math.reduce_mean_24[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_mean_25[0][0]
#                                                                     ']
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.abs (TFOpLambda)    ()                           0         ['tf.math.subtract[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)  ()                           0         ['tf.math.subtract_1[0][0]']
#
#  tf.math.abs_2 (TFOpLambda)  ()                           0         ['tf.math.subtract_2[0][0]']
#
#  tf.math.abs_3 (TFOpLambda)  ()                           0         ['tf.math.subtract_3[0][0]']
#
#  tf.math.abs_4 (TFOpLambda)  ()                           0         ['tf.math.subtract_4[0][0]']
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  tf.math.sigmoid (TFOpLambd  ()                           0         ['tf.math.abs[0][0]']
#  a)
#
#  tf.math.sigmoid_1 (TFOpLam  ()                           0         ['tf.math.abs_1[0][0]']
#  bda)
#
#  tf.math.sigmoid_2 (TFOpLam  ()                           0         ['tf.math.abs_2[0][0]']
#  bda)
#
#  tf.math.sigmoid_3 (TFOpLam  ()                           0         ['tf.math.abs_3[0][0]']
#  bda)
#
#  tf.math.sigmoid_4 (TFOpLam  ()                           0         ['tf.math.abs_4[0][0]']
#  bda)
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          20        ['multiply_15[0][0]']
#
#  output_2 (Add)              ()                           0         ['tf.math.sigmoid[0][0]',
#                                                                      'tf.math.sigmoid_1[0][0]',
#                                                                      'tf.math.sigmoid_2[0][0]',
#                                                                      'tf.math.sigmoid_3[0][0]',
#                                                                      'tf.math.sigmoid_4[0][0]']
#
# ==================================================================================================
# Total params: 25705415 (98.06 MB)
# Trainable params: 25676885 (97.95 MB)
# Non-trainable params: 28530 (111.45 KB)
# __________________________________________________________________________________________________

# %%
model = build_WNet((256,256,3))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss=total_loss,
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=6
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_dice_coeff', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger,earlystopping]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=50,callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-01-19 09:23:53.191436: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_3/encoder1/dropout_28/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.4802 - iou_score: 0.3176 - dice_coeff: 0.5440 - precision: 0.5515 - recall: 0.5859 - sensitivity: 0.6431 - specificity: 0.9859 - auc: 0.8692
# Epoch 1: val_loss improved from inf to 1.07070, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 115s 239ms/step - loss: 0.4802 - iou_score: 0.3176 - dice_coeff: 0.5440 - precision: 0.5515 - recall: 0.5859 - sensitivity: 0.6431 - specificity: 0.9859 - auc: 0.8692 - val_loss: 1.0707 - val_iou_score: 9.0874e-05 - val_dice_coeff: 1.9191e-04 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3620 - iou_score: 0.4178 - dice_coeff: 0.6608 - precision: 0.7798 - recall: 0.6592 - sensitivity: 0.6891 - specificity: 0.9945 - auc: 0.9010
# Epoch 2: val_loss did not improve from 1.07070
# 233/233 [==============================] - 45s 191ms/step - loss: 0.3620 - iou_score: 0.4178 - dice_coeff: 0.6608 - precision: 0.7798 - recall: 0.6592 - sensitivity: 0.6891 - specificity: 0.9945 - auc: 0.9010 - val_loss: 1.0713 - val_iou_score: 6.8944e-05 - val_dice_coeff: 1.8091e-04 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_auc: 0.5003 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3254 - iou_score: 0.4466 - dice_coeff: 0.6942 - precision: 0.8011 - recall: 0.6859 - sensitivity: 0.7064 - specificity: 0.9949 - auc: 0.9122
# Epoch 3: val_loss improved from 1.07070 to 1.01966, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 192ms/step - loss: 0.3254 - iou_score: 0.4466 - dice_coeff: 0.6942 - precision: 0.8011 - recall: 0.6859 - sensitivity: 0.7064 - specificity: 0.9949 - auc: 0.9122 - val_loss: 1.0197 - val_iou_score: 0.0046 - val_dice_coeff: 0.0151 - val_precision: 2.9545e-04 - val_recall: 7.2834e-06 - val_sensitivity: 3.3684e-06 - val_specificity: 0.9993 - val_auc: 0.6730 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3003 - iou_score: 0.4618 - dice_coeff: 0.7172 - precision: 0.8152 - recall: 0.7203 - sensitivity: 0.7198 - specificity: 0.9951 - auc: 0.9285
# Epoch 4: val_loss improved from 1.01966 to 0.91086, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.3003 - iou_score: 0.4618 - dice_coeff: 0.7172 - precision: 0.8152 - recall: 0.7203 - sensitivity: 0.7198 - specificity: 0.9951 - auc: 0.9285 - val_loss: 0.9109 - val_iou_score: 0.0499 - val_dice_coeff: 0.1385 - val_precision: 0.9796 - val_recall: 0.0807 - val_sensitivity: 0.0736 - val_specificity: 1.0000 - val_auc: 0.6559 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2877 - iou_score: 0.4761 - dice_coeff: 0.7291 - precision: 0.8151 - recall: 0.7315 - sensitivity: 0.7324 - specificity: 0.9950 - auc: 0.9332
# Epoch 5: val_loss improved from 0.91086 to 0.34519, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2877 - iou_score: 0.4761 - dice_coeff: 0.7291 - precision: 0.8151 - recall: 0.7315 - sensitivity: 0.7324 - specificity: 0.9950 - auc: 0.9332 - val_loss: 0.3452 - val_iou_score: 0.3985 - val_dice_coeff: 0.6692 - val_precision: 0.7820 - val_recall: 0.7532 - val_sensitivity: 0.6783 - val_specificity: 0.9941 - val_auc: 0.9400 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2803 - iou_score: 0.4847 - dice_coeff: 0.7363 - precision: 0.8189 - recall: 0.7608 - sensitivity: 0.7409 - specificity: 0.9950 - auc: 0.9368
# Epoch 6: val_loss improved from 0.34519 to 0.27372, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2803 - iou_score: 0.4847 - dice_coeff: 0.7363 - precision: 0.8189 - recall: 0.7608 - sensitivity: 0.7409 - specificity: 0.9950 - auc: 0.9368 - val_loss: 0.2737 - val_iou_score: 0.4833 - val_dice_coeff: 0.7408 - val_precision: 0.7897 - val_recall: 0.8282 - val_sensitivity: 0.7659 - val_specificity: 0.9938 - val_auc: 0.9571 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2701 - iou_score: 0.5072 - dice_coeff: 0.7449 - precision: 0.8257 - recall: 0.7706 - sensitivity: 0.7496 - specificity: 0.9951 - auc: 0.9426
# Epoch 7: val_loss did not improve from 0.27372
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2701 - iou_score: 0.5072 - dice_coeff: 0.7449 - precision: 0.8257 - recall: 0.7706 - sensitivity: 0.7496 - specificity: 0.9951 - auc: 0.9426 - val_loss: 0.2893 - val_iou_score: 0.4714 - val_dice_coeff: 0.7242 - val_precision: 0.8774 - val_recall: 0.7353 - val_sensitivity: 0.6614 - val_specificity: 0.9971 - val_auc: 0.9314 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2805 - iou_score: 0.4955 - dice_coeff: 0.7347 - precision: 0.8241 - recall: 0.7667 - sensitivity: 0.7382 - specificity: 0.9951 - auc: 0.9412
# Epoch 8: val_loss did not improve from 0.27372
# 233/233 [==============================] - 45s 192ms/step - loss: 0.2805 - iou_score: 0.4955 - dice_coeff: 0.7347 - precision: 0.8241 - recall: 0.7667 - sensitivity: 0.7382 - specificity: 0.9951 - auc: 0.9412 - val_loss: 0.3014 - val_iou_score: 0.4586 - val_dice_coeff: 0.7161 - val_precision: 0.7457 - val_recall: 0.7663 - val_sensitivity: 0.7693 - val_specificity: 0.9926 - val_auc: 0.9352 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2754 - iou_score: 0.4956 - dice_coeff: 0.7400 - precision: 0.8222 - recall: 0.7634 - sensitivity: 0.7485 - specificity: 0.9951 - auc: 0.9414
# Epoch 9: val_loss did not improve from 0.27372
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2754 - iou_score: 0.4956 - dice_coeff: 0.7400 - precision: 0.8222 - recall: 0.7634 - sensitivity: 0.7485 - specificity: 0.9951 - auc: 0.9414 - val_loss: 0.2829 - val_iou_score: 0.4662 - val_dice_coeff: 0.7323 - val_precision: 0.7778 - val_recall: 0.8332 - val_sensitivity: 0.7635 - val_specificity: 0.9933 - val_auc: 0.9573 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2620 - iou_score: 0.5114 - dice_coeff: 0.7521 - precision: 0.8295 - recall: 0.7832 - sensitivity: 0.7546 - specificity: 0.9952 - auc: 0.9453
# Epoch 10: val_loss did not improve from 0.27372
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2620 - iou_score: 0.5114 - dice_coeff: 0.7521 - precision: 0.8295 - recall: 0.7832 - sensitivity: 0.7546 - specificity: 0.9952 - auc: 0.9453 - val_loss: 0.2778 - val_iou_score: 0.4796 - val_dice_coeff: 0.7348 - val_precision: 0.8522 - val_recall: 0.7743 - val_sensitivity: 0.7095 - val_specificity: 0.9962 - val_auc: 0.9443 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2531 - iou_score: 0.5205 - dice_coeff: 0.7610 - precision: 0.8305 - recall: 0.7874 - sensitivity: 0.7623 - specificity: 0.9952 - auc: 0.9480
# Epoch 11: val_loss did not improve from 0.27372
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2531 - iou_score: 0.5205 - dice_coeff: 0.7610 - precision: 0.8305 - recall: 0.7874 - sensitivity: 0.7623 - specificity: 0.9952 - auc: 0.9480 - val_loss: 0.2849 - val_iou_score: 0.4752 - val_dice_coeff: 0.7311 - val_precision: 0.7610 - val_recall: 0.8439 - val_sensitivity: 0.8020 - val_specificity: 0.9925 - val_auc: 0.9613 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2580 - iou_score: 0.5200 - dice_coeff: 0.7560 - precision: 0.8307 - recall: 0.7871 - sensitivity: 0.7596 - specificity: 0.9952 - auc: 0.9482
# Epoch 12: val_loss improved from 0.27372 to 0.27012, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2580 - iou_score: 0.5200 - dice_coeff: 0.7560 - precision: 0.8307 - recall: 0.7871 - sensitivity: 0.7596 - specificity: 0.9952 - auc: 0.9482 - val_loss: 0.2701 - val_iou_score: 0.4930 - val_dice_coeff: 0.7415 - val_precision: 0.8413 - val_recall: 0.7874 - val_sensitivity: 0.7191 - val_specificity: 0.9958 - val_auc: 0.9510 - lr: 1.0000e-04
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2423 - iou_score: 0.5402 - dice_coeff: 0.7710 - precision: 0.8321 - recall: 0.8008 - sensitivity: 0.7692 - specificity: 0.9951 - auc: 0.9523
# Epoch 13: val_loss did not improve from 0.27012
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2423 - iou_score: 0.5402 - dice_coeff: 0.7710 - precision: 0.8321 - recall: 0.8008 - sensitivity: 0.7692 - specificity: 0.9951 - auc: 0.9523 - val_loss: 0.2882 - val_iou_score: 0.4821 - val_dice_coeff: 0.7280 - val_precision: 0.7288 - val_recall: 0.8618 - val_sensitivity: 0.8136 - val_specificity: 0.9909 - val_auc: 0.9666 - lr: 1.0000e-04
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2394 - iou_score: 0.5394 - dice_coeff: 0.7728 - precision: 0.8364 - recall: 0.8048 - sensitivity: 0.7729 - specificity: 0.9953 - auc: 0.9538
# Epoch 14: val_loss did not improve from 0.27012
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2394 - iou_score: 0.5394 - dice_coeff: 0.7728 - precision: 0.8364 - recall: 0.8048 - sensitivity: 0.7729 - specificity: 0.9953 - auc: 0.9538 - val_loss: 0.2801 - val_iou_score: 0.4699 - val_dice_coeff: 0.7343 - val_precision: 0.8059 - val_recall: 0.8177 - val_sensitivity: 0.7332 - val_specificity: 0.9944 - val_auc: 0.9500 - lr: 1.0000e-04
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2480 - iou_score: 0.5349 - dice_coeff: 0.7643 - precision: 0.8379 - recall: 0.7954 - sensitivity: 0.7642 - specificity: 0.9954 - auc: 0.9508
# Epoch 15: val_loss did not improve from 0.27012
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2480 - iou_score: 0.5349 - dice_coeff: 0.7643 - precision: 0.8379 - recall: 0.7954 - sensitivity: 0.7642 - specificity: 0.9954 - auc: 0.9508 - val_loss: 0.2851 - val_iou_score: 0.4751 - val_dice_coeff: 0.7281 - val_precision: 0.8229 - val_recall: 0.7838 - val_sensitivity: 0.7279 - val_specificity: 0.9952 - val_auc: 0.9451 - lr: 1.0000e-04
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2431 - iou_score: 0.5451 - dice_coeff: 0.7694 - precision: 0.8366 - recall: 0.8083 - sensitivity: 0.7759 - specificity: 0.9952 - auc: 0.9548
# Epoch 16: val_loss did not improve from 0.27012
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2431 - iou_score: 0.5451 - dice_coeff: 0.7694 - precision: 0.8366 - recall: 0.8083 - sensitivity: 0.7759 - specificity: 0.9952 - auc: 0.9548 - val_loss: 0.4256 - val_iou_score: 0.3592 - val_dice_coeff: 0.5944 - val_precision: 0.6315 - val_recall: 0.8059 - val_sensitivity: 0.7015 - val_specificity: 0.9868 - val_auc: 0.9367 - lr: 1.0000e-04
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2436 - iou_score: 0.5381 - dice_coeff: 0.7694 - precision: 0.8367 - recall: 0.8010 - sensitivity: 0.7673 - specificity: 0.9953 - auc: 0.9514
# Epoch 17: val_loss did not improve from 0.27012
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2436 - iou_score: 0.5381 - dice_coeff: 0.7694 - precision: 0.8367 - recall: 0.8010 - sensitivity: 0.7673 - specificity: 0.9953 - auc: 0.9514 - val_loss: 0.3061 - val_iou_score: 0.4586 - val_dice_coeff: 0.7108 - val_precision: 0.6952 - val_recall: 0.8891 - val_sensitivity: 0.8330 - val_specificity: 0.9890 - val_auc: 0.9720 - lr: 1.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2333 - iou_score: 0.5513 - dice_coeff: 0.7788 - precision: 0.8401 - recall: 0.8094 - sensitivity: 0.7791 - specificity: 0.9954 - auc: 0.9564
# Epoch 18: val_loss improved from 0.27012 to 0.26558, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2333 - iou_score: 0.5513 - dice_coeff: 0.7788 - precision: 0.8401 - recall: 0.8094 - sensitivity: 0.7791 - specificity: 0.9954 - auc: 0.9564 - val_loss: 0.2656 - val_iou_score: 0.5095 - val_dice_coeff: 0.7476 - val_precision: 0.7752 - val_recall: 0.8563 - val_sensitivity: 0.7956 - val_specificity: 0.9930 - val_auc: 0.9649 - lr: 1.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2311 - iou_score: 0.5581 - dice_coeff: 0.7810 - precision: 0.8444 - recall: 0.8074 - sensitivity: 0.7808 - specificity: 0.9955 - auc: 0.9547
# Epoch 19: val_loss improved from 0.26558 to 0.25832, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2311 - iou_score: 0.5581 - dice_coeff: 0.7810 - precision: 0.8444 - recall: 0.8074 - sensitivity: 0.7808 - specificity: 0.9955 - auc: 0.9547 - val_loss: 0.2583 - val_iou_score: 0.4954 - val_dice_coeff: 0.7552 - val_precision: 0.7862 - val_recall: 0.8464 - val_sensitivity: 0.7862 - val_specificity: 0.9935 - val_auc: 0.9600 - lr: 1.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2333 - iou_score: 0.5589 - dice_coeff: 0.7789 - precision: 0.8391 - recall: 0.8154 - sensitivity: 0.7835 - specificity: 0.9953 - auc: 0.9560
# Epoch 20: val_loss did not improve from 0.25832
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2333 - iou_score: 0.5589 - dice_coeff: 0.7789 - precision: 0.8391 - recall: 0.8154 - sensitivity: 0.7835 - specificity: 0.9953 - auc: 0.9560 - val_loss: 0.2948 - val_iou_score: 0.4763 - val_dice_coeff: 0.7240 - val_precision: 0.7016 - val_recall: 0.8926 - val_sensitivity: 0.8328 - val_specificity: 0.9893 - val_auc: 0.9694 - lr: 1.0000e-04
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2515 - iou_score: 0.5324 - dice_coeff: 0.7621 - precision: 0.8311 - recall: 0.7826 - sensitivity: 0.7688 - specificity: 0.9953 - auc: 0.9478
# Epoch 21: val_loss did not improve from 0.25832
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2515 - iou_score: 0.5324 - dice_coeff: 0.7621 - precision: 0.8311 - recall: 0.7826 - sensitivity: 0.7688 - specificity: 0.9953 - auc: 0.9478 - val_loss: 0.2715 - val_iou_score: 0.4873 - val_dice_coeff: 0.7410 - val_precision: 0.8091 - val_recall: 0.8238 - val_sensitivity: 0.7492 - val_specificity: 0.9945 - val_auc: 0.9549 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2247 - iou_score: 0.5670 - dice_coeff: 0.7870 - precision: 0.8443 - recall: 0.8121 - sensitivity: 0.7880 - specificity: 0.9955 - auc: 0.9555
# Epoch 22: val_loss did not improve from 0.25832
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2247 - iou_score: 0.5670 - dice_coeff: 0.7870 - precision: 0.8443 - recall: 0.8121 - sensitivity: 0.7880 - specificity: 0.9955 - auc: 0.9555 - val_loss: 0.2651 - val_iou_score: 0.5063 - val_dice_coeff: 0.7486 - val_precision: 0.7778 - val_recall: 0.8495 - val_sensitivity: 0.7851 - val_specificity: 0.9931 - val_auc: 0.9602 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2246 - iou_score: 0.5685 - dice_coeff: 0.7867 - precision: 0.8444 - recall: 0.8198 - sensitivity: 0.7876 - specificity: 0.9955 - auc: 0.9571
# Epoch 23: val_loss improved from 0.25832 to 0.25733, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2246 - iou_score: 0.5685 - dice_coeff: 0.7867 - precision: 0.8444 - recall: 0.8198 - sensitivity: 0.7876 - specificity: 0.9955 - auc: 0.9571 - val_loss: 0.2573 - val_iou_score: 0.5007 - val_dice_coeff: 0.7546 - val_precision: 0.8123 - val_recall: 0.8250 - val_sensitivity: 0.7686 - val_specificity: 0.9946 - val_auc: 0.9557 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2267 - iou_score: 0.5680 - dice_coeff: 0.7847 - precision: 0.8412 - recall: 0.8211 - sensitivity: 0.7865 - specificity: 0.9954 - auc: 0.9578
# Epoch 24: val_loss did not improve from 0.25733
# 233/233 [==============================] - 45s 191ms/step - loss: 0.2267 - iou_score: 0.5680 - dice_coeff: 0.7847 - precision: 0.8412 - recall: 0.8211 - sensitivity: 0.7865 - specificity: 0.9954 - auc: 0.9578 - val_loss: 0.3054 - val_iou_score: 0.4591 - val_dice_coeff: 0.7118 - val_precision: 0.7001 - val_recall: 0.8910 - val_sensitivity: 0.8390 - val_specificity: 0.9892 - val_auc: 0.9711 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2232 - iou_score: 0.5641 - dice_coeff: 0.7885 - precision: 0.8463 - recall: 0.8150 - sensitivity: 0.7923 - specificity: 0.9956 - auc: 0.9564
# Epoch 25: val_loss did not improve from 0.25733
# 233/233 [==============================] - 44s 191ms/step - loss: 0.2232 - iou_score: 0.5641 - dice_coeff: 0.7885 - precision: 0.8463 - recall: 0.8150 - sensitivity: 0.7923 - specificity: 0.9956 - auc: 0.9564 - val_loss: 0.2594 - val_iou_score: 0.5126 - val_dice_coeff: 0.7538 - val_precision: 0.8253 - val_recall: 0.8116 - val_sensitivity: 0.7492 - val_specificity: 0.9951 - val_auc: 0.9459 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2135 - iou_score: 0.5831 - dice_coeff: 0.7978 - precision: 0.8474 - recall: 0.8230 - sensitivity: 0.7972 - specificity: 0.9955 - auc: 0.9577
# Epoch 26: val_loss did not improve from 0.25733
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2135 - iou_score: 0.5831 - dice_coeff: 0.7978 - precision: 0.8474 - recall: 0.8230 - sensitivity: 0.7972 - specificity: 0.9955 - auc: 0.9577 - val_loss: 0.2691 - val_iou_score: 0.4948 - val_dice_coeff: 0.7441 - val_precision: 0.7712 - val_recall: 0.8498 - val_sensitivity: 0.7956 - val_specificity: 0.9929 - val_auc: 0.9589 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2221 - iou_score: 0.5757 - dice_coeff: 0.7890 - precision: 0.8457 - recall: 0.8256 - sensitivity: 0.7908 - specificity: 0.9955 - auc: 0.9582
# Epoch 27: val_loss did not improve from 0.25733
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2221 - iou_score: 0.5757 - dice_coeff: 0.7890 - precision: 0.8457 - recall: 0.8256 - sensitivity: 0.7908 - specificity: 0.9955 - auc: 0.9582 - val_loss: 0.2673 - val_iou_score: 0.4969 - val_dice_coeff: 0.7457 - val_precision: 0.7919 - val_recall: 0.8357 - val_sensitivity: 0.7793 - val_specificity: 0.9938 - val_auc: 0.9532 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2159 - iou_score: 0.5834 - dice_coeff: 0.7951 - precision: 0.8480 - recall: 0.8262 - sensitivity: 0.7948 - specificity: 0.9956 - auc: 0.9579
# Epoch 28: val_loss did not improve from 0.25733
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2159 - iou_score: 0.5834 - dice_coeff: 0.7951 - precision: 0.8480 - recall: 0.8262 - sensitivity: 0.7948 - specificity: 0.9956 - auc: 0.9579 - val_loss: 0.2753 - val_iou_score: 0.4830 - val_dice_coeff: 0.7384 - val_precision: 0.7616 - val_recall: 0.8560 - val_sensitivity: 0.7810 - val_specificity: 0.9924 - val_auc: 0.9579 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2089 - iou_score: 0.5937 - dice_coeff: 0.8018 - precision: 0.8529 - recall: 0.8258 - sensitivity: 0.8020 - specificity: 0.9957 - auc: 0.9584
# Epoch 29: val_loss did not improve from 0.25733
# 233/233 [==============================] - 44s 190ms/step - loss: 0.2089 - iou_score: 0.5937 - dice_coeff: 0.8018 - precision: 0.8529 - recall: 0.8258 - sensitivity: 0.8020 - specificity: 0.9957 - auc: 0.9584 - val_loss: 0.2664 - val_iou_score: 0.5036 - val_dice_coeff: 0.7471 - val_precision: 0.7608 - val_recall: 0.8688 - val_sensitivity: 0.8242 - val_specificity: 0.9923 - val_auc: 0.9640 - lr: 1.0000e-04
# Epoch 29: early stopping

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['iou_score']
val_iou_score=history['val_iou_score']

loss=history['loss']
val_loss=history['val_loss']

train_dice=history['dice_coeff']
val_dice=history['val_dice_coeff']


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()



# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepring Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 270.13it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
            #images.append(image)
            #masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 7s 245ms/step - loss: 0.2393 - iou_score: 0.5023 - dice_coeff: 0.7799 - precision: 0.7364 - recall: 0.8801 - sensitivity: 0.8699 - specificity: 0.9894 - auc: 0.9637

# %%
# !zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool_fine_tune.h5
# Out:
#   adding: kaggle/working/WNet_maxpool_fine_tune.h5 (deflated 8%)

# %%
from IPython.display import FileLink
FileLink(r'weights_WNet_Res50_AT_CL.zip')
# Out:
# /kaggle/working/weights_WNet_Res50_AT_CL.zip
