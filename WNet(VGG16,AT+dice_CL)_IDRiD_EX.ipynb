# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:03<00:00, 337.06it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import VGG16
def build_encoder2(inputs):

    s=[]
    """ Pre-trained VGG16 Model """
    vgg16 = VGG16(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in vgg16.layers:
        layer.trainable = True

    """ Encoder """
    s1 = vgg16.get_layer("block1_conv2").output         ## (512 x 512)
    s.append(s1)
    s2 = vgg16.get_layer("block2_conv2").output         ## (256 x 256)
    s.append(s2)
    s3 = vgg16.get_layer("block3_conv3").output         ## (128 x 128)
    s.append(s3)
    s4 = vgg16.get_layer("block4_conv3").output         ## (64 x 64)
    s.append(s4)

    """ Bridge """
    b = vgg16.get_layer("block5_conv3").output         ## (32 x 32)
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Symmetric architecture

# %%
# Code for W-Net

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [64,128,256,512]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3])
    d2 = decoder_block(d1, s2[2],s1[2], f[2])
    d3 = decoder_block(d2, s2[1],s1[1], f[1])
    d4 = decoder_block(d3, s2[0],s1[0],f[0])
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2')([comp3,comp4,comp5])

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Asymmetric Architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import mean_squared_error

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice
"""def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))"""
def complementary_loss(feature_map1,feature_map2):
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    feature_map1 = tf.reduce_mean(feature_map1, axis=-1, keepdims=True)
    feature_map2  = tf.reduce_mean(feature_map2, axis=-1, keepdims=True)
    #print(feature_map1.shape) #shapes are (none,H,W,1) so axis = 1 2 3 
    """intersection = tf.reduce_sum(feature_map1 * feature_map2, axis=[1, 2, 3])
    union = tf.reduce_sum(feature_map1 + feature_map2, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou"""
    return dice_coeff(feature_map1,feature_map2)

    
clipping_layer = tf.keras.layers.Lambda(
    lambda x: tf.clip_by_value(x , clip_value_min=0, clip_value_max=1),
    name='output_2'
)



def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+128)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+64)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    #comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2_sum')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])
    output_2 = clipping_layer(output_2)

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 64),      1670035   ['model_input[0][0]']
#                               (None, 128, 128, 128),      2
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 160)        204960    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 320)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 320)        1280      ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 320)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 160)        460960    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 160)        0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 160)        640       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 160)        0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 160)        230560    ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 160)        51360     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 160)        0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 160)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 160)            0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 320)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 10)             3210      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 160)            1760      ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 160)        0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 160)        0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 80)         51280     ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 160)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 160)        640       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 160)        0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 80)         115280    ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 80)         0         ['conv2d_54[0][0]']
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['encoder2[0][0]']
#  mbda)
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['encoder1[0][0]']
#  Lambda)
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['encoder2[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['encoder1[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['encoder2[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['encoder1[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['encoder2[0][3]']
#  Lambda)
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['encoder1[0][3]']
#  Lambda)
#
#  batch_normalization_26 (Ba  (None, 256, 256, 80)         320       ['dropout_6[0][0]']
#  tchNormalization)
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 64)         0         ['encoder2[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 16)         0         ['encoder1[0][0]',
#  bda)                                                                'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 128)        0         ['encoder2[0][1]',
#  bda)                                                                'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 128, 128, 32)         0         ['encoder1[0][1]',
#  bda)                                                                'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 64, 64, 256)          0         ['encoder2[0][2]',
#  bda)                                                                'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 64, 64, 64)           0         ['encoder1[0][2]',
#  bda)                                                                'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 32, 32, 512)          0         ['encoder2[0][3]',
#  bda)                                                                'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_10 (TFOpLa  (None, 32, 32, 128)          0         ['encoder1[0][3]',
#  mbda)                                                               'tf.math.reduce_max_7[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 80)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  tf.math.reduce_mean_16 (TF  (None, 256, 256, 1)          0         ['tf.math.truediv[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  (None, 256, 256, 1)          0         ['tf.math.truediv_1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  (None, 128, 128, 1)          0         ['tf.math.truediv_3[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  (None, 128, 128, 1)          0         ['tf.math.truediv_4[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  (None, 64, 64, 1)            0         ['tf.math.truediv_6[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  (None, 64, 64, 1)            0         ['tf.math.truediv_7[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  (None, 32, 32, 1)            0         ['tf.math.truediv_9[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  (None, 32, 32, 1)            0         ['tf.math.truediv_10[0][0]']
#  OpLambda)
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 80)         57680     ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 80)         12880     ['concatenate_6[0][0]']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.reduce_mean_16[0][0]
#                                                                     ']
#
#  tf.reshape_1 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_17[0][0]
#                                                                     ']
#
#  tf.reshape_2 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_18[0][0]
#                                                                     ']
#
#  tf.reshape_3 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_19[0][0]
#                                                                     ']
#
#  tf.reshape_4 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_20[0][0]
#                                                                     ']
#
#  tf.reshape_5 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_21[0][0]
#                                                                     ']
#
#  tf.reshape_6 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_22[0][0]
#                                                                     ']
#
#  tf.reshape_7 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_23[0][0]
#                                                                     ']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 80)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.reshape[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.reshape_2[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.reshape_4[0][0]',
#  mbda)                                                               'tf.reshape_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.reshape_6[0][0]',
#  mbda)                                                               'tf.reshape_7[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 80)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 80)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_sum (TFOpLa  ()                           0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  ()                           0         ['tf.reshape[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_2 (TFOp  ()                           0         ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_3 (TFOp  ()                           0         ['tf.math.multiply_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_4 (TFOp  ()                           0         ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_5 (TFOp  ()                           0         ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_6 (TFOp  ()                           0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_7 (TFOp  ()                           0         ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_8 (TFOp  ()                           0         ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_9 (TFOp  ()                           0         ['tf.math.multiply_6[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_10 (TFO  ()                           0         ['tf.reshape_6[0][0]']
#  pLambda)
#
#  tf.math.reduce_sum_11 (TFO  ()                           0         ['tf.reshape_7[0][0]']
#  pLambda)
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 160)            0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_sum[0][0]']
#  mbda)
#
#  tf.__operators__.add_9 (TF  ()                           0         ['tf.math.reduce_sum_1[0][0]',
#  OpLambda)                                                           'tf.math.reduce_sum_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  ()                           0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_12 (T  ()                           0         ['tf.math.reduce_sum_4[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  ()                           0         ['tf.math.reduce_sum_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_15 (T  ()                           0         ['tf.math.reduce_sum_7[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_8[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  ()                           0         ['tf.math.reduce_sum_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_18 (T  ()                           0         ['tf.math.reduce_sum_10[0][0]'
#  FOpLambda)                                                         , 'tf.math.reduce_sum_11[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 5)              805       ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.add_8 (TF  ()                           0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.__operators__.add_10 (T  ()                           0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.__operators__.add_11 (T  ()                           0         ['tf.math.multiply_3[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_13 (T  ()                           0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_14 (T  ()                           0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_16 (T  ()                           0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_17 (T  ()                           0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_19 (T  ()                           0         ['tf.__operators__.add_18[0][0
#  FOpLambda)                                                         ]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 80)             480       ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.truediv_2 (TFOpLam  ()                           0         ['tf.__operators__.add_8[0][0]
#  bda)                                                               ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.truediv_5 (TFOpLam  ()                           0         ['tf.__operators__.add_11[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.__operators__.add_14[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.__operators__.add_17[0][0
#  mbda)                                                              ]',
#                                                                      'tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 80)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.truediv_12 (TFOpLa  ()                           0         ['tf.math.truediv_2[0][0]']
#  mbda)
#
#  tf.math.truediv_13 (TFOpLa  ()                           0         ['tf.math.truediv_5[0][0]']
#  mbda)
#
#  tf.math.truediv_14 (TFOpLa  ()                           0         ['tf.math.truediv_8[0][0]']
#  mbda)
#
#  tf.math.truediv_15 (TFOpLa  ()                           0         ['tf.math.truediv_11[0][0]']
#  mbda)
#
#  multiply_15 (Multiply)      (None, 256, 256, 80)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_2_sum (Add)          ()                           0         ['tf.math.truediv_12[0][0]',
#                                                                      'tf.math.truediv_13[0][0]',
#                                                                      'tf.math.truediv_14[0][0]',
#                                                                      'tf.math.truediv_15[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          81        ['multiply_15[0][0]']
#
#  output_2 (Lambda)           ()                           0         ['output_2_sum[0][0]']
#
# ==================================================================================================
# Total params: 35200043 (134.28 MB)
# Trainable params: 35189067 (134.24 MB)
# Non-trainable params: 10976 (42.88 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':-0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_dice_coeff', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
"""# Clear output folder
import os

def remove_folder_contents(folder):
    for the_file in os.listdir(folder):
        file_path = os.path.join(folder, the_file)
        try:
            if os.path.isfile(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                remove_folder_contents(file_path)
                os.rmdir(file_path)
        except Exception as e:
            print(e)

folder_path = '/kaggle/working'
remove_folder_contents(folder_path)
os.rmdir(folder_path)"""
# Out:
# "# Clear output folder\nimport os\n\ndef remove_folder_contents(folder):\n    for the_file in os.listdir(folder):\n        file_path = os.path.join(folder, the_file)\n        try:\n            if os.path.isfile(file_path):\n                os.unlink(file_path)\n            elif os.path.isdir(file_path):\n                remove_folder_contents(file_path)\n                os.rmdir(file_path)\n        except Exception as e:\n            print(e)\n\nfolder_path = '/kaggle/working'\nremove_folder_contents(folder_path)\nos.rmdir(folder_path)"

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=1,callbacks=callbacks)

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-22 19:06:16.831133: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.6258 - output_1_loss: 0.6277 - output_2_loss: 0.0194 - output_1_iou_score: 0.2064 - output_1_dice_coeff: 0.4034 - output_1_precision: 0.5057 - output_1_recall: 0.4282 - output_1_sensitivity: 0.4418 - output_1_specificity: 0.9877 - output_1_auc: 0.8237
# Epoch 1: val_loss improved from inf to 0.64546, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 128s 336ms/step - loss: 0.6258 - output_1_loss: 0.6277 - output_2_loss: 0.0194 - output_1_iou_score: 0.2064 - output_1_dice_coeff: 0.4034 - output_1_precision: 0.5057 - output_1_recall: 0.4282 - output_1_sensitivity: 0.4418 - output_1_specificity: 0.9877 - output_1_auc: 0.8237 - val_loss: 0.6455 - val_output_1_loss: 0.6455 - val_output_2_loss: 5.8077e-04 - val_output_1_iou_score: 0.1875 - val_output_1_dice_coeff: 0.3859 - val_output_1_precision: 0.5972 - val_output_1_recall: 0.4159 - val_output_1_sensitivity: 0.3314 - val_output_1_specificity: 0.9922 - val_output_1_auc: 0.8144 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4477 - output_1_loss: 0.4477 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3261 - output_1_dice_coeff: 0.5792 - output_1_precision: 0.7224 - output_1_recall: 0.5520 - output_1_sensitivity: 0.5880 - output_1_specificity: 0.9937 - output_1_auc: 0.8682
# Epoch 1: val_loss improved from 0.64546 to 0.47801, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 301ms/step - loss: 0.4477 - output_1_loss: 0.4477 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3261 - output_1_dice_coeff: 0.5792 - output_1_precision: 0.7224 - output_1_recall: 0.5520 - output_1_sensitivity: 0.5880 - output_1_specificity: 0.9937 - output_1_auc: 0.8682 - val_loss: 0.4780 - val_output_1_loss: 0.4780 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3120 - val_output_1_dice_coeff: 0.5450 - val_output_1_precision: 0.6013 - val_output_1_recall: 0.6993 - val_output_1_sensitivity: 0.6964 - val_output_1_specificity: 0.9871 - val_output_1_auc: 0.9252 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4222 - output_1_loss: 0.4224 - output_2_loss: 0.0013 - output_1_iou_score: 0.3581 - output_1_dice_coeff: 0.6006 - output_1_precision: 0.7595 - output_1_recall: 0.5894 - output_1_sensitivity: 0.6134 - output_1_specificity: 0.9945 - output_1_auc: 0.8870
# Epoch 1: val_loss did not improve from 0.47801
# 233/233 [==============================] - 70s 299ms/step - loss: 0.4222 - output_1_loss: 0.4224 - output_2_loss: 0.0013 - output_1_iou_score: 0.3581 - output_1_dice_coeff: 0.6006 - output_1_precision: 0.7595 - output_1_recall: 0.5894 - output_1_sensitivity: 0.6134 - output_1_specificity: 0.9945 - output_1_auc: 0.8870 - val_loss: 0.7271 - val_output_1_loss: 0.7271 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.1278 - val_output_1_dice_coeff: 0.3138 - val_output_1_precision: 0.9036 - val_output_1_recall: 0.2965 - val_output_1_sensitivity: 0.2071 - val_output_1_specificity: 0.9991 - val_output_1_auc: 0.7359 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3857 - output_1_loss: 0.3857 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3792 - output_1_dice_coeff: 0.6356 - output_1_precision: 0.7697 - output_1_recall: 0.6306 - output_1_sensitivity: 0.6448 - output_1_specificity: 0.9944 - output_1_auc: 0.8980
# Epoch 1: val_loss improved from 0.47801 to 0.39177, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.3857 - output_1_loss: 0.3857 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3792 - output_1_dice_coeff: 0.6356 - output_1_precision: 0.7697 - output_1_recall: 0.6306 - output_1_sensitivity: 0.6448 - output_1_specificity: 0.9944 - output_1_auc: 0.8980 - val_loss: 0.3918 - val_output_1_loss: 0.3918 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3773 - val_output_1_dice_coeff: 0.6274 - val_output_1_precision: 0.6964 - val_output_1_recall: 0.7639 - val_output_1_sensitivity: 0.6862 - val_output_1_specificity: 0.9906 - val_output_1_auc: 0.9397 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3668 - output_1_loss: 0.3668 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3944 - output_1_dice_coeff: 0.6549 - output_1_precision: 0.7724 - output_1_recall: 0.6494 - output_1_sensitivity: 0.6632 - output_1_specificity: 0.9943 - output_1_auc: 0.9038
# Epoch 1: val_loss did not improve from 0.39177
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3668 - output_1_loss: 0.3668 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3944 - output_1_dice_coeff: 0.6549 - output_1_precision: 0.7724 - output_1_recall: 0.6494 - output_1_sensitivity: 0.6632 - output_1_specificity: 0.9943 - output_1_auc: 0.9038 - val_loss: 0.4018 - val_output_1_loss: 0.4018 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3562 - val_output_1_dice_coeff: 0.6165 - val_output_1_precision: 0.8224 - val_output_1_recall: 0.6476 - val_output_1_sensitivity: 0.5510 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9018 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3708 - output_1_loss: 0.3708 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3968 - output_1_dice_coeff: 0.6496 - output_1_precision: 0.7848 - output_1_recall: 0.6503 - output_1_sensitivity: 0.6546 - output_1_specificity: 0.9947 - output_1_auc: 0.9041
# Epoch 1: val_loss improved from 0.39177 to 0.36419, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.3708 - output_1_loss: 0.3708 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.3968 - output_1_dice_coeff: 0.6496 - output_1_precision: 0.7848 - output_1_recall: 0.6503 - output_1_sensitivity: 0.6546 - output_1_specificity: 0.9947 - output_1_auc: 0.9041 - val_loss: 0.3642 - val_output_1_loss: 0.3642 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4038 - val_output_1_dice_coeff: 0.6557 - val_output_1_precision: 0.7165 - val_output_1_recall: 0.7675 - val_output_1_sensitivity: 0.7057 - val_output_1_specificity: 0.9915 - val_output_1_auc: 0.9369 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3409 - output_1_loss: 0.3409 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4128 - output_1_dice_coeff: 0.6786 - output_1_precision: 0.7789 - output_1_recall: 0.6927 - output_1_sensitivity: 0.6859 - output_1_specificity: 0.9941 - output_1_auc: 0.9181
# Epoch 1: val_loss did not improve from 0.36419
# 233/233 [==============================] - 70s 298ms/step - loss: 0.3409 - output_1_loss: 0.3409 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4128 - output_1_dice_coeff: 0.6786 - output_1_precision: 0.7789 - output_1_recall: 0.6927 - output_1_sensitivity: 0.6859 - output_1_specificity: 0.9941 - output_1_auc: 0.9181 - val_loss: 0.4557 - val_output_1_loss: 0.4557 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.2873 - val_output_1_dice_coeff: 0.5639 - val_output_1_precision: 0.8907 - val_output_1_recall: 0.5770 - val_output_1_sensitivity: 0.4517 - val_output_1_specificity: 0.9980 - val_output_1_auc: 0.8803 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3527 - output_1_loss: 0.3527 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4109 - output_1_dice_coeff: 0.6669 - output_1_precision: 0.7846 - output_1_recall: 0.6949 - output_1_sensitivity: 0.6697 - output_1_specificity: 0.9943 - output_1_auc: 0.9163
# Epoch 1: val_loss did not improve from 0.36419
# 233/233 [==============================] - 70s 299ms/step - loss: 0.3527 - output_1_loss: 0.3527 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4109 - output_1_dice_coeff: 0.6669 - output_1_precision: 0.7846 - output_1_recall: 0.6949 - output_1_sensitivity: 0.6697 - output_1_specificity: 0.9943 - output_1_auc: 0.9163 - val_loss: 0.5299 - val_output_1_loss: 0.5299 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.2523 - val_output_1_dice_coeff: 0.4975 - val_output_1_precision: 0.9413 - val_output_1_recall: 0.4766 - val_output_1_sensitivity: 0.3674 - val_output_1_specificity: 0.9992 - val_output_1_auc: 0.8275 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3404 - output_1_loss: 0.3404 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4110 - output_1_dice_coeff: 0.6777 - output_1_precision: 0.7910 - output_1_recall: 0.7016 - output_1_sensitivity: 0.6763 - output_1_specificity: 0.9945 - output_1_auc: 0.9212
# Epoch 1: val_loss did not improve from 0.36419
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3404 - output_1_loss: 0.3404 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4110 - output_1_dice_coeff: 0.6777 - output_1_precision: 0.7910 - output_1_recall: 0.7016 - output_1_sensitivity: 0.6763 - output_1_specificity: 0.9945 - output_1_auc: 0.9212 - val_loss: 0.4455 - val_output_1_loss: 0.4455 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3330 - val_output_1_dice_coeff: 0.5807 - val_output_1_precision: 0.6221 - val_output_1_recall: 0.7242 - val_output_1_sensitivity: 0.6966 - val_output_1_specificity: 0.9876 - val_output_1_auc: 0.9293 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3440 - output_1_loss: 0.3440 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4199 - output_1_dice_coeff: 0.6748 - output_1_precision: 0.7891 - output_1_recall: 0.7015 - output_1_sensitivity: 0.6763 - output_1_specificity: 0.9944 - output_1_auc: 0.9223
# Epoch 1: val_loss improved from 0.36419 to 0.35865, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.3440 - output_1_loss: 0.3440 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4199 - output_1_dice_coeff: 0.6748 - output_1_precision: 0.7891 - output_1_recall: 0.7015 - output_1_sensitivity: 0.6763 - output_1_specificity: 0.9944 - output_1_auc: 0.9223 - val_loss: 0.3587 - val_output_1_loss: 0.3587 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4161 - val_output_1_dice_coeff: 0.6610 - val_output_1_precision: 0.7089 - val_output_1_recall: 0.7399 - val_output_1_sensitivity: 0.7130 - val_output_1_specificity: 0.9914 - val_output_1_auc: 0.9380 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3319 - output_1_loss: 0.3319 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4245 - output_1_dice_coeff: 0.6865 - output_1_precision: 0.7839 - output_1_recall: 0.7128 - output_1_sensitivity: 0.6883 - output_1_specificity: 0.9941 - output_1_auc: 0.9276
# Epoch 1: val_loss did not improve from 0.35865
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3319 - output_1_loss: 0.3319 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4245 - output_1_dice_coeff: 0.6865 - output_1_precision: 0.7839 - output_1_recall: 0.7128 - output_1_sensitivity: 0.6883 - output_1_specificity: 0.9941 - output_1_auc: 0.9276 - val_loss: 0.3845 - val_output_1_loss: 0.3845 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3622 - val_output_1_dice_coeff: 0.6332 - val_output_1_precision: 0.8668 - val_output_1_recall: 0.6560 - val_output_1_sensitivity: 0.5443 - val_output_1_specificity: 0.9972 - val_output_1_auc: 0.9009 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3328 - output_1_loss: 0.3328 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4280 - output_1_dice_coeff: 0.6849 - output_1_precision: 0.7876 - output_1_recall: 0.7245 - output_1_sensitivity: 0.6843 - output_1_specificity: 0.9941 - output_1_auc: 0.9300
# Epoch 1: val_loss improved from 0.35865 to 0.35834, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.3328 - output_1_loss: 0.3328 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4280 - output_1_dice_coeff: 0.6849 - output_1_precision: 0.7876 - output_1_recall: 0.7245 - output_1_sensitivity: 0.6843 - output_1_specificity: 0.9941 - output_1_auc: 0.9300 - val_loss: 0.3583 - val_output_1_loss: 0.3583 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4055 - val_output_1_dice_coeff: 0.6609 - val_output_1_precision: 0.7889 - val_output_1_recall: 0.6600 - val_output_1_sensitivity: 0.6386 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9120 - lr: 1.0000e-04
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3307 - output_1_loss: 0.3307 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4298 - output_1_dice_coeff: 0.6868 - output_1_precision: 0.7949 - output_1_recall: 0.7232 - output_1_sensitivity: 0.6870 - output_1_specificity: 0.9944 - output_1_auc: 0.9293
# Epoch 1: val_loss improved from 0.35834 to 0.34449, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 301ms/step - loss: 0.3307 - output_1_loss: 0.3307 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4298 - output_1_dice_coeff: 0.6868 - output_1_precision: 0.7949 - output_1_recall: 0.7232 - output_1_sensitivity: 0.6870 - output_1_specificity: 0.9944 - output_1_auc: 0.9293 - val_loss: 0.3445 - val_output_1_loss: 0.3445 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4219 - val_output_1_dice_coeff: 0.6733 - val_output_1_precision: 0.7545 - val_output_1_recall: 0.7669 - val_output_1_sensitivity: 0.6903 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9376 - lr: 1.0000e-04
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3380 - output_1_loss: 0.3380 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4199 - output_1_dice_coeff: 0.6799 - output_1_precision: 0.7978 - output_1_recall: 0.6995 - output_1_sensitivity: 0.6823 - output_1_specificity: 0.9947 - output_1_auc: 0.9200
# Epoch 1: val_loss did not improve from 0.34449
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3380 - output_1_loss: 0.3380 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4199 - output_1_dice_coeff: 0.6799 - output_1_precision: 0.7978 - output_1_recall: 0.6995 - output_1_sensitivity: 0.6823 - output_1_specificity: 0.9947 - output_1_auc: 0.9200 - val_loss: 0.3459 - val_output_1_loss: 0.3459 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4145 - val_output_1_dice_coeff: 0.6734 - val_output_1_precision: 0.8115 - val_output_1_recall: 0.6653 - val_output_1_sensitivity: 0.6330 - val_output_1_specificity: 0.9956 - val_output_1_auc: 0.9074 - lr: 1.0000e-04
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3346 - output_1_loss: 0.3346 - output_2_loss: 1.0351e-04 - output_1_iou_score: 0.4289 - output_1_dice_coeff: 0.6839 - output_1_precision: 0.7915 - output_1_recall: 0.7038 - output_1_sensitivity: 0.6911 - output_1_specificity: 0.9945 - output_1_auc: 0.9214
# Epoch 1: val_loss improved from 0.34449 to 0.33242, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 71s 304ms/step - loss: 0.3346 - output_1_loss: 0.3346 - output_2_loss: 1.0351e-04 - output_1_iou_score: 0.4289 - output_1_dice_coeff: 0.6839 - output_1_precision: 0.7915 - output_1_recall: 0.7038 - output_1_sensitivity: 0.6911 - output_1_specificity: 0.9945 - output_1_auc: 0.9214 - val_loss: 0.3324 - val_output_1_loss: 0.3324 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4263 - val_output_1_dice_coeff: 0.6854 - val_output_1_precision: 0.7785 - val_output_1_recall: 0.7362 - val_output_1_sensitivity: 0.6921 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9292 - lr: 1.0000e-04
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3305 - output_1_loss: 0.3305 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4410 - output_1_dice_coeff: 0.6869 - output_1_precision: 0.8028 - output_1_recall: 0.7317 - output_1_sensitivity: 0.6846 - output_1_specificity: 0.9946 - output_1_auc: 0.9322
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3305 - output_1_loss: 0.3305 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4410 - output_1_dice_coeff: 0.6869 - output_1_precision: 0.8028 - output_1_recall: 0.7317 - output_1_sensitivity: 0.6846 - output_1_specificity: 0.9946 - output_1_auc: 0.9322 - val_loss: 0.3663 - val_output_1_loss: 0.3663 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3934 - val_output_1_dice_coeff: 0.6526 - val_output_1_precision: 0.6946 - val_output_1_recall: 0.7981 - val_output_1_sensitivity: 0.7551 - val_output_1_specificity: 0.9901 - val_output_1_auc: 0.9513 - lr: 1.0000e-04
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3209 - output_1_loss: 0.3209 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4367 - output_1_dice_coeff: 0.6964 - output_1_precision: 0.7947 - output_1_recall: 0.7312 - output_1_sensitivity: 0.6994 - output_1_specificity: 0.9944 - output_1_auc: 0.9325
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 70s 298ms/step - loss: 0.3209 - output_1_loss: 0.3209 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4367 - output_1_dice_coeff: 0.6964 - output_1_precision: 0.7947 - output_1_recall: 0.7312 - output_1_sensitivity: 0.6994 - output_1_specificity: 0.9944 - output_1_auc: 0.9325 - val_loss: 0.5219 - val_output_1_loss: 0.5219 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.2903 - val_output_1_dice_coeff: 0.5198 - val_output_1_precision: 0.4790 - val_output_1_recall: 0.8269 - val_output_1_sensitivity: 0.8452 - val_output_1_specificity: 0.9748 - val_output_1_auc: 0.9554 - lr: 1.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3149 - output_1_loss: 0.3149 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4338 - output_1_dice_coeff: 0.7028 - output_1_precision: 0.8002 - output_1_recall: 0.7333 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9945 - output_1_auc: 0.9320
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3149 - output_1_loss: 0.3149 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4338 - output_1_dice_coeff: 0.7028 - output_1_precision: 0.8002 - output_1_recall: 0.7333 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9945 - output_1_auc: 0.9320 - val_loss: 0.3367 - val_output_1_loss: 0.3367 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4300 - val_output_1_dice_coeff: 0.6817 - val_output_1_precision: 0.7457 - val_output_1_recall: 0.7303 - val_output_1_sensitivity: 0.7163 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9367 - lr: 1.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3104 - output_1_loss: 0.3104 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4396 - output_1_dice_coeff: 0.7063 - output_1_precision: 0.8085 - output_1_recall: 0.7409 - output_1_sensitivity: 0.7016 - output_1_specificity: 0.9947 - output_1_auc: 0.9340
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3104 - output_1_loss: 0.3104 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4396 - output_1_dice_coeff: 0.7063 - output_1_precision: 0.8085 - output_1_recall: 0.7409 - output_1_sensitivity: 0.7016 - output_1_specificity: 0.9947 - output_1_auc: 0.9340 - val_loss: 0.3868 - val_output_1_loss: 0.3868 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4008 - val_output_1_dice_coeff: 0.6350 - val_output_1_precision: 0.6490 - val_output_1_recall: 0.7749 - val_output_1_sensitivity: 0.7460 - val_output_1_specificity: 0.9882 - val_output_1_auc: 0.9499 - lr: 1.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3233 - output_1_loss: 0.3233 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4389 - output_1_dice_coeff: 0.6943 - output_1_precision: 0.7995 - output_1_recall: 0.7365 - output_1_sensitivity: 0.6996 - output_1_specificity: 0.9945 - output_1_auc: 0.9318
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3233 - output_1_loss: 0.3233 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4389 - output_1_dice_coeff: 0.6943 - output_1_precision: 0.7995 - output_1_recall: 0.7365 - output_1_sensitivity: 0.6996 - output_1_specificity: 0.9945 - output_1_auc: 0.9318 - val_loss: 0.3404 - val_output_1_loss: 0.3404 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4308 - val_output_1_dice_coeff: 0.6814 - val_output_1_precision: 0.8259 - val_output_1_recall: 0.6581 - val_output_1_sensitivity: 0.6339 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.8829 - lr: 1.0000e-04
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3185 - output_1_loss: 0.3185 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4397 - output_1_dice_coeff: 0.6992 - output_1_precision: 0.8073 - output_1_recall: 0.7204 - output_1_sensitivity: 0.6961 - output_1_specificity: 0.9948 - output_1_auc: 0.9289
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3185 - output_1_loss: 0.3185 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4397 - output_1_dice_coeff: 0.6992 - output_1_precision: 0.8073 - output_1_recall: 0.7204 - output_1_sensitivity: 0.6961 - output_1_specificity: 0.9948 - output_1_auc: 0.9289 - val_loss: 0.4689 - val_output_1_loss: 0.4689 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3058 - val_output_1_dice_coeff: 0.5566 - val_output_1_precision: 0.9194 - val_output_1_recall: 0.4907 - val_output_1_sensitivity: 0.4286 - val_output_1_specificity: 0.9988 - val_output_1_auc: 0.8463 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3260 - output_1_loss: 0.3260 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4367 - output_1_dice_coeff: 0.6913 - output_1_precision: 0.8016 - output_1_recall: 0.7422 - output_1_sensitivity: 0.6946 - output_1_specificity: 0.9945 - output_1_auc: 0.9325
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 70s 298ms/step - loss: 0.3260 - output_1_loss: 0.3260 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4367 - output_1_dice_coeff: 0.6913 - output_1_precision: 0.8016 - output_1_recall: 0.7422 - output_1_sensitivity: 0.6946 - output_1_specificity: 0.9945 - output_1_auc: 0.9325 - val_loss: 0.4250 - val_output_1_loss: 0.4250 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.3760 - val_output_1_dice_coeff: 0.6063 - val_output_1_precision: 0.8960 - val_output_1_recall: 0.5146 - val_output_1_sensitivity: 0.4953 - val_output_1_specificity: 0.9983 - val_output_1_auc: 0.8229 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3039 - output_1_loss: 0.3039 - output_2_loss: 3.9560e-04 - output_1_iou_score: 0.4416 - output_1_dice_coeff: 0.7134 - output_1_precision: 0.8072 - output_1_recall: 0.7350 - output_1_sensitivity: 0.7099 - output_1_specificity: 0.9947 - output_1_auc: 0.9320
# Epoch 1: val_loss did not improve from 0.33242
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3039 - output_1_loss: 0.3039 - output_2_loss: 3.9560e-04 - output_1_iou_score: 0.4416 - output_1_dice_coeff: 0.7134 - output_1_precision: 0.8072 - output_1_recall: 0.7350 - output_1_sensitivity: 0.7099 - output_1_specificity: 0.9947 - output_1_auc: 0.9320 - val_loss: 0.3411 - val_output_1_loss: 0.3411 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4341 - val_output_1_dice_coeff: 0.6801 - val_output_1_precision: 0.8448 - val_output_1_recall: 0.6411 - val_output_1_sensitivity: 0.6251 - val_output_1_specificity: 0.9967 - val_output_1_auc: 0.8802 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3083 - output_1_loss: 0.3083 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4462 - output_1_dice_coeff: 0.7080 - output_1_precision: 0.8109 - output_1_recall: 0.7395 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9948 - output_1_auc: 0.9348
# Epoch 1: val_loss improved from 0.33242 to 0.32748, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.3083 - output_1_loss: 0.3083 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.4462 - output_1_dice_coeff: 0.7080 - output_1_precision: 0.8109 - output_1_recall: 0.7395 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9948 - output_1_auc: 0.9348 - val_loss: 0.3275 - val_output_1_loss: 0.3275 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4383 - val_output_1_dice_coeff: 0.6899 - val_output_1_precision: 0.7727 - val_output_1_recall: 0.7262 - val_output_1_sensitivity: 0.7071 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9352 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3009 - output_1_loss: 0.3024 - output_2_loss: 0.0151 - output_1_iou_score: 0.4528 - output_1_dice_coeff: 0.7140 - output_1_precision: 0.8094 - output_1_recall: 0.7562 - output_1_sensitivity: 0.7118 - output_1_specificity: 0.9947 - output_1_auc: 0.9379
# Epoch 1: val_loss did not improve from 0.32748
# 233/233 [==============================] - 69s 298ms/step - loss: 0.3009 - output_1_loss: 0.3024 - output_2_loss: 0.0151 - output_1_iou_score: 0.4528 - output_1_dice_coeff: 0.7140 - output_1_precision: 0.8094 - output_1_recall: 0.7562 - output_1_sensitivity: 0.7118 - output_1_specificity: 0.9947 - output_1_auc: 0.9379 - val_loss: 0.3279 - val_output_1_loss: 0.3355 - val_output_2_loss: 0.0758 - val_output_1_iou_score: 0.4174 - val_output_1_dice_coeff: 0.6816 - val_output_1_precision: 0.7552 - val_output_1_recall: 0.7611 - val_output_1_sensitivity: 0.7103 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9408 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2869 - output_1_loss: 0.3012 - output_2_loss: 0.1431 - output_1_iou_score: 0.4483 - output_1_dice_coeff: 0.7151 - output_1_precision: 0.8113 - output_1_recall: 0.7531 - output_1_sensitivity: 0.7085 - output_1_specificity: 0.9947 - output_1_auc: 0.9371
# Epoch 1: val_loss improved from 0.32748 to 0.30320, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2869 - output_1_loss: 0.3012 - output_2_loss: 0.1431 - output_1_iou_score: 0.4483 - output_1_dice_coeff: 0.7151 - output_1_precision: 0.8113 - output_1_recall: 0.7531 - output_1_sensitivity: 0.7085 - output_1_specificity: 0.9947 - output_1_auc: 0.9371 - val_loss: 0.3032 - val_output_1_loss: 0.3236 - val_output_2_loss: 0.2040 - val_output_1_iou_score: 0.4421 - val_output_1_dice_coeff: 0.6935 - val_output_1_precision: 0.8130 - val_output_1_recall: 0.7110 - val_output_1_sensitivity: 0.6682 - val_output_1_specificity: 0.9954 - val_output_1_auc: 0.9237 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2920 - output_1_loss: 0.3139 - output_2_loss: 0.2185 - output_1_iou_score: 0.4464 - output_1_dice_coeff: 0.7024 - output_1_precision: 0.8074 - output_1_recall: 0.7444 - output_1_sensitivity: 0.6987 - output_1_specificity: 0.9947 - output_1_auc: 0.9348
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 70s 299ms/step - loss: 0.2920 - output_1_loss: 0.3139 - output_2_loss: 0.2185 - output_1_iou_score: 0.4464 - output_1_dice_coeff: 0.7024 - output_1_precision: 0.8074 - output_1_recall: 0.7444 - output_1_sensitivity: 0.6987 - output_1_specificity: 0.9947 - output_1_auc: 0.9348 - val_loss: 0.3126 - val_output_1_loss: 0.3373 - val_output_2_loss: 0.2472 - val_output_1_iou_score: 0.4367 - val_output_1_dice_coeff: 0.6859 - val_output_1_precision: 0.7857 - val_output_1_recall: 0.6985 - val_output_1_sensitivity: 0.6851 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.8906 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2745 - output_1_loss: 0.2991 - output_2_loss: 0.2461 - output_1_iou_score: 0.4533 - output_1_dice_coeff: 0.7175 - output_1_precision: 0.8125 - output_1_recall: 0.7522 - output_1_sensitivity: 0.7097 - output_1_specificity: 0.9948 - output_1_auc: 0.9363
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2745 - output_1_loss: 0.2991 - output_2_loss: 0.2461 - output_1_iou_score: 0.4533 - output_1_dice_coeff: 0.7175 - output_1_precision: 0.8125 - output_1_recall: 0.7522 - output_1_sensitivity: 0.7097 - output_1_specificity: 0.9948 - output_1_auc: 0.9363 - val_loss: 0.3159 - val_output_1_loss: 0.3425 - val_output_2_loss: 0.2661 - val_output_1_iou_score: 0.4221 - val_output_1_dice_coeff: 0.6777 - val_output_1_precision: 0.7275 - val_output_1_recall: 0.7483 - val_output_1_sensitivity: 0.7408 - val_output_1_specificity: 0.9921 - val_output_1_auc: 0.9316 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2781 - output_1_loss: 0.3042 - output_2_loss: 0.2606 - output_1_iou_score: 0.4495 - output_1_dice_coeff: 0.7125 - output_1_precision: 0.8152 - output_1_recall: 0.7490 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9949 - output_1_auc: 0.9344
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2781 - output_1_loss: 0.3042 - output_2_loss: 0.2606 - output_1_iou_score: 0.4495 - output_1_dice_coeff: 0.7125 - output_1_precision: 0.8152 - output_1_recall: 0.7490 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9949 - output_1_auc: 0.9344 - val_loss: 0.4679 - val_output_1_loss: 0.4954 - val_output_2_loss: 0.2755 - val_output_1_iou_score: 0.3095 - val_output_1_dice_coeff: 0.5412 - val_output_1_precision: 0.5017 - val_output_1_recall: 0.8259 - val_output_1_sensitivity: 0.8343 - val_output_1_specificity: 0.9769 - val_output_1_auc: 0.9535 - lr: 1.0000e-04
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2735 - output_1_loss: 0.3005 - output_2_loss: 0.2698 - output_1_iou_score: 0.4576 - output_1_dice_coeff: 0.7161 - output_1_precision: 0.8127 - output_1_recall: 0.7586 - output_1_sensitivity: 0.7141 - output_1_specificity: 0.9948 - output_1_auc: 0.9372
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 70s 299ms/step - loss: 0.2735 - output_1_loss: 0.3005 - output_2_loss: 0.2698 - output_1_iou_score: 0.4576 - output_1_dice_coeff: 0.7161 - output_1_precision: 0.8127 - output_1_recall: 0.7586 - output_1_sensitivity: 0.7141 - output_1_specificity: 0.9948 - output_1_auc: 0.9372 - val_loss: 0.3233 - val_output_1_loss: 0.3518 - val_output_2_loss: 0.2854 - val_output_1_iou_score: 0.4247 - val_output_1_dice_coeff: 0.6705 - val_output_1_precision: 0.7965 - val_output_1_recall: 0.6843 - val_output_1_sensitivity: 0.6549 - val_output_1_specificity: 0.9951 - val_output_1_auc: 0.8935 - lr: 1.0000e-04
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2828 - output_1_loss: 0.3105 - output_2_loss: 0.2774 - output_1_iou_score: 0.4500 - output_1_dice_coeff: 0.7056 - output_1_precision: 0.8101 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9947 - output_1_auc: 0.9360
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2828 - output_1_loss: 0.3105 - output_2_loss: 0.2774 - output_1_iou_score: 0.4500 - output_1_dice_coeff: 0.7056 - output_1_precision: 0.8101 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7060 - output_1_specificity: 0.9947 - output_1_auc: 0.9360 - val_loss: 0.3107 - val_output_1_loss: 0.3397 - val_output_2_loss: 0.2899 - val_output_1_iou_score: 0.4288 - val_output_1_dice_coeff: 0.6805 - val_output_1_precision: 0.7571 - val_output_1_recall: 0.7234 - val_output_1_sensitivity: 0.7118 - val_output_1_specificity: 0.9935 - val_output_1_auc: 0.9184 - lr: 1.0000e-04
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2773 - output_1_loss: 0.3058 - output_2_loss: 0.2846 - output_1_iou_score: 0.4561 - output_1_dice_coeff: 0.7120 - output_1_precision: 0.8124 - output_1_recall: 0.7348 - output_1_sensitivity: 0.7069 - output_1_specificity: 0.9949 - output_1_auc: 0.9304
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 70s 298ms/step - loss: 0.2773 - output_1_loss: 0.3058 - output_2_loss: 0.2846 - output_1_iou_score: 0.4561 - output_1_dice_coeff: 0.7120 - output_1_precision: 0.8124 - output_1_recall: 0.7348 - output_1_sensitivity: 0.7069 - output_1_specificity: 0.9949 - output_1_auc: 0.9304 - val_loss: 0.3190 - val_output_1_loss: 0.3488 - val_output_2_loss: 0.2978 - val_output_1_iou_score: 0.4124 - val_output_1_dice_coeff: 0.6682 - val_output_1_precision: 0.8591 - val_output_1_recall: 0.6282 - val_output_1_sensitivity: 0.5935 - val_output_1_specificity: 0.9971 - val_output_1_auc: 0.9097 - lr: 1.0000e-04
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2936 - output_1_loss: 0.3226 - output_2_loss: 0.2894 - output_1_iou_score: 0.4534 - output_1_dice_coeff: 0.6944 - output_1_precision: 0.8141 - output_1_recall: 0.7433 - output_1_sensitivity: 0.6914 - output_1_specificity: 0.9949 - output_1_auc: 0.9346
# Epoch 1: val_loss did not improve from 0.30320
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2936 - output_1_loss: 0.3226 - output_2_loss: 0.2894 - output_1_iou_score: 0.4534 - output_1_dice_coeff: 0.6944 - output_1_precision: 0.8141 - output_1_recall: 0.7433 - output_1_sensitivity: 0.6914 - output_1_specificity: 0.9949 - output_1_auc: 0.9346 - val_loss: 0.3846 - val_output_1_loss: 0.4146 - val_output_2_loss: 0.3000 - val_output_1_iou_score: 0.3746 - val_output_1_dice_coeff: 0.6145 - val_output_1_precision: 0.6016 - val_output_1_recall: 0.8048 - val_output_1_sensitivity: 0.8063 - val_output_1_specificity: 0.9850 - val_output_1_auc: 0.9343 - lr: 1.0000e-04
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2647 - output_1_loss: 0.2941 - output_2_loss: 0.2941 - output_1_iou_score: 0.4608 - output_1_dice_coeff: 0.7215 - output_1_precision: 0.8150 - output_1_recall: 0.7627 - output_1_sensitivity: 0.7176 - output_1_specificity: 0.9948 - output_1_auc: 0.9407
# Epoch 1: val_loss improved from 0.30320 to 0.29719, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2647 - output_1_loss: 0.2941 - output_2_loss: 0.2941 - output_1_iou_score: 0.4608 - output_1_dice_coeff: 0.7215 - output_1_precision: 0.8150 - output_1_recall: 0.7627 - output_1_sensitivity: 0.7176 - output_1_specificity: 0.9948 - output_1_auc: 0.9407 - val_loss: 0.2972 - val_output_1_loss: 0.3279 - val_output_2_loss: 0.3070 - val_output_1_iou_score: 0.4465 - val_output_1_dice_coeff: 0.6933 - val_output_1_precision: 0.8071 - val_output_1_recall: 0.6934 - val_output_1_sensitivity: 0.6755 - val_output_1_specificity: 0.9953 - val_output_1_auc: 0.9018 - lr: 1.0000e-04
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2828 - output_1_loss: 0.3125 - output_2_loss: 0.2970 - output_1_iou_score: 0.4507 - output_1_dice_coeff: 0.7047 - output_1_precision: 0.8080 - output_1_recall: 0.7416 - output_1_sensitivity: 0.7081 - output_1_specificity: 0.9947 - output_1_auc: 0.9320
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2828 - output_1_loss: 0.3125 - output_2_loss: 0.2970 - output_1_iou_score: 0.4507 - output_1_dice_coeff: 0.7047 - output_1_precision: 0.8080 - output_1_recall: 0.7416 - output_1_sensitivity: 0.7081 - output_1_specificity: 0.9947 - output_1_auc: 0.9320 - val_loss: 0.3090 - val_output_1_loss: 0.3396 - val_output_2_loss: 0.3065 - val_output_1_iou_score: 0.4341 - val_output_1_dice_coeff: 0.6825 - val_output_1_precision: 0.7370 - val_output_1_recall: 0.7406 - val_output_1_sensitivity: 0.7359 - val_output_1_specificity: 0.9926 - val_output_1_auc: 0.9130 - lr: 1.0000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2665 - output_1_loss: 0.2967 - output_2_loss: 0.3012 - output_1_iou_score: 0.4567 - output_1_dice_coeff: 0.7197 - output_1_precision: 0.8191 - output_1_recall: 0.7558 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9950 - output_1_auc: 0.9372
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2665 - output_1_loss: 0.2967 - output_2_loss: 0.3012 - output_1_iou_score: 0.4567 - output_1_dice_coeff: 0.7197 - output_1_precision: 0.8191 - output_1_recall: 0.7558 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9950 - output_1_auc: 0.9372 - val_loss: 0.3007 - val_output_1_loss: 0.3316 - val_output_2_loss: 0.3087 - val_output_1_iou_score: 0.4434 - val_output_1_dice_coeff: 0.6873 - val_output_1_precision: 0.8190 - val_output_1_recall: 0.6783 - val_output_1_sensitivity: 0.6565 - val_output_1_specificity: 0.9958 - val_output_1_auc: 0.9111 - lr: 1.0000e-04
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2733 - output_1_loss: 0.3036 - output_2_loss: 0.3034 - output_1_iou_score: 0.4544 - output_1_dice_coeff: 0.7126 - output_1_precision: 0.8173 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7123 - output_1_specificity: 0.9949 - output_1_auc: 0.9358
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2733 - output_1_loss: 0.3036 - output_2_loss: 0.3034 - output_1_iou_score: 0.4544 - output_1_dice_coeff: 0.7126 - output_1_precision: 0.8173 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7123 - output_1_specificity: 0.9949 - output_1_auc: 0.9358 - val_loss: 0.3092 - val_output_1_loss: 0.3403 - val_output_2_loss: 0.3112 - val_output_1_iou_score: 0.4376 - val_output_1_dice_coeff: 0.6829 - val_output_1_precision: 0.8095 - val_output_1_recall: 0.6825 - val_output_1_sensitivity: 0.6636 - val_output_1_specificity: 0.9955 - val_output_1_auc: 0.8906 - lr: 1.0000e-04
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2715 - output_1_loss: 0.3022 - output_2_loss: 0.3076 - output_1_iou_score: 0.4643 - output_1_dice_coeff: 0.7145 - output_1_precision: 0.8170 - output_1_recall: 0.7556 - output_1_sensitivity: 0.7130 - output_1_specificity: 0.9950 - output_1_auc: 0.9359
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2715 - output_1_loss: 0.3022 - output_2_loss: 0.3076 - output_1_iou_score: 0.4643 - output_1_dice_coeff: 0.7145 - output_1_precision: 0.8170 - output_1_recall: 0.7556 - output_1_sensitivity: 0.7130 - output_1_specificity: 0.9950 - output_1_auc: 0.9359 - val_loss: 0.2995 - val_output_1_loss: 0.3312 - val_output_2_loss: 0.3165 - val_output_1_iou_score: 0.4480 - val_output_1_dice_coeff: 0.6902 - val_output_1_precision: 0.8489 - val_output_1_recall: 0.6566 - val_output_1_sensitivity: 0.6355 - val_output_1_specificity: 0.9967 - val_output_1_auc: 0.8876 - lr: 1.0000e-04
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2616 - output_1_loss: 0.2927 - output_2_loss: 0.3104 - output_1_iou_score: 0.4579 - output_1_dice_coeff: 0.7235 - output_1_precision: 0.8186 - output_1_recall: 0.7537 - output_1_sensitivity: 0.7192 - output_1_specificity: 0.9950 - output_1_auc: 0.9360
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2616 - output_1_loss: 0.2927 - output_2_loss: 0.3104 - output_1_iou_score: 0.4579 - output_1_dice_coeff: 0.7235 - output_1_precision: 0.8186 - output_1_recall: 0.7537 - output_1_sensitivity: 0.7192 - output_1_specificity: 0.9950 - output_1_auc: 0.9360 - val_loss: 0.3003 - val_output_1_loss: 0.3319 - val_output_2_loss: 0.3161 - val_output_1_iou_score: 0.4377 - val_output_1_dice_coeff: 0.6891 - val_output_1_precision: 0.8273 - val_output_1_recall: 0.6702 - val_output_1_sensitivity: 0.6501 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.8907 - lr: 1.0000e-04
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2844 - output_1_loss: 0.3157 - output_2_loss: 0.3125 - output_1_iou_score: 0.4562 - output_1_dice_coeff: 0.7016 - output_1_precision: 0.8146 - output_1_recall: 0.7233 - output_1_sensitivity: 0.6966 - output_1_specificity: 0.9951 - output_1_auc: 0.9318
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2844 - output_1_loss: 0.3157 - output_2_loss: 0.3125 - output_1_iou_score: 0.4562 - output_1_dice_coeff: 0.7016 - output_1_precision: 0.8146 - output_1_recall: 0.7233 - output_1_sensitivity: 0.6966 - output_1_specificity: 0.9951 - output_1_auc: 0.9318 - val_loss: 0.3645 - val_output_1_loss: 0.3967 - val_output_2_loss: 0.3213 - val_output_1_iou_score: 0.3666 - val_output_1_dice_coeff: 0.6295 - val_output_1_precision: 0.7829 - val_output_1_recall: 0.6341 - val_output_1_sensitivity: 0.6044 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.8761 - lr: 1.0000e-04
# Epoch 41/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2709 - output_1_loss: 0.3024 - output_2_loss: 0.3148 - output_1_iou_score: 0.4603 - output_1_dice_coeff: 0.7137 - output_1_precision: 0.8114 - output_1_recall: 0.7541 - output_1_sensitivity: 0.7062 - output_1_specificity: 0.9948 - output_1_auc: 0.9377
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2709 - output_1_loss: 0.3024 - output_2_loss: 0.3148 - output_1_iou_score: 0.4603 - output_1_dice_coeff: 0.7137 - output_1_precision: 0.8114 - output_1_recall: 0.7541 - output_1_sensitivity: 0.7062 - output_1_specificity: 0.9948 - output_1_auc: 0.9377 - val_loss: 0.3186 - val_output_1_loss: 0.3510 - val_output_2_loss: 0.3242 - val_output_1_iou_score: 0.4196 - val_output_1_dice_coeff: 0.6713 - val_output_1_precision: 0.7816 - val_output_1_recall: 0.6947 - val_output_1_sensitivity: 0.6726 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.8973 - lr: 1.0000e-04
# Epoch 42/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2659 - output_1_loss: 0.2977 - output_2_loss: 0.3179 - output_1_iou_score: 0.4617 - output_1_dice_coeff: 0.7190 - output_1_precision: 0.8151 - output_1_recall: 0.7600 - output_1_sensitivity: 0.7185 - output_1_specificity: 0.9948 - output_1_auc: 0.9376
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 70s 298ms/step - loss: 0.2659 - output_1_loss: 0.2977 - output_2_loss: 0.3179 - output_1_iou_score: 0.4617 - output_1_dice_coeff: 0.7190 - output_1_precision: 0.8151 - output_1_recall: 0.7600 - output_1_sensitivity: 0.7185 - output_1_specificity: 0.9948 - output_1_auc: 0.9376 - val_loss: 0.3075 - val_output_1_loss: 0.3401 - val_output_2_loss: 0.3258 - val_output_1_iou_score: 0.4309 - val_output_1_dice_coeff: 0.6802 - val_output_1_precision: 0.8467 - val_output_1_recall: 0.6455 - val_output_1_sensitivity: 0.6205 - val_output_1_specificity: 0.9967 - val_output_1_auc: 0.8855 - lr: 1.0000e-04
# Epoch 43/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2648 - output_1_loss: 0.2968 - output_2_loss: 0.3204 - output_1_iou_score: 0.4613 - output_1_dice_coeff: 0.7201 - output_1_precision: 0.8147 - output_1_recall: 0.7591 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9948 - output_1_auc: 0.9369
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2648 - output_1_loss: 0.2968 - output_2_loss: 0.3204 - output_1_iou_score: 0.4613 - output_1_dice_coeff: 0.7201 - output_1_precision: 0.8147 - output_1_recall: 0.7591 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9948 - output_1_auc: 0.9369 - val_loss: 0.3104 - val_output_1_loss: 0.3433 - val_output_2_loss: 0.3291 - val_output_1_iou_score: 0.4341 - val_output_1_dice_coeff: 0.6819 - val_output_1_precision: 0.7889 - val_output_1_recall: 0.6868 - val_output_1_sensitivity: 0.6806 - val_output_1_specificity: 0.9948 - val_output_1_auc: 0.8937 - lr: 1.0000e-04
# Epoch 44/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2661 - output_1_loss: 0.2983 - output_2_loss: 0.3211 - output_1_iou_score: 0.4613 - output_1_dice_coeff: 0.7182 - output_1_precision: 0.8116 - output_1_recall: 0.7473 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9948 - output_1_auc: 0.9395
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2661 - output_1_loss: 0.2983 - output_2_loss: 0.3211 - output_1_iou_score: 0.4613 - output_1_dice_coeff: 0.7182 - output_1_precision: 0.8116 - output_1_recall: 0.7473 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9948 - output_1_auc: 0.9395 - val_loss: 0.3045 - val_output_1_loss: 0.3373 - val_output_2_loss: 0.3281 - val_output_1_iou_score: 0.4318 - val_output_1_dice_coeff: 0.6834 - val_output_1_precision: 0.7491 - val_output_1_recall: 0.7374 - val_output_1_sensitivity: 0.7331 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9176 - lr: 1.0000e-04
# Epoch 45/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2691 - output_1_loss: 0.3016 - output_2_loss: 0.3247 - output_1_iou_score: 0.4616 - output_1_dice_coeff: 0.7151 - output_1_precision: 0.8155 - output_1_recall: 0.7612 - output_1_sensitivity: 0.7158 - output_1_specificity: 0.9948 - output_1_auc: 0.9394
# Epoch 1: val_loss did not improve from 0.29719
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2691 - output_1_loss: 0.3016 - output_2_loss: 0.3247 - output_1_iou_score: 0.4616 - output_1_dice_coeff: 0.7151 - output_1_precision: 0.8155 - output_1_recall: 0.7612 - output_1_sensitivity: 0.7158 - output_1_specificity: 0.9948 - output_1_auc: 0.9394 - val_loss: 0.3133 - val_output_1_loss: 0.3465 - val_output_2_loss: 0.3321 - val_output_1_iou_score: 0.4182 - val_output_1_dice_coeff: 0.6710 - val_output_1_precision: 0.8683 - val_output_1_recall: 0.6307 - val_output_1_sensitivity: 0.5920 - val_output_1_specificity: 0.9973 - val_output_1_auc: 0.9048 - lr: 1.0000e-04
# Epoch 46/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2534 - output_1_loss: 0.2861 - output_2_loss: 0.3274 - output_1_iou_score: 0.4680 - output_1_dice_coeff: 0.7300 - output_1_precision: 0.8192 - output_1_recall: 0.7618 - output_1_sensitivity: 0.7247 - output_1_specificity: 0.9950 - output_1_auc: 0.9388
# Epoch 1: val_loss improved from 0.29719 to 0.29452, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2534 - output_1_loss: 0.2861 - output_2_loss: 0.3274 - output_1_iou_score: 0.4680 - output_1_dice_coeff: 0.7300 - output_1_precision: 0.8192 - output_1_recall: 0.7618 - output_1_sensitivity: 0.7247 - output_1_specificity: 0.9950 - output_1_auc: 0.9388 - val_loss: 0.2945 - val_output_1_loss: 0.3280 - val_output_2_loss: 0.3346 - val_output_1_iou_score: 0.4479 - val_output_1_dice_coeff: 0.6922 - val_output_1_precision: 0.7634 - val_output_1_recall: 0.7326 - val_output_1_sensitivity: 0.7201 - val_output_1_specificity: 0.9936 - val_output_1_auc: 0.9162 - lr: 1.0000e-04
# Epoch 47/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2595 - output_1_loss: 0.2924 - output_2_loss: 0.3294 - output_1_iou_score: 0.4592 - output_1_dice_coeff: 0.7233 - output_1_precision: 0.8253 - output_1_recall: 0.7562 - output_1_sensitivity: 0.7151 - output_1_specificity: 0.9952 - output_1_auc: 0.9380
# Epoch 1: val_loss did not improve from 0.29452
# 233/233 [==============================] - 70s 299ms/step - loss: 0.2595 - output_1_loss: 0.2924 - output_2_loss: 0.3294 - output_1_iou_score: 0.4592 - output_1_dice_coeff: 0.7233 - output_1_precision: 0.8253 - output_1_recall: 0.7562 - output_1_sensitivity: 0.7151 - output_1_specificity: 0.9952 - output_1_auc: 0.9380 - val_loss: 0.3174 - val_output_1_loss: 0.3512 - val_output_2_loss: 0.3382 - val_output_1_iou_score: 0.4311 - val_output_1_dice_coeff: 0.6735 - val_output_1_precision: 0.7153 - val_output_1_recall: 0.7521 - val_output_1_sensitivity: 0.7173 - val_output_1_specificity: 0.9915 - val_output_1_auc: 0.9165 - lr: 1.0000e-04
# Epoch 48/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2620 - output_1_loss: 0.2951 - output_2_loss: 0.3316 - output_1_iou_score: 0.4702 - output_1_dice_coeff: 0.7208 - output_1_precision: 0.8170 - output_1_recall: 0.7648 - output_1_sensitivity: 0.7168 - output_1_specificity: 0.9948 - output_1_auc: 0.9408
# Epoch 1: val_loss did not improve from 0.29452
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2620 - output_1_loss: 0.2951 - output_2_loss: 0.3316 - output_1_iou_score: 0.4702 - output_1_dice_coeff: 0.7208 - output_1_precision: 0.8170 - output_1_recall: 0.7648 - output_1_sensitivity: 0.7168 - output_1_specificity: 0.9948 - output_1_auc: 0.9408 - val_loss: 0.3104 - val_output_1_loss: 0.3444 - val_output_2_loss: 0.3405 - val_output_1_iou_score: 0.4194 - val_output_1_dice_coeff: 0.6770 - val_output_1_precision: 0.7219 - val_output_1_recall: 0.7553 - val_output_1_sensitivity: 0.7545 - val_output_1_specificity: 0.9918 - val_output_1_auc: 0.9199 - lr: 1.0000e-04
# Epoch 49/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2546 - output_1_loss: 0.2880 - output_2_loss: 0.3340 - output_1_iou_score: 0.4705 - output_1_dice_coeff: 0.7276 - output_1_precision: 0.8214 - output_1_recall: 0.7700 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9950 - output_1_auc: 0.9421
# Epoch 1: val_loss improved from 0.29452 to 0.29423, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2546 - output_1_loss: 0.2880 - output_2_loss: 0.3340 - output_1_iou_score: 0.4705 - output_1_dice_coeff: 0.7276 - output_1_precision: 0.8214 - output_1_recall: 0.7700 - output_1_sensitivity: 0.7164 - output_1_specificity: 0.9950 - output_1_auc: 0.9421 - val_loss: 0.2942 - val_output_1_loss: 0.3285 - val_output_2_loss: 0.3429 - val_output_1_iou_score: 0.4403 - val_output_1_dice_coeff: 0.6910 - val_output_1_precision: 0.8120 - val_output_1_recall: 0.6837 - val_output_1_sensitivity: 0.6657 - val_output_1_specificity: 0.9955 - val_output_1_auc: 0.9000 - lr: 1.0000e-04
# Epoch 50/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2695 - output_1_loss: 0.3032 - output_2_loss: 0.3364 - output_1_iou_score: 0.4638 - output_1_dice_coeff: 0.7132 - output_1_precision: 0.8160 - output_1_recall: 0.7587 - output_1_sensitivity: 0.7091 - output_1_specificity: 0.9949 - output_1_auc: 0.9379
# Epoch 1: val_loss did not improve from 0.29423
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2695 - output_1_loss: 0.3032 - output_2_loss: 0.3364 - output_1_iou_score: 0.4638 - output_1_dice_coeff: 0.7132 - output_1_precision: 0.8160 - output_1_recall: 0.7587 - output_1_sensitivity: 0.7091 - output_1_specificity: 0.9949 - output_1_auc: 0.9379 - val_loss: 0.2957 - val_output_1_loss: 0.3298 - val_output_2_loss: 0.3407 - val_output_1_iou_score: 0.4450 - val_output_1_dice_coeff: 0.6892 - val_output_1_precision: 0.7720 - val_output_1_recall: 0.7217 - val_output_1_sensitivity: 0.6969 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9269 - lr: 1.0000e-04
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_iou_score', 'output_1_dice_coeff', 'output_1_precision', 'output_1_recall', 'output_1_sensitivity', 'output_1_specificity', 'output_1_auc', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_iou_score', 'val_output_1_dice_coeff', 'val_output_1_precision', 'val_output_1_recall', 'val_output_1_sensitivity', 'val_output_1_specificity', 'val_output_1_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %%
"""from tensorflow.keras.models import load_model

custom_objects = {'total_loss': total_loss,
                  '<lambda>': lambda y_true, y_pred: y_pred,
                  'iou_score':iou_score,
                  'dice_coeff':dice_coeff,
                  'precision':tf.keras.metrics.Precision(),
                  'recall':tf.keras.metrics.Recall(),
                  'sensitivity':sensitivity,
                  'specificity':specificity
                 }

with tf.keras.utils.custom_object_scope(custom_objects):
    model = load_model('/kaggle/working/final_model.h5')"""
# Out:
# "from tensorflow.keras.models import load_model\n\ncustom_objects = {'total_loss': total_loss,\n                  '<lambda>': lambda y_true, y_pred: y_pred,\n                  'iou_score':iou_score,\n                  'dice_coeff':dice_coeff,\n                  'precision':tf.keras.metrics.Precision(),\n                  'recall':tf.keras.metrics.Recall(),\n                  'sensitivity':sensitivity,\n                  'specificity':specificity\n                 }\n\nwith tf.keras.utils.custom_object_scope(custom_objects):\n    model = load_model('/kaggle/working/final_model.h5')"

# %% [markdown]
# Im going for this method instead...more efficient

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model = build_WNet((256,256,3))

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00005), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':-0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-22 20:05:56.977646: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.2439 - output_1_loss: 0.2771 - output_2_loss: 0.3320 - output_1_iou_score: 0.4771 - output_1_dice_coeff: 0.7377 - output_1_precision_1: 0.8256 - output_1_recall_1: 0.7688 - output_1_sensitivity: 0.7279 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9414
# Epoch 1: val_loss improved from inf to 0.31558, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 112s 309ms/step - loss: 0.2439 - output_1_loss: 0.2771 - output_2_loss: 0.3320 - output_1_iou_score: 0.4771 - output_1_dice_coeff: 0.7377 - output_1_precision_1: 0.8256 - output_1_recall_1: 0.7688 - output_1_sensitivity: 0.7279 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9414 - val_loss: 0.3156 - val_output_1_loss: 0.3486 - val_output_2_loss: 0.3305 - val_output_1_iou_score: 0.4325 - val_output_1_dice_coeff: 0.6736 - val_output_1_precision_1: 0.8862 - val_output_1_recall_1: 0.6119 - val_output_1_sensitivity: 0.5826 - val_output_1_specificity: 0.9978 - val_output_1_auc_1: 0.8652 - lr: 5.0000e-05
# Epoch 2/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2588 - output_1_loss: 0.2921 - output_2_loss: 0.3326 - output_1_iou_score: 0.4778 - output_1_dice_coeff: 0.7237 - output_1_precision_1: 0.8242 - output_1_recall_1: 0.7715 - output_1_sensitivity: 0.7163 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9422
# Epoch 2: val_loss improved from 0.31558 to 0.29560, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2588 - output_1_loss: 0.2921 - output_2_loss: 0.3326 - output_1_iou_score: 0.4778 - output_1_dice_coeff: 0.7237 - output_1_precision_1: 0.8242 - output_1_recall_1: 0.7715 - output_1_sensitivity: 0.7163 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9422 - val_loss: 0.2956 - val_output_1_loss: 0.3300 - val_output_2_loss: 0.3435 - val_output_1_iou_score: 0.4474 - val_output_1_dice_coeff: 0.6931 - val_output_1_precision_1: 0.7574 - val_output_1_recall_1: 0.7376 - val_output_1_sensitivity: 0.7319 - val_output_1_specificity: 0.9933 - val_output_1_auc_1: 0.9109 - lr: 5.0000e-05
# Epoch 3/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2538 - output_1_loss: 0.2879 - output_2_loss: 0.3407 - output_1_iou_score: 0.4774 - output_1_dice_coeff: 0.7275 - output_1_precision_1: 0.8214 - output_1_recall_1: 0.7720 - output_1_sensitivity: 0.7225 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9425
# Epoch 3: val_loss did not improve from 0.29560
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2538 - output_1_loss: 0.2879 - output_2_loss: 0.3407 - output_1_iou_score: 0.4774 - output_1_dice_coeff: 0.7275 - output_1_precision_1: 0.8214 - output_1_recall_1: 0.7720 - output_1_sensitivity: 0.7225 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9425 - val_loss: 0.3072 - val_output_1_loss: 0.3422 - val_output_2_loss: 0.3495 - val_output_1_iou_score: 0.4260 - val_output_1_dice_coeff: 0.6788 - val_output_1_precision_1: 0.7368 - val_output_1_recall_1: 0.7452 - val_output_1_sensitivity: 0.7376 - val_output_1_specificity: 0.9925 - val_output_1_auc_1: 0.9163 - lr: 5.0000e-05
# Epoch 4/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2578 - output_1_loss: 0.2923 - output_2_loss: 0.3447 - output_1_iou_score: 0.4784 - output_1_dice_coeff: 0.7225 - output_1_precision_1: 0.8230 - output_1_recall_1: 0.7711 - output_1_sensitivity: 0.7192 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9413
# Epoch 4: val_loss improved from 0.29560 to 0.27656, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2578 - output_1_loss: 0.2923 - output_2_loss: 0.3447 - output_1_iou_score: 0.4784 - output_1_dice_coeff: 0.7225 - output_1_precision_1: 0.8230 - output_1_recall_1: 0.7711 - output_1_sensitivity: 0.7192 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9413 - val_loss: 0.2766 - val_output_1_loss: 0.3116 - val_output_2_loss: 0.3505 - val_output_1_iou_score: 0.4495 - val_output_1_dice_coeff: 0.7054 - val_output_1_precision_1: 0.7843 - val_output_1_recall_1: 0.7635 - val_output_1_sensitivity: 0.7277 - val_output_1_specificity: 0.9941 - val_output_1_auc_1: 0.9430 - lr: 5.0000e-05
# Epoch 5/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2479 - output_1_loss: 0.2826 - output_2_loss: 0.3474 - output_1_iou_score: 0.4841 - output_1_dice_coeff: 0.7329 - output_1_precision_1: 0.8218 - output_1_recall_1: 0.7751 - output_1_sensitivity: 0.7291 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9431
# Epoch 5: val_loss did not improve from 0.27656
# 233/233 [==============================] - 70s 298ms/step - loss: 0.2479 - output_1_loss: 0.2826 - output_2_loss: 0.3474 - output_1_iou_score: 0.4841 - output_1_dice_coeff: 0.7329 - output_1_precision_1: 0.8218 - output_1_recall_1: 0.7751 - output_1_sensitivity: 0.7291 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9431 - val_loss: 0.2839 - val_output_1_loss: 0.3192 - val_output_2_loss: 0.3535 - val_output_1_iou_score: 0.4443 - val_output_1_dice_coeff: 0.6981 - val_output_1_precision_1: 0.7553 - val_output_1_recall_1: 0.8055 - val_output_1_sensitivity: 0.7489 - val_output_1_specificity: 0.9926 - val_output_1_auc_1: 0.9543 - lr: 5.0000e-05
# Epoch 6/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2480 - output_1_loss: 0.2829 - output_2_loss: 0.3491 - output_1_iou_score: 0.4843 - output_1_dice_coeff: 0.7326 - output_1_precision_1: 0.8233 - output_1_recall_1: 0.7754 - output_1_sensitivity: 0.7291 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9441
# Epoch 6: val_loss improved from 0.27656 to 0.27577, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2480 - output_1_loss: 0.2829 - output_2_loss: 0.3491 - output_1_iou_score: 0.4843 - output_1_dice_coeff: 0.7326 - output_1_precision_1: 0.8233 - output_1_recall_1: 0.7754 - output_1_sensitivity: 0.7291 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9441 - val_loss: 0.2758 - val_output_1_loss: 0.3114 - val_output_2_loss: 0.3559 - val_output_1_iou_score: 0.4558 - val_output_1_dice_coeff: 0.7049 - val_output_1_precision_1: 0.8173 - val_output_1_recall_1: 0.7264 - val_output_1_sensitivity: 0.6890 - val_output_1_specificity: 0.9954 - val_output_1_auc_1: 0.9335 - lr: 5.0000e-05
# Epoch 7/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2545 - output_1_loss: 0.2896 - output_2_loss: 0.3506 - output_1_iou_score: 0.4785 - output_1_dice_coeff: 0.7259 - output_1_precision_1: 0.8231 - output_1_recall_1: 0.7709 - output_1_sensitivity: 0.7200 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9421
# Epoch 7: val_loss did not improve from 0.27577
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2545 - output_1_loss: 0.2896 - output_2_loss: 0.3506 - output_1_iou_score: 0.4785 - output_1_dice_coeff: 0.7259 - output_1_precision_1: 0.8231 - output_1_recall_1: 0.7709 - output_1_sensitivity: 0.7200 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9421 - val_loss: 0.2985 - val_output_1_loss: 0.3340 - val_output_2_loss: 0.3556 - val_output_1_iou_score: 0.4457 - val_output_1_dice_coeff: 0.6867 - val_output_1_precision_1: 0.7260 - val_output_1_recall_1: 0.7593 - val_output_1_sensitivity: 0.7409 - val_output_1_specificity: 0.9919 - val_output_1_auc_1: 0.9247 - lr: 5.0000e-05
# Epoch 8/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2534 - output_1_loss: 0.2886 - output_2_loss: 0.3519 - output_1_iou_score: 0.4810 - output_1_dice_coeff: 0.7268 - output_1_precision_1: 0.8259 - output_1_recall_1: 0.7707 - output_1_sensitivity: 0.7207 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9422
# Epoch 8: val_loss did not improve from 0.27577
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2534 - output_1_loss: 0.2886 - output_2_loss: 0.3519 - output_1_iou_score: 0.4810 - output_1_dice_coeff: 0.7268 - output_1_precision_1: 0.8259 - output_1_recall_1: 0.7707 - output_1_sensitivity: 0.7207 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9422 - val_loss: 0.3581 - val_output_1_loss: 0.3937 - val_output_2_loss: 0.3559 - val_output_1_iou_score: 0.3731 - val_output_1_dice_coeff: 0.6309 - val_output_1_precision_1: 0.9082 - val_output_1_recall_1: 0.5615 - val_output_1_sensitivity: 0.5202 - val_output_1_specificity: 0.9984 - val_output_1_auc_1: 0.8532 - lr: 5.0000e-05
# Epoch 9/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2477 - output_1_loss: 0.2829 - output_2_loss: 0.3519 - output_1_iou_score: 0.4806 - output_1_dice_coeff: 0.7329 - output_1_precision_1: 0.8238 - output_1_recall_1: 0.7700 - output_1_sensitivity: 0.7313 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9409
# Epoch 9: val_loss did not improve from 0.27577
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 233/233 [==============================] - 69s 298ms/step - loss: 0.2477 - output_1_loss: 0.2829 - output_2_loss: 0.3519 - output_1_iou_score: 0.4806 - output_1_dice_coeff: 0.7329 - output_1_precision_1: 0.8238 - output_1_recall_1: 0.7700 - output_1_sensitivity: 0.7313 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9409 - val_loss: 0.2775 - val_output_1_loss: 0.3132 - val_output_2_loss: 0.3564 - val_output_1_iou_score: 0.4657 - val_output_1_dice_coeff: 0.7036 - val_output_1_precision_1: 0.8071 - val_output_1_recall_1: 0.7040 - val_output_1_sensitivity: 0.6900 - val_output_1_specificity: 0.9953 - val_output_1_auc_1: 0.9301 - lr: 5.0000e-05
# Epoch 10/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2459 - output_1_loss: 0.2814 - output_2_loss: 0.3546 - output_1_iou_score: 0.4913 - output_1_dice_coeff: 0.7341 - output_1_precision_1: 0.8272 - output_1_recall_1: 0.7765 - output_1_sensitivity: 0.7322 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9439
# Epoch 10: val_loss improved from 0.27577 to 0.27462, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 70s 300ms/step - loss: 0.2459 - output_1_loss: 0.2814 - output_2_loss: 0.3546 - output_1_iou_score: 0.4913 - output_1_dice_coeff: 0.7341 - output_1_precision_1: 0.8272 - output_1_recall_1: 0.7765 - output_1_sensitivity: 0.7322 - output_1_specificity: 0.9951 - output_1_auc_1: 0.9439 - val_loss: 0.2746 - val_output_1_loss: 0.3107 - val_output_2_loss: 0.3606 - val_output_1_iou_score: 0.4663 - val_output_1_dice_coeff: 0.7068 - val_output_1_precision_1: 0.8018 - val_output_1_recall_1: 0.7140 - val_output_1_sensitivity: 0.7035 - val_output_1_specificity: 0.9950 - val_output_1_auc_1: 0.9302 - lr: 1.5000e-05

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 363.80it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            #augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 25s 560ms/step - loss: 0.2368 - output_1_loss: 0.2732 - output_2_loss: 0.3638 - output_1_iou_score: 0.4861 - output_1_dice_coeff: 0.7507 - output_1_precision_1: 0.7986 - output_1_recall_1: 0.7259 - output_1_sensitivity: 0.7460 - output_1_specificity: 0.9938 - output_1_auc_1: 0.9195

# %%
#!zip -r weights_WNet_VGG16_AT_CL.zip /kaggle/working/WNet_maxpool_fine_tune.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_VGG16_AT_CL.zip')
