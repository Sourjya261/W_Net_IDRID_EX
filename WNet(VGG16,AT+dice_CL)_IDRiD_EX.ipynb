# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:03<00:00, 385.53it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import VGG16
def build_encoder2(inputs):

    s=[]
    """ Pre-trained VGG16 Model """
    vgg16 = VGG16(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in vgg16.layers:
        layer.trainable = True

    """ Encoder """
    s1 = vgg16.get_layer("block1_conv2").output         ## (512 x 512)
    s.append(s1)
    s2 = vgg16.get_layer("block2_conv2").output         ## (256 x 256)
    s.append(s2)
    s3 = vgg16.get_layer("block3_conv3").output         ## (128 x 128)
    s.append(s3)
    s4 = vgg16.get_layer("block4_conv3").output         ## (64 x 64)
    s.append(s4)

    """ Bridge """
    b = vgg16.get_layer("block5_conv3").output         ## (32 x 32)
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Symmetric architecture

# %% [markdown]
# # Code for W-Net
#
# from tensorflow.keras import layers
# from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
# from tensorflow.keras.models import Model
#
#
# def complementary_loss(y_true, y_pred):
#     mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
#     return tf.math.sigmoid(mse_loss)
#
#
# def batchnorm_relu(inputs):
#     x = BatchNormalization()(inputs)
#     #x = Activation("relu")(x)
#     x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)
#
#     return x
#
# def residual_block(inputs, num_filters):
#     """ Convolutional Layer """
#     x = batchnorm_relu(inputs)
#     x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
#     x = Dropout(0.1)(x)
#     x = batchnorm_relu(x)
#     x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
#
#
#     """ Shortcut Connection """
#     s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
#     x = x + s
#     return x
#
# def decoder_block(inputs, s1,s2, num_filters):
#     x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
#     x = Concatenate()([x,s1,s2])
#     x = residual_block(x, num_filters)
#     x = GCSE(x)
#     return x
# def build_encoder1(inputs,f):
#
#     x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
#     x = batchnorm_relu(x)
#     x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
#     s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
#
#     c1 = x + s
#     c1 = GCSE(c1)
#     p1 = MaxPooling2D((2,2))(c1)
#     s1 = c1
#
#     c2 = residual_block(p1, f[1])
#     c2 = GCSE(c2)
#     p2 = MaxPooling2D((2,2))(c2)
#     s2 = c2
#
#     c3 = residual_block(p2, f[2])
#     c3 = GCSE(c3)
#     p3 = MaxPooling2D((2,2))(c3)
#     s3 = c3
#
#     c4 = residual_block(p3, f[3])
#     c4 = GCSE(c4)
#     p4 = MaxPooling2D((2,2))(c4)
#     s4 = c4
#
#     s_ = [s1,s2,s3,s4]
#     """ Bridge """
#     b = ASPP(p4,128)
#     encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
#     return encoder1
#
#
#
#
# def build_WNet(input_shape):
#     f = [64,128,256,512]
#
#     inputs = Input(input_shape,name="model_input")
#     encoder1 = build_encoder1(inputs,f)
#     encoder2 = build_encoder2(inputs)
#     s1,b1 = encoder1(inputs)
#     s2,b2 = encoder2(inputs)
#
#     b = Concatenate()([b1,b2])
#
#     """ Decoder 1, 2, 3 """
#     d1 = decoder_block(b, s2[3],s1[3], f[3])
#     d2 = decoder_block(d1, s2[2],s1[2], f[2])
#     d3 = decoder_block(d2, s2[1],s1[1], f[1])
#     d4 = decoder_block(d3, s2[0],s1[0],f[0])
#
#     comp1 = complementary_loss(s2[0], s1[0])
#     comp2 = complementary_loss(s2[1], s1[1])
#     comp3 = complementary_loss(s2[2], s1[2])
#     comp4 = complementary_loss(s2[3], s1[3])
#     comp5 = complementary_loss(b1, b2)
#
#
#     output_2 = tf.keras.layers.Add(name='output_2')([comp3,comp4,comp5])
#
#     """ Classifier """
#     output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)
#
#     """ Model """
#     model = Model(inputs,outputs=[output_1,output_2])
#     return model

# %% [markdown]
# # Asymmetric Architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model
from sklearn.metrics import mean_squared_error

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice
"""def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))"""
def complementary_loss(feature_map1,feature_map2):
    feature_map1 = tf.reduce_mean(feature_map1, axis=-1, keepdims=True)
    feature_map2  = tf.reduce_mean(feature_map2, axis=-1, keepdims=True)
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    #print(feature_map1.shape) #shapes are (none,H,W,1) so axis = 1 2 3 
    """intersection = tf.reduce_sum(feature_map1 * feature_map2, axis=[1, 2, 3])
    union = tf.reduce_sum(feature_map1 + feature_map2, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou"""
    return dice_coeff(feature_map1,feature_map2)

    
clipping_layer = tf.keras.layers.Lambda(
    lambda x: tf.clip_by_value(x , clip_value_min=0, clip_value_max=1),
    name='output_2'
)



def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+128)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+64)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    #comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2_sum')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])
    output_2 = clipping_layer(output_2)

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 64),      1670035   ['model_input[0][0]']
#                               (None, 128, 128, 128),      2
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 160)        204960    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 320)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 320)        1280      ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 320)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 160)        460960    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 160)        0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 160)        640       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 160)        0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 160)        230560    ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 160)        51360     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 160)        0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 160)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 160)            0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 320)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 10)             3210      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 160)            1760      ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 160)        0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 160)        0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 80)         51280     ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 160)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 160)        640       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 160)        0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 80)         115280    ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 80)         0         ['conv2d_54[0][0]']
#
#  tf.math.reduce_mean_16 (TF  (None, 256, 256, 1)          0         ['encoder2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  (None, 256, 256, 1)          0         ['encoder1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  (None, 128, 128, 1)          0         ['encoder2[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  (None, 128, 128, 1)          0         ['encoder1[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  (None, 64, 64, 1)            0         ['encoder2[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  (None, 64, 64, 1)            0         ['encoder1[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  (None, 32, 32, 1)            0         ['encoder2[0][3]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  (None, 32, 32, 1)            0         ['encoder1[0][3]']
#  OpLambda)
#
#  batch_normalization_26 (Ba  (None, 256, 256, 80)         320       ['dropout_6[0][0]']
#  tchNormalization)
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  mbda)                                                              ']
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['tf.math.reduce_mean_17[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['tf.math.reduce_mean_18[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['tf.math.reduce_mean_19[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['tf.math.reduce_mean_21[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['tf.math.reduce_mean_22[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['tf.math.reduce_mean_23[0][0]
#  Lambda)                                                            ']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 80)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_16[0][0]
#  a)                                                                 ',
#                                                                      'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_17[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_18[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_19[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_20[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_21[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_22[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_10 (TFOpLa  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_23[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_max_7[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 80)         57680     ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 80)         12880     ['concatenate_6[0][0]']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.truediv[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_1[0][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_3[0][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_4[0][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_6[0][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_7[0][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_9[0][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_10[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 80)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.reshape[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.reshape_2[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.reshape_4[0][0]',
#  mbda)                                                               'tf.reshape_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.reshape_6[0][0]',
#  mbda)                                                               'tf.reshape_7[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 80)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 80)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_sum (TFOpLa  ()                           0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  ()                           0         ['tf.reshape[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_2 (TFOp  ()                           0         ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_3 (TFOp  ()                           0         ['tf.math.multiply_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_4 (TFOp  ()                           0         ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_5 (TFOp  ()                           0         ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_6 (TFOp  ()                           0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_7 (TFOp  ()                           0         ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_8 (TFOp  ()                           0         ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_9 (TFOp  ()                           0         ['tf.math.multiply_6[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_10 (TFO  ()                           0         ['tf.reshape_6[0][0]']
#  pLambda)
#
#  tf.math.reduce_sum_11 (TFO  ()                           0         ['tf.reshape_7[0][0]']
#  pLambda)
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 160)            0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_sum[0][0]']
#  mbda)
#
#  tf.__operators__.add_9 (TF  ()                           0         ['tf.math.reduce_sum_1[0][0]',
#  OpLambda)                                                           'tf.math.reduce_sum_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  ()                           0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_12 (T  ()                           0         ['tf.math.reduce_sum_4[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  ()                           0         ['tf.math.reduce_sum_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_15 (T  ()                           0         ['tf.math.reduce_sum_7[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_8[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  ()                           0         ['tf.math.reduce_sum_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_18 (T  ()                           0         ['tf.math.reduce_sum_10[0][0]'
#  FOpLambda)                                                         , 'tf.math.reduce_sum_11[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 5)              805       ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.add_8 (TF  ()                           0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.__operators__.add_10 (T  ()                           0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.__operators__.add_11 (T  ()                           0         ['tf.math.multiply_3[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_13 (T  ()                           0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_14 (T  ()                           0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_16 (T  ()                           0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_17 (T  ()                           0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_19 (T  ()                           0         ['tf.__operators__.add_18[0][0
#  FOpLambda)                                                         ]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 80)             480       ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.truediv_2 (TFOpLam  ()                           0         ['tf.__operators__.add_8[0][0]
#  bda)                                                               ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.truediv_5 (TFOpLam  ()                           0         ['tf.__operators__.add_11[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.__operators__.add_14[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.__operators__.add_17[0][0
#  mbda)                                                              ]',
#                                                                      'tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 80)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.truediv_12 (TFOpLa  ()                           0         ['tf.math.truediv_2[0][0]']
#  mbda)
#
#  tf.math.truediv_13 (TFOpLa  ()                           0         ['tf.math.truediv_5[0][0]']
#  mbda)
#
#  tf.math.truediv_14 (TFOpLa  ()                           0         ['tf.math.truediv_8[0][0]']
#  mbda)
#
#  tf.math.truediv_15 (TFOpLa  ()                           0         ['tf.math.truediv_11[0][0]']
#  mbda)
#
#  multiply_15 (Multiply)      (None, 256, 256, 80)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_2_sum (Add)          ()                           0         ['tf.math.truediv_12[0][0]',
#                                                                      'tf.math.truediv_13[0][0]',
#                                                                      'tf.math.truediv_14[0][0]',
#                                                                      'tf.math.truediv_15[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          81        ['multiply_15[0][0]']
#
#  output_2 (Lambda)           ()                           0         ['output_2_sum[0][0]']
#
# ==================================================================================================
# Total params: 35200043 (134.28 MB)
# Trainable params: 35189067 (134.24 MB)
# Non-trainable params: 10976 (42.88 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5",
                               monitor="val_output_1_loss",
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
"""# Clear output folder
import os

def remove_folder_contents(folder):
    for the_file in os.listdir(folder):
        file_path = os.path.join(folder, the_file)
        try:
            if os.path.isfile(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                remove_folder_contents(file_path)
                os.rmdir(file_path)
        except Exception as e:
            print(e)

folder_path = '/kaggle/working'
remove_folder_contents(folder_path)
os.rmdir(folder_path)"""
# Out:
# "# Clear output folder\nimport os\n\ndef remove_folder_contents(folder):\n    for the_file in os.listdir(folder):\n        file_path = os.path.join(folder, the_file)\n        try:\n            if os.path.isfile(file_path):\n                os.unlink(file_path)\n            elif os.path.isdir(file_path):\n                remove_folder_contents(file_path)\n                os.rmdir(file_path)\n        except Exception as e:\n            print(e)\n\nfolder_path = '/kaggle/working'\nremove_folder_contents(folder_path)\nos.rmdir(folder_path)"

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=1,callbacks=callbacks)

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-23 10:17:30.956879: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.6291 - output_1_loss: 0.6285 - output_2_loss: 0.0068 - output_1_iou_score: 0.1977 - output_1_dice_coeff: 0.3962 - output_1_precision: 0.4032 - output_1_recall: 0.4745 - output_1_sensitivity: 0.4623 - output_1_specificity: 0.9793 - output_1_auc: 0.8572
# Epoch 1: val_output_1_loss improved from inf to 0.65179, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 123s 327ms/step - loss: 0.6291 - output_1_loss: 0.6285 - output_2_loss: 0.0068 - output_1_iou_score: 0.1977 - output_1_dice_coeff: 0.3962 - output_1_precision: 0.4032 - output_1_recall: 0.4745 - output_1_sensitivity: 0.4623 - output_1_specificity: 0.9793 - output_1_auc: 0.8572 - val_loss: 0.7014 - val_output_1_loss: 0.6518 - val_output_2_loss: 0.4961 - val_output_1_iou_score: 0.1674 - val_output_1_dice_coeff: 0.3822 - val_output_1_precision: 0.7237 - val_output_1_recall: 0.3960 - val_output_1_sensitivity: 0.2959 - val_output_1_specificity: 0.9958 - val_output_1_auc: 0.7984 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4847 - output_1_loss: 0.4540 - output_2_loss: 0.3070 - output_1_iou_score: 0.3166 - output_1_dice_coeff: 0.5686 - output_1_precision: 0.7261 - output_1_recall: 0.5739 - output_1_sensitivity: 0.5873 - output_1_specificity: 0.9936 - output_1_auc: 0.8805
# Epoch 1: val_output_1_loss improved from 0.65179 to 0.48032, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.4847 - output_1_loss: 0.4540 - output_2_loss: 0.3070 - output_1_iou_score: 0.3166 - output_1_dice_coeff: 0.5686 - output_1_precision: 0.7261 - output_1_recall: 0.5739 - output_1_sensitivity: 0.5873 - output_1_specificity: 0.9936 - output_1_auc: 0.8805 - val_loss: 0.5754 - val_output_1_loss: 0.4803 - val_output_2_loss: 0.9506 - val_output_1_iou_score: 0.2934 - val_output_1_dice_coeff: 0.5391 - val_output_1_precision: 0.8077 - val_output_1_recall: 0.5240 - val_output_1_sensitivity: 0.4674 - val_output_1_specificity: 0.9965 - val_output_1_auc: 0.8851 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4925 - output_1_loss: 0.4059 - output_2_loss: 0.8667 - output_1_iou_score: 0.3613 - output_1_dice_coeff: 0.6158 - output_1_precision: 0.7560 - output_1_recall: 0.6222 - output_1_sensitivity: 0.6317 - output_1_specificity: 0.9940 - output_1_auc: 0.8943
# Epoch 1: val_output_1_loss improved from 0.48032 to 0.40581, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 69s 296ms/step - loss: 0.4925 - output_1_loss: 0.4059 - output_2_loss: 0.8667 - output_1_iou_score: 0.3613 - output_1_dice_coeff: 0.6158 - output_1_precision: 0.7560 - output_1_recall: 0.6222 - output_1_sensitivity: 0.6317 - output_1_specificity: 0.9940 - output_1_auc: 0.8943 - val_loss: 0.4848 - val_output_1_loss: 0.4058 - val_output_2_loss: 0.7895 - val_output_1_iou_score: 0.3667 - val_output_1_dice_coeff: 0.6132 - val_output_1_precision: 0.7359 - val_output_1_recall: 0.6758 - val_output_1_sensitivity: 0.6197 - val_output_1_specificity: 0.9932 - val_output_1_auc: 0.9132 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.5000 - output_1_loss: 0.4714 - output_2_loss: 0.2856 - output_1_iou_score: 0.3104 - output_1_dice_coeff: 0.5493 - output_1_precision: 0.6792 - output_1_recall: 0.6061 - output_1_sensitivity: 0.5850 - output_1_specificity: 0.9916 - output_1_auc: 0.9075
# Epoch 1: val_output_1_loss did not improve from 0.40581
# 233/233 [==============================] - 68s 290ms/step - loss: 0.5000 - output_1_loss: 0.4714 - output_2_loss: 0.2856 - output_1_iou_score: 0.3104 - output_1_dice_coeff: 0.5493 - output_1_precision: 0.6792 - output_1_recall: 0.6061 - output_1_sensitivity: 0.5850 - output_1_specificity: 0.9916 - output_1_auc: 0.9075 - val_loss: 0.6337 - val_output_1_loss: 0.6174 - val_output_2_loss: 0.1627 - val_output_1_iou_score: 0.1956 - val_output_1_dice_coeff: 0.3983 - val_output_1_precision: 0.5829 - val_output_1_recall: 0.6054 - val_output_1_sensitivity: 0.5800 - val_output_1_specificity: 0.9880 - val_output_1_auc: 0.9027 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3978 - output_1_loss: 0.3969 - output_2_loss: 0.0086 - output_1_iou_score: 0.3643 - output_1_dice_coeff: 0.6216 - output_1_precision: 0.7679 - output_1_recall: 0.6410 - output_1_sensitivity: 0.6322 - output_1_specificity: 0.9942 - output_1_auc: 0.9090
# Epoch 1: val_output_1_loss did not improve from 0.40581
# 233/233 [==============================] - 68s 291ms/step - loss: 0.3978 - output_1_loss: 0.3969 - output_2_loss: 0.0086 - output_1_iou_score: 0.3643 - output_1_dice_coeff: 0.6216 - output_1_precision: 0.7679 - output_1_recall: 0.6410 - output_1_sensitivity: 0.6322 - output_1_specificity: 0.9942 - output_1_auc: 0.9090 - val_loss: 0.5559 - val_output_1_loss: 0.5402 - val_output_2_loss: 0.1573 - val_output_1_iou_score: 0.2451 - val_output_1_dice_coeff: 0.4740 - val_output_1_precision: 0.7072 - val_output_1_recall: 0.6019 - val_output_1_sensitivity: 0.5211 - val_output_1_specificity: 0.9931 - val_output_1_auc: 0.9211 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3787 - output_1_loss: 0.3765 - output_2_loss: 0.0215 - output_1_iou_score: 0.3812 - output_1_dice_coeff: 0.6430 - output_1_precision: 0.7670 - output_1_recall: 0.6661 - output_1_sensitivity: 0.6505 - output_1_specificity: 0.9940 - output_1_auc: 0.9118
# Epoch 1: val_output_1_loss did not improve from 0.40581
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3787 - output_1_loss: 0.3765 - output_2_loss: 0.0215 - output_1_iou_score: 0.3812 - output_1_dice_coeff: 0.6430 - output_1_precision: 0.7670 - output_1_recall: 0.6661 - output_1_sensitivity: 0.6505 - output_1_specificity: 0.9940 - output_1_auc: 0.9118 - val_loss: 0.5199 - val_output_1_loss: 0.5142 - val_output_2_loss: 0.0573 - val_output_1_iou_score: 0.2630 - val_output_1_dice_coeff: 0.5003 - val_output_1_precision: 0.7510 - val_output_1_recall: 0.5853 - val_output_1_sensitivity: 0.4812 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9212 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3781 - output_1_loss: 0.3738 - output_2_loss: 0.0430 - output_1_iou_score: 0.3930 - output_1_dice_coeff: 0.6435 - output_1_precision: 0.7757 - output_1_recall: 0.6938 - output_1_sensitivity: 0.6512 - output_1_specificity: 0.9940 - output_1_auc: 0.9224
# Epoch 1: val_output_1_loss did not improve from 0.40581
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3781 - output_1_loss: 0.3738 - output_2_loss: 0.0430 - output_1_iou_score: 0.3930 - output_1_dice_coeff: 0.6435 - output_1_precision: 0.7757 - output_1_recall: 0.6938 - output_1_sensitivity: 0.6512 - output_1_specificity: 0.9940 - output_1_auc: 0.9224 - val_loss: 0.4563 - val_output_1_loss: 0.4502 - val_output_2_loss: 0.0613 - val_output_1_iou_score: 0.3322 - val_output_1_dice_coeff: 0.5635 - val_output_1_precision: 0.7112 - val_output_1_recall: 0.6959 - val_output_1_sensitivity: 0.6009 - val_output_1_specificity: 0.9921 - val_output_1_auc: 0.9430 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3732 - output_1_loss: 0.3702 - output_2_loss: 0.0301 - output_1_iou_score: 0.3928 - output_1_dice_coeff: 0.6492 - output_1_precision: 0.7659 - output_1_recall: 0.6988 - output_1_sensitivity: 0.6598 - output_1_specificity: 0.9936 - output_1_auc: 0.9208
# Epoch 1: val_output_1_loss improved from 0.40581 to 0.36884, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3732 - output_1_loss: 0.3702 - output_2_loss: 0.0301 - output_1_iou_score: 0.3928 - output_1_dice_coeff: 0.6492 - output_1_precision: 0.7659 - output_1_recall: 0.6988 - output_1_sensitivity: 0.6598 - output_1_specificity: 0.9936 - output_1_auc: 0.9208 - val_loss: 0.3767 - val_output_1_loss: 0.3688 - val_output_2_loss: 0.0781 - val_output_1_iou_score: 0.3975 - val_output_1_dice_coeff: 0.6463 - val_output_1_precision: 0.7528 - val_output_1_recall: 0.7577 - val_output_1_sensitivity: 0.6772 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9409 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3651 - output_1_loss: 0.3617 - output_2_loss: 0.0344 - output_1_iou_score: 0.4033 - output_1_dice_coeff: 0.6579 - output_1_precision: 0.7693 - output_1_recall: 0.6957 - output_1_sensitivity: 0.6636 - output_1_specificity: 0.9938 - output_1_auc: 0.9169
# Epoch 1: val_output_1_loss improved from 0.36884 to 0.36623, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3651 - output_1_loss: 0.3617 - output_2_loss: 0.0344 - output_1_iou_score: 0.4033 - output_1_dice_coeff: 0.6579 - output_1_precision: 0.7693 - output_1_recall: 0.6957 - output_1_sensitivity: 0.6636 - output_1_specificity: 0.9938 - output_1_auc: 0.9169 - val_loss: 0.3730 - val_output_1_loss: 0.3662 - val_output_2_loss: 0.0673 - val_output_1_iou_score: 0.3975 - val_output_1_dice_coeff: 0.6502 - val_output_1_precision: 0.7320 - val_output_1_recall: 0.7755 - val_output_1_sensitivity: 0.6927 - val_output_1_specificity: 0.9920 - val_output_1_auc: 0.9426 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3502 - output_1_loss: 0.3442 - output_2_loss: 0.0602 - output_1_iou_score: 0.4064 - output_1_dice_coeff: 0.6739 - output_1_precision: 0.7832 - output_1_recall: 0.7216 - output_1_sensitivity: 0.6797 - output_1_specificity: 0.9940 - output_1_auc: 0.9273
# Epoch 1: val_output_1_loss did not improve from 0.36623
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3502 - output_1_loss: 0.3442 - output_2_loss: 0.0602 - output_1_iou_score: 0.4064 - output_1_dice_coeff: 0.6739 - output_1_precision: 0.7832 - output_1_recall: 0.7216 - output_1_sensitivity: 0.6797 - output_1_specificity: 0.9940 - output_1_auc: 0.9273 - val_loss: 0.3838 - val_output_1_loss: 0.3742 - val_output_2_loss: 0.0955 - val_output_1_iou_score: 0.3982 - val_output_1_dice_coeff: 0.6495 - val_output_1_precision: 0.8256 - val_output_1_recall: 0.6206 - val_output_1_sensitivity: 0.5971 - val_output_1_specificity: 0.9963 - val_output_1_auc: 0.8781 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3457 - output_1_loss: 0.3440 - output_2_loss: 0.0172 - output_1_iou_score: 0.4152 - output_1_dice_coeff: 0.6735 - output_1_precision: 0.7796 - output_1_recall: 0.7224 - output_1_sensitivity: 0.6775 - output_1_specificity: 0.9939 - output_1_auc: 0.9273
# Epoch 1: val_output_1_loss did not improve from 0.36623
# 233/233 [==============================] - 68s 291ms/step - loss: 0.3457 - output_1_loss: 0.3440 - output_2_loss: 0.0172 - output_1_iou_score: 0.4152 - output_1_dice_coeff: 0.6735 - output_1_precision: 0.7796 - output_1_recall: 0.7224 - output_1_sensitivity: 0.6775 - output_1_specificity: 0.9939 - output_1_auc: 0.9273 - val_loss: 0.3714 - val_output_1_loss: 0.3675 - val_output_2_loss: 0.0393 - val_output_1_iou_score: 0.3908 - val_output_1_dice_coeff: 0.6502 - val_output_1_precision: 0.7133 - val_output_1_recall: 0.7570 - val_output_1_sensitivity: 0.7256 - val_output_1_specificity: 0.9914 - val_output_1_auc: 0.9396 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3468 - output_1_loss: 0.3447 - output_2_loss: 0.0215 - output_1_iou_score: 0.4181 - output_1_dice_coeff: 0.6741 - output_1_precision: 0.7791 - output_1_recall: 0.7166 - output_1_sensitivity: 0.6793 - output_1_specificity: 0.9940 - output_1_auc: 0.9239
# Epoch 1: val_output_1_loss improved from 0.36623 to 0.36394, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 293ms/step - loss: 0.3468 - output_1_loss: 0.3447 - output_2_loss: 0.0215 - output_1_iou_score: 0.4181 - output_1_dice_coeff: 0.6741 - output_1_precision: 0.7791 - output_1_recall: 0.7166 - output_1_sensitivity: 0.6793 - output_1_specificity: 0.9940 - output_1_auc: 0.9239 - val_loss: 0.3693 - val_output_1_loss: 0.3639 - val_output_2_loss: 0.0539 - val_output_1_iou_score: 0.4057 - val_output_1_dice_coeff: 0.6579 - val_output_1_precision: 0.7408 - val_output_1_recall: 0.7018 - val_output_1_sensitivity: 0.6884 - val_output_1_specificity: 0.9931 - val_output_1_auc: 0.9052 - lr: 1.0000e-04
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3433 - output_1_loss: 0.3386 - output_2_loss: 0.0473 - output_1_iou_score: 0.4151 - output_1_dice_coeff: 0.6807 - output_1_precision: 0.7734 - output_1_recall: 0.7178 - output_1_sensitivity: 0.6841 - output_1_specificity: 0.9937 - output_1_auc: 0.9235
# Epoch 1: val_output_1_loss improved from 0.36394 to 0.36330, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3433 - output_1_loss: 0.3386 - output_2_loss: 0.0473 - output_1_iou_score: 0.4151 - output_1_dice_coeff: 0.6807 - output_1_precision: 0.7734 - output_1_recall: 0.7178 - output_1_sensitivity: 0.6841 - output_1_specificity: 0.9937 - output_1_auc: 0.9235 - val_loss: 0.3704 - val_output_1_loss: 0.3633 - val_output_2_loss: 0.0711 - val_output_1_iou_score: 0.3985 - val_output_1_dice_coeff: 0.6535 - val_output_1_precision: 0.7256 - val_output_1_recall: 0.8018 - val_output_1_sensitivity: 0.7089 - val_output_1_specificity: 0.9915 - val_output_1_auc: 0.9494 - lr: 1.0000e-04
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3402 - output_1_loss: 0.3291 - output_2_loss: 0.1118 - output_1_iou_score: 0.4241 - output_1_dice_coeff: 0.6891 - output_1_precision: 0.7904 - output_1_recall: 0.7440 - output_1_sensitivity: 0.6900 - output_1_specificity: 0.9941 - output_1_auc: 0.9303
# Epoch 1: val_output_1_loss improved from 0.36330 to 0.35894, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3402 - output_1_loss: 0.3291 - output_2_loss: 0.1118 - output_1_iou_score: 0.4241 - output_1_dice_coeff: 0.6891 - output_1_precision: 0.7904 - output_1_recall: 0.7440 - output_1_sensitivity: 0.6900 - output_1_specificity: 0.9941 - output_1_auc: 0.9303 - val_loss: 0.3659 - val_output_1_loss: 0.3589 - val_output_2_loss: 0.0696 - val_output_1_iou_score: 0.4040 - val_output_1_dice_coeff: 0.6628 - val_output_1_precision: 0.7939 - val_output_1_recall: 0.6687 - val_output_1_sensitivity: 0.6426 - val_output_1_specificity: 0.9951 - val_output_1_auc: 0.8927 - lr: 1.0000e-04
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3595 - output_1_loss: 0.3534 - output_2_loss: 0.0602 - output_1_iou_score: 0.4204 - output_1_dice_coeff: 0.6660 - output_1_precision: 0.7823 - output_1_recall: 0.7212 - output_1_sensitivity: 0.6689 - output_1_specificity: 0.9940 - output_1_auc: 0.9236
# Epoch 1: val_output_1_loss did not improve from 0.35894
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3595 - output_1_loss: 0.3534 - output_2_loss: 0.0602 - output_1_iou_score: 0.4204 - output_1_dice_coeff: 0.6660 - output_1_precision: 0.7823 - output_1_recall: 0.7212 - output_1_sensitivity: 0.6689 - output_1_specificity: 0.9940 - output_1_auc: 0.9236 - val_loss: 0.4462 - val_output_1_loss: 0.4358 - val_output_2_loss: 0.1038 - val_output_1_iou_score: 0.3797 - val_output_1_dice_coeff: 0.5845 - val_output_1_precision: 0.6341 - val_output_1_recall: 0.7466 - val_output_1_sensitivity: 0.6643 - val_output_1_specificity: 0.9880 - val_output_1_auc: 0.9347 - lr: 1.0000e-04
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3405 - output_1_loss: 0.3358 - output_2_loss: 0.0473 - output_1_iou_score: 0.4203 - output_1_dice_coeff: 0.6819 - output_1_precision: 0.7827 - output_1_recall: 0.7370 - output_1_sensitivity: 0.6825 - output_1_specificity: 0.9938 - output_1_auc: 0.9281
# Epoch 1: val_output_1_loss improved from 0.35894 to 0.35483, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 293ms/step - loss: 0.3405 - output_1_loss: 0.3358 - output_2_loss: 0.0473 - output_1_iou_score: 0.4203 - output_1_dice_coeff: 0.6819 - output_1_precision: 0.7827 - output_1_recall: 0.7370 - output_1_sensitivity: 0.6825 - output_1_specificity: 0.9938 - output_1_auc: 0.9281 - val_loss: 0.3582 - val_output_1_loss: 0.3548 - val_output_2_loss: 0.0341 - val_output_1_iou_score: 0.4056 - val_output_1_dice_coeff: 0.6638 - val_output_1_precision: 0.7220 - val_output_1_recall: 0.7870 - val_output_1_sensitivity: 0.7273 - val_output_1_specificity: 0.9915 - val_output_1_auc: 0.9424 - lr: 1.0000e-04
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3374 - output_1_loss: 0.3351 - output_2_loss: 0.0237 - output_1_iou_score: 0.4232 - output_1_dice_coeff: 0.6827 - output_1_precision: 0.7817 - output_1_recall: 0.7286 - output_1_sensitivity: 0.6871 - output_1_specificity: 0.9940 - output_1_auc: 0.9260
# Epoch 1: val_output_1_loss improved from 0.35483 to 0.34446, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3374 - output_1_loss: 0.3351 - output_2_loss: 0.0237 - output_1_iou_score: 0.4232 - output_1_dice_coeff: 0.6827 - output_1_precision: 0.7817 - output_1_recall: 0.7286 - output_1_sensitivity: 0.6871 - output_1_specificity: 0.9940 - output_1_auc: 0.9260 - val_loss: 0.3499 - val_output_1_loss: 0.3445 - val_output_2_loss: 0.0542 - val_output_1_iou_score: 0.4085 - val_output_1_dice_coeff: 0.6721 - val_output_1_precision: 0.8135 - val_output_1_recall: 0.7326 - val_output_1_sensitivity: 0.6406 - val_output_1_specificity: 0.9953 - val_output_1_auc: 0.9256 - lr: 1.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3409 - output_1_loss: 0.3358 - output_2_loss: 0.0516 - output_1_iou_score: 0.4261 - output_1_dice_coeff: 0.6829 - output_1_precision: 0.7798 - output_1_recall: 0.7360 - output_1_sensitivity: 0.6848 - output_1_specificity: 0.9938 - output_1_auc: 0.9275
# Epoch 1: val_output_1_loss improved from 0.34446 to 0.33768, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3409 - output_1_loss: 0.3358 - output_2_loss: 0.0516 - output_1_iou_score: 0.4261 - output_1_dice_coeff: 0.6829 - output_1_precision: 0.7798 - output_1_recall: 0.7360 - output_1_sensitivity: 0.6848 - output_1_specificity: 0.9938 - output_1_auc: 0.9275 - val_loss: 0.3488 - val_output_1_loss: 0.3377 - val_output_2_loss: 0.1109 - val_output_1_iou_score: 0.4245 - val_output_1_dice_coeff: 0.6808 - val_output_1_precision: 0.7798 - val_output_1_recall: 0.7239 - val_output_1_sensitivity: 0.6795 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9252 - lr: 1.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3317 - output_1_loss: 0.3253 - output_2_loss: 0.0645 - output_1_iou_score: 0.4302 - output_1_dice_coeff: 0.6926 - output_1_precision: 0.7810 - output_1_recall: 0.7363 - output_1_sensitivity: 0.6915 - output_1_specificity: 0.9938 - output_1_auc: 0.9303
# Epoch 1: val_output_1_loss did not improve from 0.33768
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3317 - output_1_loss: 0.3253 - output_2_loss: 0.0645 - output_1_iou_score: 0.4302 - output_1_dice_coeff: 0.6926 - output_1_precision: 0.7810 - output_1_recall: 0.7363 - output_1_sensitivity: 0.6915 - output_1_specificity: 0.9938 - output_1_auc: 0.9303 - val_loss: 0.3701 - val_output_1_loss: 0.3633 - val_output_2_loss: 0.0675 - val_output_1_iou_score: 0.3889 - val_output_1_dice_coeff: 0.6552 - val_output_1_precision: 0.6993 - val_output_1_recall: 0.8211 - val_output_1_sensitivity: 0.7558 - val_output_1_specificity: 0.9901 - val_output_1_auc: 0.9533 - lr: 1.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3324 - output_1_loss: 0.3249 - output_2_loss: 0.0753 - output_1_iou_score: 0.4341 - output_1_dice_coeff: 0.6946 - output_1_precision: 0.7905 - output_1_recall: 0.7294 - output_1_sensitivity: 0.6959 - output_1_specificity: 0.9942 - output_1_auc: 0.9227
# Epoch 1: val_output_1_loss improved from 0.33768 to 0.33610, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.3324 - output_1_loss: 0.3249 - output_2_loss: 0.0753 - output_1_iou_score: 0.4341 - output_1_dice_coeff: 0.6946 - output_1_precision: 0.7905 - output_1_recall: 0.7294 - output_1_sensitivity: 0.6959 - output_1_specificity: 0.9942 - output_1_auc: 0.9227 - val_loss: 0.3464 - val_output_1_loss: 0.3361 - val_output_2_loss: 0.1028 - val_output_1_iou_score: 0.4213 - val_output_1_dice_coeff: 0.6807 - val_output_1_precision: 0.7732 - val_output_1_recall: 0.7306 - val_output_1_sensitivity: 0.6873 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9355 - lr: 1.0000e-04
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3402 - output_1_loss: 0.3324 - output_2_loss: 0.0774 - output_1_iou_score: 0.4267 - output_1_dice_coeff: 0.6864 - output_1_precision: 0.7806 - output_1_recall: 0.7386 - output_1_sensitivity: 0.6901 - output_1_specificity: 0.9938 - output_1_auc: 0.9296
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3402 - output_1_loss: 0.3324 - output_2_loss: 0.0774 - output_1_iou_score: 0.4267 - output_1_dice_coeff: 0.6864 - output_1_precision: 0.7806 - output_1_recall: 0.7386 - output_1_sensitivity: 0.6901 - output_1_specificity: 0.9938 - output_1_auc: 0.9296 - val_loss: 0.3939 - val_output_1_loss: 0.3885 - val_output_2_loss: 0.0539 - val_output_1_iou_score: 0.3670 - val_output_1_dice_coeff: 0.6333 - val_output_1_precision: 0.6620 - val_output_1_recall: 0.8325 - val_output_1_sensitivity: 0.7823 - val_output_1_specificity: 0.9881 - val_output_1_auc: 0.9543 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3427 - output_1_loss: 0.3371 - output_2_loss: 0.0559 - output_1_iou_score: 0.4246 - output_1_dice_coeff: 0.6816 - output_1_precision: 0.7775 - output_1_recall: 0.7232 - output_1_sensitivity: 0.6876 - output_1_specificity: 0.9938 - output_1_auc: 0.9249
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3427 - output_1_loss: 0.3371 - output_2_loss: 0.0559 - output_1_iou_score: 0.4246 - output_1_dice_coeff: 0.6816 - output_1_precision: 0.7775 - output_1_recall: 0.7232 - output_1_sensitivity: 0.6876 - output_1_specificity: 0.9938 - output_1_auc: 0.9249 - val_loss: 0.4388 - val_output_1_loss: 0.4329 - val_output_2_loss: 0.0591 - val_output_1_iou_score: 0.3561 - val_output_1_dice_coeff: 0.5874 - val_output_1_precision: 0.6185 - val_output_1_recall: 0.7899 - val_output_1_sensitivity: 0.7330 - val_output_1_specificity: 0.9864 - val_output_1_auc: 0.9523 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3455 - output_1_loss: 0.3313 - output_2_loss: 0.1419 - output_1_iou_score: 0.4272 - output_1_dice_coeff: 0.6866 - output_1_precision: 0.7892 - output_1_recall: 0.7435 - output_1_sensitivity: 0.6954 - output_1_specificity: 0.9940 - output_1_auc: 0.9319
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3455 - output_1_loss: 0.3313 - output_2_loss: 0.1419 - output_1_iou_score: 0.4272 - output_1_dice_coeff: 0.6866 - output_1_precision: 0.7892 - output_1_recall: 0.7435 - output_1_sensitivity: 0.6954 - output_1_specificity: 0.9940 - output_1_auc: 0.9319 - val_loss: 0.3434 - val_output_1_loss: 0.3363 - val_output_2_loss: 0.0709 - val_output_1_iou_score: 0.4219 - val_output_1_dice_coeff: 0.6791 - val_output_1_precision: 0.7617 - val_output_1_recall: 0.7821 - val_output_1_sensitivity: 0.7113 - val_output_1_specificity: 0.9931 - val_output_1_auc: 0.9459 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3332 - output_1_loss: 0.3246 - output_2_loss: 0.0860 - output_1_iou_score: 0.4348 - output_1_dice_coeff: 0.6935 - output_1_precision: 0.7942 - output_1_recall: 0.7481 - output_1_sensitivity: 0.6948 - output_1_specificity: 0.9942 - output_1_auc: 0.9318
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3332 - output_1_loss: 0.3246 - output_2_loss: 0.0860 - output_1_iou_score: 0.4348 - output_1_dice_coeff: 0.6935 - output_1_precision: 0.7942 - output_1_recall: 0.7481 - output_1_sensitivity: 0.6948 - output_1_specificity: 0.9942 - output_1_auc: 0.9318 - val_loss: 0.3646 - val_output_1_loss: 0.3559 - val_output_2_loss: 0.0862 - val_output_1_iou_score: 0.4099 - val_output_1_dice_coeff: 0.6651 - val_output_1_precision: 0.7156 - val_output_1_recall: 0.7386 - val_output_1_sensitivity: 0.7268 - val_output_1_specificity: 0.9917 - val_output_1_auc: 0.9208 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3393 - output_1_loss: 0.3337 - output_2_loss: 0.0559 - output_1_iou_score: 0.4260 - output_1_dice_coeff: 0.6842 - output_1_precision: 0.7930 - output_1_recall: 0.7341 - output_1_sensitivity: 0.6849 - output_1_specificity: 0.9943 - output_1_auc: 0.9279
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3393 - output_1_loss: 0.3337 - output_2_loss: 0.0559 - output_1_iou_score: 0.4260 - output_1_dice_coeff: 0.6842 - output_1_precision: 0.7930 - output_1_recall: 0.7341 - output_1_sensitivity: 0.6849 - output_1_specificity: 0.9943 - output_1_auc: 0.9279 - val_loss: 0.4186 - val_output_1_loss: 0.4102 - val_output_2_loss: 0.0836 - val_output_1_iou_score: 0.3882 - val_output_1_dice_coeff: 0.6118 - val_output_1_precision: 0.6607 - val_output_1_recall: 0.7643 - val_output_1_sensitivity: 0.6748 - val_output_1_specificity: 0.9890 - val_output_1_auc: 0.9372 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3446 - output_1_loss: 0.3343 - output_2_loss: 0.1032 - output_1_iou_score: 0.4182 - output_1_dice_coeff: 0.6852 - output_1_precision: 0.7801 - output_1_recall: 0.7296 - output_1_sensitivity: 0.6920 - output_1_specificity: 0.9939 - output_1_auc: 0.9260
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3446 - output_1_loss: 0.3343 - output_2_loss: 0.1032 - output_1_iou_score: 0.4182 - output_1_dice_coeff: 0.6852 - output_1_precision: 0.7801 - output_1_recall: 0.7296 - output_1_sensitivity: 0.6920 - output_1_specificity: 0.9939 - output_1_auc: 0.9260 - val_loss: 0.3450 - val_output_1_loss: 0.3370 - val_output_2_loss: 0.0804 - val_output_1_iou_score: 0.4158 - val_output_1_dice_coeff: 0.6793 - val_output_1_precision: 0.7761 - val_output_1_recall: 0.7091 - val_output_1_sensitivity: 0.6841 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9344 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3450 - output_1_loss: 0.3300 - output_2_loss: 0.1505 - output_1_iou_score: 0.4299 - output_1_dice_coeff: 0.6882 - output_1_precision: 0.7928 - output_1_recall: 0.7437 - output_1_sensitivity: 0.6909 - output_1_specificity: 0.9941 - output_1_auc: 0.9314
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3450 - output_1_loss: 0.3300 - output_2_loss: 0.1505 - output_1_iou_score: 0.4299 - output_1_dice_coeff: 0.6882 - output_1_precision: 0.7928 - output_1_recall: 0.7437 - output_1_sensitivity: 0.6909 - output_1_specificity: 0.9941 - output_1_auc: 0.9314 - val_loss: 0.3895 - val_output_1_loss: 0.3808 - val_output_2_loss: 0.0874 - val_output_1_iou_score: 0.3799 - val_output_1_dice_coeff: 0.6384 - val_output_1_precision: 0.6953 - val_output_1_recall: 0.7369 - val_output_1_sensitivity: 0.7241 - val_output_1_specificity: 0.9909 - val_output_1_auc: 0.9351 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3380 - output_1_loss: 0.3298 - output_2_loss: 0.0817 - output_1_iou_score: 0.4262 - output_1_dice_coeff: 0.6888 - output_1_precision: 0.7879 - output_1_recall: 0.7342 - output_1_sensitivity: 0.6905 - output_1_specificity: 0.9940 - output_1_auc: 0.9299
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3380 - output_1_loss: 0.3298 - output_2_loss: 0.0817 - output_1_iou_score: 0.4262 - output_1_dice_coeff: 0.6888 - output_1_precision: 0.7879 - output_1_recall: 0.7342 - output_1_sensitivity: 0.6905 - output_1_specificity: 0.9940 - output_1_auc: 0.9299 - val_loss: 0.3864 - val_output_1_loss: 0.3756 - val_output_2_loss: 0.1079 - val_output_1_iou_score: 0.3830 - val_output_1_dice_coeff: 0.6446 - val_output_1_precision: 0.6849 - val_output_1_recall: 0.8199 - val_output_1_sensitivity: 0.7473 - val_output_1_specificity: 0.9894 - val_output_1_auc: 0.9483 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3559 - output_1_loss: 0.3328 - output_2_loss: 0.2308 - output_1_iou_score: 0.4272 - output_1_dice_coeff: 0.6869 - output_1_precision: 0.7958 - output_1_recall: 0.7212 - output_1_sensitivity: 0.6876 - output_1_specificity: 0.9944 - output_1_auc: 0.9234
# Epoch 1: val_output_1_loss did not improve from 0.33610
# 233/233 [==============================] - 68s 290ms/step - loss: 0.3559 - output_1_loss: 0.3328 - output_2_loss: 0.2308 - output_1_iou_score: 0.4272 - output_1_dice_coeff: 0.6869 - output_1_precision: 0.7958 - output_1_recall: 0.7212 - output_1_sensitivity: 0.6876 - output_1_specificity: 0.9944 - output_1_auc: 0.9234 - val_loss: 0.5033 - val_output_1_loss: 0.4383 - val_output_2_loss: 0.6498 - val_output_1_iou_score: 0.3695 - val_output_1_dice_coeff: 0.5877 - val_output_1_precision: 0.5881 - val_output_1_recall: 0.8298 - val_output_1_sensitivity: 0.7653 - val_output_1_specificity: 0.9838 - val_output_1_auc: 0.9538 - lr: 1.0000e-04
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4185 - output_1_loss: 0.3199 - output_2_loss: 0.9859 - output_1_iou_score: 0.4326 - output_1_dice_coeff: 0.6975 - output_1_precision: 0.7861 - output_1_recall: 0.7510 - output_1_sensitivity: 0.7030 - output_1_specificity: 0.9939 - output_1_auc: 0.9330
# Epoch 1: val_output_1_loss improved from 0.33610 to 0.32926, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.4185 - output_1_loss: 0.3199 - output_2_loss: 0.9859 - output_1_iou_score: 0.4326 - output_1_dice_coeff: 0.6975 - output_1_precision: 0.7861 - output_1_recall: 0.7510 - output_1_sensitivity: 0.7030 - output_1_specificity: 0.9939 - output_1_auc: 0.9330 - val_loss: 0.4275 - val_output_1_loss: 0.3293 - val_output_2_loss: 0.9828 - val_output_1_iou_score: 0.4279 - val_output_1_dice_coeff: 0.6859 - val_output_1_precision: 0.8481 - val_output_1_recall: 0.7130 - val_output_1_sensitivity: 0.6333 - val_output_1_specificity: 0.9964 - val_output_1_auc: 0.9249 - lr: 1.0000e-04
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4248 - output_1_loss: 0.3248 - output_2_loss: 1.0000 - output_1_iou_score: 0.4345 - output_1_dice_coeff: 0.6919 - output_1_precision: 0.7947 - output_1_recall: 0.7466 - output_1_sensitivity: 0.6960 - output_1_specificity: 0.9942 - output_1_auc: 0.9315
# Epoch 1: val_output_1_loss did not improve from 0.32926
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4248 - output_1_loss: 0.3248 - output_2_loss: 1.0000 - output_1_iou_score: 0.4345 - output_1_dice_coeff: 0.6919 - output_1_precision: 0.7947 - output_1_recall: 0.7466 - output_1_sensitivity: 0.6960 - output_1_specificity: 0.9942 - output_1_auc: 0.9315 - val_loss: 0.4302 - val_output_1_loss: 0.3337 - val_output_2_loss: 0.9655 - val_output_1_iou_score: 0.4307 - val_output_1_dice_coeff: 0.6827 - val_output_1_precision: 0.7882 - val_output_1_recall: 0.7013 - val_output_1_sensitivity: 0.6718 - val_output_1_specificity: 0.9947 - val_output_1_auc: 0.9339 - lr: 1.0000e-04
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4157 - output_1_loss: 0.3157 - output_2_loss: 1.0000 - output_1_iou_score: 0.4384 - output_1_dice_coeff: 0.7019 - output_1_precision: 0.7970 - output_1_recall: 0.7513 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9943 - output_1_auc: 0.9330
# Epoch 1: val_output_1_loss did not improve from 0.32926
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4157 - output_1_loss: 0.3157 - output_2_loss: 1.0000 - output_1_iou_score: 0.4384 - output_1_dice_coeff: 0.7019 - output_1_precision: 0.7970 - output_1_recall: 0.7513 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9943 - output_1_auc: 0.9330 - val_loss: 0.4553 - val_output_1_loss: 0.3588 - val_output_2_loss: 0.9655 - val_output_1_iou_score: 0.4151 - val_output_1_dice_coeff: 0.6602 - val_output_1_precision: 0.7798 - val_output_1_recall: 0.6795 - val_output_1_sensitivity: 0.6563 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.8993 - lr: 1.0000e-04
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4153 - output_1_loss: 0.3153 - output_2_loss: 1.0000 - output_1_iou_score: 0.4370 - output_1_dice_coeff: 0.7027 - output_1_precision: 0.7998 - output_1_recall: 0.7478 - output_1_sensitivity: 0.7005 - output_1_specificity: 0.9943 - output_1_auc: 0.9321
# Epoch 1: val_output_1_loss did not improve from 0.32926
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4153 - output_1_loss: 0.3153 - output_2_loss: 1.0000 - output_1_iou_score: 0.4370 - output_1_dice_coeff: 0.7027 - output_1_precision: 0.7998 - output_1_recall: 0.7478 - output_1_sensitivity: 0.7005 - output_1_specificity: 0.9943 - output_1_auc: 0.9321 - val_loss: 0.4381 - val_output_1_loss: 0.3381 - val_output_2_loss: 1.0000 - val_output_1_iou_score: 0.4217 - val_output_1_dice_coeff: 0.6791 - val_output_1_precision: 0.7495 - val_output_1_recall: 0.7628 - val_output_1_sensitivity: 0.7153 - val_output_1_specificity: 0.9928 - val_output_1_auc: 0.9429 - lr: 1.0000e-04
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4232 - output_1_loss: 0.3232 - output_2_loss: 1.0000 - output_1_iou_score: 0.4384 - output_1_dice_coeff: 0.6932 - output_1_precision: 0.7956 - output_1_recall: 0.7477 - output_1_sensitivity: 0.6905 - output_1_specificity: 0.9942 - output_1_auc: 0.9333
# Epoch 1: val_output_1_loss improved from 0.32926 to 0.32400, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 293ms/step - loss: 0.4232 - output_1_loss: 0.3232 - output_2_loss: 1.0000 - output_1_iou_score: 0.4384 - output_1_dice_coeff: 0.6932 - output_1_precision: 0.7956 - output_1_recall: 0.7477 - output_1_sensitivity: 0.6905 - output_1_specificity: 0.9942 - output_1_auc: 0.9333 - val_loss: 0.4182 - val_output_1_loss: 0.3240 - val_output_2_loss: 0.9421 - val_output_1_iou_score: 0.4290 - val_output_1_dice_coeff: 0.6925 - val_output_1_precision: 0.8059 - val_output_1_recall: 0.7506 - val_output_1_sensitivity: 0.6719 - val_output_1_specificity: 0.9949 - val_output_1_auc: 0.9315 - lr: 1.0000e-04
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4163 - output_1_loss: 0.3163 - output_2_loss: 1.0000 - output_1_iou_score: 0.4457 - output_1_dice_coeff: 0.7010 - output_1_precision: 0.8013 - output_1_recall: 0.7561 - output_1_sensitivity: 0.7003 - output_1_specificity: 0.9944 - output_1_auc: 0.9350
# Epoch 1: val_output_1_loss did not improve from 0.32400
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4163 - output_1_loss: 0.3163 - output_2_loss: 1.0000 - output_1_iou_score: 0.4457 - output_1_dice_coeff: 0.7010 - output_1_precision: 0.8013 - output_1_recall: 0.7561 - output_1_sensitivity: 0.7003 - output_1_specificity: 0.9944 - output_1_auc: 0.9350 - val_loss: 0.6054 - val_output_1_loss: 0.5074 - val_output_2_loss: 0.9796 - val_output_1_iou_score: 0.2946 - val_output_1_dice_coeff: 0.5293 - val_output_1_precision: 0.6769 - val_output_1_recall: 0.6089 - val_output_1_sensitivity: 0.5432 - val_output_1_specificity: 0.9919 - val_output_1_auc: 0.8470 - lr: 1.0000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4160 - output_1_loss: 0.3160 - output_2_loss: 1.0000 - output_1_iou_score: 0.4357 - output_1_dice_coeff: 0.7026 - output_1_precision: 0.7942 - output_1_recall: 0.7359 - output_1_sensitivity: 0.7026 - output_1_specificity: 0.9943 - output_1_auc: 0.9292
# Epoch 1: val_output_1_loss did not improve from 0.32400
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4160 - output_1_loss: 0.3160 - output_2_loss: 1.0000 - output_1_iou_score: 0.4357 - output_1_dice_coeff: 0.7026 - output_1_precision: 0.7942 - output_1_recall: 0.7359 - output_1_sensitivity: 0.7026 - output_1_specificity: 0.9943 - output_1_auc: 0.9292 - val_loss: 0.4676 - val_output_1_loss: 0.3676 - val_output_2_loss: 1.0000 - val_output_1_iou_score: 0.3977 - val_output_1_dice_coeff: 0.6493 - val_output_1_precision: 0.8542 - val_output_1_recall: 0.6159 - val_output_1_sensitivity: 0.5786 - val_output_1_specificity: 0.9970 - val_output_1_auc: 0.9104 - lr: 1.0000e-04
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4095 - output_1_loss: 0.3095 - output_2_loss: 1.0000 - output_1_iou_score: 0.4423 - output_1_dice_coeff: 0.7076 - output_1_precision: 0.8021 - output_1_recall: 0.7559 - output_1_sensitivity: 0.7022 - output_1_specificity: 0.9945 - output_1_auc: 0.9344
# Epoch 1: val_output_1_loss did not improve from 0.32400
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4095 - output_1_loss: 0.3095 - output_2_loss: 1.0000 - output_1_iou_score: 0.4423 - output_1_dice_coeff: 0.7076 - output_1_precision: 0.8021 - output_1_recall: 0.7559 - output_1_sensitivity: 0.7022 - output_1_specificity: 0.9945 - output_1_auc: 0.9344 - val_loss: 0.4267 - val_output_1_loss: 0.3332 - val_output_2_loss: 0.9344 - val_output_1_iou_score: 0.4309 - val_output_1_dice_coeff: 0.6846 - val_output_1_precision: 0.8292 - val_output_1_recall: 0.6695 - val_output_1_sensitivity: 0.6365 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9140 - lr: 1.0000e-04
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4205 - output_1_loss: 0.3205 - output_2_loss: 1.0000 - output_1_iou_score: 0.4461 - output_1_dice_coeff: 0.6971 - output_1_precision: 0.7971 - output_1_recall: 0.7543 - output_1_sensitivity: 0.6972 - output_1_specificity: 0.9942 - output_1_auc: 0.9336
# Epoch 1: val_output_1_loss did not improve from 0.32400
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4205 - output_1_loss: 0.3205 - output_2_loss: 1.0000 - output_1_iou_score: 0.4461 - output_1_dice_coeff: 0.6971 - output_1_precision: 0.7971 - output_1_recall: 0.7543 - output_1_sensitivity: 0.6972 - output_1_specificity: 0.9942 - output_1_auc: 0.9336 - val_loss: 0.4523 - val_output_1_loss: 0.3558 - val_output_2_loss: 0.9648 - val_output_1_iou_score: 0.4010 - val_output_1_dice_coeff: 0.6651 - val_output_1_precision: 0.7390 - val_output_1_recall: 0.7674 - val_output_1_sensitivity: 0.7152 - val_output_1_specificity: 0.9924 - val_output_1_auc: 0.9317 - lr: 1.0000e-04
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4175 - output_1_loss: 0.3175 - output_2_loss: 1.0000 - output_1_iou_score: 0.4387 - output_1_dice_coeff: 0.6992 - output_1_precision: 0.8021 - output_1_recall: 0.7504 - output_1_sensitivity: 0.6977 - output_1_specificity: 0.9945 - output_1_auc: 0.9325
# Epoch 1: val_output_1_loss did not improve from 0.32400
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4175 - output_1_loss: 0.3175 - output_2_loss: 1.0000 - output_1_iou_score: 0.4387 - output_1_dice_coeff: 0.6992 - output_1_precision: 0.8021 - output_1_recall: 0.7504 - output_1_sensitivity: 0.6977 - output_1_specificity: 0.9945 - output_1_auc: 0.9325 - val_loss: 0.4353 - val_output_1_loss: 0.3369 - val_output_2_loss: 0.9833 - val_output_1_iou_score: 0.4157 - val_output_1_dice_coeff: 0.6818 - val_output_1_precision: 0.8001 - val_output_1_recall: 0.7045 - val_output_1_sensitivity: 0.6552 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9189 - lr: 1.0000e-04
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4195 - output_1_loss: 0.3195 - output_2_loss: 1.0000 - output_1_iou_score: 0.4431 - output_1_dice_coeff: 0.6985 - output_1_precision: 0.7902 - output_1_recall: 0.7498 - output_1_sensitivity: 0.6977 - output_1_specificity: 0.9940 - output_1_auc: 0.9337
# Epoch 1: val_output_1_loss improved from 0.32400 to 0.32273, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.4195 - output_1_loss: 0.3195 - output_2_loss: 1.0000 - output_1_iou_score: 0.4431 - output_1_dice_coeff: 0.6985 - output_1_precision: 0.7902 - output_1_recall: 0.7498 - output_1_sensitivity: 0.6977 - output_1_specificity: 0.9940 - output_1_auc: 0.9337 - val_loss: 0.4201 - val_output_1_loss: 0.3227 - val_output_2_loss: 0.9732 - val_output_1_iou_score: 0.4299 - val_output_1_dice_coeff: 0.6944 - val_output_1_precision: 0.7865 - val_output_1_recall: 0.7786 - val_output_1_sensitivity: 0.6988 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9370 - lr: 1.0000e-04
# Epoch 41/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4051 - output_1_loss: 0.3051 - output_2_loss: 1.0000 - output_1_iou_score: 0.4538 - output_1_dice_coeff: 0.7120 - output_1_precision: 0.8120 - output_1_recall: 0.7577 - output_1_sensitivity: 0.7045 - output_1_specificity: 0.9947 - output_1_auc: 0.9343
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4051 - output_1_loss: 0.3051 - output_2_loss: 1.0000 - output_1_iou_score: 0.4538 - output_1_dice_coeff: 0.7120 - output_1_precision: 0.8120 - output_1_recall: 0.7577 - output_1_sensitivity: 0.7045 - output_1_specificity: 0.9947 - output_1_auc: 0.9343 - val_loss: 0.4396 - val_output_1_loss: 0.3430 - val_output_2_loss: 0.9655 - val_output_1_iou_score: 0.4234 - val_output_1_dice_coeff: 0.6789 - val_output_1_precision: 0.7498 - val_output_1_recall: 0.7226 - val_output_1_sensitivity: 0.7006 - val_output_1_specificity: 0.9932 - val_output_1_auc: 0.9050 - lr: 1.0000e-04
# Epoch 42/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4139 - output_1_loss: 0.3139 - output_2_loss: 1.0000 - output_1_iou_score: 0.4457 - output_1_dice_coeff: 0.7033 - output_1_precision: 0.8028 - output_1_recall: 0.7591 - output_1_sensitivity: 0.7000 - output_1_specificity: 0.9944 - output_1_auc: 0.9358
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4139 - output_1_loss: 0.3139 - output_2_loss: 1.0000 - output_1_iou_score: 0.4457 - output_1_dice_coeff: 0.7033 - output_1_precision: 0.8028 - output_1_recall: 0.7591 - output_1_sensitivity: 0.7000 - output_1_specificity: 0.9944 - output_1_auc: 0.9358 - val_loss: 0.4378 - val_output_1_loss: 0.3413 - val_output_2_loss: 0.9655 - val_output_1_iou_score: 0.4336 - val_output_1_dice_coeff: 0.6822 - val_output_1_precision: 0.8322 - val_output_1_recall: 0.6654 - val_output_1_sensitivity: 0.6331 - val_output_1_specificity: 0.9962 - val_output_1_auc: 0.8889 - lr: 1.0000e-04
# Epoch 43/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4103 - output_1_loss: 0.3103 - output_2_loss: 1.0000 - output_1_iou_score: 0.4550 - output_1_dice_coeff: 0.7061 - output_1_precision: 0.8089 - output_1_recall: 0.7582 - output_1_sensitivity: 0.7051 - output_1_specificity: 0.9946 - output_1_auc: 0.9359
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4103 - output_1_loss: 0.3103 - output_2_loss: 1.0000 - output_1_iou_score: 0.4550 - output_1_dice_coeff: 0.7061 - output_1_precision: 0.8089 - output_1_recall: 0.7582 - output_1_sensitivity: 0.7051 - output_1_specificity: 0.9946 - output_1_auc: 0.9359 - val_loss: 0.4441 - val_output_1_loss: 0.3475 - val_output_2_loss: 0.9665 - val_output_1_iou_score: 0.4075 - val_output_1_dice_coeff: 0.6712 - val_output_1_precision: 0.7461 - val_output_1_recall: 0.7841 - val_output_1_sensitivity: 0.7240 - val_output_1_specificity: 0.9925 - val_output_1_auc: 0.9412 - lr: 1.0000e-04
# Epoch 44/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4087 - output_1_loss: 0.3087 - output_2_loss: 1.0000 - output_1_iou_score: 0.4455 - output_1_dice_coeff: 0.7083 - output_1_precision: 0.8065 - output_1_recall: 0.7527 - output_1_sensitivity: 0.7037 - output_1_specificity: 0.9946 - output_1_auc: 0.9346
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4087 - output_1_loss: 0.3087 - output_2_loss: 1.0000 - output_1_iou_score: 0.4455 - output_1_dice_coeff: 0.7083 - output_1_precision: 0.8065 - output_1_recall: 0.7527 - output_1_sensitivity: 0.7037 - output_1_specificity: 0.9946 - output_1_auc: 0.9346 - val_loss: 0.6295 - val_output_1_loss: 0.5312 - val_output_2_loss: 0.9828 - val_output_1_iou_score: 0.3001 - val_output_1_dice_coeff: 0.4939 - val_output_1_precision: 0.5990 - val_output_1_recall: 0.5465 - val_output_1_sensitivity: 0.5593 - val_output_1_specificity: 0.9898 - val_output_1_auc: 0.8617 - lr: 1.0000e-04
# Epoch 45/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4123 - output_1_loss: 0.3123 - output_2_loss: 1.0000 - output_1_iou_score: 0.4510 - output_1_dice_coeff: 0.7047 - output_1_precision: 0.8043 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7041 - output_1_specificity: 0.9945 - output_1_auc: 0.9340
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4123 - output_1_loss: 0.3123 - output_2_loss: 1.0000 - output_1_iou_score: 0.4510 - output_1_dice_coeff: 0.7047 - output_1_precision: 0.8043 - output_1_recall: 0.7520 - output_1_sensitivity: 0.7041 - output_1_specificity: 0.9945 - output_1_auc: 0.9340 - val_loss: 0.4713 - val_output_1_loss: 0.3729 - val_output_2_loss: 0.9834 - val_output_1_iou_score: 0.3943 - val_output_1_dice_coeff: 0.6533 - val_output_1_precision: 0.8649 - val_output_1_recall: 0.6007 - val_output_1_sensitivity: 0.5752 - val_output_1_specificity: 0.9974 - val_output_1_auc: 0.8641 - lr: 1.0000e-04
# Epoch 46/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4049 - output_1_loss: 0.3049 - output_2_loss: 1.0000 - output_1_iou_score: 0.4467 - output_1_dice_coeff: 0.7106 - output_1_precision: 0.8080 - output_1_recall: 0.7521 - output_1_sensitivity: 0.7078 - output_1_specificity: 0.9947 - output_1_auc: 0.9339
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4049 - output_1_loss: 0.3049 - output_2_loss: 1.0000 - output_1_iou_score: 0.4467 - output_1_dice_coeff: 0.7106 - output_1_precision: 0.8080 - output_1_recall: 0.7521 - output_1_sensitivity: 0.7078 - output_1_specificity: 0.9947 - output_1_auc: 0.9339 - val_loss: 0.4705 - val_output_1_loss: 0.3740 - val_output_2_loss: 0.9655 - val_output_1_iou_score: 0.3988 - val_output_1_dice_coeff: 0.6515 - val_output_1_precision: 0.8392 - val_output_1_recall: 0.6150 - val_output_1_sensitivity: 0.5942 - val_output_1_specificity: 0.9967 - val_output_1_auc: 0.8657 - lr: 1.0000e-04
# Epoch 47/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4113 - output_1_loss: 0.3113 - output_2_loss: 1.0000 - output_1_iou_score: 0.4480 - output_1_dice_coeff: 0.7055 - output_1_precision: 0.8072 - output_1_recall: 0.7555 - output_1_sensitivity: 0.7041 - output_1_specificity: 0.9946 - output_1_auc: 0.9351
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4113 - output_1_loss: 0.3113 - output_2_loss: 1.0000 - output_1_iou_score: 0.4480 - output_1_dice_coeff: 0.7055 - output_1_precision: 0.8072 - output_1_recall: 0.7555 - output_1_sensitivity: 0.7041 - output_1_specificity: 0.9946 - output_1_auc: 0.9351 - val_loss: 0.4735 - val_output_1_loss: 0.3786 - val_output_2_loss: 0.9483 - val_output_1_iou_score: 0.3700 - val_output_1_dice_coeff: 0.6429 - val_output_1_precision: 0.6985 - val_output_1_recall: 0.7705 - val_output_1_sensitivity: 0.7548 - val_output_1_specificity: 0.9907 - val_output_1_auc: 0.9385 - lr: 1.0000e-04
# Epoch 48/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4080 - output_1_loss: 0.3080 - output_2_loss: 1.0000 - output_1_iou_score: 0.4524 - output_1_dice_coeff: 0.7095 - output_1_precision: 0.8089 - output_1_recall: 0.7619 - output_1_sensitivity: 0.7068 - output_1_specificity: 0.9946 - output_1_auc: 0.9352
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4080 - output_1_loss: 0.3080 - output_2_loss: 1.0000 - output_1_iou_score: 0.4524 - output_1_dice_coeff: 0.7095 - output_1_precision: 0.8089 - output_1_recall: 0.7619 - output_1_sensitivity: 0.7068 - output_1_specificity: 0.9946 - output_1_auc: 0.9352 - val_loss: 0.4484 - val_output_1_loss: 0.3546 - val_output_2_loss: 0.9386 - val_output_1_iou_score: 0.4078 - val_output_1_dice_coeff: 0.6660 - val_output_1_precision: 0.7444 - val_output_1_recall: 0.7178 - val_output_1_sensitivity: 0.7049 - val_output_1_specificity: 0.9931 - val_output_1_auc: 0.9071 - lr: 1.0000e-04
# Epoch 49/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4111 - output_1_loss: 0.3111 - output_2_loss: 1.0000 - output_1_iou_score: 0.4542 - output_1_dice_coeff: 0.7054 - output_1_precision: 0.8079 - output_1_recall: 0.7635 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9945 - output_1_auc: 0.9362
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4111 - output_1_loss: 0.3111 - output_2_loss: 1.0000 - output_1_iou_score: 0.4542 - output_1_dice_coeff: 0.7054 - output_1_precision: 0.8079 - output_1_recall: 0.7635 - output_1_sensitivity: 0.7023 - output_1_specificity: 0.9945 - output_1_auc: 0.9362 - val_loss: 0.4362 - val_output_1_loss: 0.3379 - val_output_2_loss: 0.9828 - val_output_1_iou_score: 0.4293 - val_output_1_dice_coeff: 0.6815 - val_output_1_precision: 0.7581 - val_output_1_recall: 0.7242 - val_output_1_sensitivity: 0.7129 - val_output_1_specificity: 0.9935 - val_output_1_auc: 0.9182 - lr: 1.0000e-04
# Epoch 50/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4007 - output_1_loss: 0.3007 - output_2_loss: 1.0000 - output_1_iou_score: 0.4591 - output_1_dice_coeff: 0.7157 - output_1_precision: 0.8077 - output_1_recall: 0.7647 - output_1_sensitivity: 0.7094 - output_1_specificity: 0.9946 - output_1_auc: 0.9371
# Epoch 1: val_output_1_loss did not improve from 0.32273
# 233/233 [==============================] - 69s 294ms/step - loss: 0.4007 - output_1_loss: 0.3007 - output_2_loss: 1.0000 - output_1_iou_score: 0.4591 - output_1_dice_coeff: 0.7157 - output_1_precision: 0.8077 - output_1_recall: 0.7647 - output_1_sensitivity: 0.7094 - output_1_specificity: 0.9946 - output_1_auc: 0.9371 - val_loss: 0.4360 - val_output_1_loss: 0.3368 - val_output_2_loss: 0.9922 - val_output_1_iou_score: 0.4360 - val_output_1_dice_coeff: 0.6878 - val_output_1_precision: 0.7833 - val_output_1_recall: 0.7055 - val_output_1_sensitivity: 0.6799 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.8979 - lr: 1.0000e-04
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_iou_score', 'output_1_dice_coeff', 'output_1_precision', 'output_1_recall', 'output_1_sensitivity', 'output_1_specificity', 'output_1_auc', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_iou_score', 'val_output_1_dice_coeff', 'val_output_1_precision', 'val_output_1_recall', 'val_output_1_sensitivity', 'val_output_1_specificity', 'val_output_1_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %%
"""from tensorflow.keras.models import load_model

custom_objects = {'total_loss': total_loss,
                  '<lambda>': lambda y_true, y_pred: y_pred,
                  'iou_score':iou_score,
                  'dice_coeff':dice_coeff,
                  'precision':tf.keras.metrics.Precision(),
                  'recall':tf.keras.metrics.Recall(),
                  'sensitivity':sensitivity,
                  'specificity':specificity
                 }

with tf.keras.utils.custom_object_scope(custom_objects):
    model = load_model('/kaggle/working/final_model.h5')"""
# Out:
# "from tensorflow.keras.models import load_model\n\ncustom_objects = {'total_loss': total_loss,\n                  '<lambda>': lambda y_true, y_pred: y_pred,\n                  'iou_score':iou_score,\n                  'dice_coeff':dice_coeff,\n                  'precision':tf.keras.metrics.Precision(),\n                  'recall':tf.keras.metrics.Recall(),\n                  'sensitivity':sensitivity,\n                  'specificity':specificity\n                 }\n\nwith tf.keras.utils.custom_object_scope(custom_objects):\n    model = load_model('/kaggle/working/final_model.h5')"

# %% [markdown]
# Im going for this method instead...more efficient

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model = build_WNet((256,256,3))

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00005), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5", 
                               monitor='val_output_1_loss',
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor="val_output_1_loss", factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-23 11:15:36.753895: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.4063 - output_1_loss: 0.3063 - output_2_loss: 1.0000 - output_1_iou_score: 0.4570 - output_1_dice_coeff: 0.7103 - output_1_precision_1: 0.8048 - output_1_recall_1: 0.7614 - output_1_sensitivity: 0.7097 - output_1_specificity: 0.9945 - output_1_auc_1: 0.9371
# Epoch 1: val_output_1_loss improved from inf to 0.36872, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 106s 300ms/step - loss: 0.4063 - output_1_loss: 0.3063 - output_2_loss: 1.0000 - output_1_iou_score: 0.4570 - output_1_dice_coeff: 0.7103 - output_1_precision_1: 0.8048 - output_1_recall_1: 0.7614 - output_1_sensitivity: 0.7097 - output_1_specificity: 0.9945 - output_1_auc_1: 0.9371 - val_loss: 0.4635 - val_output_1_loss: 0.3687 - val_output_2_loss: 0.9483 - val_output_1_iou_score: 0.4103 - val_output_1_dice_coeff: 0.6524 - val_output_1_precision_1: 0.8044 - val_output_1_recall_1: 0.6339 - val_output_1_sensitivity: 0.6239 - val_output_1_specificity: 0.9957 - val_output_1_auc_1: 0.8803 - lr: 5.0000e-05
# Epoch 2/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4013 - output_1_loss: 0.3013 - output_2_loss: 1.0000 - output_1_iou_score: 0.4564 - output_1_dice_coeff: 0.7156 - output_1_precision_1: 0.8140 - output_1_recall_1: 0.7593 - output_1_sensitivity: 0.7117 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9352
# Epoch 2: val_output_1_loss improved from 0.36872 to 0.34524, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4013 - output_1_loss: 0.3013 - output_2_loss: 1.0000 - output_1_iou_score: 0.4564 - output_1_dice_coeff: 0.7156 - output_1_precision_1: 0.8140 - output_1_recall_1: 0.7593 - output_1_sensitivity: 0.7117 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9352 - val_loss: 0.4415 - val_output_1_loss: 0.3452 - val_output_2_loss: 0.9631 - val_output_1_iou_score: 0.4235 - val_output_1_dice_coeff: 0.6759 - val_output_1_precision_1: 0.8389 - val_output_1_recall_1: 0.6444 - val_output_1_sensitivity: 0.6293 - val_output_1_specificity: 0.9965 - val_output_1_auc_1: 0.8837 - lr: 5.0000e-05
# Epoch 3/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4069 - output_1_loss: 0.3069 - output_2_loss: 1.0000 - output_1_iou_score: 0.4547 - output_1_dice_coeff: 0.7092 - output_1_precision_1: 0.8137 - output_1_recall_1: 0.7605 - output_1_sensitivity: 0.7025 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9378
# Epoch 3: val_output_1_loss improved from 0.34524 to 0.33222, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.4069 - output_1_loss: 0.3069 - output_2_loss: 1.0000 - output_1_iou_score: 0.4547 - output_1_dice_coeff: 0.7092 - output_1_precision_1: 0.8137 - output_1_recall_1: 0.7605 - output_1_sensitivity: 0.7025 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9378 - val_loss: 0.4271 - val_output_1_loss: 0.3322 - val_output_2_loss: 0.9484 - val_output_1_iou_score: 0.4249 - val_output_1_dice_coeff: 0.6853 - val_output_1_precision_1: 0.7447 - val_output_1_recall_1: 0.8017 - val_output_1_sensitivity: 0.7425 - val_output_1_specificity: 0.9923 - val_output_1_auc_1: 0.9491 - lr: 5.0000e-05
# Epoch 4/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4049 - output_1_loss: 0.3049 - output_2_loss: 1.0000 - output_1_iou_score: 0.4510 - output_1_dice_coeff: 0.7117 - output_1_precision_1: 0.7930 - output_1_recall_1: 0.7527 - output_1_sensitivity: 0.7117 - output_1_specificity: 0.9941 - output_1_auc_1: 0.9366
# Epoch 4: val_output_1_loss improved from 0.33222 to 0.31240, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 68s 292ms/step - loss: 0.4049 - output_1_loss: 0.3049 - output_2_loss: 1.0000 - output_1_iou_score: 0.4510 - output_1_dice_coeff: 0.7117 - output_1_precision_1: 0.7930 - output_1_recall_1: 0.7527 - output_1_sensitivity: 0.7117 - output_1_specificity: 0.9941 - output_1_auc_1: 0.9366 - val_loss: 0.4102 - val_output_1_loss: 0.3124 - val_output_2_loss: 0.9782 - val_output_1_iou_score: 0.4407 - val_output_1_dice_coeff: 0.7018 - val_output_1_precision_1: 0.8147 - val_output_1_recall_1: 0.7675 - val_output_1_sensitivity: 0.6862 - val_output_1_specificity: 0.9951 - val_output_1_auc_1: 0.9418 - lr: 5.0000e-05
# Epoch 5/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4064 - output_1_loss: 0.3064 - output_2_loss: 1.0000 - output_1_iou_score: 0.4529 - output_1_dice_coeff: 0.7097 - output_1_precision_1: 0.8108 - output_1_recall_1: 0.7575 - output_1_sensitivity: 0.7029 - output_1_specificity: 0.9947 - output_1_auc_1: 0.9371
# Epoch 5: val_output_1_loss did not improve from 0.31240
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4064 - output_1_loss: 0.3064 - output_2_loss: 1.0000 - output_1_iou_score: 0.4529 - output_1_dice_coeff: 0.7097 - output_1_precision_1: 0.8108 - output_1_recall_1: 0.7575 - output_1_sensitivity: 0.7029 - output_1_specificity: 0.9947 - output_1_auc_1: 0.9371 - val_loss: 0.4266 - val_output_1_loss: 0.3309 - val_output_2_loss: 0.9564 - val_output_1_iou_score: 0.4418 - val_output_1_dice_coeff: 0.6872 - val_output_1_precision_1: 0.7797 - val_output_1_recall_1: 0.7119 - val_output_1_sensitivity: 0.6892 - val_output_1_specificity: 0.9943 - val_output_1_auc_1: 0.9089 - lr: 5.0000e-05
# Epoch 6/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4249 - output_1_loss: 0.3249 - output_2_loss: 1.0000 - output_1_iou_score: 0.4325 - output_1_dice_coeff: 0.6907 - output_1_precision_1: 0.8112 - output_1_recall_1: 0.7460 - output_1_sensitivity: 0.6860 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9379
# Epoch 6: val_output_1_loss did not improve from 0.31240
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4249 - output_1_loss: 0.3249 - output_2_loss: 1.0000 - output_1_iou_score: 0.4325 - output_1_dice_coeff: 0.6907 - output_1_precision_1: 0.8112 - output_1_recall_1: 0.7460 - output_1_sensitivity: 0.6860 - output_1_specificity: 0.9948 - output_1_auc_1: 0.9379 - val_loss: 0.5142 - val_output_1_loss: 0.4142 - val_output_2_loss: 1.0000 - val_output_1_iou_score: 0.3554 - val_output_1_dice_coeff: 0.6046 - val_output_1_precision_1: 0.8037 - val_output_1_recall_1: 0.6073 - val_output_1_sensitivity: 0.5966 - val_output_1_specificity: 0.9958 - val_output_1_auc_1: 0.8883 - lr: 5.0000e-05
# Epoch 7/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4307 - output_1_loss: 0.3307 - output_2_loss: 1.0000 - output_1_iou_score: 0.4149 - output_1_dice_coeff: 0.6845 - output_1_precision_1: 0.8145 - output_1_recall_1: 0.7355 - output_1_sensitivity: 0.6722 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9365
# Epoch 7: val_output_1_loss did not improve from 0.31240
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4307 - output_1_loss: 0.3307 - output_2_loss: 1.0000 - output_1_iou_score: 0.4149 - output_1_dice_coeff: 0.6845 - output_1_precision_1: 0.8145 - output_1_recall_1: 0.7355 - output_1_sensitivity: 0.6722 - output_1_specificity: 0.9950 - output_1_auc_1: 0.9365 - val_loss: 0.5178 - val_output_1_loss: 0.4234 - val_output_2_loss: 0.9431 - val_output_1_iou_score: 0.3415 - val_output_1_dice_coeff: 0.5958 - val_output_1_precision_1: 0.6706 - val_output_1_recall_1: 0.7238 - val_output_1_sensitivity: 0.7282 - val_output_1_specificity: 0.9900 - val_output_1_auc_1: 0.9160 - lr: 5.0000e-05
# Epoch 8/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4221 - output_1_loss: 0.3221 - output_2_loss: 1.0000 - output_1_iou_score: 0.4308 - output_1_dice_coeff: 0.6933 - output_1_precision_1: 0.8150 - output_1_recall_1: 0.7485 - output_1_sensitivity: 0.6822 - output_1_specificity: 0.9949 - output_1_auc_1: 0.9401
# Epoch 8: val_output_1_loss did not improve from 0.31240
# 233/233 [==============================] - 68s 291ms/step - loss: 0.4221 - output_1_loss: 0.3221 - output_2_loss: 1.0000 - output_1_iou_score: 0.4308 - output_1_dice_coeff: 0.6933 - output_1_precision_1: 0.8150 - output_1_recall_1: 0.7485 - output_1_sensitivity: 0.6822 - output_1_specificity: 0.9949 - output_1_auc_1: 0.9401 - val_loss: 0.4569 - val_output_1_loss: 0.3623 - val_output_2_loss: 0.9463 - val_output_1_iou_score: 0.3974 - val_output_1_dice_coeff: 0.6556 - val_output_1_precision_1: 0.7454 - val_output_1_recall_1: 0.7093 - val_output_1_sensitivity: 0.6974 - val_output_1_specificity: 0.9932 - val_output_1_auc_1: 0.9226 - lr: 1.5000e-05
# Epoch 9/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4180 - output_1_loss: 0.3180 - output_2_loss: 1.0000 - output_1_iou_score: 0.4309 - output_1_dice_coeff: 0.6974 - output_1_precision_1: 0.8102 - output_1_recall_1: 0.7533 - output_1_sensitivity: 0.6851 - output_1_specificity: 0.9947 - output_1_auc_1: 0.9399
# Epoch 9: val_output_1_loss did not improve from 0.31240
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4180 - output_1_loss: 0.3180 - output_2_loss: 1.0000 - output_1_iou_score: 0.4309 - output_1_dice_coeff: 0.6974 - output_1_precision_1: 0.8102 - output_1_recall_1: 0.7533 - output_1_sensitivity: 0.6851 - output_1_specificity: 0.9947 - output_1_auc_1: 0.9399 - val_loss: 0.4544 - val_output_1_loss: 0.3583 - val_output_2_loss: 0.9609 - val_output_1_iou_score: 0.4013 - val_output_1_dice_coeff: 0.6605 - val_output_1_precision_1: 0.7483 - val_output_1_recall_1: 0.7136 - val_output_1_sensitivity: 0.6983 - val_output_1_specificity: 0.9932 - val_output_1_auc_1: 0.9173 - lr: 1.5000e-05
# Epoch 10/10
# 233/233 [==============================] - ETA: 0s - loss: 0.4250 - output_1_loss: 0.3250 - output_2_loss: 1.0000 - output_1_iou_score: 0.4318 - output_1_dice_coeff: 0.6906 - output_1_precision_1: 0.8157 - output_1_recall_1: 0.7470 - output_1_sensitivity: 0.6816 - output_1_specificity: 0.9949 - output_1_auc_1: 0.9374
# Epoch 10: val_output_1_loss did not improve from 0.31240
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.499999886320438e-06.
# 233/233 [==============================] - 68s 290ms/step - loss: 0.4250 - output_1_loss: 0.3250 - output_2_loss: 1.0000 - output_1_iou_score: 0.4318 - output_1_dice_coeff: 0.6906 - output_1_precision_1: 0.8157 - output_1_recall_1: 0.7470 - output_1_sensitivity: 0.6816 - output_1_specificity: 0.9949 - output_1_auc_1: 0.9374 - val_loss: 0.4476 - val_output_1_loss: 0.3525 - val_output_2_loss: 0.9503 - val_output_1_iou_score: 0.4120 - val_output_1_dice_coeff: 0.6689 - val_output_1_precision_1: 0.8013 - val_output_1_recall_1: 0.6732 - val_output_1_sensitivity: 0.6533 - val_output_1_specificity: 0.9953 - val_output_1_auc_1: 0.8985 - lr: 1.5000e-05

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:00<00:00, 464.41it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            #augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 25s 566ms/step - loss: 0.4632 - output_1_loss: 0.3632 - output_2_loss: 1.0000 - output_1_iou_score: 0.3600 - output_1_dice_coeff: 0.6811 - output_1_precision_1: 0.6770 - output_1_recall_1: 0.7498 - output_1_sensitivity: 0.7376 - output_1_specificity: 0.9881 - output_1_auc_1: 0.8990

# %%
#!zip -r weights_WNet_VGG16_AT_CL.zip /kaggle/working/WNet_maxpool_fine_tune.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_VGG16_AT_CL.zip')
