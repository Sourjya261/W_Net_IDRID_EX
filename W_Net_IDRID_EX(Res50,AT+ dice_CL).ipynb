# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:04<00:00, 242.68it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice
"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
"""def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1,axis=-1, keepdims=True)
    m2  = tf.reduce_mean(feature_map2,axis=-1, keepdims=True)
    return (tf.abs(m1-m2))"""

def complementary_loss(feature_map1,feature_map2):
    feature_map1 = tf.reduce_mean(feature_map1, axis=-1, keepdims=True)
    feature_map2  = tf.reduce_mean(feature_map2, axis=-1, keepdims=True)
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    #print(feature_map1.shape) #shapes are (none,H,W,1) so axis = 1 2 3 
    """intersection = tf.reduce_sum(feature_map1 * feature_map2, axis=[1, 2, 3])
    union = tf.reduce_sum(feature_map1 + feature_map2, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou"""
    return dice_coeff(feature_map1,feature_map2)

    
clipping_layer = tf.keras.layers.Lambda(
    lambda x: tf.clip_by_value(x , clip_value_min=0, clip_value_max=1),
    name='output_2'
)

def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    
    #output_2 = (comp1+comp2+comp3+comp4)/4.0
    output_2 = tf.keras.layers.Add(name='output_2_sum')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])
    output_2 = clipping_layer(output_2)

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#  tf.math.reduce_mean_16 (TF  (None, 256, 256, 1)          0         ['encoder2[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  (None, 256, 256, 1)          0         ['encoder1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  (None, 128, 128, 1)          0         ['encoder2[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  (None, 128, 128, 1)          0         ['encoder1[0][1]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  (None, 64, 64, 1)            0         ['encoder2[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  (None, 64, 64, 1)            0         ['encoder1[0][2]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  (None, 32, 32, 1)            0         ['encoder2[0][3]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  (None, 32, 32, 1)            0         ['encoder1[0][3]']
#  OpLambda)
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#  tchNormalization)
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['tf.math.reduce_mean_16[0][0]
#  mbda)                                                              ']
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['tf.math.reduce_mean_17[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['tf.math.reduce_mean_18[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['tf.math.reduce_mean_19[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['tf.math.reduce_mean_20[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['tf.math.reduce_mean_21[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['tf.math.reduce_mean_22[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['tf.math.reduce_mean_23[0][0]
#  Lambda)                                                            ']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_16[0][0]
#  a)                                                                 ',
#                                                                      'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 1)          0         ['tf.math.reduce_mean_17[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_18[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 128, 128, 1)          0         ['tf.math.reduce_mean_19[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_20[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 64, 64, 1)            0         ['tf.math.reduce_mean_21[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_22[0][0]
#  bda)                                                               ',
#                                                                      'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_10 (TFOpLa  (None, 32, 32, 1)            0         ['tf.math.reduce_mean_23[0][0]
#  mbda)                                                              ',
#                                                                      'tf.math.reduce_max_7[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.truediv[0][0]']
#
#  tf.reshape_1 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_1[0][0]']
#
#  tf.reshape_2 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_3[0][0]']
#
#  tf.reshape_3 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_4[0][0]']
#
#  tf.reshape_4 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_6[0][0]']
#
#  tf.reshape_5 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_7[0][0]']
#
#  tf.reshape_6 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_9[0][0]']
#
#  tf.reshape_7 (TFOpLambda)   (None,)                      0         ['tf.math.truediv_10[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.reshape[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.reshape_2[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.reshape_4[0][0]',
#  mbda)                                                               'tf.reshape_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.reshape_6[0][0]',
#  mbda)                                                               'tf.reshape_7[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_sum (TFOpLa  ()                           0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  ()                           0         ['tf.reshape[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_2 (TFOp  ()                           0         ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_3 (TFOp  ()                           0         ['tf.math.multiply_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_4 (TFOp  ()                           0         ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_5 (TFOp  ()                           0         ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_6 (TFOp  ()                           0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_7 (TFOp  ()                           0         ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_8 (TFOp  ()                           0         ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_9 (TFOp  ()                           0         ['tf.math.multiply_6[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_10 (TFO  ()                           0         ['tf.reshape_6[0][0]']
#  pLambda)
#
#  tf.math.reduce_sum_11 (TFO  ()                           0         ['tf.reshape_7[0][0]']
#  pLambda)
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_sum[0][0]']
#  mbda)
#
#  tf.__operators__.add_9 (TF  ()                           0         ['tf.math.reduce_sum_1[0][0]',
#  OpLambda)                                                           'tf.math.reduce_sum_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  ()                           0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_12 (T  ()                           0         ['tf.math.reduce_sum_4[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  ()                           0         ['tf.math.reduce_sum_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_15 (T  ()                           0         ['tf.math.reduce_sum_7[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_8[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  ()                           0         ['tf.math.reduce_sum_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_18 (T  ()                           0         ['tf.math.reduce_sum_10[0][0]'
#  FOpLambda)                                                         , 'tf.math.reduce_sum_11[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.add_8 (TF  ()                           0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.__operators__.add_10 (T  ()                           0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.__operators__.add_11 (T  ()                           0         ['tf.math.multiply_3[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_13 (T  ()                           0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_14 (T  ()                           0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_16 (T  ()                           0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_17 (T  ()                           0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_19 (T  ()                           0         ['tf.__operators__.add_18[0][0
#  FOpLambda)                                                         ]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.truediv_2 (TFOpLam  ()                           0         ['tf.__operators__.add_8[0][0]
#  bda)                                                               ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.truediv_5 (TFOpLam  ()                           0         ['tf.__operators__.add_11[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.__operators__.add_14[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.__operators__.add_17[0][0
#  mbda)                                                              ]',
#                                                                      'tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.truediv_12 (TFOpLa  ()                           0         ['tf.math.truediv_2[0][0]']
#  mbda)
#
#  tf.math.truediv_13 (TFOpLa  ()                           0         ['tf.math.truediv_5[0][0]']
#  mbda)
#
#  tf.math.truediv_14 (TFOpLa  ()                           0         ['tf.math.truediv_8[0][0]']
#  mbda)
#
#  tf.math.truediv_15 (TFOpLa  ()                           0         ['tf.math.truediv_11[0][0]']
#  mbda)
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_2_sum (Add)          ()                           0         ['tf.math.truediv_12[0][0]',
#                                                                      'tf.math.truediv_13[0][0]',
#                                                                      'tf.math.truediv_14[0][0]',
#                                                                      'tf.math.truediv_15[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          20        ['multiply_15[0][0]']
#
#  output_2 (Lambda)           ()                           0         ['output_2_sum[0][0]']
#
# ==================================================================================================
# Total params: 25705415 (98.06 MB)
# Trainable params: 25676885 (97.95 MB)
# Non-trainable params: 28530 (111.45 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5", 
                               monitor="val_output_1_loss",
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=1,callbacks=callbacks)

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-23 10:15:56.683035: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.5790 - output_1_loss: 0.5261 - output_2_loss: 0.5287 - output_1_iou_score: 0.2891 - output_1_dice_coeff: 0.5017 - output_1_precision: 0.2435 - output_1_recall: 0.5837 - output_1_sensitivity: 0.6230 - output_1_specificity: 0.9466 - output_1_auc: 0.8602
# Epoch 1: val_output_1_loss improved from inf to 1.09578, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 115s 229ms/step - loss: 0.5790 - output_1_loss: 0.5261 - output_2_loss: 0.5287 - output_1_iou_score: 0.2891 - output_1_dice_coeff: 0.5017 - output_1_precision: 0.2435 - output_1_recall: 0.5837 - output_1_sensitivity: 0.6230 - output_1_specificity: 0.9466 - output_1_auc: 0.8602 - val_loss: 1.1453 - val_output_1_loss: 1.0958 - val_output_2_loss: 0.4948 - val_output_1_iou_score: 2.7940e-05 - val_output_1_dice_coeff: 5.3216e-05 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5000 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.4303 - output_1_loss: 0.3516 - output_2_loss: 0.7870 - output_1_iou_score: 0.4137 - output_1_dice_coeff: 0.6702 - output_1_precision: 0.7812 - output_1_recall: 0.6627 - output_1_sensitivity: 0.6882 - output_1_specificity: 0.9945 - output_1_auc: 0.9006
# Epoch 1: val_output_1_loss improved from 1.09578 to 1.09064, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.4303 - output_1_loss: 0.3516 - output_2_loss: 0.7870 - output_1_iou_score: 0.4137 - output_1_dice_coeff: 0.6702 - output_1_precision: 0.7812 - output_1_recall: 0.6627 - output_1_sensitivity: 0.6882 - output_1_specificity: 0.9945 - output_1_auc: 0.9006 - val_loss: 1.1904 - val_output_1_loss: 1.0906 - val_output_2_loss: 0.9972 - val_output_1_iou_score: 5.3588e-04 - val_output_1_dice_coeff: 0.0011 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.4990 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3742 - output_1_loss: 0.3278 - output_2_loss: 0.4643 - output_1_iou_score: 0.4407 - output_1_dice_coeff: 0.6922 - output_1_precision: 0.7994 - output_1_recall: 0.6893 - output_1_sensitivity: 0.7049 - output_1_specificity: 0.9948 - output_1_auc: 0.9123
# Epoch 1: val_output_1_loss improved from 1.09064 to 1.08920, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.3742 - output_1_loss: 0.3278 - output_2_loss: 0.4643 - output_1_iou_score: 0.4407 - output_1_dice_coeff: 0.6922 - output_1_precision: 0.7994 - output_1_recall: 0.6893 - output_1_sensitivity: 0.7049 - output_1_specificity: 0.9948 - output_1_auc: 0.9123 - val_loss: 1.1657 - val_output_1_loss: 1.0892 - val_output_2_loss: 0.7646 - val_output_1_iou_score: 9.6803e-05 - val_output_1_dice_coeff: 1.8085e-04 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5021 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3812 - output_1_loss: 0.3303 - output_2_loss: 0.5088 - output_1_iou_score: 0.4538 - output_1_dice_coeff: 0.6903 - output_1_precision: 0.7864 - output_1_recall: 0.7004 - output_1_sensitivity: 0.7114 - output_1_specificity: 0.9943 - output_1_auc: 0.9110
# Epoch 1: val_output_1_loss improved from 1.08920 to 0.79520, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 195ms/step - loss: 0.3812 - output_1_loss: 0.3303 - output_2_loss: 0.5088 - output_1_iou_score: 0.4538 - output_1_dice_coeff: 0.6903 - output_1_precision: 0.7864 - output_1_recall: 0.7004 - output_1_sensitivity: 0.7114 - output_1_specificity: 0.9943 - output_1_auc: 0.9110 - val_loss: 0.8805 - val_output_1_loss: 0.7952 - val_output_2_loss: 0.8531 - val_output_1_iou_score: 0.0942 - val_output_1_dice_coeff: 0.2483 - val_output_1_precision: 0.9542 - val_output_1_recall: 0.2120 - val_output_1_sensitivity: 0.1586 - val_output_1_specificity: 0.9997 - val_output_1_auc: 0.7249 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3480 - output_1_loss: 0.2999 - output_2_loss: 0.4810 - output_1_iou_score: 0.4610 - output_1_dice_coeff: 0.7175 - output_1_precision: 0.8070 - output_1_recall: 0.7371 - output_1_sensitivity: 0.7249 - output_1_specificity: 0.9947 - output_1_auc: 0.9292
# Epoch 1: val_output_1_loss improved from 0.79520 to 0.37410, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 45s 195ms/step - loss: 0.3480 - output_1_loss: 0.2999 - output_2_loss: 0.4810 - output_1_iou_score: 0.4610 - output_1_dice_coeff: 0.7175 - output_1_precision: 0.8070 - output_1_recall: 0.7371 - output_1_sensitivity: 0.7249 - output_1_specificity: 0.9947 - output_1_auc: 0.9292 - val_loss: 0.4359 - val_output_1_loss: 0.3741 - val_output_2_loss: 0.6175 - val_output_1_iou_score: 0.3650 - val_output_1_dice_coeff: 0.6413 - val_output_1_precision: 0.7948 - val_output_1_recall: 0.7110 - val_output_1_sensitivity: 0.6016 - val_output_1_specificity: 0.9948 - val_output_1_auc: 0.9263 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3401 - output_1_loss: 0.2966 - output_2_loss: 0.4355 - output_1_iou_score: 0.4759 - output_1_dice_coeff: 0.7201 - output_1_precision: 0.8079 - output_1_recall: 0.7506 - output_1_sensitivity: 0.7273 - output_1_specificity: 0.9946 - output_1_auc: 0.9337
# Epoch 1: val_output_1_loss improved from 0.37410 to 0.34592, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.3401 - output_1_loss: 0.2966 - output_2_loss: 0.4355 - output_1_iou_score: 0.4759 - output_1_dice_coeff: 0.7201 - output_1_precision: 0.8079 - output_1_recall: 0.7506 - output_1_sensitivity: 0.7273 - output_1_specificity: 0.9946 - output_1_auc: 0.9337 - val_loss: 0.3973 - val_output_1_loss: 0.3459 - val_output_2_loss: 0.5135 - val_output_1_iou_score: 0.4223 - val_output_1_dice_coeff: 0.6751 - val_output_1_precision: 0.7331 - val_output_1_recall: 0.7507 - val_output_1_sensitivity: 0.7519 - val_output_1_specificity: 0.9923 - val_output_1_auc: 0.9174 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3335 - output_1_loss: 0.2927 - output_2_loss: 0.4071 - output_1_iou_score: 0.4787 - output_1_dice_coeff: 0.7238 - output_1_precision: 0.8154 - output_1_recall: 0.7424 - output_1_sensitivity: 0.7305 - output_1_specificity: 0.9950 - output_1_auc: 0.9323
# Epoch 1: val_output_1_loss improved from 0.34592 to 0.28673, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 195ms/step - loss: 0.3335 - output_1_loss: 0.2927 - output_2_loss: 0.4071 - output_1_iou_score: 0.4787 - output_1_dice_coeff: 0.7238 - output_1_precision: 0.8154 - output_1_recall: 0.7424 - output_1_sensitivity: 0.7305 - output_1_specificity: 0.9950 - output_1_auc: 0.9323 - val_loss: 0.3331 - val_output_1_loss: 0.2867 - val_output_2_loss: 0.4636 - val_output_1_iou_score: 0.4725 - val_output_1_dice_coeff: 0.7270 - val_output_1_precision: 0.8232 - val_output_1_recall: 0.7843 - val_output_1_sensitivity: 0.7140 - val_output_1_specificity: 0.9952 - val_output_1_auc: 0.9437 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3257 - output_1_loss: 0.2866 - output_2_loss: 0.3911 - output_1_iou_score: 0.4899 - output_1_dice_coeff: 0.7287 - output_1_precision: 0.8153 - output_1_recall: 0.7651 - output_1_sensitivity: 0.7411 - output_1_specificity: 0.9948 - output_1_auc: 0.9386
# Epoch 1: val_output_1_loss did not improve from 0.28673
# 233/233 [==============================] - 45s 192ms/step - loss: 0.3257 - output_1_loss: 0.2866 - output_2_loss: 0.3911 - output_1_iou_score: 0.4899 - output_1_dice_coeff: 0.7287 - output_1_precision: 0.8153 - output_1_recall: 0.7651 - output_1_sensitivity: 0.7411 - output_1_specificity: 0.9948 - output_1_auc: 0.9386 - val_loss: 0.3358 - val_output_1_loss: 0.2937 - val_output_2_loss: 0.4207 - val_output_1_iou_score: 0.4564 - val_output_1_dice_coeff: 0.7187 - val_output_1_precision: 0.7724 - val_output_1_recall: 0.8345 - val_output_1_sensitivity: 0.7265 - val_output_1_specificity: 0.9930 - val_output_1_auc: 0.9598 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3331 - output_1_loss: 0.2950 - output_2_loss: 0.3811 - output_1_iou_score: 0.4812 - output_1_dice_coeff: 0.7215 - output_1_precision: 0.8017 - output_1_recall: 0.7508 - output_1_sensitivity: 0.7347 - output_1_specificity: 0.9945 - output_1_auc: 0.9334
# Epoch 1: val_output_1_loss did not improve from 0.28673
# 233/233 [==============================] - 45s 193ms/step - loss: 0.3331 - output_1_loss: 0.2950 - output_2_loss: 0.3811 - output_1_iou_score: 0.4812 - output_1_dice_coeff: 0.7215 - output_1_precision: 0.8017 - output_1_recall: 0.7508 - output_1_sensitivity: 0.7347 - output_1_specificity: 0.9945 - output_1_auc: 0.9334 - val_loss: 0.3518 - val_output_1_loss: 0.3102 - val_output_2_loss: 0.4164 - val_output_1_iou_score: 0.4517 - val_output_1_dice_coeff: 0.7126 - val_output_1_precision: 0.7747 - val_output_1_recall: 0.7367 - val_output_1_sensitivity: 0.7314 - val_output_1_specificity: 0.9939 - val_output_1_auc: 0.9072 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3079 - output_1_loss: 0.2708 - output_2_loss: 0.3708 - output_1_iou_score: 0.5077 - output_1_dice_coeff: 0.7447 - output_1_precision: 0.8220 - output_1_recall: 0.7664 - output_1_sensitivity: 0.7496 - output_1_specificity: 0.9950 - output_1_auc: 0.9380
# Epoch 1: val_output_1_loss did not improve from 0.28673
# 233/233 [==============================] - 45s 194ms/step - loss: 0.3079 - output_1_loss: 0.2708 - output_2_loss: 0.3708 - output_1_iou_score: 0.5077 - output_1_dice_coeff: 0.7447 - output_1_precision: 0.8220 - output_1_recall: 0.7664 - output_1_sensitivity: 0.7496 - output_1_specificity: 0.9950 - output_1_auc: 0.9380 - val_loss: 0.3802 - val_output_1_loss: 0.3370 - val_output_2_loss: 0.4321 - val_output_1_iou_score: 0.4425 - val_output_1_dice_coeff: 0.6865 - val_output_1_precision: 0.6671 - val_output_1_recall: 0.7991 - val_output_1_sensitivity: 0.8143 - val_output_1_specificity: 0.9887 - val_output_1_auc: 0.9263 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3006 - output_1_loss: 0.2653 - output_2_loss: 0.3525 - output_1_iou_score: 0.5125 - output_1_dice_coeff: 0.7489 - output_1_precision: 0.8194 - output_1_recall: 0.7846 - output_1_sensitivity: 0.7583 - output_1_specificity: 0.9948 - output_1_auc: 0.9444
# Epoch 1: val_output_1_loss improved from 0.28673 to 0.28078, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.3006 - output_1_loss: 0.2653 - output_2_loss: 0.3525 - output_1_iou_score: 0.5125 - output_1_dice_coeff: 0.7489 - output_1_precision: 0.8194 - output_1_recall: 0.7846 - output_1_sensitivity: 0.7583 - output_1_specificity: 0.9948 - output_1_auc: 0.9444 - val_loss: 0.3214 - val_output_1_loss: 0.2808 - val_output_2_loss: 0.4065 - val_output_1_iou_score: 0.4776 - val_output_1_dice_coeff: 0.7313 - val_output_1_precision: 0.7926 - val_output_1_recall: 0.8176 - val_output_1_sensitivity: 0.7425 - val_output_1_specificity: 0.9939 - val_output_1_auc: 0.9562 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2936 - output_1_loss: 0.2585 - output_2_loss: 0.3506 - output_1_iou_score: 0.5246 - output_1_dice_coeff: 0.7552 - output_1_precision: 0.8269 - output_1_recall: 0.7969 - output_1_sensitivity: 0.7618 - output_1_specificity: 0.9950 - output_1_auc: 0.9493
# Epoch 1: val_output_1_loss did not improve from 0.28078
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2936 - output_1_loss: 0.2585 - output_2_loss: 0.3506 - output_1_iou_score: 0.5246 - output_1_dice_coeff: 0.7552 - output_1_precision: 0.8269 - output_1_recall: 0.7969 - output_1_sensitivity: 0.7618 - output_1_specificity: 0.9950 - output_1_auc: 0.9493 - val_loss: 0.3462 - val_output_1_loss: 0.3084 - val_output_2_loss: 0.3776 - val_output_1_iou_score: 0.4678 - val_output_1_dice_coeff: 0.7115 - val_output_1_precision: 0.8152 - val_output_1_recall: 0.7156 - val_output_1_sensitivity: 0.6885 - val_output_1_specificity: 0.9954 - val_output_1_auc: 0.9077 - lr: 1.0000e-04
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2917 - output_1_loss: 0.2576 - output_2_loss: 0.3406 - output_1_iou_score: 0.5200 - output_1_dice_coeff: 0.7563 - output_1_precision: 0.8303 - output_1_recall: 0.7853 - output_1_sensitivity: 0.7581 - output_1_specificity: 0.9952 - output_1_auc: 0.9464
# Epoch 1: val_output_1_loss improved from 0.28078 to 0.28074, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 195ms/step - loss: 0.2917 - output_1_loss: 0.2576 - output_2_loss: 0.3406 - output_1_iou_score: 0.5200 - output_1_dice_coeff: 0.7563 - output_1_precision: 0.8303 - output_1_recall: 0.7853 - output_1_sensitivity: 0.7581 - output_1_specificity: 0.9952 - output_1_auc: 0.9464 - val_loss: 0.3184 - val_output_1_loss: 0.2807 - val_output_2_loss: 0.3763 - val_output_1_iou_score: 0.4807 - val_output_1_dice_coeff: 0.7310 - val_output_1_precision: 0.7628 - val_output_1_recall: 0.8551 - val_output_1_sensitivity: 0.7822 - val_output_1_specificity: 0.9925 - val_output_1_auc: 0.9673 - lr: 1.0000e-04
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2872 - output_1_loss: 0.2534 - output_2_loss: 0.3382 - output_1_iou_score: 0.5285 - output_1_dice_coeff: 0.7601 - output_1_precision: 0.8292 - output_1_recall: 0.7976 - output_1_sensitivity: 0.7669 - output_1_specificity: 0.9950 - output_1_auc: 0.9499
# Epoch 1: val_output_1_loss improved from 0.28074 to 0.26683, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.2872 - output_1_loss: 0.2534 - output_2_loss: 0.3382 - output_1_iou_score: 0.5285 - output_1_dice_coeff: 0.7601 - output_1_precision: 0.8292 - output_1_recall: 0.7976 - output_1_sensitivity: 0.7669 - output_1_specificity: 0.9950 - output_1_auc: 0.9499 - val_loss: 0.3047 - val_output_1_loss: 0.2668 - val_output_2_loss: 0.3790 - val_output_1_iou_score: 0.4916 - val_output_1_dice_coeff: 0.7444 - val_output_1_precision: 0.8076 - val_output_1_recall: 0.8169 - val_output_1_sensitivity: 0.7661 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9581 - lr: 1.0000e-04
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2753 - output_1_loss: 0.2422 - output_2_loss: 0.3310 - output_1_iou_score: 0.5383 - output_1_dice_coeff: 0.7705 - output_1_precision: 0.8341 - output_1_recall: 0.8056 - output_1_sensitivity: 0.7702 - output_1_specificity: 0.9952 - output_1_auc: 0.9523
# Epoch 1: val_output_1_loss did not improve from 0.26683
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2753 - output_1_loss: 0.2422 - output_2_loss: 0.3310 - output_1_iou_score: 0.5383 - output_1_dice_coeff: 0.7705 - output_1_precision: 0.8341 - output_1_recall: 0.8056 - output_1_sensitivity: 0.7702 - output_1_specificity: 0.9952 - output_1_auc: 0.9523 - val_loss: 0.3388 - val_output_1_loss: 0.3012 - val_output_2_loss: 0.3756 - val_output_1_iou_score: 0.4473 - val_output_1_dice_coeff: 0.7132 - val_output_1_precision: 0.8042 - val_output_1_recall: 0.8045 - val_output_1_sensitivity: 0.7121 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9446 - lr: 1.0000e-04
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2773 - output_1_loss: 0.2451 - output_2_loss: 0.3224 - output_1_iou_score: 0.5401 - output_1_dice_coeff: 0.7675 - output_1_precision: 0.8298 - output_1_recall: 0.8070 - output_1_sensitivity: 0.7739 - output_1_specificity: 0.9950 - output_1_auc: 0.9528
# Epoch 1: val_output_1_loss did not improve from 0.26683
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2773 - output_1_loss: 0.2451 - output_2_loss: 0.3224 - output_1_iou_score: 0.5401 - output_1_dice_coeff: 0.7675 - output_1_precision: 0.8298 - output_1_recall: 0.8070 - output_1_sensitivity: 0.7739 - output_1_specificity: 0.9950 - output_1_auc: 0.9528 - val_loss: 0.3188 - val_output_1_loss: 0.2835 - val_output_2_loss: 0.3532 - val_output_1_iou_score: 0.4771 - val_output_1_dice_coeff: 0.7299 - val_output_1_precision: 0.8092 - val_output_1_recall: 0.8054 - val_output_1_sensitivity: 0.7439 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9484 - lr: 1.0000e-04
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2779 - output_1_loss: 0.2461 - output_2_loss: 0.3181 - output_1_iou_score: 0.5381 - output_1_dice_coeff: 0.7668 - output_1_precision: 0.8271 - output_1_recall: 0.8043 - output_1_sensitivity: 0.7724 - output_1_specificity: 0.9949 - output_1_auc: 0.9520
# Epoch 1: val_output_1_loss did not improve from 0.26683
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2779 - output_1_loss: 0.2461 - output_2_loss: 0.3181 - output_1_iou_score: 0.5381 - output_1_dice_coeff: 0.7668 - output_1_precision: 0.8271 - output_1_recall: 0.8043 - output_1_sensitivity: 0.7724 - output_1_specificity: 0.9949 - output_1_auc: 0.9520 - val_loss: 0.7440 - val_output_1_loss: 0.7108 - val_output_2_loss: 0.3323 - val_output_1_iou_score: 0.3159 - val_output_1_dice_coeff: 0.4199 - val_output_1_precision: 0.2455 - val_output_1_recall: 0.7219 - val_output_1_sensitivity: 0.6670 - val_output_1_specificity: 0.9386 - val_output_1_auc: 0.8727 - lr: 1.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2796 - output_1_loss: 0.2482 - output_2_loss: 0.3141 - output_1_iou_score: 0.5349 - output_1_dice_coeff: 0.7653 - output_1_precision: 0.8306 - output_1_recall: 0.7961 - output_1_sensitivity: 0.7694 - output_1_specificity: 0.9951 - output_1_auc: 0.9495
# Epoch 1: val_output_1_loss did not improve from 0.26683
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2796 - output_1_loss: 0.2482 - output_2_loss: 0.3141 - output_1_iou_score: 0.5349 - output_1_dice_coeff: 0.7653 - output_1_precision: 0.8306 - output_1_recall: 0.7961 - output_1_sensitivity: 0.7694 - output_1_specificity: 0.9951 - output_1_auc: 0.9495 - val_loss: 0.3502 - val_output_1_loss: 0.3138 - val_output_2_loss: 0.3631 - val_output_1_iou_score: 0.4534 - val_output_1_dice_coeff: 0.7010 - val_output_1_precision: 0.7091 - val_output_1_recall: 0.8703 - val_output_1_sensitivity: 0.8419 - val_output_1_specificity: 0.9900 - val_output_1_auc: 0.9686 - lr: 1.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2754 - output_1_loss: 0.2442 - output_2_loss: 0.3119 - output_1_iou_score: 0.5449 - output_1_dice_coeff: 0.7683 - output_1_precision: 0.8358 - output_1_recall: 0.8043 - output_1_sensitivity: 0.7703 - output_1_specificity: 0.9953 - output_1_auc: 0.9512
# Epoch 1: val_output_1_loss improved from 0.26683 to 0.25938, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.2754 - output_1_loss: 0.2442 - output_2_loss: 0.3119 - output_1_iou_score: 0.5449 - output_1_dice_coeff: 0.7683 - output_1_precision: 0.8358 - output_1_recall: 0.8043 - output_1_sensitivity: 0.7703 - output_1_specificity: 0.9953 - output_1_auc: 0.9512 - val_loss: 0.2921 - val_output_1_loss: 0.2594 - val_output_2_loss: 0.3271 - val_output_1_iou_score: 0.5078 - val_output_1_dice_coeff: 0.7520 - val_output_1_precision: 0.8230 - val_output_1_recall: 0.8155 - val_output_1_sensitivity: 0.7636 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9552 - lr: 1.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2627 - output_1_loss: 0.2322 - output_2_loss: 0.3054 - output_1_iou_score: 0.5579 - output_1_dice_coeff: 0.7793 - output_1_precision: 0.8405 - output_1_recall: 0.8118 - output_1_sensitivity: 0.7845 - output_1_specificity: 0.9953 - output_1_auc: 0.9560
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2627 - output_1_loss: 0.2322 - output_2_loss: 0.3054 - output_1_iou_score: 0.5579 - output_1_dice_coeff: 0.7793 - output_1_precision: 0.8405 - output_1_recall: 0.8118 - output_1_sensitivity: 0.7845 - output_1_specificity: 0.9953 - output_1_auc: 0.9560 - val_loss: 0.3170 - val_output_1_loss: 0.2840 - val_output_2_loss: 0.3301 - val_output_1_iou_score: 0.4847 - val_output_1_dice_coeff: 0.7296 - val_output_1_precision: 0.7439 - val_output_1_recall: 0.8620 - val_output_1_sensitivity: 0.8093 - val_output_1_specificity: 0.9916 - val_output_1_auc: 0.9666 - lr: 1.0000e-04
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2582 - output_1_loss: 0.2286 - output_2_loss: 0.2962 - output_1_iou_score: 0.5606 - output_1_dice_coeff: 0.7832 - output_1_precision: 0.8395 - output_1_recall: 0.8160 - output_1_sensitivity: 0.7862 - output_1_specificity: 0.9953 - output_1_auc: 0.9547
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2582 - output_1_loss: 0.2286 - output_2_loss: 0.2962 - output_1_iou_score: 0.5606 - output_1_dice_coeff: 0.7832 - output_1_precision: 0.8395 - output_1_recall: 0.8160 - output_1_sensitivity: 0.7862 - output_1_specificity: 0.9953 - output_1_auc: 0.9547 - val_loss: 0.3047 - val_output_1_loss: 0.2711 - val_output_2_loss: 0.3357 - val_output_1_iou_score: 0.4915 - val_output_1_dice_coeff: 0.7423 - val_output_1_precision: 0.7848 - val_output_1_recall: 0.8343 - val_output_1_sensitivity: 0.7677 - val_output_1_specificity: 0.9935 - val_output_1_auc: 0.9561 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2543 - output_1_loss: 0.2246 - output_2_loss: 0.2969 - output_1_iou_score: 0.5690 - output_1_dice_coeff: 0.7869 - output_1_precision: 0.8434 - output_1_recall: 0.8208 - output_1_sensitivity: 0.7867 - output_1_specificity: 0.9954 - output_1_auc: 0.9569
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2543 - output_1_loss: 0.2246 - output_2_loss: 0.2969 - output_1_iou_score: 0.5690 - output_1_dice_coeff: 0.7869 - output_1_precision: 0.8434 - output_1_recall: 0.8208 - output_1_sensitivity: 0.7867 - output_1_specificity: 0.9954 - output_1_auc: 0.9569 - val_loss: 0.3144 - val_output_1_loss: 0.2834 - val_output_2_loss: 0.3096 - val_output_1_iou_score: 0.4642 - val_output_1_dice_coeff: 0.7302 - val_output_1_precision: 0.8486 - val_output_1_recall: 0.7715 - val_output_1_sensitivity: 0.6876 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9344 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2639 - output_1_loss: 0.2345 - output_2_loss: 0.2942 - output_1_iou_score: 0.5591 - output_1_dice_coeff: 0.7773 - output_1_precision: 0.8416 - output_1_recall: 0.8160 - output_1_sensitivity: 0.7799 - output_1_specificity: 0.9954 - output_1_auc: 0.9559
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2639 - output_1_loss: 0.2345 - output_2_loss: 0.2942 - output_1_iou_score: 0.5591 - output_1_dice_coeff: 0.7773 - output_1_precision: 0.8416 - output_1_recall: 0.8160 - output_1_sensitivity: 0.7799 - output_1_specificity: 0.9954 - output_1_auc: 0.9559 - val_loss: 0.3431 - val_output_1_loss: 0.3105 - val_output_2_loss: 0.3261 - val_output_1_iou_score: 0.4682 - val_output_1_dice_coeff: 0.7035 - val_output_1_precision: 0.7309 - val_output_1_recall: 0.8707 - val_output_1_sensitivity: 0.8199 - val_output_1_specificity: 0.9909 - val_output_1_auc: 0.9680 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2533 - output_1_loss: 0.2243 - output_2_loss: 0.2898 - output_1_iou_score: 0.5754 - output_1_dice_coeff: 0.7871 - output_1_precision: 0.8441 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7891 - output_1_specificity: 0.9954 - output_1_auc: 0.9570
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2533 - output_1_loss: 0.2243 - output_2_loss: 0.2898 - output_1_iou_score: 0.5754 - output_1_dice_coeff: 0.7871 - output_1_precision: 0.8441 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7891 - output_1_specificity: 0.9954 - output_1_auc: 0.9570 - val_loss: 0.2953 - val_output_1_loss: 0.2700 - val_output_2_loss: 0.2523 - val_output_1_iou_score: 0.4995 - val_output_1_dice_coeff: 0.7434 - val_output_1_precision: 0.7716 - val_output_1_recall: 0.8565 - val_output_1_sensitivity: 0.8024 - val_output_1_specificity: 0.9928 - val_output_1_auc: 0.9629 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2574 - output_1_loss: 0.2289 - output_2_loss: 0.2841 - output_1_iou_score: 0.5576 - output_1_dice_coeff: 0.7835 - output_1_precision: 0.8437 - output_1_recall: 0.8111 - output_1_sensitivity: 0.7859 - output_1_specificity: 0.9955 - output_1_auc: 0.9529
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2574 - output_1_loss: 0.2289 - output_2_loss: 0.2841 - output_1_iou_score: 0.5576 - output_1_dice_coeff: 0.7835 - output_1_precision: 0.8437 - output_1_recall: 0.8111 - output_1_sensitivity: 0.7859 - output_1_specificity: 0.9955 - output_1_auc: 0.9529 - val_loss: 0.2884 - val_output_1_loss: 0.2651 - val_output_2_loss: 0.2326 - val_output_1_iou_score: 0.4958 - val_output_1_dice_coeff: 0.7470 - val_output_1_precision: 0.8314 - val_output_1_recall: 0.7997 - val_output_1_sensitivity: 0.7337 - val_output_1_specificity: 0.9954 - val_output_1_auc: 0.9480 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2428 - output_1_loss: 0.2136 - output_2_loss: 0.2914 - output_1_iou_score: 0.5785 - output_1_dice_coeff: 0.7976 - output_1_precision: 0.8460 - output_1_recall: 0.8251 - output_1_sensitivity: 0.7997 - output_1_specificity: 0.9955 - output_1_auc: 0.9583
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2428 - output_1_loss: 0.2136 - output_2_loss: 0.2914 - output_1_iou_score: 0.5785 - output_1_dice_coeff: 0.7976 - output_1_precision: 0.8460 - output_1_recall: 0.8251 - output_1_sensitivity: 0.7997 - output_1_specificity: 0.9955 - output_1_auc: 0.9583 - val_loss: 0.2841 - val_output_1_loss: 0.2602 - val_output_2_loss: 0.2385 - val_output_1_iou_score: 0.5149 - val_output_1_dice_coeff: 0.7526 - val_output_1_precision: 0.7979 - val_output_1_recall: 0.8388 - val_output_1_sensitivity: 0.7802 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9560 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2470 - output_1_loss: 0.2187 - output_2_loss: 0.2832 - output_1_iou_score: 0.5782 - output_1_dice_coeff: 0.7926 - output_1_precision: 0.8465 - output_1_recall: 0.8200 - output_1_sensitivity: 0.7922 - output_1_specificity: 0.9955 - output_1_auc: 0.9569
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2470 - output_1_loss: 0.2187 - output_2_loss: 0.2832 - output_1_iou_score: 0.5782 - output_1_dice_coeff: 0.7926 - output_1_precision: 0.8465 - output_1_recall: 0.8200 - output_1_sensitivity: 0.7922 - output_1_specificity: 0.9955 - output_1_auc: 0.9569 - val_loss: 0.2870 - val_output_1_loss: 0.2634 - val_output_2_loss: 0.2358 - val_output_1_iou_score: 0.4956 - val_output_1_dice_coeff: 0.7490 - val_output_1_precision: 0.8470 - val_output_1_recall: 0.7962 - val_output_1_sensitivity: 0.7130 - val_output_1_specificity: 0.9959 - val_output_1_auc: 0.9448 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2542 - output_1_loss: 0.2262 - output_2_loss: 0.2794 - output_1_iou_score: 0.5666 - output_1_dice_coeff: 0.7855 - output_1_precision: 0.8399 - output_1_recall: 0.8178 - output_1_sensitivity: 0.7897 - output_1_specificity: 0.9953 - output_1_auc: 0.9562
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2542 - output_1_loss: 0.2262 - output_2_loss: 0.2794 - output_1_iou_score: 0.5666 - output_1_dice_coeff: 0.7855 - output_1_precision: 0.8399 - output_1_recall: 0.8178 - output_1_sensitivity: 0.7897 - output_1_specificity: 0.9953 - output_1_auc: 0.9562 - val_loss: 0.2917 - val_output_1_loss: 0.2664 - val_output_2_loss: 0.2529 - val_output_1_iou_score: 0.4949 - val_output_1_dice_coeff: 0.7477 - val_output_1_precision: 0.8264 - val_output_1_recall: 0.7649 - val_output_1_sensitivity: 0.7397 - val_output_1_specificity: 0.9955 - val_output_1_auc: 0.9365 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2419 - output_1_loss: 0.2143 - output_2_loss: 0.2755 - output_1_iou_score: 0.5855 - output_1_dice_coeff: 0.7965 - output_1_precision: 0.8482 - output_1_recall: 0.8291 - output_1_sensitivity: 0.7999 - output_1_specificity: 0.9955 - output_1_auc: 0.9593
# Epoch 1: val_output_1_loss did not improve from 0.25938
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2419 - output_1_loss: 0.2143 - output_2_loss: 0.2755 - output_1_iou_score: 0.5855 - output_1_dice_coeff: 0.7965 - output_1_precision: 0.8482 - output_1_recall: 0.8291 - output_1_sensitivity: 0.7999 - output_1_specificity: 0.9955 - output_1_auc: 0.9593 - val_loss: 0.2862 - val_output_1_loss: 0.2621 - val_output_2_loss: 0.2408 - val_output_1_iou_score: 0.5045 - val_output_1_dice_coeff: 0.7515 - val_output_1_precision: 0.8153 - val_output_1_recall: 0.7725 - val_output_1_sensitivity: 0.7497 - val_output_1_specificity: 0.9951 - val_output_1_auc: 0.9367 - lr: 1.0000e-04
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2438 - output_1_loss: 0.2169 - output_2_loss: 0.2692 - output_1_iou_score: 0.5726 - output_1_dice_coeff: 0.7945 - output_1_precision: 0.8507 - output_1_recall: 0.8190 - output_1_sensitivity: 0.7932 - output_1_specificity: 0.9957 - output_1_auc: 0.9553
# Epoch 1: val_output_1_loss improved from 0.25938 to 0.25454, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2438 - output_1_loss: 0.2169 - output_2_loss: 0.2692 - output_1_iou_score: 0.5726 - output_1_dice_coeff: 0.7945 - output_1_precision: 0.8507 - output_1_recall: 0.8190 - output_1_sensitivity: 0.7932 - output_1_specificity: 0.9957 - output_1_auc: 0.9553 - val_loss: 0.2771 - val_output_1_loss: 0.2545 - val_output_2_loss: 0.2256 - val_output_1_iou_score: 0.5186 - val_output_1_dice_coeff: 0.7574 - val_output_1_precision: 0.8279 - val_output_1_recall: 0.8134 - val_output_1_sensitivity: 0.7642 - val_output_1_specificity: 0.9952 - val_output_1_auc: 0.9498 - lr: 1.0000e-04
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2334 - output_1_loss: 0.2070 - output_2_loss: 0.2647 - output_1_iou_score: 0.5877 - output_1_dice_coeff: 0.8038 - output_1_precision: 0.8502 - output_1_recall: 0.8292 - output_1_sensitivity: 0.8051 - output_1_specificity: 0.9956 - output_1_auc: 0.9597
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2334 - output_1_loss: 0.2070 - output_2_loss: 0.2647 - output_1_iou_score: 0.5877 - output_1_dice_coeff: 0.8038 - output_1_precision: 0.8502 - output_1_recall: 0.8292 - output_1_sensitivity: 0.8051 - output_1_specificity: 0.9956 - output_1_auc: 0.9597 - val_loss: 0.2809 - val_output_1_loss: 0.2617 - val_output_2_loss: 0.1920 - val_output_1_iou_score: 0.5034 - val_output_1_dice_coeff: 0.7510 - val_output_1_precision: 0.8102 - val_output_1_recall: 0.8233 - val_output_1_sensitivity: 0.7697 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9495 - lr: 1.0000e-04
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2401 - output_1_loss: 0.2137 - output_2_loss: 0.2645 - output_1_iou_score: 0.5934 - output_1_dice_coeff: 0.7975 - output_1_precision: 0.8491 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7973 - output_1_specificity: 0.9956 - output_1_auc: 0.9565
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2401 - output_1_loss: 0.2137 - output_2_loss: 0.2645 - output_1_iou_score: 0.5934 - output_1_dice_coeff: 0.7975 - output_1_precision: 0.8491 - output_1_recall: 0.8209 - output_1_sensitivity: 0.7973 - output_1_specificity: 0.9956 - output_1_auc: 0.9565 - val_loss: 0.3019 - val_output_1_loss: 0.2817 - val_output_2_loss: 0.2025 - val_output_1_iou_score: 0.4825 - val_output_1_dice_coeff: 0.7330 - val_output_1_precision: 0.7521 - val_output_1_recall: 0.8273 - val_output_1_sensitivity: 0.7779 - val_output_1_specificity: 0.9923 - val_output_1_auc: 0.9543 - lr: 1.0000e-04
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2314 - output_1_loss: 0.2058 - output_2_loss: 0.2556 - output_1_iou_score: 0.5975 - output_1_dice_coeff: 0.8048 - output_1_precision: 0.8500 - output_1_recall: 0.8353 - output_1_sensitivity: 0.8070 - output_1_specificity: 0.9956 - output_1_auc: 0.9609
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2314 - output_1_loss: 0.2058 - output_2_loss: 0.2556 - output_1_iou_score: 0.5975 - output_1_dice_coeff: 0.8048 - output_1_precision: 0.8500 - output_1_recall: 0.8353 - output_1_sensitivity: 0.8070 - output_1_specificity: 0.9956 - output_1_auc: 0.9609 - val_loss: 0.3015 - val_output_1_loss: 0.2814 - val_output_2_loss: 0.2007 - val_output_1_iou_score: 0.5055 - val_output_1_dice_coeff: 0.7401 - val_output_1_precision: 0.8154 - val_output_1_recall: 0.7276 - val_output_1_sensitivity: 0.7315 - val_output_1_specificity: 0.9953 - val_output_1_auc: 0.9024 - lr: 1.0000e-04
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2308 - output_1_loss: 0.2057 - output_2_loss: 0.2509 - output_1_iou_score: 0.6041 - output_1_dice_coeff: 0.8047 - output_1_precision: 0.8516 - output_1_recall: 0.8323 - output_1_sensitivity: 0.8053 - output_1_specificity: 0.9956 - output_1_auc: 0.9604
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 46s 195ms/step - loss: 0.2308 - output_1_loss: 0.2057 - output_2_loss: 0.2509 - output_1_iou_score: 0.6041 - output_1_dice_coeff: 0.8047 - output_1_precision: 0.8516 - output_1_recall: 0.8323 - output_1_sensitivity: 0.8053 - output_1_specificity: 0.9956 - output_1_auc: 0.9604 - val_loss: 0.2852 - val_output_1_loss: 0.2633 - val_output_2_loss: 0.2198 - val_output_1_iou_score: 0.5173 - val_output_1_dice_coeff: 0.7510 - val_output_1_precision: 0.7606 - val_output_1_recall: 0.8677 - val_output_1_sensitivity: 0.8246 - val_output_1_specificity: 0.9923 - val_output_1_auc: 0.9632 - lr: 1.0000e-04
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2356 - output_1_loss: 0.2097 - output_2_loss: 0.2584 - output_1_iou_score: 0.5983 - output_1_dice_coeff: 0.8013 - output_1_precision: 0.8503 - output_1_recall: 0.8285 - output_1_sensitivity: 0.8027 - output_1_specificity: 0.9956 - output_1_auc: 0.9576
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2356 - output_1_loss: 0.2097 - output_2_loss: 0.2584 - output_1_iou_score: 0.5983 - output_1_dice_coeff: 0.8013 - output_1_precision: 0.8503 - output_1_recall: 0.8285 - output_1_sensitivity: 0.8027 - output_1_specificity: 0.9956 - output_1_auc: 0.9576 - val_loss: 0.2836 - val_output_1_loss: 0.2633 - val_output_2_loss: 0.2029 - val_output_1_iou_score: 0.5053 - val_output_1_dice_coeff: 0.7493 - val_output_1_precision: 0.8018 - val_output_1_recall: 0.8293 - val_output_1_sensitivity: 0.7607 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9516 - lr: 1.0000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2257 - output_1_loss: 0.2004 - output_2_loss: 0.2535 - output_1_iou_score: 0.6066 - output_1_dice_coeff: 0.8098 - output_1_precision: 0.8556 - output_1_recall: 0.8327 - output_1_sensitivity: 0.8092 - output_1_specificity: 0.9958 - output_1_auc: 0.9599
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 46s 199ms/step - loss: 0.2257 - output_1_loss: 0.2004 - output_2_loss: 0.2535 - output_1_iou_score: 0.6066 - output_1_dice_coeff: 0.8098 - output_1_precision: 0.8556 - output_1_recall: 0.8327 - output_1_sensitivity: 0.8092 - output_1_specificity: 0.9958 - output_1_auc: 0.9599 - val_loss: 0.2890 - val_output_1_loss: 0.2659 - val_output_2_loss: 0.2310 - val_output_1_iou_score: 0.4930 - val_output_1_dice_coeff: 0.7467 - val_output_1_precision: 0.8184 - val_output_1_recall: 0.8169 - val_output_1_sensitivity: 0.7490 - val_output_1_specificity: 0.9949 - val_output_1_auc: 0.9471 - lr: 1.0000e-04
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2275 - output_1_loss: 0.2021 - output_2_loss: 0.2541 - output_1_iou_score: 0.6116 - output_1_dice_coeff: 0.8082 - output_1_precision: 0.8563 - output_1_recall: 0.8388 - output_1_sensitivity: 0.8072 - output_1_specificity: 0.9957 - output_1_auc: 0.9608
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2275 - output_1_loss: 0.2021 - output_2_loss: 0.2541 - output_1_iou_score: 0.6116 - output_1_dice_coeff: 0.8082 - output_1_precision: 0.8563 - output_1_recall: 0.8388 - output_1_sensitivity: 0.8072 - output_1_specificity: 0.9957 - output_1_auc: 0.9608 - val_loss: 0.2828 - val_output_1_loss: 0.2620 - val_output_2_loss: 0.2088 - val_output_1_iou_score: 0.5062 - val_output_1_dice_coeff: 0.7522 - val_output_1_precision: 0.8171 - val_output_1_recall: 0.7923 - val_output_1_sensitivity: 0.7495 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9399 - lr: 1.0000e-04
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2226 - output_1_loss: 0.1983 - output_2_loss: 0.2432 - output_1_iou_score: 0.6185 - output_1_dice_coeff: 0.8117 - output_1_precision: 0.8581 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8119 - output_1_specificity: 0.9958 - output_1_auc: 0.9631
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2226 - output_1_loss: 0.1983 - output_2_loss: 0.2432 - output_1_iou_score: 0.6185 - output_1_dice_coeff: 0.8117 - output_1_precision: 0.8581 - output_1_recall: 0.8428 - output_1_sensitivity: 0.8119 - output_1_specificity: 0.9958 - output_1_auc: 0.9631 - val_loss: 0.2935 - val_output_1_loss: 0.2717 - val_output_2_loss: 0.2179 - val_output_1_iou_score: 0.4864 - val_output_1_dice_coeff: 0.7418 - val_output_1_precision: 0.8462 - val_output_1_recall: 0.7901 - val_output_1_sensitivity: 0.7072 - val_output_1_specificity: 0.9959 - val_output_1_auc: 0.9346 - lr: 1.0000e-04
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2208 - output_1_loss: 0.1959 - output_2_loss: 0.2493 - output_1_iou_score: 0.6090 - output_1_dice_coeff: 0.8143 - output_1_precision: 0.8575 - output_1_recall: 0.8405 - output_1_sensitivity: 0.8145 - output_1_specificity: 0.9958 - output_1_auc: 0.9621
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2208 - output_1_loss: 0.1959 - output_2_loss: 0.2493 - output_1_iou_score: 0.6090 - output_1_dice_coeff: 0.8143 - output_1_precision: 0.8575 - output_1_recall: 0.8405 - output_1_sensitivity: 0.8145 - output_1_specificity: 0.9958 - output_1_auc: 0.9621 - val_loss: 0.3407 - val_output_1_loss: 0.3191 - val_output_2_loss: 0.2162 - val_output_1_iou_score: 0.4601 - val_output_1_dice_coeff: 0.7036 - val_output_1_precision: 0.8438 - val_output_1_recall: 0.6780 - val_output_1_sensitivity: 0.6495 - val_output_1_specificity: 0.9964 - val_output_1_auc: 0.8800 - lr: 1.0000e-04
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2182 - output_1_loss: 0.1938 - output_2_loss: 0.2439 - output_1_iou_score: 0.6199 - output_1_dice_coeff: 0.8161 - output_1_precision: 0.8591 - output_1_recall: 0.8399 - output_1_sensitivity: 0.8158 - output_1_specificity: 0.9958 - output_1_auc: 0.9615
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2182 - output_1_loss: 0.1938 - output_2_loss: 0.2439 - output_1_iou_score: 0.6199 - output_1_dice_coeff: 0.8161 - output_1_precision: 0.8591 - output_1_recall: 0.8399 - output_1_sensitivity: 0.8158 - output_1_specificity: 0.9958 - output_1_auc: 0.9615 - val_loss: 0.2778 - val_output_1_loss: 0.2577 - val_output_2_loss: 0.2014 - val_output_1_iou_score: 0.5018 - val_output_1_dice_coeff: 0.7553 - val_output_1_precision: 0.7967 - val_output_1_recall: 0.8378 - val_output_1_sensitivity: 0.7692 - val_output_1_specificity: 0.9939 - val_output_1_auc: 0.9502 - lr: 1.0000e-04
# Epoch 41/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2190 - output_1_loss: 0.1953 - output_2_loss: 0.2365 - output_1_iou_score: 0.6155 - output_1_dice_coeff: 0.8149 - output_1_precision: 0.8561 - output_1_recall: 0.8395 - output_1_sensitivity: 0.8182 - output_1_specificity: 0.9957 - output_1_auc: 0.9619
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2190 - output_1_loss: 0.1953 - output_2_loss: 0.2365 - output_1_iou_score: 0.6155 - output_1_dice_coeff: 0.8149 - output_1_precision: 0.8561 - output_1_recall: 0.8395 - output_1_sensitivity: 0.8182 - output_1_specificity: 0.9957 - output_1_auc: 0.9619 - val_loss: 0.2895 - val_output_1_loss: 0.2703 - val_output_2_loss: 0.1919 - val_output_1_iou_score: 0.4900 - val_output_1_dice_coeff: 0.7440 - val_output_1_precision: 0.7920 - val_output_1_recall: 0.8168 - val_output_1_sensitivity: 0.7493 - val_output_1_specificity: 0.9939 - val_output_1_auc: 0.9436 - lr: 1.0000e-04
# Epoch 42/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2164 - output_1_loss: 0.1915 - output_2_loss: 0.2485 - output_1_iou_score: 0.6246 - output_1_dice_coeff: 0.8184 - output_1_precision: 0.8561 - output_1_recall: 0.8459 - output_1_sensitivity: 0.8198 - output_1_specificity: 0.9957 - output_1_auc: 0.9631
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2164 - output_1_loss: 0.1915 - output_2_loss: 0.2485 - output_1_iou_score: 0.6246 - output_1_dice_coeff: 0.8184 - output_1_precision: 0.8561 - output_1_recall: 0.8459 - output_1_sensitivity: 0.8198 - output_1_specificity: 0.9957 - output_1_auc: 0.9631 - val_loss: 0.2908 - val_output_1_loss: 0.2693 - val_output_2_loss: 0.2153 - val_output_1_iou_score: 0.4949 - val_output_1_dice_coeff: 0.7434 - val_output_1_precision: 0.8307 - val_output_1_recall: 0.7986 - val_output_1_sensitivity: 0.7335 - val_output_1_specificity: 0.9954 - val_output_1_auc: 0.9392 - lr: 1.0000e-04
# Epoch 43/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2204 - output_1_loss: 0.1951 - output_2_loss: 0.2531 - output_1_iou_score: 0.6167 - output_1_dice_coeff: 0.8148 - output_1_precision: 0.8618 - output_1_recall: 0.8419 - output_1_sensitivity: 0.8128 - output_1_specificity: 0.9959 - output_1_auc: 0.9627
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2204 - output_1_loss: 0.1951 - output_2_loss: 0.2531 - output_1_iou_score: 0.6167 - output_1_dice_coeff: 0.8148 - output_1_precision: 0.8618 - output_1_recall: 0.8419 - output_1_sensitivity: 0.8128 - output_1_specificity: 0.9959 - output_1_auc: 0.9627 - val_loss: 0.2897 - val_output_1_loss: 0.2695 - val_output_2_loss: 0.2021 - val_output_1_iou_score: 0.4965 - val_output_1_dice_coeff: 0.7445 - val_output_1_precision: 0.8000 - val_output_1_recall: 0.8256 - val_output_1_sensitivity: 0.7458 - val_output_1_specificity: 0.9941 - val_output_1_auc: 0.9437 - lr: 1.0000e-04
# Epoch 44/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2123 - output_1_loss: 0.1884 - output_2_loss: 0.2392 - output_1_iou_score: 0.6220 - output_1_dice_coeff: 0.8217 - output_1_precision: 0.8596 - output_1_recall: 0.8469 - output_1_sensitivity: 0.8221 - output_1_specificity: 0.9958 - output_1_auc: 0.9628
# Epoch 1: val_output_1_loss did not improve from 0.25454
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2123 - output_1_loss: 0.1884 - output_2_loss: 0.2392 - output_1_iou_score: 0.6220 - output_1_dice_coeff: 0.8217 - output_1_precision: 0.8596 - output_1_recall: 0.8469 - output_1_sensitivity: 0.8221 - output_1_specificity: 0.9958 - output_1_auc: 0.9628 - val_loss: 0.2939 - val_output_1_loss: 0.2712 - val_output_2_loss: 0.2269 - val_output_1_iou_score: 0.4884 - val_output_1_dice_coeff: 0.7420 - val_output_1_precision: 0.8111 - val_output_1_recall: 0.8188 - val_output_1_sensitivity: 0.7281 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9435 - lr: 1.0000e-04
# Epoch 45/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2056 - output_1_loss: 0.1822 - output_2_loss: 0.2346 - output_1_iou_score: 0.6306 - output_1_dice_coeff: 0.8274 - output_1_precision: 0.8630 - output_1_recall: 0.8500 - output_1_sensitivity: 0.8260 - output_1_specificity: 0.9959 - output_1_auc: 0.9641
# Epoch 1: val_output_1_loss improved from 0.25454 to 0.25335, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 195ms/step - loss: 0.2056 - output_1_loss: 0.1822 - output_2_loss: 0.2346 - output_1_iou_score: 0.6306 - output_1_dice_coeff: 0.8274 - output_1_precision: 0.8630 - output_1_recall: 0.8500 - output_1_sensitivity: 0.8260 - output_1_specificity: 0.9959 - output_1_auc: 0.9641 - val_loss: 0.2747 - val_output_1_loss: 0.2534 - val_output_2_loss: 0.2135 - val_output_1_iou_score: 0.5214 - val_output_1_dice_coeff: 0.7601 - val_output_1_precision: 0.7921 - val_output_1_recall: 0.8517 - val_output_1_sensitivity: 0.7921 - val_output_1_specificity: 0.9937 - val_output_1_auc: 0.9548 - lr: 1.0000e-04
# Epoch 46/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2066 - output_1_loss: 0.1819 - output_2_loss: 0.2474 - output_1_iou_score: 0.6361 - output_1_dice_coeff: 0.8277 - output_1_precision: 0.8632 - output_1_recall: 0.8527 - output_1_sensitivity: 0.8284 - output_1_specificity: 0.9959 - output_1_auc: 0.9643
# Epoch 1: val_output_1_loss did not improve from 0.25335
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2066 - output_1_loss: 0.1819 - output_2_loss: 0.2474 - output_1_iou_score: 0.6361 - output_1_dice_coeff: 0.8277 - output_1_precision: 0.8632 - output_1_recall: 0.8527 - output_1_sensitivity: 0.8284 - output_1_specificity: 0.9959 - output_1_auc: 0.9643 - val_loss: 0.2814 - val_output_1_loss: 0.2603 - val_output_2_loss: 0.2105 - val_output_1_iou_score: 0.5016 - val_output_1_dice_coeff: 0.7526 - val_output_1_precision: 0.8175 - val_output_1_recall: 0.8187 - val_output_1_sensitivity: 0.7608 - val_output_1_specificity: 0.9948 - val_output_1_auc: 0.9426 - lr: 1.0000e-04
# Epoch 47/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2042 - output_1_loss: 0.1814 - output_2_loss: 0.2277 - output_1_iou_score: 0.6365 - output_1_dice_coeff: 0.8282 - output_1_precision: 0.8651 - output_1_recall: 0.8467 - output_1_sensitivity: 0.8301 - output_1_specificity: 0.9961 - output_1_auc: 0.9628
# Epoch 1: val_output_1_loss did not improve from 0.25335
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2042 - output_1_loss: 0.1814 - output_2_loss: 0.2277 - output_1_iou_score: 0.6365 - output_1_dice_coeff: 0.8282 - output_1_precision: 0.8651 - output_1_recall: 0.8467 - output_1_sensitivity: 0.8301 - output_1_specificity: 0.9961 - output_1_auc: 0.9628 - val_loss: 0.2893 - val_output_1_loss: 0.2676 - val_output_2_loss: 0.2174 - val_output_1_iou_score: 0.5165 - val_output_1_dice_coeff: 0.7457 - val_output_1_precision: 0.8571 - val_output_1_recall: 0.7644 - val_output_1_sensitivity: 0.7035 - val_output_1_specificity: 0.9964 - val_output_1_auc: 0.9293 - lr: 1.0000e-04
# Epoch 48/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2184 - output_1_loss: 0.1950 - output_2_loss: 0.2341 - output_1_iou_score: 0.6234 - output_1_dice_coeff: 0.8154 - output_1_precision: 0.8602 - output_1_recall: 0.8399 - output_1_sensitivity: 0.8146 - output_1_specificity: 0.9959 - output_1_auc: 0.9611
# Epoch 1: val_output_1_loss did not improve from 0.25335
# 233/233 [==============================] - 46s 196ms/step - loss: 0.2184 - output_1_loss: 0.1950 - output_2_loss: 0.2341 - output_1_iou_score: 0.6234 - output_1_dice_coeff: 0.8154 - output_1_precision: 0.8602 - output_1_recall: 0.8399 - output_1_sensitivity: 0.8146 - output_1_specificity: 0.9959 - output_1_auc: 0.9611 - val_loss: 0.3024 - val_output_1_loss: 0.2831 - val_output_2_loss: 0.1937 - val_output_1_iou_score: 0.5046 - val_output_1_dice_coeff: 0.7386 - val_output_1_precision: 0.8487 - val_output_1_recall: 0.6908 - val_output_1_sensitivity: 0.7084 - val_output_1_specificity: 0.9965 - val_output_1_auc: 0.8873 - lr: 1.0000e-04
# Epoch 49/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2064 - output_1_loss: 0.1827 - output_2_loss: 0.2363 - output_1_iou_score: 0.6305 - output_1_dice_coeff: 0.8270 - output_1_precision: 0.8624 - output_1_recall: 0.8495 - output_1_sensitivity: 0.8289 - output_1_specificity: 0.9959 - output_1_auc: 0.9640
# Epoch 1: val_output_1_loss did not improve from 0.25335
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2064 - output_1_loss: 0.1827 - output_2_loss: 0.2363 - output_1_iou_score: 0.6305 - output_1_dice_coeff: 0.8270 - output_1_precision: 0.8624 - output_1_recall: 0.8495 - output_1_sensitivity: 0.8289 - output_1_specificity: 0.9959 - output_1_auc: 0.9640 - val_loss: 0.2853 - val_output_1_loss: 0.2659 - val_output_2_loss: 0.1934 - val_output_1_iou_score: 0.5041 - val_output_1_dice_coeff: 0.7471 - val_output_1_precision: 0.8218 - val_output_1_recall: 0.8158 - val_output_1_sensitivity: 0.7323 - val_output_1_specificity: 0.9950 - val_output_1_auc: 0.9425 - lr: 1.0000e-04
# Epoch 50/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2046 - output_1_loss: 0.1813 - output_2_loss: 0.2338 - output_1_iou_score: 0.6418 - output_1_dice_coeff: 0.8276 - output_1_precision: 0.8677 - output_1_recall: 0.8533 - output_1_sensitivity: 0.8283 - output_1_specificity: 0.9961 - output_1_auc: 0.9658
# Epoch 1: val_output_1_loss did not improve from 0.25335
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2046 - output_1_loss: 0.1813 - output_2_loss: 0.2338 - output_1_iou_score: 0.6418 - output_1_dice_coeff: 0.8276 - output_1_precision: 0.8677 - output_1_recall: 0.8533 - output_1_sensitivity: 0.8283 - output_1_specificity: 0.9961 - output_1_auc: 0.9658 - val_loss: 0.2824 - val_output_1_loss: 0.2611 - val_output_2_loss: 0.2126 - val_output_1_iou_score: 0.5104 - val_output_1_dice_coeff: 0.7523 - val_output_1_precision: 0.8047 - val_output_1_recall: 0.8363 - val_output_1_sensitivity: 0.7608 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9480 - lr: 1.0000e-04
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_iou_score', 'output_1_dice_coeff', 'output_1_precision', 'output_1_recall', 'output_1_sensitivity', 'output_1_specificity', 'output_1_auc', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_iou_score', 'val_output_1_dice_coeff', 'val_output_1_precision', 'val_output_1_recall', 'val_output_1_sensitivity', 'val_output_1_specificity', 'val_output_1_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %%
"""from tensorflow.keras.models import load_model

custom_objects = {'total_loss': total_loss,
                  '<lambda>': lambda y_true, y_pred: y_pred,
                  'iou_score':iou_score,
                  'dice_coeff':dice_coeff,
                  'precision':tf.keras.metrics.Precision(),
                  'recall':tf.keras.metrics.Recall(),
                  'sensitivity':sensitivity,
                  'specificity':specificity
                 }

with tf.keras.utils.custom_object_scope(custom_objects):
    model = load_model('/kaggle/working/final_model.h5')"""
# Out:
# "from tensorflow.keras.models import load_model\n\ncustom_objects = {'total_loss': total_loss,\n                  '<lambda>': lambda y_true, y_pred: y_pred,\n                  'iou_score':iou_score,\n                  'dice_coeff':dice_coeff,\n                  'precision':tf.keras.metrics.Precision(),\n                  'recall':tf.keras.metrics.Recall(),\n                  'sensitivity':sensitivity,\n                  'specificity':specificity\n                 }\n\nwith tf.keras.utils.custom_object_scope(custom_objects):\n    model = load_model('/kaggle/working/final_model.h5')"

# %% [markdown]
# Im going for this method instead...more efficient

# %%
model = build_WNet((256,256,3))

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00005), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.1},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5",
                               monitor='val_output_1_loss',
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=2, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-23 10:55:38.382905: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.2034 - output_1_loss: 0.1805 - output_2_loss: 0.2290 - output_1_iou_score: 0.6403 - output_1_dice_coeff: 0.8289 - output_1_precision_1: 0.8650 - output_1_recall_1: 0.8530 - output_1_sensitivity: 0.8303 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9644
# Epoch 1: val_output_1_loss improved from inf to 0.25278, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 105s 207ms/step - loss: 0.2034 - output_1_loss: 0.1805 - output_2_loss: 0.2290 - output_1_iou_score: 0.6403 - output_1_dice_coeff: 0.8289 - output_1_precision_1: 0.8650 - output_1_recall_1: 0.8530 - output_1_sensitivity: 0.8303 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9644 - val_loss: 0.2723 - val_output_1_loss: 0.2528 - val_output_2_loss: 0.1952 - val_output_1_iou_score: 0.5199 - val_output_1_dice_coeff: 0.7604 - val_output_1_precision_1: 0.7978 - val_output_1_recall_1: 0.8460 - val_output_1_sensitivity: 0.7844 - val_output_1_specificity: 0.9939 - val_output_1_auc_1: 0.9545 - lr: 5.0000e-05
# Epoch 2/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2040 - output_1_loss: 0.1803 - output_2_loss: 0.2375 - output_1_iou_score: 0.6471 - output_1_dice_coeff: 0.8289 - output_1_precision_1: 0.8666 - output_1_recall_1: 0.8599 - output_1_sensitivity: 0.8300 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9667
# Epoch 2: val_output_1_loss did not improve from 0.25278
# 233/233 [==============================] - 45s 193ms/step - loss: 0.2040 - output_1_loss: 0.1803 - output_2_loss: 0.2375 - output_1_iou_score: 0.6471 - output_1_dice_coeff: 0.8289 - output_1_precision_1: 0.8666 - output_1_recall_1: 0.8599 - output_1_sensitivity: 0.8300 - output_1_specificity: 0.9960 - output_1_auc_1: 0.9667 - val_loss: 0.2788 - val_output_1_loss: 0.2568 - val_output_2_loss: 0.2201 - val_output_1_iou_score: 0.5197 - val_output_1_dice_coeff: 0.7562 - val_output_1_precision_1: 0.8506 - val_output_1_recall_1: 0.7942 - val_output_1_sensitivity: 0.7323 - val_output_1_specificity: 0.9960 - val_output_1_auc_1: 0.9341 - lr: 5.0000e-05
# Epoch 3/10
# 233/233 [==============================] - ETA: 0s - loss: 0.2014 - output_1_loss: 0.1783 - output_2_loss: 0.2311 - output_1_iou_score: 0.6511 - output_1_dice_coeff: 0.8309 - output_1_precision_1: 0.8702 - output_1_recall_1: 0.8588 - output_1_sensitivity: 0.8297 - output_1_specificity: 0.9961 - output_1_auc_1: 0.9661
# Epoch 3: val_output_1_loss improved from 0.25278 to 0.24827, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2014 - output_1_loss: 0.1783 - output_2_loss: 0.2311 - output_1_iou_score: 0.6511 - output_1_dice_coeff: 0.8309 - output_1_precision_1: 0.8702 - output_1_recall_1: 0.8588 - output_1_sensitivity: 0.8297 - output_1_specificity: 0.9961 - output_1_auc_1: 0.9661 - val_loss: 0.2669 - val_output_1_loss: 0.2483 - val_output_2_loss: 0.1859 - val_output_1_iou_score: 0.5322 - val_output_1_dice_coeff: 0.7639 - val_output_1_precision_1: 0.8379 - val_output_1_recall_1: 0.8152 - val_output_1_sensitivity: 0.7541 - val_output_1_specificity: 0.9955 - val_output_1_auc_1: 0.9428 - lr: 5.0000e-05
# Epoch 4/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1961 - output_1_loss: 0.1728 - output_2_loss: 0.2333 - output_1_iou_score: 0.6625 - output_1_dice_coeff: 0.8360 - output_1_precision_1: 0.8728 - output_1_recall_1: 0.8601 - output_1_sensitivity: 0.8363 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9670
# Epoch 4: val_output_1_loss improved from 0.24827 to 0.24606, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1961 - output_1_loss: 0.1728 - output_2_loss: 0.2333 - output_1_iou_score: 0.6625 - output_1_dice_coeff: 0.8360 - output_1_precision_1: 0.8728 - output_1_recall_1: 0.8601 - output_1_sensitivity: 0.8363 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9670 - val_loss: 0.2671 - val_output_1_loss: 0.2461 - val_output_2_loss: 0.2107 - val_output_1_iou_score: 0.5359 - val_output_1_dice_coeff: 0.7666 - val_output_1_precision_1: 0.8316 - val_output_1_recall_1: 0.8227 - val_output_1_sensitivity: 0.7674 - val_output_1_specificity: 0.9953 - val_output_1_auc_1: 0.9455 - lr: 5.0000e-05
# Epoch 5/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1892 - output_1_loss: 0.1670 - output_2_loss: 0.2221 - output_1_iou_score: 0.6633 - output_1_dice_coeff: 0.8420 - output_1_precision_1: 0.8732 - output_1_recall_1: 0.8600 - output_1_sensitivity: 0.8426 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9663
# Epoch 5: val_output_1_loss did not improve from 0.24606
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1892 - output_1_loss: 0.1670 - output_2_loss: 0.2221 - output_1_iou_score: 0.6633 - output_1_dice_coeff: 0.8420 - output_1_precision_1: 0.8732 - output_1_recall_1: 0.8600 - output_1_sensitivity: 0.8426 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9663 - val_loss: 0.2692 - val_output_1_loss: 0.2485 - val_output_2_loss: 0.2073 - val_output_1_iou_score: 0.5259 - val_output_1_dice_coeff: 0.7643 - val_output_1_precision_1: 0.8319 - val_output_1_recall_1: 0.8217 - val_output_1_sensitivity: 0.7552 - val_output_1_specificity: 0.9953 - val_output_1_auc_1: 0.9434 - lr: 5.0000e-05
# Epoch 6/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1905 - output_1_loss: 0.1676 - output_2_loss: 0.2289 - output_1_iou_score: 0.6654 - output_1_dice_coeff: 0.8413 - output_1_precision_1: 0.8734 - output_1_recall_1: 0.8648 - output_1_sensitivity: 0.8410 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9676
# Epoch 6: val_output_1_loss did not improve from 0.24606
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1905 - output_1_loss: 0.1676 - output_2_loss: 0.2289 - output_1_iou_score: 0.6654 - output_1_dice_coeff: 0.8413 - output_1_precision_1: 0.8734 - output_1_recall_1: 0.8648 - output_1_sensitivity: 0.8410 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9676 - val_loss: 0.2785 - val_output_1_loss: 0.2577 - val_output_2_loss: 0.2078 - val_output_1_iou_score: 0.5241 - val_output_1_dice_coeff: 0.7557 - val_output_1_precision_1: 0.8275 - val_output_1_recall_1: 0.8163 - val_output_1_sensitivity: 0.7483 - val_output_1_specificity: 0.9952 - val_output_1_auc_1: 0.9398 - lr: 5.0000e-05
# Epoch 7/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1853 - output_1_loss: 0.1623 - output_2_loss: 0.2306 - output_1_iou_score: 0.6692 - output_1_dice_coeff: 0.8463 - output_1_precision_1: 0.8733 - output_1_recall_1: 0.8678 - output_1_sensitivity: 0.8463 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9680
# Epoch 7: val_output_1_loss improved from 0.24606 to 0.24582, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1853 - output_1_loss: 0.1623 - output_2_loss: 0.2306 - output_1_iou_score: 0.6692 - output_1_dice_coeff: 0.8463 - output_1_precision_1: 0.8733 - output_1_recall_1: 0.8678 - output_1_sensitivity: 0.8463 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9680 - val_loss: 0.2650 - val_output_1_loss: 0.2458 - val_output_2_loss: 0.1921 - val_output_1_iou_score: 0.5329 - val_output_1_dice_coeff: 0.7670 - val_output_1_precision_1: 0.8275 - val_output_1_recall_1: 0.8250 - val_output_1_sensitivity: 0.7709 - val_output_1_specificity: 0.9951 - val_output_1_auc_1: 0.9445 - lr: 1.5000e-05
# Epoch 8/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1864 - output_1_loss: 0.1635 - output_2_loss: 0.2285 - output_1_iou_score: 0.6723 - output_1_dice_coeff: 0.8450 - output_1_precision_1: 0.8769 - output_1_recall_1: 0.8667 - output_1_sensitivity: 0.8446 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9677
# Epoch 8: val_output_1_loss did not improve from 0.24582
# 233/233 [==============================] - 45s 193ms/step - loss: 0.1864 - output_1_loss: 0.1635 - output_2_loss: 0.2285 - output_1_iou_score: 0.6723 - output_1_dice_coeff: 0.8450 - output_1_precision_1: 0.8769 - output_1_recall_1: 0.8667 - output_1_sensitivity: 0.8446 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9677 - val_loss: 0.2681 - val_output_1_loss: 0.2490 - val_output_2_loss: 0.1913 - val_output_1_iou_score: 0.5258 - val_output_1_dice_coeff: 0.7639 - val_output_1_precision_1: 0.8264 - val_output_1_recall_1: 0.8236 - val_output_1_sensitivity: 0.7645 - val_output_1_specificity: 0.9951 - val_output_1_auc_1: 0.9440 - lr: 1.5000e-05
# Epoch 9/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1848 - output_1_loss: 0.1615 - output_2_loss: 0.2329 - output_1_iou_score: 0.6769 - output_1_dice_coeff: 0.8469 - output_1_precision_1: 0.8776 - output_1_recall_1: 0.8676 - output_1_sensitivity: 0.8465 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9688
# Epoch 9: val_output_1_loss did not improve from 0.24582
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.499999886320438e-06.
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1848 - output_1_loss: 0.1615 - output_2_loss: 0.2329 - output_1_iou_score: 0.6769 - output_1_dice_coeff: 0.8469 - output_1_precision_1: 0.8776 - output_1_recall_1: 0.8676 - output_1_sensitivity: 0.8465 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9688 - val_loss: 0.2702 - val_output_1_loss: 0.2499 - val_output_2_loss: 0.2034 - val_output_1_iou_score: 0.5312 - val_output_1_dice_coeff: 0.7631 - val_output_1_precision_1: 0.8352 - val_output_1_recall_1: 0.8154 - val_output_1_sensitivity: 0.7537 - val_output_1_specificity: 0.9954 - val_output_1_auc_1: 0.9406 - lr: 1.5000e-05
# Epoch 10/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1845 - output_1_loss: 0.1627 - output_2_loss: 0.2178 - output_1_iou_score: 0.6782 - output_1_dice_coeff: 0.8458 - output_1_precision_1: 0.8777 - output_1_recall_1: 0.8696 - output_1_sensitivity: 0.8446 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9685
# Epoch 10: val_output_1_loss did not improve from 0.24582
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1845 - output_1_loss: 0.1627 - output_2_loss: 0.2178 - output_1_iou_score: 0.6782 - output_1_dice_coeff: 0.8458 - output_1_precision_1: 0.8777 - output_1_recall_1: 0.8696 - output_1_sensitivity: 0.8446 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9685 - val_loss: 0.2701 - val_output_1_loss: 0.2501 - val_output_2_loss: 0.2005 - val_output_1_iou_score: 0.5235 - val_output_1_dice_coeff: 0.7628 - val_output_1_precision_1: 0.8296 - val_output_1_recall_1: 0.8227 - val_output_1_sensitivity: 0.7587 - val_output_1_specificity: 0.9952 - val_output_1_auc_1: 0.9437 - lr: 4.5000e-06

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 364.17it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            #augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 20s 508ms/step - loss: 0.2538 - output_1_loss: 0.2365 - output_2_loss: 0.1725 - output_1_iou_score: 0.5167 - output_1_dice_coeff: 0.7839 - output_1_precision_1: 0.8056 - output_1_recall_1: 0.7917 - output_1_sensitivity: 0.7939 - output_1_specificity: 0.9936 - output_1_auc_1: 0.9279

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
