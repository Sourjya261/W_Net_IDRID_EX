# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:02<00:00, 448.87it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice
"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
"""def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1,axis=-1, keepdims=True)
    m2  = tf.reduce_mean(feature_map2,axis=-1, keepdims=True)
    return (tf.abs(m1-m2))"""

def complementary_loss(feature_map1,feature_map2):
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    feature_map1 = tf.reduce_mean(feature_map1, axis=-1, keepdims=True)
    feature_map2  = tf.reduce_mean(feature_map2, axis=-1, keepdims=True)
    #print(feature_map1.shape) #shapes are (none,H,W,1) so axis = 1 2 3 
    """intersection = tf.reduce_sum(feature_map1 * feature_map2, axis=[1, 2, 3])
    union = tf.reduce_sum(feature_map1 + feature_map2, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou"""
    return dice_coeff(feature_map1,feature_map2)

    
clipping_layer = tf.keras.layers.Lambda(
    lambda x: tf.clip_by_value(x , clip_value_min=0, clip_value_max=1),
    name='output_2'
)

def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1,s2, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1,s2])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    
    #output_2 = (comp1+comp2+comp3+comp4)/4.0
    output_2 = tf.keras.layers.Add(name='output_2_sum')([comp1/4.0,comp2/4.0,comp3/4.0,comp4/4.0])
    output_2 = clipping_layer(output_2)

    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    model = Model(inputs,outputs=[output_1,output_2])
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model = build_WNet((256,256,3))
adam = tf.keras.optimizers.Adam(learning_rate = 0.0001)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder1 (Functional)       [[(None, 256, 256, 16),      870567    ['model_input[0][0]']
#                               (None, 128, 128, 32),
#                               (None, 64, 64, 64),
#                               (None, 32, 32, 128)],
#                               (None, 16, 16, 128)]
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  concatenate_2 (Concatenate  (None, 16, 16, 256)          0         ['encoder1[0][4]',
#  )                                                                   'encoder2[0][4]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 640)          656000    ['concatenate_2[0][0]']
#  anspose)
#
#  concatenate_3 (Concatenate  (None, 32, 32, 1280)         0         ['conv2d_transpose[0][0]',
#  )                                                                   'encoder2[0][3]',
#                                                                      'encoder1[0][3]']
#
#  batch_normalization_19 (Ba  (None, 32, 32, 1280)         5120      ['concatenate_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 1280)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 640)          7373440   ['leaky_re_lu_7[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 640)          0         ['conv2d_36[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 640)          2560      ['dropout_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 640)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 640)          3687040   ['leaky_re_lu_8[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 640)          819840    ['concatenate_3[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 32, 32, 640)          0         ['conv2d_37[0][0]',
#  OpLambda)                                                           'conv2d_38[0][0]']
#
#  tf.math.reduce_mean_8 (TFO  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  tf.math.reduce_std_4 (TFOp  (None, 1, 1, 640)            0         ['tf.__operators__.add_4[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 1, 1280)           0         ['tf.math.reduce_mean_8[0][0]'
#                                                                     , 'tf.math.reduce_std_4[0][0]'
#                                                                     ]
#
#  conv2d_39 (Conv2D)          (None, 1, 1, 40)             51240     ['tf.concat_4[0][0]']
#
#  tf.math.reduce_mean_9 (TFO  (None, 32, 32, 1)            0         ['tf.__operators__.add_4[0][0]
#  pLambda)                                                           ']
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 640)            26240     ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_9[0][0]'
#                                                                     ]
#
#  multiply_8 (Multiply)       (None, 32, 32, 640)          0         ['conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]']
#
#  multiply_9 (Multiply)       (None, 32, 32, 640)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ',
#                                                                      'multiply_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 320)          819520    ['multiply_9[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 64, 64, 640)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'encoder2[0][2]',
#                                                                      'encoder1[0][2]']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 640)          2560      ['concatenate_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 64, 64, 640)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 320)          1843520   ['leaky_re_lu_9[0][0]']
#
#  dropout_4 (Dropout)         (None, 64, 64, 320)          0         ['conv2d_42[0][0]']
#
#  batch_normalization_22 (Ba  (None, 64, 64, 320)          1280      ['dropout_4[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 64, 64, 320)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 320)          921920    ['leaky_re_lu_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 320)          205120    ['concatenate_4[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 64, 64, 320)          0         ['conv2d_43[0][0]',
#  OpLambda)                                                           'conv2d_44[0][0]']
#
#  tf.math.reduce_mean_10 (TF  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_5 (TFOp  (None, 1, 1, 320)            0         ['tf.__operators__.add_5[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 1, 640)            0         ['tf.math.reduce_mean_10[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_5[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 1, 1, 20)             12820     ['tf.concat_5[0][0]']
#
#  tf.math.reduce_mean_11 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 320)            6720      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_11[0][0]
#                                                                     ']
#
#  multiply_10 (Multiply)      (None, 64, 64, 320)          0         ['conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  multiply_11 (Multiply)      (None, 64, 64, 320)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ',
#                                                                      'multiply_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 96)         122976    ['multiply_11[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 128, 128, 192)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'encoder2[0][1]',
#                                                                      'encoder1[0][1]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 192)        768       ['concatenate_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 96)         165984    ['leaky_re_lu_11[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 96)         0         ['conv2d_48[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 96)         384       ['dropout_5[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 128, 128, 96)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 96)         83040     ['leaky_re_lu_12[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 96)         18528     ['concatenate_5[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 128, 128, 96)         0         ['conv2d_49[0][0]',
#  OpLambda)                                                           'conv2d_50[0][0]']
#
#  tf.math.reduce_mean_12 (TF  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_6 (TFOp  (None, 1, 1, 96)             0         ['tf.__operators__.add_6[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_6 (TFOpLambda)    (None, 1, 1, 192)            0         ['tf.math.reduce_mean_12[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_6[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 6)              1158      ['tf.concat_6[0][0]']
#
#  tf.math.reduce_mean_13 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 96)             672       ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_13[0][0]
#                                                                     ']
#
#  multiply_12 (Multiply)      (None, 128, 128, 96)         0         ['conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]']
#
#  multiply_13 (Multiply)      (None, 128, 128, 96)         0         ['tf.__operators__.add_6[0][0]
#                                                                     ',
#                                                                      'multiply_12[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 19)         7315      ['multiply_13[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 256, 256, 38)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'encoder2[0][0]',
#                                                                      'encoder1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 38)         152       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256, 256, 38)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 256, 256, 19)         6517      ['leaky_re_lu_13[0][0]']
#
#  dropout_6 (Dropout)         (None, 256, 256, 19)         0         ['conv2d_54[0][0]']
#
#  tf.math.reduce_max (TFOpLa  ()                           0         ['encoder2[0][0]']
#  mbda)
#
#  tf.math.reduce_max_1 (TFOp  ()                           0         ['encoder1[0][0]']
#  Lambda)
#
#  tf.math.reduce_max_2 (TFOp  ()                           0         ['encoder2[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_3 (TFOp  ()                           0         ['encoder1[0][1]']
#  Lambda)
#
#  tf.math.reduce_max_4 (TFOp  ()                           0         ['encoder2[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_5 (TFOp  ()                           0         ['encoder1[0][2]']
#  Lambda)
#
#  tf.math.reduce_max_6 (TFOp  ()                           0         ['encoder2[0][3]']
#  Lambda)
#
#  tf.math.reduce_max_7 (TFOp  ()                           0         ['encoder1[0][3]']
#  Lambda)
#
#  batch_normalization_26 (Ba  (None, 256, 256, 19)         76        ['dropout_6[0][0]']
#  tchNormalization)
#
#  tf.math.truediv (TFOpLambd  (None, 256, 256, 3)          0         ['encoder2[0][0]',
#  a)                                                                  'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv_1 (TFOpLam  (None, 256, 256, 16)         0         ['encoder1[0][0]',
#  bda)                                                                'tf.math.reduce_max_1[0][0]']
#
#  tf.math.truediv_3 (TFOpLam  (None, 128, 128, 64)         0         ['encoder2[0][1]',
#  bda)                                                                'tf.math.reduce_max_2[0][0]']
#
#  tf.math.truediv_4 (TFOpLam  (None, 128, 128, 32)         0         ['encoder1[0][1]',
#  bda)                                                                'tf.math.reduce_max_3[0][0]']
#
#  tf.math.truediv_6 (TFOpLam  (None, 64, 64, 256)          0         ['encoder2[0][2]',
#  bda)                                                                'tf.math.reduce_max_4[0][0]']
#
#  tf.math.truediv_7 (TFOpLam  (None, 64, 64, 64)           0         ['encoder1[0][2]',
#  bda)                                                                'tf.math.reduce_max_5[0][0]']
#
#  tf.math.truediv_9 (TFOpLam  (None, 32, 32, 512)          0         ['encoder2[0][3]',
#  bda)                                                                'tf.math.reduce_max_6[0][0]']
#
#  tf.math.truediv_10 (TFOpLa  (None, 32, 32, 128)          0         ['encoder1[0][3]',
#  mbda)                                                               'tf.math.reduce_max_7[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 256, 19)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  tf.math.reduce_mean_16 (TF  (None, 256, 256, 1)          0         ['tf.math.truediv[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_17 (TF  (None, 256, 256, 1)          0         ['tf.math.truediv_1[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_18 (TF  (None, 128, 128, 1)          0         ['tf.math.truediv_3[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_19 (TF  (None, 128, 128, 1)          0         ['tf.math.truediv_4[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_20 (TF  (None, 64, 64, 1)            0         ['tf.math.truediv_6[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_21 (TF  (None, 64, 64, 1)            0         ['tf.math.truediv_7[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_22 (TF  (None, 32, 32, 1)            0         ['tf.math.truediv_9[0][0]']
#  OpLambda)
#
#  tf.math.reduce_mean_23 (TF  (None, 32, 32, 1)            0         ['tf.math.truediv_10[0][0]']
#  OpLambda)
#
#  conv2d_55 (Conv2D)          (None, 256, 256, 19)         3268      ['leaky_re_lu_14[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 256, 256, 19)         741       ['concatenate_6[0][0]']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.reduce_mean_16[0][0]
#                                                                     ']
#
#  tf.reshape_1 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_17[0][0]
#                                                                     ']
#
#  tf.reshape_2 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_18[0][0]
#                                                                     ']
#
#  tf.reshape_3 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_19[0][0]
#                                                                     ']
#
#  tf.reshape_4 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_20[0][0]
#                                                                     ']
#
#  tf.reshape_5 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_21[0][0]
#                                                                     ']
#
#  tf.reshape_6 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_22[0][0]
#                                                                     ']
#
#  tf.reshape_7 (TFOpLambda)   (None,)                      0         ['tf.math.reduce_mean_23[0][0]
#                                                                     ']
#
#  tf.__operators__.add_7 (TF  (None, 256, 256, 19)         0         ['conv2d_55[0][0]',
#  OpLambda)                                                           'conv2d_56[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None,)                      0         ['tf.reshape[0][0]',
#  da)                                                                 'tf.reshape_1[0][0]']
#
#  tf.math.multiply_2 (TFOpLa  (None,)                      0         ['tf.reshape_2[0][0]',
#  mbda)                                                               'tf.reshape_3[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None,)                      0         ['tf.reshape_4[0][0]',
#  mbda)                                                               'tf.reshape_5[0][0]']
#
#  tf.math.multiply_6 (TFOpLa  (None,)                      0         ['tf.reshape_6[0][0]',
#  mbda)                                                               'tf.reshape_7[0][0]']
#
#  tf.math.reduce_mean_14 (TF  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_7 (TFOp  (None, 1, 1, 19)             0         ['tf.__operators__.add_7[0][0]
#  Lambda)                                                            ']
#
#  tf.math.reduce_sum (TFOpLa  ()                           0         ['tf.math.multiply[0][0]']
#  mbda)
#
#  tf.math.reduce_sum_1 (TFOp  ()                           0         ['tf.reshape[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_2 (TFOp  ()                           0         ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_3 (TFOp  ()                           0         ['tf.math.multiply_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_4 (TFOp  ()                           0         ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_5 (TFOp  ()                           0         ['tf.reshape_3[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_6 (TFOp  ()                           0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_7 (TFOp  ()                           0         ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_8 (TFOp  ()                           0         ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_9 (TFOp  ()                           0         ['tf.math.multiply_6[0][0]']
#  Lambda)
#
#  tf.math.reduce_sum_10 (TFO  ()                           0         ['tf.reshape_6[0][0]']
#  pLambda)
#
#  tf.math.reduce_sum_11 (TFO  ()                           0         ['tf.reshape_7[0][0]']
#  pLambda)
#
#  tf.concat_7 (TFOpLambda)    (None, 1, 1, 38)             0         ['tf.math.reduce_mean_14[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_7[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  ()                           0         ['tf.math.reduce_sum[0][0]']
#  mbda)
#
#  tf.__operators__.add_9 (TF  ()                           0         ['tf.math.reduce_sum_1[0][0]',
#  OpLambda)                                                           'tf.math.reduce_sum_2[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  ()                           0         ['tf.math.reduce_sum_3[0][0]']
#  mbda)
#
#  tf.__operators__.add_12 (T  ()                           0         ['tf.math.reduce_sum_4[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  ()                           0         ['tf.math.reduce_sum_6[0][0]']
#  mbda)
#
#  tf.__operators__.add_15 (T  ()                           0         ['tf.math.reduce_sum_7[0][0]',
#  FOpLambda)                                                          'tf.math.reduce_sum_8[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  ()                           0         ['tf.math.reduce_sum_9[0][0]']
#  mbda)
#
#  tf.__operators__.add_18 (T  ()                           0         ['tf.math.reduce_sum_10[0][0]'
#  FOpLambda)                                                         , 'tf.math.reduce_sum_11[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 1, 1, 1)              39        ['tf.concat_7[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ']
#
#  tf.__operators__.add_8 (TF  ()                           0         ['tf.math.multiply_1[0][0]']
#  OpLambda)
#
#  tf.__operators__.add_10 (T  ()                           0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ']
#
#  tf.__operators__.add_11 (T  ()                           0         ['tf.math.multiply_3[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_13 (T  ()                           0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_14 (T  ()                           0         ['tf.math.multiply_5[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_16 (T  ()                           0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]']
#
#  tf.__operators__.add_17 (T  ()                           0         ['tf.math.multiply_7[0][0]']
#  FOpLambda)
#
#  tf.__operators__.add_19 (T  ()                           0         ['tf.__operators__.add_18[0][0
#  FOpLambda)                                                         ]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 19)             38        ['conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_15[0][0]
#                                                                     ']
#
#  tf.math.truediv_2 (TFOpLam  ()                           0         ['tf.__operators__.add_8[0][0]
#  bda)                                                               ',
#                                                                      'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  tf.math.truediv_5 (TFOpLam  ()                           0         ['tf.__operators__.add_11[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  tf.math.truediv_8 (TFOpLam  ()                           0         ['tf.__operators__.add_14[0][0
#  bda)                                                               ]',
#                                                                      'tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  tf.math.truediv_11 (TFOpLa  ()                           0         ['tf.__operators__.add_17[0][0
#  mbda)                                                              ]',
#                                                                      'tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  multiply_14 (Multiply)      (None, 256, 256, 19)         0         ['conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  tf.math.truediv_12 (TFOpLa  ()                           0         ['tf.math.truediv_2[0][0]']
#  mbda)
#
#  tf.math.truediv_13 (TFOpLa  ()                           0         ['tf.math.truediv_5[0][0]']
#  mbda)
#
#  tf.math.truediv_14 (TFOpLa  ()                           0         ['tf.math.truediv_8[0][0]']
#  mbda)
#
#  tf.math.truediv_15 (TFOpLa  ()                           0         ['tf.math.truediv_11[0][0]']
#  mbda)
#
#  multiply_15 (Multiply)      (None, 256, 256, 19)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  output_2_sum (Add)          ()                           0         ['tf.math.truediv_12[0][0]',
#                                                                      'tf.math.truediv_13[0][0]',
#                                                                      'tf.math.truediv_14[0][0]',
#                                                                      'tf.math.truediv_15[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          20        ['multiply_15[0][0]']
#
#  output_2 (Lambda)           ()                           0         ['output_2_sum[0][0]']
#
# ==================================================================================================
# Total params: 25705415 (98.06 MB)
# Trainable params: 25676885 (97.95 MB)
# Non-trainable params: 28530 (111.45 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.25},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

#callbacks
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=9
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool.h5", 
                               monitor="val_loss",
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=4, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, earlystopping, reduce_lr, csv_logger]

# %% [markdown]
# # Iterative Training Scheme
# # Two losses are used:
# * for segmentation: $Dice Loss + Focal Loss$
# * $Complementary~Loss$: to ensure that both models do not learn the same features

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
num_epochs = 50
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Set the training status for encoder1 and encoder2
    if epoch % 2 == 0:
        model.get_layer('encoder1').trainable = True
        model.get_layer('encoder2').trainable = False
    else:
        model.get_layer('encoder1').trainable = False
        model.get_layer('encoder2').trainable = True

    # Train the model for one epoch
    history = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=1,callbacks=callbacks)

# Save the final trained model
model.save('final_model.h5')
# Out:
# Epoch 1/50
# 2024-01-23 06:43:19.460156: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/encoder1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.4833 - output_1_loss: 0.4737 - output_2_loss: 0.0384 - output_1_iou_score: 0.3208 - output_1_dice_coeff: 0.5491 - output_1_precision: 0.6164 - output_1_recall: 0.5788 - output_1_sensitivity: 0.6184 - output_1_specificity: 0.9894 - output_1_auc: 0.8735
# Epoch 1: val_loss improved from inf to 1.11839, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 114s 231ms/step - loss: 0.4833 - output_1_loss: 0.4737 - output_2_loss: 0.0384 - output_1_iou_score: 0.3208 - output_1_dice_coeff: 0.5491 - output_1_precision: 0.6164 - output_1_recall: 0.5788 - output_1_sensitivity: 0.6184 - output_1_specificity: 0.9894 - output_1_auc: 0.8735 - val_loss: 1.1184 - val_output_1_loss: 1.0982 - val_output_2_loss: 0.0807 - val_output_1_iou_score: 2.6150e-06 - val_output_1_dice_coeff: 4.8651e-06 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5000 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3598 - output_1_loss: 0.3515 - output_2_loss: 0.0334 - output_1_iou_score: 0.4178 - output_1_dice_coeff: 0.6707 - output_1_precision: 0.7970 - output_1_recall: 0.6605 - output_1_sensitivity: 0.6814 - output_1_specificity: 0.9950 - output_1_auc: 0.8993
# Epoch 1: val_loss did not improve from 1.11839
# 233/233 [==============================] - 46s 195ms/step - loss: 0.3598 - output_1_loss: 0.3515 - output_2_loss: 0.0334 - output_1_iou_score: 0.4178 - output_1_dice_coeff: 0.6707 - output_1_precision: 0.7970 - output_1_recall: 0.6605 - output_1_sensitivity: 0.6814 - output_1_specificity: 0.9950 - output_1_auc: 0.8993 - val_loss: 1.1397 - val_output_1_loss: 1.1010 - val_output_2_loss: 0.1546 - val_output_1_iou_score: 8.3168e-07 - val_output_1_dice_coeff: 1.3461e-06 - val_output_1_precision: 0.0000e+00 - val_output_1_recall: 0.0000e+00 - val_output_1_sensitivity: 0.0000e+00 - val_output_1_specificity: 1.0000 - val_output_1_auc: 0.5000 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3343 - output_1_loss: 0.3293 - output_2_loss: 0.0200 - output_1_iou_score: 0.4432 - output_1_dice_coeff: 0.6917 - output_1_precision: 0.8004 - output_1_recall: 0.6755 - output_1_sensitivity: 0.6990 - output_1_specificity: 0.9950 - output_1_auc: 0.9065
# Epoch 1: val_loss improved from 1.11839 to 1.02543, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.3343 - output_1_loss: 0.3293 - output_2_loss: 0.0200 - output_1_iou_score: 0.4432 - output_1_dice_coeff: 0.6917 - output_1_precision: 0.8004 - output_1_recall: 0.6755 - output_1_sensitivity: 0.6990 - output_1_specificity: 0.9950 - output_1_auc: 0.9065 - val_loss: 1.0254 - val_output_1_loss: 0.9725 - val_output_2_loss: 0.2116 - val_output_1_iou_score: 0.0223 - val_output_1_dice_coeff: 0.0687 - val_output_1_precision: 0.8566 - val_output_1_recall: 0.0331 - val_output_1_sensitivity: 0.0265 - val_output_1_specificity: 0.9998 - val_output_1_auc: 0.6514 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3160 - output_1_loss: 0.3147 - output_2_loss: 0.0051 - output_1_iou_score: 0.4541 - output_1_dice_coeff: 0.7053 - output_1_precision: 0.8017 - output_1_recall: 0.6965 - output_1_sensitivity: 0.7092 - output_1_specificity: 0.9948 - output_1_auc: 0.9141
# Epoch 1: val_loss improved from 1.02543 to 0.72730, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.3160 - output_1_loss: 0.3147 - output_2_loss: 0.0051 - output_1_iou_score: 0.4541 - output_1_dice_coeff: 0.7053 - output_1_precision: 0.8017 - output_1_recall: 0.6965 - output_1_sensitivity: 0.7092 - output_1_specificity: 0.9948 - output_1_auc: 0.9141 - val_loss: 0.7273 - val_output_1_loss: 0.7177 - val_output_2_loss: 0.0383 - val_output_1_iou_score: 0.1369 - val_output_1_dice_coeff: 0.3157 - val_output_1_precision: 0.9722 - val_output_1_recall: 0.2254 - val_output_1_sensitivity: 0.1948 - val_output_1_specificity: 0.9998 - val_output_1_auc: 0.7565 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3095 - output_1_loss: 0.3093 - output_2_loss: 9.4408e-04 - output_1_iou_score: 0.4621 - output_1_dice_coeff: 0.7099 - output_1_precision: 0.8081 - output_1_recall: 0.7155 - output_1_sensitivity: 0.7194 - output_1_specificity: 0.9949 - output_1_auc: 0.9188
# Epoch 1: val_loss improved from 0.72730 to 0.34026, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.3095 - output_1_loss: 0.3093 - output_2_loss: 9.4408e-04 - output_1_iou_score: 0.4621 - output_1_dice_coeff: 0.7099 - output_1_precision: 0.8081 - output_1_recall: 0.7155 - output_1_sensitivity: 0.7194 - output_1_specificity: 0.9949 - output_1_auc: 0.9188 - val_loss: 0.3403 - val_output_1_loss: 0.3393 - val_output_2_loss: 0.0038 - val_output_1_iou_score: 0.4216 - val_output_1_dice_coeff: 0.6723 - val_output_1_precision: 0.8624 - val_output_1_recall: 0.6782 - val_output_1_sensitivity: 0.6200 - val_output_1_specificity: 0.9970 - val_output_1_auc: 0.9373 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3038 - output_1_loss: 0.3037 - output_2_loss: 6.7484e-04 - output_1_iou_score: 0.4655 - output_1_dice_coeff: 0.7131 - output_1_precision: 0.8157 - output_1_recall: 0.7317 - output_1_sensitivity: 0.7230 - output_1_specificity: 0.9952 - output_1_auc: 0.9305
# Epoch 1: val_loss did not improve from 0.34026
# 233/233 [==============================] - 45s 195ms/step - loss: 0.3038 - output_1_loss: 0.3037 - output_2_loss: 6.7484e-04 - output_1_iou_score: 0.4655 - output_1_dice_coeff: 0.7131 - output_1_precision: 0.8157 - output_1_recall: 0.7317 - output_1_sensitivity: 0.7230 - output_1_specificity: 0.9952 - output_1_auc: 0.9305 - val_loss: 0.3587 - val_output_1_loss: 0.3587 - val_output_2_loss: 3.5335e-04 - val_output_1_iou_score: 0.4103 - val_output_1_dice_coeff: 0.6608 - val_output_1_precision: 0.6949 - val_output_1_recall: 0.7829 - val_output_1_sensitivity: 0.7862 - val_output_1_specificity: 0.9903 - val_output_1_auc: 0.9414 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2827 - output_1_loss: 0.2827 - output_2_loss: 2.7892e-04 - output_1_iou_score: 0.4936 - output_1_dice_coeff: 0.7328 - output_1_precision: 0.8200 - output_1_recall: 0.7619 - output_1_sensitivity: 0.7372 - output_1_specificity: 0.9950 - output_1_auc: 0.9415
# Epoch 1: val_loss improved from 0.34026 to 0.32463, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2827 - output_1_loss: 0.2827 - output_2_loss: 2.7892e-04 - output_1_iou_score: 0.4936 - output_1_dice_coeff: 0.7328 - output_1_precision: 0.8200 - output_1_recall: 0.7619 - output_1_sensitivity: 0.7372 - output_1_specificity: 0.9950 - output_1_auc: 0.9415 - val_loss: 0.3246 - val_output_1_loss: 0.3245 - val_output_2_loss: 3.7424e-04 - val_output_1_iou_score: 0.4567 - val_output_1_dice_coeff: 0.6969 - val_output_1_precision: 0.6667 - val_output_1_recall: 0.8134 - val_output_1_sensitivity: 0.8079 - val_output_1_specificity: 0.9885 - val_output_1_auc: 0.9481 - lr: 1.0000e-04
# Epoch 8/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2784 - output_1_loss: 0.2784 - output_2_loss: 1.4447e-04 - output_1_iou_score: 0.4919 - output_1_dice_coeff: 0.7390 - output_1_precision: 0.8209 - output_1_recall: 0.7544 - output_1_sensitivity: 0.7411 - output_1_specificity: 0.9951 - output_1_auc: 0.9319
# Epoch 1: val_loss did not improve from 0.32463
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2784 - output_1_loss: 0.2784 - output_2_loss: 1.4447e-04 - output_1_iou_score: 0.4919 - output_1_dice_coeff: 0.7390 - output_1_precision: 0.8209 - output_1_recall: 0.7544 - output_1_sensitivity: 0.7411 - output_1_specificity: 0.9951 - output_1_auc: 0.9319 - val_loss: 0.4449 - val_output_1_loss: 0.4405 - val_output_2_loss: 0.0177 - val_output_1_iou_score: 0.4048 - val_output_1_dice_coeff: 0.5925 - val_output_1_precision: 0.5228 - val_output_1_recall: 0.8403 - val_output_1_sensitivity: 0.7912 - val_output_1_specificity: 0.9786 - val_output_1_auc: 0.9641 - lr: 1.0000e-04
# Epoch 9/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2769 - output_1_loss: 0.2766 - output_2_loss: 0.0012 - output_1_iou_score: 0.4962 - output_1_dice_coeff: 0.7413 - output_1_precision: 0.8185 - output_1_recall: 0.7470 - output_1_sensitivity: 0.7428 - output_1_specificity: 0.9951 - output_1_auc: 0.9281
# Epoch 1: val_loss improved from 0.32463 to 0.30703, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 198ms/step - loss: 0.2769 - output_1_loss: 0.2766 - output_2_loss: 0.0012 - output_1_iou_score: 0.4962 - output_1_dice_coeff: 0.7413 - output_1_precision: 0.8185 - output_1_recall: 0.7470 - output_1_sensitivity: 0.7428 - output_1_specificity: 0.9951 - output_1_auc: 0.9281 - val_loss: 0.3070 - val_output_1_loss: 0.2930 - val_output_2_loss: 0.0560 - val_output_1_iou_score: 0.4478 - val_output_1_dice_coeff: 0.7245 - val_output_1_precision: 0.7844 - val_output_1_recall: 0.7954 - val_output_1_sensitivity: 0.7301 - val_output_1_specificity: 0.9938 - val_output_1_auc: 0.9431 - lr: 1.0000e-04
# Epoch 10/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2922 - output_1_loss: 0.2638 - output_2_loss: 0.1139 - output_1_iou_score: 0.5057 - output_1_dice_coeff: 0.7510 - output_1_precision: 0.8273 - output_1_recall: 0.7641 - output_1_sensitivity: 0.7508 - output_1_specificity: 0.9953 - output_1_auc: 0.9428
# Epoch 1: val_loss did not improve from 0.30703
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2922 - output_1_loss: 0.2638 - output_2_loss: 0.1139 - output_1_iou_score: 0.5057 - output_1_dice_coeff: 0.7510 - output_1_precision: 0.8273 - output_1_recall: 0.7641 - output_1_sensitivity: 0.7508 - output_1_specificity: 0.9953 - output_1_auc: 0.9428 - val_loss: 0.3085 - val_output_1_loss: 0.2891 - val_output_2_loss: 0.0774 - val_output_1_iou_score: 0.4875 - val_output_1_dice_coeff: 0.7270 - val_output_1_precision: 0.8813 - val_output_1_recall: 0.7195 - val_output_1_sensitivity: 0.6661 - val_output_1_specificity: 0.9973 - val_output_1_auc: 0.9174 - lr: 1.0000e-04
# Epoch 11/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2773 - output_1_loss: 0.2583 - output_2_loss: 0.0761 - output_1_iou_score: 0.5191 - output_1_dice_coeff: 0.7563 - output_1_precision: 0.8308 - output_1_recall: 0.7841 - output_1_sensitivity: 0.7559 - output_1_specificity: 0.9952 - output_1_auc: 0.9449
# Epoch 1: val_loss improved from 0.30703 to 0.28913, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2773 - output_1_loss: 0.2583 - output_2_loss: 0.0761 - output_1_iou_score: 0.5191 - output_1_dice_coeff: 0.7563 - output_1_precision: 0.8308 - output_1_recall: 0.7841 - output_1_sensitivity: 0.7559 - output_1_specificity: 0.9952 - output_1_auc: 0.9449 - val_loss: 0.2891 - val_output_1_loss: 0.2723 - val_output_2_loss: 0.0673 - val_output_1_iou_score: 0.4845 - val_output_1_dice_coeff: 0.7409 - val_output_1_precision: 0.7792 - val_output_1_recall: 0.8405 - val_output_1_sensitivity: 0.7714 - val_output_1_specificity: 0.9933 - val_output_1_auc: 0.9640 - lr: 1.0000e-04
# Epoch 12/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2959 - output_1_loss: 0.2790 - output_2_loss: 0.0676 - output_1_iou_score: 0.5059 - output_1_dice_coeff: 0.7375 - output_1_precision: 0.8273 - output_1_recall: 0.7609 - output_1_sensitivity: 0.7401 - output_1_specificity: 0.9952 - output_1_auc: 0.9362
# Epoch 1: val_loss improved from 0.28913 to 0.28460, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2959 - output_1_loss: 0.2790 - output_2_loss: 0.0676 - output_1_iou_score: 0.5059 - output_1_dice_coeff: 0.7375 - output_1_precision: 0.8273 - output_1_recall: 0.7609 - output_1_sensitivity: 0.7401 - output_1_specificity: 0.9952 - output_1_auc: 0.9362 - val_loss: 0.2846 - val_output_1_loss: 0.2689 - val_output_2_loss: 0.0628 - val_output_1_iou_score: 0.5004 - val_output_1_dice_coeff: 0.7437 - val_output_1_precision: 0.8053 - val_output_1_recall: 0.8184 - val_output_1_sensitivity: 0.7650 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9604 - lr: 1.0000e-04
# Epoch 13/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2771 - output_1_loss: 0.2619 - output_2_loss: 0.0608 - output_1_iou_score: 0.5180 - output_1_dice_coeff: 0.7543 - output_1_precision: 0.8213 - output_1_recall: 0.7682 - output_1_sensitivity: 0.7563 - output_1_specificity: 0.9950 - output_1_auc: 0.9385
# Epoch 1: val_loss did not improve from 0.28460
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2771 - output_1_loss: 0.2619 - output_2_loss: 0.0608 - output_1_iou_score: 0.5180 - output_1_dice_coeff: 0.7543 - output_1_precision: 0.8213 - output_1_recall: 0.7682 - output_1_sensitivity: 0.7563 - output_1_specificity: 0.9950 - output_1_auc: 0.9385 - val_loss: 0.2959 - val_output_1_loss: 0.2816 - val_output_2_loss: 0.0573 - val_output_1_iou_score: 0.4935 - val_output_1_dice_coeff: 0.7336 - val_output_1_precision: 0.7625 - val_output_1_recall: 0.7755 - val_output_1_sensitivity: 0.7698 - val_output_1_specificity: 0.9932 - val_output_1_auc: 0.9560 - lr: 1.0000e-04
# Epoch 14/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2674 - output_1_loss: 0.2537 - output_2_loss: 0.0550 - output_1_iou_score: 0.5277 - output_1_dice_coeff: 0.7601 - output_1_precision: 0.8312 - output_1_recall: 0.7787 - output_1_sensitivity: 0.7593 - output_1_specificity: 0.9953 - output_1_auc: 0.9488
# Epoch 1: val_loss did not improve from 0.28460
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2674 - output_1_loss: 0.2537 - output_2_loss: 0.0550 - output_1_iou_score: 0.5277 - output_1_dice_coeff: 0.7601 - output_1_precision: 0.8312 - output_1_recall: 0.7787 - output_1_sensitivity: 0.7593 - output_1_specificity: 0.9953 - output_1_auc: 0.9488 - val_loss: 0.3008 - val_output_1_loss: 0.2880 - val_output_2_loss: 0.0510 - val_output_1_iou_score: 0.4819 - val_output_1_dice_coeff: 0.7295 - val_output_1_precision: 0.7409 - val_output_1_recall: 0.8632 - val_output_1_sensitivity: 0.8055 - val_output_1_specificity: 0.9915 - val_output_1_auc: 0.9638 - lr: 1.0000e-04
# Epoch 15/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2525 - output_1_loss: 0.2404 - output_2_loss: 0.0482 - output_1_iou_score: 0.5399 - output_1_dice_coeff: 0.7734 - output_1_precision: 0.8365 - output_1_recall: 0.8019 - output_1_sensitivity: 0.7738 - output_1_specificity: 0.9953 - output_1_auc: 0.9513
# Epoch 1: val_loss improved from 0.28460 to 0.27289, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2525 - output_1_loss: 0.2404 - output_2_loss: 0.0482 - output_1_iou_score: 0.5399 - output_1_dice_coeff: 0.7734 - output_1_precision: 0.8365 - output_1_recall: 0.8019 - output_1_sensitivity: 0.7738 - output_1_specificity: 0.9953 - output_1_auc: 0.9513 - val_loss: 0.2729 - val_output_1_loss: 0.2618 - val_output_2_loss: 0.0444 - val_output_1_iou_score: 0.4917 - val_output_1_dice_coeff: 0.7502 - val_output_1_precision: 0.8428 - val_output_1_recall: 0.7916 - val_output_1_sensitivity: 0.7257 - val_output_1_specificity: 0.9958 - val_output_1_auc: 0.9507 - lr: 1.0000e-04
# Epoch 16/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2425 - output_1_loss: 0.2326 - output_2_loss: 0.0396 - output_1_iou_score: 0.5491 - output_1_dice_coeff: 0.7807 - output_1_precision: 0.8403 - output_1_recall: 0.8029 - output_1_sensitivity: 0.7785 - output_1_specificity: 0.9954 - output_1_auc: 0.9538
# Epoch 1: val_loss did not improve from 0.27289
# 233/233 [==============================] - 46s 195ms/step - loss: 0.2425 - output_1_loss: 0.2326 - output_2_loss: 0.0396 - output_1_iou_score: 0.5491 - output_1_dice_coeff: 0.7807 - output_1_precision: 0.8403 - output_1_recall: 0.8029 - output_1_sensitivity: 0.7785 - output_1_specificity: 0.9954 - output_1_auc: 0.9538 - val_loss: 0.2733 - val_output_1_loss: 0.2645 - val_output_2_loss: 0.0354 - val_output_1_iou_score: 0.4994 - val_output_1_dice_coeff: 0.7492 - val_output_1_precision: 0.7970 - val_output_1_recall: 0.8309 - val_output_1_sensitivity: 0.7713 - val_output_1_specificity: 0.9940 - val_output_1_auc: 0.9586 - lr: 1.0000e-04
# Epoch 17/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2479 - output_1_loss: 0.2415 - output_2_loss: 0.0255 - output_1_iou_score: 0.5405 - output_1_dice_coeff: 0.7719 - output_1_precision: 0.8415 - output_1_recall: 0.7997 - output_1_sensitivity: 0.7695 - output_1_specificity: 0.9955 - output_1_auc: 0.9522
# Epoch 1: val_loss improved from 0.27289 to 0.26505, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2479 - output_1_loss: 0.2415 - output_2_loss: 0.0255 - output_1_iou_score: 0.5405 - output_1_dice_coeff: 0.7719 - output_1_precision: 0.8415 - output_1_recall: 0.7997 - output_1_sensitivity: 0.7695 - output_1_specificity: 0.9955 - output_1_auc: 0.9522 - val_loss: 0.2650 - val_output_1_loss: 0.2611 - val_output_2_loss: 0.0157 - val_output_1_iou_score: 0.4988 - val_output_1_dice_coeff: 0.7514 - val_output_1_precision: 0.8114 - val_output_1_recall: 0.8203 - val_output_1_sensitivity: 0.7757 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9601 - lr: 1.0000e-04
# Epoch 18/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2399 - output_1_loss: 0.2385 - output_2_loss: 0.0056 - output_1_iou_score: 0.5570 - output_1_dice_coeff: 0.7745 - output_1_precision: 0.8402 - output_1_recall: 0.8054 - output_1_sensitivity: 0.7752 - output_1_specificity: 0.9954 - output_1_auc: 0.9537
# Epoch 1: val_loss did not improve from 0.26505
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2399 - output_1_loss: 0.2385 - output_2_loss: 0.0056 - output_1_iou_score: 0.5570 - output_1_dice_coeff: 0.7745 - output_1_precision: 0.8402 - output_1_recall: 0.8054 - output_1_sensitivity: 0.7752 - output_1_specificity: 0.9954 - output_1_auc: 0.9537 - val_loss: 0.2693 - val_output_1_loss: 0.2691 - val_output_2_loss: 8.9013e-04 - val_output_1_iou_score: 0.4767 - val_output_1_dice_coeff: 0.7454 - val_output_1_precision: 0.8043 - val_output_1_recall: 0.8201 - val_output_1_sensitivity: 0.7505 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9529 - lr: 1.0000e-04
# Epoch 19/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2324 - output_1_loss: 0.2322 - output_2_loss: 6.9021e-04 - output_1_iou_score: 0.5598 - output_1_dice_coeff: 0.7806 - output_1_precision: 0.8476 - output_1_recall: 0.8041 - output_1_sensitivity: 0.7781 - output_1_specificity: 0.9957 - output_1_auc: 0.9535
# Epoch 1: val_loss did not improve from 0.26505
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2324 - output_1_loss: 0.2322 - output_2_loss: 6.9021e-04 - output_1_iou_score: 0.5598 - output_1_dice_coeff: 0.7806 - output_1_precision: 0.8476 - output_1_recall: 0.8041 - output_1_sensitivity: 0.7781 - output_1_specificity: 0.9957 - output_1_auc: 0.9535 - val_loss: 0.2810 - val_output_1_loss: 0.2809 - val_output_2_loss: 4.3982e-04 - val_output_1_iou_score: 0.4710 - val_output_1_dice_coeff: 0.7341 - val_output_1_precision: 0.8014 - val_output_1_recall: 0.8195 - val_output_1_sensitivity: 0.7277 - val_output_1_specificity: 0.9942 - val_output_1_auc: 0.9499 - lr: 1.0000e-04
# Epoch 20/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2257 - output_1_loss: 0.2256 - output_2_loss: 1.9280e-04 - output_1_iou_score: 0.5598 - output_1_dice_coeff: 0.7868 - output_1_precision: 0.8445 - output_1_recall: 0.8121 - output_1_sensitivity: 0.7829 - output_1_specificity: 0.9955 - output_1_auc: 0.9549
# Epoch 1: val_loss improved from 0.26505 to 0.26374, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 198ms/step - loss: 0.2257 - output_1_loss: 0.2256 - output_2_loss: 1.9280e-04 - output_1_iou_score: 0.5598 - output_1_dice_coeff: 0.7868 - output_1_precision: 0.8445 - output_1_recall: 0.8121 - output_1_sensitivity: 0.7829 - output_1_specificity: 0.9955 - output_1_auc: 0.9549 - val_loss: 0.2637 - val_output_1_loss: 0.2636 - val_output_2_loss: 4.7488e-04 - val_output_1_iou_score: 0.4920 - val_output_1_dice_coeff: 0.7497 - val_output_1_precision: 0.8112 - val_output_1_recall: 0.8217 - val_output_1_sensitivity: 0.7557 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9548 - lr: 1.0000e-04
# Epoch 21/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2287 - output_1_loss: 0.2287 - output_2_loss: 7.3249e-05 - output_1_iou_score: 0.5597 - output_1_dice_coeff: 0.7841 - output_1_precision: 0.8478 - output_1_recall: 0.8108 - output_1_sensitivity: 0.7824 - output_1_specificity: 0.9956 - output_1_auc: 0.9548
# Epoch 1: val_loss did not improve from 0.26374
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2287 - output_1_loss: 0.2287 - output_2_loss: 7.3249e-05 - output_1_iou_score: 0.5597 - output_1_dice_coeff: 0.7841 - output_1_precision: 0.8478 - output_1_recall: 0.8108 - output_1_sensitivity: 0.7824 - output_1_specificity: 0.9956 - output_1_auc: 0.9548 - val_loss: 0.2685 - val_output_1_loss: 0.2685 - val_output_2_loss: 1.2476e-04 - val_output_1_iou_score: 0.4893 - val_output_1_dice_coeff: 0.7449 - val_output_1_precision: 0.7820 - val_output_1_recall: 0.8484 - val_output_1_sensitivity: 0.7885 - val_output_1_specificity: 0.9933 - val_output_1_auc: 0.9648 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2471 - output_1_loss: 0.2471 - output_2_loss: 6.9595e-05 - output_1_iou_score: 0.5446 - output_1_dice_coeff: 0.7666 - output_1_precision: 0.8343 - output_1_recall: 0.7864 - output_1_sensitivity: 0.7704 - output_1_specificity: 0.9953 - output_1_auc: 0.9496
# Epoch 1: val_loss did not improve from 0.26374
# 233/233 [==============================] - 46s 196ms/step - loss: 0.2471 - output_1_loss: 0.2471 - output_2_loss: 6.9595e-05 - output_1_iou_score: 0.5446 - output_1_dice_coeff: 0.7666 - output_1_precision: 0.8343 - output_1_recall: 0.7864 - output_1_sensitivity: 0.7704 - output_1_specificity: 0.9953 - output_1_auc: 0.9496 - val_loss: 0.2841 - val_output_1_loss: 0.2841 - val_output_2_loss: 2.6147e-04 - val_output_1_iou_score: 0.4659 - val_output_1_dice_coeff: 0.7308 - val_output_1_precision: 0.8493 - val_output_1_recall: 0.7719 - val_output_1_sensitivity: 0.6910 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9346 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2331 - output_1_loss: 0.2331 - output_2_loss: 1.0181e-04 - output_1_iou_score: 0.5563 - output_1_dice_coeff: 0.7795 - output_1_precision: 0.8436 - output_1_recall: 0.8122 - output_1_sensitivity: 0.7757 - output_1_specificity: 0.9955 - output_1_auc: 0.9560
# Epoch 1: val_loss did not improve from 0.26374
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2331 - output_1_loss: 0.2331 - output_2_loss: 1.0181e-04 - output_1_iou_score: 0.5563 - output_1_dice_coeff: 0.7795 - output_1_precision: 0.8436 - output_1_recall: 0.8122 - output_1_sensitivity: 0.7757 - output_1_specificity: 0.9955 - output_1_auc: 0.9560 - val_loss: 0.2699 - val_output_1_loss: 0.2699 - val_output_2_loss: 1.0770e-04 - val_output_1_iou_score: 0.4910 - val_output_1_dice_coeff: 0.7449 - val_output_1_precision: 0.7797 - val_output_1_recall: 0.8450 - val_output_1_sensitivity: 0.7925 - val_output_1_specificity: 0.9932 - val_output_1_auc: 0.9614 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2241 - output_1_loss: 0.2241 - output_2_loss: 8.2381e-05 - output_1_iou_score: 0.5619 - output_1_dice_coeff: 0.7887 - output_1_precision: 0.8474 - output_1_recall: 0.8088 - output_1_sensitivity: 0.7875 - output_1_specificity: 0.9956 - output_1_auc: 0.9544
# Epoch 1: val_loss did not improve from 0.26374
# 233/233 [==============================] - 45s 194ms/step - loss: 0.2241 - output_1_loss: 0.2241 - output_2_loss: 8.2381e-05 - output_1_iou_score: 0.5619 - output_1_dice_coeff: 0.7887 - output_1_precision: 0.8474 - output_1_recall: 0.8088 - output_1_sensitivity: 0.7875 - output_1_specificity: 0.9956 - output_1_auc: 0.9544 - val_loss: 0.2669 - val_output_1_loss: 0.2669 - val_output_2_loss: 8.0603e-05 - val_output_1_iou_score: 0.4889 - val_output_1_dice_coeff: 0.7457 - val_output_1_precision: 0.7952 - val_output_1_recall: 0.8363 - val_output_1_sensitivity: 0.7652 - val_output_1_specificity: 0.9939 - val_output_1_auc: 0.9629 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2241 - output_1_loss: 0.2241 - output_2_loss: 1.7310e-05 - output_1_iou_score: 0.5726 - output_1_dice_coeff: 0.7882 - output_1_precision: 0.8466 - output_1_recall: 0.8135 - output_1_sensitivity: 0.7875 - output_1_specificity: 0.9956 - output_1_auc: 0.9575
# Epoch 1: val_loss improved from 0.26374 to 0.26009, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2241 - output_1_loss: 0.2241 - output_2_loss: 1.7310e-05 - output_1_iou_score: 0.5726 - output_1_dice_coeff: 0.7882 - output_1_precision: 0.8466 - output_1_recall: 0.8135 - output_1_sensitivity: 0.7875 - output_1_specificity: 0.9956 - output_1_auc: 0.9575 - val_loss: 0.2601 - val_output_1_loss: 0.2601 - val_output_2_loss: 9.1959e-05 - val_output_1_iou_score: 0.5086 - val_output_1_dice_coeff: 0.7538 - val_output_1_precision: 0.8116 - val_output_1_recall: 0.8271 - val_output_1_sensitivity: 0.7687 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9551 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2206 - output_1_loss: 0.2206 - output_2_loss: 3.0238e-05 - output_1_iou_score: 0.5739 - output_1_dice_coeff: 0.7914 - output_1_precision: 0.8516 - output_1_recall: 0.8148 - output_1_sensitivity: 0.7886 - output_1_specificity: 0.9957 - output_1_auc: 0.9568
# Epoch 1: val_loss did not improve from 0.26009
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2206 - output_1_loss: 0.2206 - output_2_loss: 3.0238e-05 - output_1_iou_score: 0.5739 - output_1_dice_coeff: 0.7914 - output_1_precision: 0.8516 - output_1_recall: 0.8148 - output_1_sensitivity: 0.7886 - output_1_specificity: 0.9957 - output_1_auc: 0.9568 - val_loss: 0.2772 - val_output_1_loss: 0.2772 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5094 - val_output_1_dice_coeff: 0.7380 - val_output_1_precision: 0.7470 - val_output_1_recall: 0.8593 - val_output_1_sensitivity: 0.8106 - val_output_1_specificity: 0.9918 - val_output_1_auc: 0.9674 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2081 - output_1_loss: 0.2080 - output_2_loss: 6.6432e-05 - output_1_iou_score: 0.5927 - output_1_dice_coeff: 0.8035 - output_1_precision: 0.8520 - output_1_recall: 0.8249 - output_1_sensitivity: 0.8004 - output_1_specificity: 0.9957 - output_1_auc: 0.9608
# Epoch 1: val_loss improved from 0.26009 to 0.25775, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2081 - output_1_loss: 0.2080 - output_2_loss: 6.6432e-05 - output_1_iou_score: 0.5927 - output_1_dice_coeff: 0.8035 - output_1_precision: 0.8520 - output_1_recall: 0.8249 - output_1_sensitivity: 0.8004 - output_1_specificity: 0.9957 - output_1_auc: 0.9608 - val_loss: 0.2577 - val_output_1_loss: 0.2577 - val_output_2_loss: 5.1628e-05 - val_output_1_iou_score: 0.5000 - val_output_1_dice_coeff: 0.7563 - val_output_1_precision: 0.8260 - val_output_1_recall: 0.8103 - val_output_1_sensitivity: 0.7601 - val_output_1_specificity: 0.9952 - val_output_1_auc: 0.9497 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2159 - output_1_loss: 0.2159 - output_2_loss: 7.8309e-05 - output_1_iou_score: 0.5892 - output_1_dice_coeff: 0.7956 - output_1_precision: 0.8546 - output_1_recall: 0.8259 - output_1_sensitivity: 0.7906 - output_1_specificity: 0.9958 - output_1_auc: 0.9604
# Epoch 1: val_loss improved from 0.25775 to 0.25703, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2159 - output_1_loss: 0.2159 - output_2_loss: 7.8309e-05 - output_1_iou_score: 0.5892 - output_1_dice_coeff: 0.7956 - output_1_precision: 0.8546 - output_1_recall: 0.8259 - output_1_sensitivity: 0.7906 - output_1_specificity: 0.9958 - output_1_auc: 0.9604 - val_loss: 0.2570 - val_output_1_loss: 0.2570 - val_output_2_loss: 8.4389e-05 - val_output_1_iou_score: 0.5075 - val_output_1_dice_coeff: 0.7569 - val_output_1_precision: 0.8316 - val_output_1_recall: 0.8033 - val_output_1_sensitivity: 0.7560 - val_output_1_specificity: 0.9954 - val_output_1_auc: 0.9475 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2141 - output_1_loss: 0.2141 - output_2_loss: 6.0044e-05 - output_1_iou_score: 0.5920 - output_1_dice_coeff: 0.7972 - output_1_precision: 0.8529 - output_1_recall: 0.8197 - output_1_sensitivity: 0.7954 - output_1_specificity: 0.9957 - output_1_auc: 0.9589
# Epoch 1: val_loss did not improve from 0.25703
# 233/233 [==============================] - 46s 195ms/step - loss: 0.2141 - output_1_loss: 0.2141 - output_2_loss: 6.0044e-05 - output_1_iou_score: 0.5920 - output_1_dice_coeff: 0.7972 - output_1_precision: 0.8529 - output_1_recall: 0.8197 - output_1_sensitivity: 0.7954 - output_1_specificity: 0.9957 - output_1_auc: 0.9589 - val_loss: 0.2685 - val_output_1_loss: 0.2685 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4967 - val_output_1_dice_coeff: 0.7475 - val_output_1_precision: 0.7706 - val_output_1_recall: 0.8540 - val_output_1_sensitivity: 0.8039 - val_output_1_specificity: 0.9928 - val_output_1_auc: 0.9611 - lr: 1.0000e-04
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2123 - output_1_loss: 0.2123 - output_2_loss: 3.6536e-05 - output_1_iou_score: 0.5938 - output_1_dice_coeff: 0.7991 - output_1_precision: 0.8552 - output_1_recall: 0.8269 - output_1_sensitivity: 0.7970 - output_1_specificity: 0.9958 - output_1_auc: 0.9615
# Epoch 1: val_loss did not improve from 0.25703
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2123 - output_1_loss: 0.2123 - output_2_loss: 3.6536e-05 - output_1_iou_score: 0.5938 - output_1_dice_coeff: 0.7991 - output_1_precision: 0.8552 - output_1_recall: 0.8269 - output_1_sensitivity: 0.7970 - output_1_specificity: 0.9958 - output_1_auc: 0.9615 - val_loss: 0.2796 - val_output_1_loss: 0.2796 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4668 - val_output_1_dice_coeff: 0.7341 - val_output_1_precision: 0.8490 - val_output_1_recall: 0.7744 - val_output_1_sensitivity: 0.6991 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9392 - lr: 1.0000e-04
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2075 - output_1_loss: 0.2075 - output_2_loss: 2.6102e-05 - output_1_iou_score: 0.5916 - output_1_dice_coeff: 0.8030 - output_1_precision: 0.8556 - output_1_recall: 0.8257 - output_1_sensitivity: 0.8021 - output_1_specificity: 0.9958 - output_1_auc: 0.9606
# Epoch 1: val_loss improved from 0.25703 to 0.25639, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2075 - output_1_loss: 0.2075 - output_2_loss: 2.6102e-05 - output_1_iou_score: 0.5916 - output_1_dice_coeff: 0.8030 - output_1_precision: 0.8556 - output_1_recall: 0.8257 - output_1_sensitivity: 0.8021 - output_1_specificity: 0.9958 - output_1_auc: 0.9606 - val_loss: 0.2564 - val_output_1_loss: 0.2564 - val_output_2_loss: 1.3884e-04 - val_output_1_iou_score: 0.4988 - val_output_1_dice_coeff: 0.7555 - val_output_1_precision: 0.8558 - val_output_1_recall: 0.7869 - val_output_1_sensitivity: 0.7230 - val_output_1_specificity: 0.9962 - val_output_1_auc: 0.9479 - lr: 1.0000e-04
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2122 - output_1_loss: 0.2122 - output_2_loss: 4.4182e-05 - output_1_iou_score: 0.5976 - output_1_dice_coeff: 0.7995 - output_1_precision: 0.8552 - output_1_recall: 0.8284 - output_1_sensitivity: 0.7995 - output_1_specificity: 0.9958 - output_1_auc: 0.9601
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2122 - output_1_loss: 0.2122 - output_2_loss: 4.4182e-05 - output_1_iou_score: 0.5976 - output_1_dice_coeff: 0.7995 - output_1_precision: 0.8552 - output_1_recall: 0.8284 - output_1_sensitivity: 0.7995 - output_1_specificity: 0.9958 - output_1_auc: 0.9601 - val_loss: 0.2901 - val_output_1_loss: 0.2901 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4712 - val_output_1_dice_coeff: 0.7248 - val_output_1_precision: 0.8417 - val_output_1_recall: 0.7528 - val_output_1_sensitivity: 0.7016 - val_output_1_specificity: 0.9960 - val_output_1_auc: 0.9336 - lr: 1.0000e-04
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2145 - output_1_loss: 0.2145 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.5960 - output_1_dice_coeff: 0.7967 - output_1_precision: 0.8545 - output_1_recall: 0.8275 - output_1_sensitivity: 0.7962 - output_1_specificity: 0.9958 - output_1_auc: 0.9610
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2145 - output_1_loss: 0.2145 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.5960 - output_1_dice_coeff: 0.7967 - output_1_precision: 0.8545 - output_1_recall: 0.8275 - output_1_sensitivity: 0.7962 - output_1_specificity: 0.9958 - output_1_auc: 0.9610 - val_loss: 0.2572 - val_output_1_loss: 0.2572 - val_output_2_loss: 3.5228e-05 - val_output_1_iou_score: 0.5153 - val_output_1_dice_coeff: 0.7562 - val_output_1_precision: 0.8125 - val_output_1_recall: 0.8273 - val_output_1_sensitivity: 0.7677 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9564 - lr: 1.0000e-04
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2137 - output_1_loss: 0.2137 - output_2_loss: 2.7666e-05 - output_1_iou_score: 0.5910 - output_1_dice_coeff: 0.7972 - output_1_precision: 0.8535 - output_1_recall: 0.8223 - output_1_sensitivity: 0.7995 - output_1_specificity: 0.9958 - output_1_auc: 0.9598
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2137 - output_1_loss: 0.2137 - output_2_loss: 2.7666e-05 - output_1_iou_score: 0.5910 - output_1_dice_coeff: 0.7972 - output_1_precision: 0.8535 - output_1_recall: 0.8223 - output_1_sensitivity: 0.7995 - output_1_specificity: 0.9958 - output_1_auc: 0.9598 - val_loss: 0.3094 - val_output_1_loss: 0.3094 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4540 - val_output_1_dice_coeff: 0.7078 - val_output_1_precision: 0.8335 - val_output_1_recall: 0.7620 - val_output_1_sensitivity: 0.6663 - val_output_1_specificity: 0.9957 - val_output_1_auc: 0.9221 - lr: 1.0000e-04
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2071 - output_1_loss: 0.2071 - output_2_loss: 4.0201e-05 - output_1_iou_score: 0.5984 - output_1_dice_coeff: 0.8042 - output_1_precision: 0.8568 - output_1_recall: 0.8259 - output_1_sensitivity: 0.8050 - output_1_specificity: 0.9958 - output_1_auc: 0.9603
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 195ms/step - loss: 0.2071 - output_1_loss: 0.2071 - output_2_loss: 4.0201e-05 - output_1_iou_score: 0.5984 - output_1_dice_coeff: 0.8042 - output_1_precision: 0.8568 - output_1_recall: 0.8259 - output_1_sensitivity: 0.8050 - output_1_specificity: 0.9958 - output_1_auc: 0.9603 - val_loss: 0.3062 - val_output_1_loss: 0.3062 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4660 - val_output_1_dice_coeff: 0.7129 - val_output_1_precision: 0.6963 - val_output_1_recall: 0.8821 - val_output_1_sensitivity: 0.8333 - val_output_1_specificity: 0.9891 - val_output_1_auc: 0.9699 - lr: 1.0000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1957 - output_1_loss: 0.1957 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6125 - output_1_dice_coeff: 0.8153 - output_1_precision: 0.8592 - output_1_recall: 0.8339 - output_1_sensitivity: 0.8121 - output_1_specificity: 0.9959 - output_1_auc: 0.9625
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1957 - output_1_loss: 0.1957 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6125 - output_1_dice_coeff: 0.8153 - output_1_precision: 0.8592 - output_1_recall: 0.8339 - output_1_sensitivity: 0.8121 - output_1_specificity: 0.9959 - output_1_auc: 0.9625 - val_loss: 0.2607 - val_output_1_loss: 0.2607 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5063 - val_output_1_dice_coeff: 0.7542 - val_output_1_precision: 0.8398 - val_output_1_recall: 0.7913 - val_output_1_sensitivity: 0.7478 - val_output_1_specificity: 0.9957 - val_output_1_auc: 0.9407 - lr: 1.0000e-04
# Epoch 37/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1986 - output_1_loss: 0.1986 - output_2_loss: 6.3331e-05 - output_1_iou_score: 0.6109 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8579 - output_1_recall: 0.8337 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9959 - output_1_auc: 0.9632
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1986 - output_1_loss: 0.1986 - output_2_loss: 6.3331e-05 - output_1_iou_score: 0.6109 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8579 - output_1_recall: 0.8337 - output_1_sensitivity: 0.8104 - output_1_specificity: 0.9959 - output_1_auc: 0.9632 - val_loss: 0.2605 - val_output_1_loss: 0.2605 - val_output_2_loss: 7.5566e-05 - val_output_1_iou_score: 0.5150 - val_output_1_dice_coeff: 0.7534 - val_output_1_precision: 0.8289 - val_output_1_recall: 0.8068 - val_output_1_sensitivity: 0.7611 - val_output_1_specificity: 0.9953 - val_output_1_auc: 0.9479 - lr: 1.0000e-04
# Epoch 38/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1963 - output_1_loss: 0.1963 - output_2_loss: 2.0365e-05 - output_1_iou_score: 0.6147 - output_1_dice_coeff: 0.8131 - output_1_precision: 0.8592 - output_1_recall: 0.8403 - output_1_sensitivity: 0.8113 - output_1_specificity: 0.9958 - output_1_auc: 0.9655
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1963 - output_1_loss: 0.1963 - output_2_loss: 2.0365e-05 - output_1_iou_score: 0.6147 - output_1_dice_coeff: 0.8131 - output_1_precision: 0.8592 - output_1_recall: 0.8403 - output_1_sensitivity: 0.8113 - output_1_specificity: 0.9958 - output_1_auc: 0.9655 - val_loss: 0.2600 - val_output_1_loss: 0.2600 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5078 - val_output_1_dice_coeff: 0.7537 - val_output_1_precision: 0.8244 - val_output_1_recall: 0.8116 - val_output_1_sensitivity: 0.7632 - val_output_1_specificity: 0.9951 - val_output_1_auc: 0.9498 - lr: 1.0000e-04
# Epoch 39/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1941 - output_1_loss: 0.1940 - output_2_loss: 2.8093e-05 - output_1_iou_score: 0.6202 - output_1_dice_coeff: 0.8166 - output_1_precision: 0.8645 - output_1_recall: 0.8355 - output_1_sensitivity: 0.8112 - output_1_specificity: 0.9961 - output_1_auc: 0.9623
# Epoch 1: val_loss did not improve from 0.25639
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1941 - output_1_loss: 0.1940 - output_2_loss: 2.8093e-05 - output_1_iou_score: 0.6202 - output_1_dice_coeff: 0.8166 - output_1_precision: 0.8645 - output_1_recall: 0.8355 - output_1_sensitivity: 0.8112 - output_1_specificity: 0.9961 - output_1_auc: 0.9623 - val_loss: 0.2665 - val_output_1_loss: 0.2664 - val_output_2_loss: 2.1235e-04 - val_output_1_iou_score: 0.4845 - val_output_1_dice_coeff: 0.7479 - val_output_1_precision: 0.8509 - val_output_1_recall: 0.7825 - val_output_1_sensitivity: 0.7106 - val_output_1_specificity: 0.9961 - val_output_1_auc: 0.9362 - lr: 1.0000e-04
# Epoch 40/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2017 - output_1_loss: 0.2017 - output_2_loss: 1.2559e-04 - output_1_iou_score: 0.6140 - output_1_dice_coeff: 0.8093 - output_1_precision: 0.8617 - output_1_recall: 0.8346 - output_1_sensitivity: 0.8084 - output_1_specificity: 0.9960 - output_1_auc: 0.9632
# Epoch 1: val_loss improved from 0.25639 to 0.25588, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.2017 - output_1_loss: 0.2017 - output_2_loss: 1.2559e-04 - output_1_iou_score: 0.6140 - output_1_dice_coeff: 0.8093 - output_1_precision: 0.8617 - output_1_recall: 0.8346 - output_1_sensitivity: 0.8084 - output_1_specificity: 0.9960 - output_1_auc: 0.9632 - val_loss: 0.2559 - val_output_1_loss: 0.2559 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5031 - val_output_1_dice_coeff: 0.7584 - val_output_1_precision: 0.8112 - val_output_1_recall: 0.8272 - val_output_1_sensitivity: 0.7710 - val_output_1_specificity: 0.9945 - val_output_1_auc: 0.9522 - lr: 1.0000e-04
# Epoch 41/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1980 - output_1_loss: 0.1980 - output_2_loss: 6.0491e-05 - output_1_iou_score: 0.6176 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8608 - output_1_recall: 0.8397 - output_1_sensitivity: 0.8128 - output_1_specificity: 0.9960 - output_1_auc: 0.9644
# Epoch 1: val_loss did not improve from 0.25588
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1980 - output_1_loss: 0.1980 - output_2_loss: 6.0491e-05 - output_1_iou_score: 0.6176 - output_1_dice_coeff: 0.8123 - output_1_precision: 0.8608 - output_1_recall: 0.8397 - output_1_sensitivity: 0.8128 - output_1_specificity: 0.9960 - output_1_auc: 0.9644 - val_loss: 0.2650 - val_output_1_loss: 0.2650 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4966 - val_output_1_dice_coeff: 0.7491 - val_output_1_precision: 0.8443 - val_output_1_recall: 0.7931 - val_output_1_sensitivity: 0.7264 - val_output_1_specificity: 0.9959 - val_output_1_auc: 0.9397 - lr: 1.0000e-04
# Epoch 42/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1939 - output_1_loss: 0.1939 - output_2_loss: 7.6297e-05 - output_1_iou_score: 0.6245 - output_1_dice_coeff: 0.8165 - output_1_precision: 0.8644 - output_1_recall: 0.8394 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9960 - output_1_auc: 0.9646
# Epoch 1: val_loss improved from 0.25588 to 0.25307, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1939 - output_1_loss: 0.1939 - output_2_loss: 7.6297e-05 - output_1_iou_score: 0.6245 - output_1_dice_coeff: 0.8165 - output_1_precision: 0.8644 - output_1_recall: 0.8394 - output_1_sensitivity: 0.8150 - output_1_specificity: 0.9960 - output_1_auc: 0.9646 - val_loss: 0.2531 - val_output_1_loss: 0.2530 - val_output_2_loss: 2.0995e-04 - val_output_1_iou_score: 0.5152 - val_output_1_dice_coeff: 0.7609 - val_output_1_precision: 0.8073 - val_output_1_recall: 0.8365 - val_output_1_sensitivity: 0.7820 - val_output_1_specificity: 0.9943 - val_output_1_auc: 0.9564 - lr: 1.0000e-04
# Epoch 43/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1882 - output_1_loss: 0.1881 - output_2_loss: 8.3714e-05 - output_1_iou_score: 0.6306 - output_1_dice_coeff: 0.8222 - output_1_precision: 0.8661 - output_1_recall: 0.8446 - output_1_sensitivity: 0.8189 - output_1_specificity: 0.9960 - output_1_auc: 0.9652
# Epoch 1: val_loss did not improve from 0.25307
# 233/233 [==============================] - 46s 195ms/step - loss: 0.1882 - output_1_loss: 0.1881 - output_2_loss: 8.3714e-05 - output_1_iou_score: 0.6306 - output_1_dice_coeff: 0.8222 - output_1_precision: 0.8661 - output_1_recall: 0.8446 - output_1_sensitivity: 0.8189 - output_1_specificity: 0.9960 - output_1_auc: 0.9652 - val_loss: 0.2586 - val_output_1_loss: 0.2586 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.4968 - val_output_1_dice_coeff: 0.7566 - val_output_1_precision: 0.8556 - val_output_1_recall: 0.7816 - val_output_1_sensitivity: 0.7247 - val_output_1_specificity: 0.9963 - val_output_1_auc: 0.9325 - lr: 1.0000e-04
# Epoch 44/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1885 - output_1_loss: 0.1885 - output_2_loss: 3.5251e-05 - output_1_iou_score: 0.6307 - output_1_dice_coeff: 0.8216 - output_1_precision: 0.8643 - output_1_recall: 0.8462 - output_1_sensitivity: 0.8203 - output_1_specificity: 0.9960 - output_1_auc: 0.9660
# Epoch 1: val_loss did not improve from 0.25307
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1885 - output_1_loss: 0.1885 - output_2_loss: 3.5251e-05 - output_1_iou_score: 0.6307 - output_1_dice_coeff: 0.8216 - output_1_precision: 0.8643 - output_1_recall: 0.8462 - output_1_sensitivity: 0.8203 - output_1_specificity: 0.9960 - output_1_auc: 0.9660 - val_loss: 0.2545 - val_output_1_loss: 0.2544 - val_output_2_loss: 5.6094e-05 - val_output_1_iou_score: 0.5160 - val_output_1_dice_coeff: 0.7604 - val_output_1_precision: 0.8160 - val_output_1_recall: 0.8225 - val_output_1_sensitivity: 0.7676 - val_output_1_specificity: 0.9948 - val_output_1_auc: 0.9473 - lr: 1.0000e-04
# Epoch 45/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1896 - output_1_loss: 0.1896 - output_2_loss: 1.0445e-04 - output_1_iou_score: 0.6362 - output_1_dice_coeff: 0.8203 - output_1_precision: 0.8646 - output_1_recall: 0.8455 - output_1_sensitivity: 0.8181 - output_1_specificity: 0.9960 - output_1_auc: 0.9653
# Epoch 1: val_loss improved from 0.25307 to 0.25096, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1896 - output_1_loss: 0.1896 - output_2_loss: 1.0445e-04 - output_1_iou_score: 0.6362 - output_1_dice_coeff: 0.8203 - output_1_precision: 0.8646 - output_1_recall: 0.8455 - output_1_sensitivity: 0.8181 - output_1_specificity: 0.9960 - output_1_auc: 0.9653 - val_loss: 0.2510 - val_output_1_loss: 0.2510 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5046 - val_output_1_dice_coeff: 0.7620 - val_output_1_precision: 0.8255 - val_output_1_recall: 0.8204 - val_output_1_sensitivity: 0.7607 - val_output_1_specificity: 0.9951 - val_output_1_auc: 0.9522 - lr: 1.0000e-04
# Epoch 46/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1789 - output_1_loss: 0.1789 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6421 - output_1_dice_coeff: 0.8310 - output_1_precision: 0.8690 - output_1_recall: 0.8493 - output_1_sensitivity: 0.8292 - output_1_specificity: 0.9962 - output_1_auc: 0.9659
# Epoch 1: val_loss did not improve from 0.25096
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1789 - output_1_loss: 0.1789 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6421 - output_1_dice_coeff: 0.8310 - output_1_precision: 0.8690 - output_1_recall: 0.8493 - output_1_sensitivity: 0.8292 - output_1_specificity: 0.9962 - output_1_auc: 0.9659 - val_loss: 0.2579 - val_output_1_loss: 0.2579 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5126 - val_output_1_dice_coeff: 0.7578 - val_output_1_precision: 0.7941 - val_output_1_recall: 0.8413 - val_output_1_sensitivity: 0.7917 - val_output_1_specificity: 0.9938 - val_output_1_auc: 0.9537 - lr: 1.0000e-04
# Epoch 47/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1841 - output_1_loss: 0.1841 - output_2_loss: 4.7818e-05 - output_1_iou_score: 0.6326 - output_1_dice_coeff: 0.8261 - output_1_precision: 0.8648 - output_1_recall: 0.8483 - output_1_sensitivity: 0.8243 - output_1_specificity: 0.9960 - output_1_auc: 0.9654
# Epoch 1: val_loss improved from 0.25096 to 0.24923, saving model to /kaggle/working/WNet_maxpool.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1841 - output_1_loss: 0.1841 - output_2_loss: 4.7818e-05 - output_1_iou_score: 0.6326 - output_1_dice_coeff: 0.8261 - output_1_precision: 0.8648 - output_1_recall: 0.8483 - output_1_sensitivity: 0.8243 - output_1_specificity: 0.9960 - output_1_auc: 0.9654 - val_loss: 0.2492 - val_output_1_loss: 0.2492 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5198 - val_output_1_dice_coeff: 0.7650 - val_output_1_precision: 0.8096 - val_output_1_recall: 0.8268 - val_output_1_sensitivity: 0.7758 - val_output_1_specificity: 0.9944 - val_output_1_auc: 0.9503 - lr: 1.0000e-04
# Epoch 48/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1732 - output_1_loss: 0.1732 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6520 - output_1_dice_coeff: 0.8367 - output_1_precision: 0.8709 - output_1_recall: 0.8541 - output_1_sensitivity: 0.8345 - output_1_specificity: 0.9962 - output_1_auc: 0.9660
# Epoch 1: val_loss did not improve from 0.24923
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1732 - output_1_loss: 0.1732 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6520 - output_1_dice_coeff: 0.8367 - output_1_precision: 0.8709 - output_1_recall: 0.8541 - output_1_sensitivity: 0.8345 - output_1_specificity: 0.9962 - output_1_auc: 0.9660 - val_loss: 0.2565 - val_output_1_loss: 0.2565 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5102 - val_output_1_dice_coeff: 0.7580 - val_output_1_precision: 0.8117 - val_output_1_recall: 0.8257 - val_output_1_sensitivity: 0.7573 - val_output_1_specificity: 0.9946 - val_output_1_auc: 0.9474 - lr: 1.0000e-04
# Epoch 49/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1761 - output_1_loss: 0.1761 - output_2_loss: 1.1106e-05 - output_1_iou_score: 0.6435 - output_1_dice_coeff: 0.8336 - output_1_precision: 0.8715 - output_1_recall: 0.8534 - output_1_sensitivity: 0.8302 - output_1_specificity: 0.9962 - output_1_auc: 0.9667
# Epoch 1: val_loss did not improve from 0.24923
# 233/233 [==============================] - 45s 194ms/step - loss: 0.1761 - output_1_loss: 0.1761 - output_2_loss: 1.1106e-05 - output_1_iou_score: 0.6435 - output_1_dice_coeff: 0.8336 - output_1_precision: 0.8715 - output_1_recall: 0.8534 - output_1_sensitivity: 0.8302 - output_1_specificity: 0.9962 - output_1_auc: 0.9667 - val_loss: 0.2587 - val_output_1_loss: 0.2587 - val_output_2_loss: 1.9585e-05 - val_output_1_iou_score: 0.5128 - val_output_1_dice_coeff: 0.7555 - val_output_1_precision: 0.8358 - val_output_1_recall: 0.8042 - val_output_1_sensitivity: 0.7323 - val_output_1_specificity: 0.9955 - val_output_1_auc: 0.9393 - lr: 1.0000e-04
# Epoch 50/50
# 233/233 [==============================] - ETA: 0s - loss: 0.1806 - output_1_loss: 0.1806 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6425 - output_1_dice_coeff: 0.8290 - output_1_precision: 0.8717 - output_1_recall: 0.8503 - output_1_sensitivity: 0.8262 - output_1_specificity: 0.9962 - output_1_auc: 0.9653
# Epoch 1: val_loss did not improve from 0.24923
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1806 - output_1_loss: 0.1806 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6425 - output_1_dice_coeff: 0.8290 - output_1_precision: 0.8717 - output_1_recall: 0.8503 - output_1_sensitivity: 0.8262 - output_1_specificity: 0.9962 - output_1_auc: 0.9653 - val_loss: 0.2607 - val_output_1_loss: 0.2607 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5106 - val_output_1_dice_coeff: 0.7535 - val_output_1_precision: 0.8391 - val_output_1_recall: 0.7895 - val_output_1_sensitivity: 0.7305 - val_output_1_specificity: 0.9957 - val_output_1_auc: 0.9373 - lr: 1.0000e-04
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_1_loss', 'output_2_loss', 'output_1_iou_score', 'output_1_dice_coeff', 'output_1_precision', 'output_1_recall', 'output_1_sensitivity', 'output_1_specificity', 'output_1_auc', 'val_loss', 'val_output_1_loss', 'val_output_2_loss', 'val_output_1_iou_score', 'val_output_1_dice_coeff', 'val_output_1_precision', 'val_output_1_recall', 'val_output_1_sensitivity', 'val_output_1_specificity', 'val_output_1_auc', 'lr'])

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fine-tuning Joint updation

# %%
"""from tensorflow.keras.models import load_model

custom_objects = {'total_loss': total_loss,
                  '<lambda>': lambda y_true, y_pred: y_pred,
                  'iou_score':iou_score,
                  'dice_coeff':dice_coeff,
                  'precision':tf.keras.metrics.Precision(),
                  'recall':tf.keras.metrics.Recall(),
                  'sensitivity':sensitivity,
                  'specificity':specificity
                 }

with tf.keras.utils.custom_object_scope(custom_objects):
    model = load_model('/kaggle/working/final_model.h5')"""
# Out:
# "from tensorflow.keras.models import load_model\n\ncustom_objects = {'total_loss': total_loss,\n                  '<lambda>': lambda y_true, y_pred: y_pred,\n                  'iou_score':iou_score,\n                  'dice_coeff':dice_coeff,\n                  'precision':tf.keras.metrics.Precision(),\n                  'recall':tf.keras.metrics.Recall(),\n                  'sensitivity':sensitivity,\n                  'specificity':specificity\n                 }\n\nwith tf.keras.utils.custom_object_scope(custom_objects):\n    model = load_model('/kaggle/working/final_model.h5')"

# %% [markdown]
# Im going for this method instead...more efficient

# %%
model = build_WNet((256,256,3))

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model.load_weights("/kaggle/working/WNet_maxpool.h5")
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00005), loss={'output_1':total_loss, 'output_2':lambda y_true, y_pred: y_pred},
              loss_weights = {'output_1':1, 'output_2':0.25},
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
model.get_layer("encoder1").trainable = True
model.get_layer("encoder2").trainable = True

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_output_1_loss',
                              mode='min', 
                              verbose=1, 
                              patience=3
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5",
                               monitor='val_output_1_loss',
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_loss', factor=0.3, patience=2, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=10,callbacks=callbacks)
# Out:
# Epoch 1/10
# 2024-01-23 07:23:48.448916: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/encoder1/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.1758 - output_1_loss: 0.1758 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6519 - output_1_dice_coeff: 0.8336 - output_1_precision_1: 0.8742 - output_1_recall_1: 0.8548 - output_1_sensitivity: 0.8317 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9676
# Epoch 1: val_output_1_loss improved from inf to 0.24711, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 101s 208ms/step - loss: 0.1758 - output_1_loss: 0.1758 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6519 - output_1_dice_coeff: 0.8336 - output_1_precision_1: 0.8742 - output_1_recall_1: 0.8548 - output_1_sensitivity: 0.8317 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9676 - val_loss: 0.2471 - val_output_1_loss: 0.2471 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5247 - val_output_1_dice_coeff: 0.7663 - val_output_1_precision_1: 0.8293 - val_output_1_recall_1: 0.8197 - val_output_1_sensitivity: 0.7613 - val_output_1_specificity: 0.9952 - val_output_1_auc_1: 0.9491 - lr: 5.0000e-05
# Epoch 2/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1732 - output_1_loss: 0.1732 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6584 - output_1_dice_coeff: 0.8360 - output_1_precision_1: 0.8719 - output_1_recall_1: 0.8573 - output_1_sensitivity: 0.8337 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9682
# Epoch 2: val_output_1_loss did not improve from 0.24711
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1732 - output_1_loss: 0.1732 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6584 - output_1_dice_coeff: 0.8360 - output_1_precision_1: 0.8719 - output_1_recall_1: 0.8573 - output_1_sensitivity: 0.8337 - output_1_specificity: 0.9962 - output_1_auc_1: 0.9682 - val_loss: 0.2557 - val_output_1_loss: 0.2556 - val_output_2_loss: 1.1413e-04 - val_output_1_iou_score: 0.5123 - val_output_1_dice_coeff: 0.7592 - val_output_1_precision_1: 0.8225 - val_output_1_recall_1: 0.8139 - val_output_1_sensitivity: 0.7554 - val_output_1_specificity: 0.9950 - val_output_1_auc_1: 0.9429 - lr: 5.0000e-05
# Epoch 3/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1724 - output_1_loss: 0.1724 - output_2_loss: 4.8189e-06 - output_1_iou_score: 0.6628 - output_1_dice_coeff: 0.8368 - output_1_precision_1: 0.8757 - output_1_recall_1: 0.8579 - output_1_sensitivity: 0.8346 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9682
# Epoch 3: val_output_1_loss did not improve from 0.24711
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1724 - output_1_loss: 0.1724 - output_2_loss: 4.8189e-06 - output_1_iou_score: 0.6628 - output_1_dice_coeff: 0.8368 - output_1_precision_1: 0.8757 - output_1_recall_1: 0.8579 - output_1_sensitivity: 0.8346 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9682 - val_loss: 0.2556 - val_output_1_loss: 0.2556 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5212 - val_output_1_dice_coeff: 0.7590 - val_output_1_precision_1: 0.8052 - val_output_1_recall_1: 0.8341 - val_output_1_sensitivity: 0.7718 - val_output_1_specificity: 0.9943 - val_output_1_auc_1: 0.9516 - lr: 5.0000e-05
# Epoch 4/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1629 - output_1_loss: 0.1629 - output_2_loss: 8.9050e-07 - output_1_iou_score: 0.6731 - output_1_dice_coeff: 0.8459 - output_1_precision_1: 0.8770 - output_1_recall_1: 0.8651 - output_1_sensitivity: 0.8422 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9697
# Epoch 4: val_output_1_loss improved from 0.24711 to 0.24671, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1629 - output_1_loss: 0.1629 - output_2_loss: 8.9050e-07 - output_1_iou_score: 0.6731 - output_1_dice_coeff: 0.8459 - output_1_precision_1: 0.8770 - output_1_recall_1: 0.8651 - output_1_sensitivity: 0.8422 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9697 - val_loss: 0.2467 - val_output_1_loss: 0.2467 - val_output_2_loss: 8.5699e-05 - val_output_1_iou_score: 0.5254 - val_output_1_dice_coeff: 0.7676 - val_output_1_precision_1: 0.8143 - val_output_1_recall_1: 0.8317 - val_output_1_sensitivity: 0.7773 - val_output_1_specificity: 0.9946 - val_output_1_auc_1: 0.9499 - lr: 1.5000e-05
# Epoch 5/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1632 - output_1_loss: 0.1632 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6704 - output_1_dice_coeff: 0.8457 - output_1_precision_1: 0.8783 - output_1_recall_1: 0.8641 - output_1_sensitivity: 0.8428 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9698
# Epoch 5: val_output_1_loss did not improve from 0.24671
# 233/233 [==============================] - 46s 195ms/step - loss: 0.1632 - output_1_loss: 0.1632 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6704 - output_1_dice_coeff: 0.8457 - output_1_precision_1: 0.8783 - output_1_recall_1: 0.8641 - output_1_sensitivity: 0.8428 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9698 - val_loss: 0.2509 - val_output_1_loss: 0.2509 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5230 - val_output_1_dice_coeff: 0.7635 - val_output_1_precision_1: 0.8160 - val_output_1_recall_1: 0.8307 - val_output_1_sensitivity: 0.7683 - val_output_1_specificity: 0.9947 - val_output_1_auc_1: 0.9493 - lr: 1.5000e-05
# Epoch 6/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1630 - output_1_loss: 0.1630 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6784 - output_1_dice_coeff: 0.8456 - output_1_precision_1: 0.8794 - output_1_recall_1: 0.8648 - output_1_sensitivity: 0.8458 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9700
# Epoch 6: val_output_1_loss did not improve from 0.24671
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.499999886320438e-06.
# 233/233 [==============================] - 46s 195ms/step - loss: 0.1630 - output_1_loss: 0.1630 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6784 - output_1_dice_coeff: 0.8456 - output_1_precision_1: 0.8794 - output_1_recall_1: 0.8648 - output_1_sensitivity: 0.8458 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9700 - val_loss: 0.2472 - val_output_1_loss: 0.2472 - val_output_2_loss: 9.9930e-05 - val_output_1_iou_score: 0.5297 - val_output_1_dice_coeff: 0.7677 - val_output_1_precision_1: 0.8148 - val_output_1_recall_1: 0.8343 - val_output_1_sensitivity: 0.7758 - val_output_1_specificity: 0.9946 - val_output_1_auc_1: 0.9482 - lr: 1.5000e-05
# Epoch 7/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1600 - output_1_loss: 0.1600 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6787 - output_1_dice_coeff: 0.8488 - output_1_precision_1: 0.8773 - output_1_recall_1: 0.8712 - output_1_sensitivity: 0.8503 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9708
# Epoch 7: val_output_1_loss did not improve from 0.24671
# 233/233 [==============================] - 46s 196ms/step - loss: 0.1600 - output_1_loss: 0.1600 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6787 - output_1_dice_coeff: 0.8488 - output_1_precision_1: 0.8773 - output_1_recall_1: 0.8712 - output_1_sensitivity: 0.8503 - output_1_specificity: 0.9963 - output_1_auc_1: 0.9708 - val_loss: 0.2480 - val_output_1_loss: 0.2480 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5287 - val_output_1_dice_coeff: 0.7666 - val_output_1_precision_1: 0.8184 - val_output_1_recall_1: 0.8297 - val_output_1_sensitivity: 0.7709 - val_output_1_specificity: 0.9948 - val_output_1_auc_1: 0.9480 - lr: 4.5000e-06
# Epoch 8/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1611 - output_1_loss: 0.1611 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6789 - output_1_dice_coeff: 0.8475 - output_1_precision_1: 0.8801 - output_1_recall_1: 0.8667 - output_1_sensitivity: 0.8445 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9702
# Epoch 8: val_output_1_loss did not improve from 0.24671
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.3499999113264492e-06.
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1611 - output_1_loss: 0.1611 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6789 - output_1_dice_coeff: 0.8475 - output_1_precision_1: 0.8801 - output_1_recall_1: 0.8667 - output_1_sensitivity: 0.8445 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9702 - val_loss: 0.2498 - val_output_1_loss: 0.2498 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5284 - val_output_1_dice_coeff: 0.7651 - val_output_1_precision_1: 0.8158 - val_output_1_recall_1: 0.8267 - val_output_1_sensitivity: 0.7678 - val_output_1_specificity: 0.9947 - val_output_1_auc_1: 0.9465 - lr: 4.5000e-06
# Epoch 9/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1643 - output_1_loss: 0.1643 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6826 - output_1_dice_coeff: 0.8444 - output_1_precision_1: 0.8828 - output_1_recall_1: 0.8671 - output_1_sensitivity: 0.8413 - output_1_specificity: 0.9965 - output_1_auc_1: 0.9703
# Epoch 9: val_output_1_loss did not improve from 0.24671
# 233/233 [==============================] - 45s 195ms/step - loss: 0.1643 - output_1_loss: 0.1643 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6826 - output_1_dice_coeff: 0.8444 - output_1_precision_1: 0.8828 - output_1_recall_1: 0.8671 - output_1_sensitivity: 0.8413 - output_1_specificity: 0.9965 - output_1_auc_1: 0.9703 - val_loss: 0.2489 - val_output_1_loss: 0.2489 - val_output_2_loss: 0.0000e+00 - val_output_1_iou_score: 0.5335 - val_output_1_dice_coeff: 0.7657 - val_output_1_precision_1: 0.8190 - val_output_1_recall_1: 0.8298 - val_output_1_sensitivity: 0.7731 - val_output_1_specificity: 0.9948 - val_output_1_auc_1: 0.9480 - lr: 1.3500e-06
# Epoch 10/10
# 233/233 [==============================] - ETA: 0s - loss: 0.1621 - output_1_loss: 0.1621 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6804 - output_1_dice_coeff: 0.8468 - output_1_precision_1: 0.8810 - output_1_recall_1: 0.8645 - output_1_sensitivity: 0.8435 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9696
# Epoch 10: val_output_1_loss improved from 0.24671 to 0.24553, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 46s 197ms/step - loss: 0.1621 - output_1_loss: 0.1621 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.6804 - output_1_dice_coeff: 0.8468 - output_1_precision_1: 0.8810 - output_1_recall_1: 0.8645 - output_1_sensitivity: 0.8435 - output_1_specificity: 0.9964 - output_1_auc_1: 0.9696 - val_loss: 0.2456 - val_output_1_loss: 0.2455 - val_output_2_loss: 1.1378e-04 - val_output_1_iou_score: 0.5363 - val_output_1_dice_coeff: 0.7690 - val_output_1_precision_1: 0.8189 - val_output_1_recall_1: 0.8305 - val_output_1_sensitivity: 0.7733 - val_output_1_specificity: 0.9948 - val_output_1_auc_1: 0.9484 - lr: 1.3500e-06

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['output_1_iou_score']
val_iou_score=history['val_output_1_iou_score']

loss=history['output_1_loss']
val_loss=history['val_output_1_loss']

train_dice=history['output_1_dice_coeff']
val_dice=history['val_output_1_dice_coeff']

train_cl = history['output_2_loss']
train_cl = train_cl-np.min(train_cl)
val_cl = history['val_output_2_loss']
val_cl = val_cl-np.min(val_cl)

epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 4, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()

# Plot 3: Dice Coefficients
axes[3].plot(epoch, train_cl, 'b', label='Training Comp_loss', linewidth=1.5)
axes[3].plot(epoch, val_cl, 'r', label='Validation Comp_loss', linewidth=1.5)
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Complementary loss')
axes[3].set_title('Training and Validation Complementary Loss')
axes[3].legend()

# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 262.55it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            #augmented = self.transform(image=image, mask=mask)
            #images.append(augmented['image'])
            #masks.append(augmented['mask'])
            images.append(image)
            masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 22s 572ms/step - loss: 0.2314 - output_1_loss: 0.2314 - output_2_loss: 0.0000e+00 - output_1_iou_score: 0.5114 - output_1_dice_coeff: 0.7891 - output_1_precision_1: 0.8019 - output_1_recall_1: 0.8142 - output_1_sensitivity: 0.8066 - output_1_specificity: 0.9932 - output_1_auc_1: 0.9427

# %%
#!zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool.h5

# %%
#from IPython.display import FileLink
#FileLink(r'weights_WNet_Res50_AT_CL.zip')
