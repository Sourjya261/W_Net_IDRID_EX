# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/image_patches_512/"
mask_patch_folder = "/kaggle/input/training-patches-he-512-idrid/HE_patches - Copy/mask_patches_512/"

# Read patch paths and create a DataFrame
df_patches = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 1168/1168 [00:02<00:00, 569.22it/s]

# %%
df_patches.head()
# Out:
#                                                Image  \
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...
#
#                                                 Mask
# 0  /kaggle/input/training-patches-he-512-idrid/HE...
# 1  /kaggle/input/training-patches-he-512-idrid/HE...
# 2  /kaggle/input/training-patches-he-512-idrid/HE...
# 3  /kaggle/input/training-patches-he-512-idrid/HE...
# 4  /kaggle/input/training-patches-he-512-idrid/HE...

# %%
#for multiclass
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
train_generator = CustomDataGenerator(df_patches, batch_size=8, image_size=(256, 256), shuffle=True)

# %%
import matplotlib.pyplot as plt

# Load a single batch
batch = train_generator[0]  # Assuming you want to load the first batch

# Extract images and labels from the batch
images, masks = batch

# Display the images and masks
n_images_to_display = len(images)
fig, ax = plt.subplots(n_images_to_display, 2, figsize=(10, 20))
for i in range(n_images_to_display):
    ax[i, 0].imshow(images[i], cmap='bone')
    #print(np.max(images[i]))
    ax[i, 0].set_title('Image')
    ax[i, 1].imshow(masks[i], cmap='bone')
    #print(np.max(masks[i]))
    ax[i, 1].set_title('Mask')

    ax[i, 0].axis('off')
    ax[i, 1].axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

df_shuffled = df_patches.sample(frac=1, random_state=42)
train_df, val_df = train_test_split(df_shuffled, test_size=0.2, random_state=42)

# %%
# bar plot
from matplotlib import pyplot as plt
sizes = [len(train_df), len(val_df)]
labels = ['Train', 'Validation']

plt.bar(labels, sizes, color=['blue', 'orange'])
plt.xlabel('Data Split')
plt.ylabel('Number of Samples')
plt.title('Dataset Split: Train, Validation')
plt.show()

# %% [markdown]
# # Model Architecture and Helper blocks

# %%
#GCSE Block...from the GCSER UNET (Mukherjee et al.)
def GCSE(input_tensor, ratio=16):


    # Compute the global statistics (mean and std deviation) along the channel axis.
    mean = tf.reduce_mean(input_tensor, axis=[1, 2], keepdims=True)
    std = tf.math.reduce_std(input_tensor, axis=[1, 2], keepdims=True)

    # Compute channel-wise attention using a convolutional neural network.
    attn_channel = tf.concat([mean, std], axis=-1)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1] // ratio, kernel_size=(1, 1), activation='relu')(attn_channel)
    attn_channel = tf.keras.layers.Conv2D(filters=input_tensor.shape[-1], kernel_size=(1, 1), activation='sigmoid')(attn_channel)

    # Compute spatial attention using global information from the input tensor.
    global_info = tf.reduce_mean(input_tensor, axis=-1, keepdims=True)
    attn_spatial = tf.keras.layers.Conv2D(filters=1, kernel_size=(1, 1), activation='sigmoid')(global_info)

    # Combine channel-wise and spatial attention.
    attn = tf.keras.layers.Multiply()([attn_channel,attn_spatial])

    # Multiply the input tensor by the learned attention weights.
    output_tensor = tf.keras.layers.Multiply()([input_tensor,attn])

    return output_tensor

# %%
def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=3, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=5, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=7, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

# %%
from tensorflow.keras.applications import ResNet50
def build_encoder2(inputs):

    s=[]
    """ Pre-trained ResNet50 Model """
    resnet50= ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)
    for layer in resnet50.layers:
        layer.trainable = True


    """ Encoder """
    s1 = resnet50.get_layer("model_input").output    
    s.append(s1)
    s2 = resnet50.get_layer("conv1_relu").output   
    s.append(s2)
    s3 = resnet50.get_layer("conv2_block3_out").output  
    s.append(s3)
    s4 = resnet50.get_layer("conv3_block4_out").output  
    s.append(s4)

    """ Bridge """
    #b1 = resnet50.get_layer("conv4_block6_out").output 
    b = resnet50.get_layer("conv4_block2_out").output 
    b = ASPP(b,128)
    
    encoder2 = Model(inputs,outputs=[s,b],name = "encoder2")

    return encoder2

# %% [markdown]
# # Asymmetric architecture

# %%
# Code for W-Net

from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D,Conv2DTranspose, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input, ZeroPadding2D,Dropout,Dense,MaxPooling2D,Reshape,Multiply,GlobalAveragePooling2D,AveragePooling2D
from tensorflow.keras.models import Model


"""def complementary_loss(y_true, y_pred):
    mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))
    return tf.math.sigmoid(mse_loss)"""
def complementary_loss(feature_map1,feature_map2):
    # Normalize the feature maps to [0, 1]
    feature_map1 /= tf.reduce_max(feature_map1)
    feature_map2 /= tf.reduce_max(feature_map2)
    m1 = tf.reduce_mean(feature_map1)
    m2  = tf.reduce_mean(feature_map2)

    return tf.math.sigmoid(tf.abs(m1-m2))


def batchnorm_relu(inputs):
    x = BatchNormalization()(inputs)
    #x = Activation("relu")(x)
    x = tf.keras.layers.LeakyReLU(alpha=0.1)(x)

    return x

def residual_block(inputs, num_filters):
    """ Convolutional Layer """
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)
    x = Dropout(0.1)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1,kernel_initializer = "he_normal")(x)


    """ Shortcut Connection """
    s = Conv2D(num_filters, 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = x + s
    return x

def decoder_block(inputs, s1, num_filters):
    x = Conv2DTranspose(num_filters,2, strides=(2,2), kernel_initializer="he_normal",padding = "same")(inputs)
    x = Concatenate()([x,s1])
    x = residual_block(x, num_filters)
    x = GCSE(x)
    return x
def build_encoder1(inputs,f):
    
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(f[0], 3, padding="same", strides=1,kernel_initializer="he_normal")(x)
    s = Conv2D(f[0], 1, padding="same", strides=1,kernel_initializer="he_normal")(inputs)

    c1 = x + s
    c1 = GCSE(c1)
    p1 = MaxPooling2D((2,2))(c1)
    s1 = c1

    c2 = residual_block(p1, f[1])
    c2 = GCSE(c2)
    p2 = MaxPooling2D((2,2))(c2)
    s2 = c2

    c3 = residual_block(p2, f[2])
    c3 = GCSE(c3)
    p3 = MaxPooling2D((2,2))(c3)
    s3 = c3

    c4 = residual_block(p3, f[3])
    c4 = GCSE(c4)
    p4 = MaxPooling2D((2,2))(c4)
    s4 = c4
    
    s_ = [s1,s2,s3,s4]
    """ Bridge """
    b = ASPP(p4,128)
    encoder1 = Model(inputs,outputs=[s_,b],name="encoder1")
    return encoder1

    
    

def build_WNet(input_shape):
    f = [16,32,64,128]

    inputs = Input(input_shape,name="model_input")
    encoder1 = build_encoder1(inputs,f)
    encoder2 = build_encoder2(inputs)
    s1,b1 = encoder1(inputs)
    s2,b2 = encoder2(inputs)

    b = Concatenate()([b1,b2])

    """ Decoder 1, 2, 3 """
    d1 = decoder_block(b, s2[3],s1[3], f[3]+512)
    d2 = decoder_block(d1, s2[2],s1[2], f[2]+256)
    d3 = decoder_block(d2, s2[1],s1[1], f[1]+64)
    d4 = decoder_block(d3, s2[0],s1[0],f[0]+3)
    
    """ comp1 = complementary_loss(s2[0], s1[0])
    comp2 = complementary_loss(s2[1], s1[1])
    comp3 = complementary_loss(s2[2], s1[2])
    comp4 = complementary_loss(s2[3], s1[3])
    comp5 = complementary_loss(b1, b2)
    

    output_2 = tf.keras.layers.Add(name='output_2')([comp1,comp2,comp3,comp4,comp5])
    """
    """ Classifier """
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    
    return model
def build_Net2(input_shape):
    inputs = Input(input_shape,name="model_input")
    encoder2 = build_encoder2(inputs)
    s2,b2 = encoder2(inputs)
    b = b2
    d1 = decoder_block(b, s2[3], 512)
    d2 = decoder_block(d1, s2[2], 256)
    d3 = decoder_block(d2, s2[1], 128)
    d4 = decoder_block(d3, s2[0], 64)
    
    output_1 = Conv2D(1, (1,1) , activation="sigmoid",name='output_1')(d4)

    """ Model """
    #model = Model(inputs,outputs=[output_1,output_2])
    model = Model(inputs,outputs=output_1)
    return model

# %% [markdown]
# # Evaluation Metrics

# %%
from keras import backend as K
import tensorflow as tf
epsilon = 1e-5
smooth = 1e-5

def dice_coeff(y_true, y_pred, smooth=1e-5):
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    dice = (2. * intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) + smooth)
    return dice

def dice_loss(y_true, y_pred):
    return  1- dice_coeff(y_true, y_pred, smooth=1e-5)

def FocalLoss(targets, inputs, alpha=0.25, gamma=2):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

def total_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return dice_loss(y_true, y_pred) + FocalLoss(y_true, y_pred, 0.25,2)
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def iou_score(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + 1e-5) / (union + 1e-5)
    return iou

# %%
model = build_Net2((256,256,3))

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  model_input (InputLayer)    [(None, 256, 256, 3)]        0         []
#
#  encoder2 (Functional)       [[(None, 256, 256, 3),       7988224   ['model_input[0][0]']
#                               (None, 128, 128, 64),
#                               (None, 64, 64, 256),
#                               (None, 32, 32, 512)],
#                               (None, 16, 16, 128)]
#
#  conv2d_transpose_8 (Conv2D  (None, 32, 32, 512)          262656    ['encoder2[0][4]']
#  Transpose)
#
#  concatenate_12 (Concatenat  (None, 32, 32, 1024)         0         ['conv2d_transpose_8[0][0]',
#  e)                                                                  'encoder2[0][3]']
#
#  batch_normalization_40 (Ba  (None, 32, 32, 1024)         4096      ['concatenate_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 32, 32, 1024)         0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 32, 32, 512)          4719104   ['leaky_re_lu_16[0][0]']
#
#  dropout_8 (Dropout)         (None, 32, 32, 512)          0         ['conv2d_70[0][0]']
#
#  batch_normalization_41 (Ba  (None, 32, 32, 512)          2048      ['dropout_8[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 32, 32, 512)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 32, 32, 512)          2359808   ['leaky_re_lu_17[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 32, 32, 512)          524800    ['concatenate_12[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 32, 32, 512)          0         ['conv2d_71[0][0]',
#  OpLambda)                                                           'conv2d_72[0][0]']
#
#  tf.math.reduce_mean_15 (TF  (None, 1, 1, 512)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_8 (TFOp  (None, 1, 1, 512)            0         ['tf.__operators__.add_8[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_8 (TFOpLambda)    (None, 1, 1, 1024)           0         ['tf.math.reduce_mean_15[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_8[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 1, 1, 32)             32800     ['tf.concat_8[0][0]']
#
#  tf.math.reduce_mean_16 (TF  (None, 32, 32, 1)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_74 (Conv2D)          (None, 1, 1, 512)            16896     ['conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 32, 32, 1)            2         ['tf.math.reduce_mean_16[0][0]
#                                                                     ']
#
#  multiply_14 (Multiply)      (None, 32, 32, 512)          0         ['conv2d_74[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  multiply_15 (Multiply)      (None, 32, 32, 512)          0         ['tf.__operators__.add_8[0][0]
#                                                                     ',
#                                                                      'multiply_14[0][0]']
#
#  conv2d_transpose_9 (Conv2D  (None, 64, 64, 256)          524544    ['multiply_15[0][0]']
#  Transpose)
#
#  concatenate_13 (Concatenat  (None, 64, 64, 512)          0         ['conv2d_transpose_9[0][0]',
#  e)                                                                  'encoder2[0][2]']
#
#  batch_normalization_42 (Ba  (None, 64, 64, 512)          2048      ['concatenate_13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 64, 64, 512)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 256)          1179904   ['leaky_re_lu_18[0][0]']
#
#  dropout_9 (Dropout)         (None, 64, 64, 256)          0         ['conv2d_76[0][0]']
#
#  batch_normalization_43 (Ba  (None, 64, 64, 256)          1024      ['dropout_9[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 64, 64, 256)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 64, 64, 256)          590080    ['leaky_re_lu_19[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 64, 64, 256)          131328    ['concatenate_13[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 64, 64, 256)          0         ['conv2d_77[0][0]',
#  OpLambda)                                                           'conv2d_78[0][0]']
#
#  tf.math.reduce_mean_17 (TF  (None, 1, 1, 256)            0         ['tf.__operators__.add_9[0][0]
#  OpLambda)                                                          ']
#
#  tf.math.reduce_std_9 (TFOp  (None, 1, 1, 256)            0         ['tf.__operators__.add_9[0][0]
#  Lambda)                                                            ']
#
#  tf.concat_9 (TFOpLambda)    (None, 1, 1, 512)            0         ['tf.math.reduce_mean_17[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_9[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 1, 1, 16)             8208      ['tf.concat_9[0][0]']
#
#  tf.math.reduce_mean_18 (TF  (None, 64, 64, 1)            0         ['tf.__operators__.add_9[0][0]
#  OpLambda)                                                          ']
#
#  conv2d_80 (Conv2D)          (None, 1, 1, 256)            4352      ['conv2d_79[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 1)            2         ['tf.math.reduce_mean_18[0][0]
#                                                                     ']
#
#  multiply_16 (Multiply)      (None, 64, 64, 256)          0         ['conv2d_80[0][0]',
#                                                                      'conv2d_81[0][0]']
#
#  multiply_17 (Multiply)      (None, 64, 64, 256)          0         ['tf.__operators__.add_9[0][0]
#                                                                     ',
#                                                                      'multiply_16[0][0]']
#
#  conv2d_transpose_10 (Conv2  (None, 128, 128, 128)        131200    ['multiply_17[0][0]']
#  DTranspose)
#
#  concatenate_14 (Concatenat  (None, 128, 128, 192)        0         ['conv2d_transpose_10[0][0]',
#  e)                                                                  'encoder2[0][1]']
#
#  batch_normalization_44 (Ba  (None, 128, 128, 192)        768       ['concatenate_14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 128, 128, 192)        0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 128, 128, 128)        221312    ['leaky_re_lu_20[0][0]']
#
#  dropout_10 (Dropout)        (None, 128, 128, 128)        0         ['conv2d_82[0][0]']
#
#  batch_normalization_45 (Ba  (None, 128, 128, 128)        512       ['dropout_10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 128, 128, 128)        0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 128, 128, 128)        147584    ['leaky_re_lu_21[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 128, 128, 128)        24704     ['concatenate_14[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 128, 128, 128)        0         ['conv2d_83[0][0]',
#  FOpLambda)                                                          'conv2d_84[0][0]']
#
#  tf.math.reduce_mean_19 (TF  (None, 1, 1, 128)            0         ['tf.__operators__.add_10[0][0
#  OpLambda)                                                          ]']
#
#  tf.math.reduce_std_10 (TFO  (None, 1, 1, 128)            0         ['tf.__operators__.add_10[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_10 (TFOpLambda)   (None, 1, 1, 256)            0         ['tf.math.reduce_mean_19[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_10[0][0]'
#                                                                     ]
#
#  conv2d_85 (Conv2D)          (None, 1, 1, 8)              2056      ['tf.concat_10[0][0]']
#
#  tf.math.reduce_mean_20 (TF  (None, 128, 128, 1)          0         ['tf.__operators__.add_10[0][0
#  OpLambda)                                                          ]']
#
#  conv2d_86 (Conv2D)          (None, 1, 1, 128)            1152      ['conv2d_85[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 128, 128, 1)          2         ['tf.math.reduce_mean_20[0][0]
#                                                                     ']
#
#  multiply_18 (Multiply)      (None, 128, 128, 128)        0         ['conv2d_86[0][0]',
#                                                                      'conv2d_87[0][0]']
#
#  multiply_19 (Multiply)      (None, 128, 128, 128)        0         ['tf.__operators__.add_10[0][0
#                                                                     ]',
#                                                                      'multiply_18[0][0]']
#
#  conv2d_transpose_11 (Conv2  (None, 256, 256, 64)         32832     ['multiply_19[0][0]']
#  DTranspose)
#
#  concatenate_15 (Concatenat  (None, 256, 256, 67)         0         ['conv2d_transpose_11[0][0]',
#  e)                                                                  'encoder2[0][0]']
#
#  batch_normalization_46 (Ba  (None, 256, 256, 67)         268       ['concatenate_15[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 256, 256, 67)         0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 256, 256, 64)         38656     ['leaky_re_lu_22[0][0]']
#
#  dropout_11 (Dropout)        (None, 256, 256, 64)         0         ['conv2d_88[0][0]']
#
#  batch_normalization_47 (Ba  (None, 256, 256, 64)         256       ['dropout_11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 256, 256, 64)         0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 256, 256, 64)         36928     ['leaky_re_lu_23[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 256, 256, 64)         4352      ['concatenate_15[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 256, 256, 64)         0         ['conv2d_89[0][0]',
#  FOpLambda)                                                          'conv2d_90[0][0]']
#
#  tf.math.reduce_mean_21 (TF  (None, 1, 1, 64)             0         ['tf.__operators__.add_11[0][0
#  OpLambda)                                                          ]']
#
#  tf.math.reduce_std_11 (TFO  (None, 1, 1, 64)             0         ['tf.__operators__.add_11[0][0
#  pLambda)                                                           ]']
#
#  tf.concat_11 (TFOpLambda)   (None, 1, 1, 128)            0         ['tf.math.reduce_mean_21[0][0]
#                                                                     ',
#                                                                      'tf.math.reduce_std_11[0][0]'
#                                                                     ]
#
#  conv2d_91 (Conv2D)          (None, 1, 1, 4)              516       ['tf.concat_11[0][0]']
#
#  tf.math.reduce_mean_22 (TF  (None, 256, 256, 1)          0         ['tf.__operators__.add_11[0][0
#  OpLambda)                                                          ]']
#
#  conv2d_92 (Conv2D)          (None, 1, 1, 64)             320       ['conv2d_91[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 256, 256, 1)          2         ['tf.math.reduce_mean_22[0][0]
#                                                                     ']
#
#  multiply_20 (Multiply)      (None, 256, 256, 64)         0         ['conv2d_92[0][0]',
#                                                                      'conv2d_93[0][0]']
#
#  multiply_21 (Multiply)      (None, 256, 256, 64)         0         ['tf.__operators__.add_11[0][0
#                                                                     ]',
#                                                                      'multiply_20[0][0]']
#
#  output_1 (Conv2D)           (None, 256, 256, 1)          65        ['multiply_21[0][0]']
#
# ==================================================================================================
# Total params: 18995409 (72.46 MB)
# Trainable params: 18970059 (72.37 MB)
# Non-trainable params: 25350 (99.02 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from keras.callbacks import CSVLogger
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001), loss=total_loss,
              metrics = {"output_1":[iou_score,dice_coeff,tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),sensitivity,specificity,tf.keras.metrics.AUC()]})

# %%
csv_logger = CSVLogger('/kaggle/working/training_log_WCE_segmentation', separator=',', append=True)
earlystopping = EarlyStopping(monitor='val_loss',
                              mode='min', 
                              verbose=1, 
                              patience=6
                             )
# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="/kaggle/working/WNet_maxpool_fine_tune.h5", 
                               verbose=1, 
                               save_best_only=True,
                               save_weights_only=True
                              )

reduce_lr = ReduceLROnPlateau(monitor='val_output_1_dice_coeff', factor=0.3, patience=3, min_lr=1e-6, verbose=1)
                              
"""reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode='min',
                              verbose=1,
                              patience=4,
                              min_delta=0.000001,
                              factor=0.3
                             )"""
callbacks = [checkpointer, reduce_lr, csv_logger,earlystopping]

# %%
batch_size = 4
N = 256
train_generator = CustomDataGenerator(train_df, batch_size=batch_size, image_size=(N,N), shuffle=True)
val_generator = CustomDataGenerator(val_df, batch_size=batch_size, image_size=(N,N), shuffle=False)
history_ = model.fit(train_generator, steps_per_epoch=len(train_df) // batch_size,
                    validation_data=val_generator, validation_steps=len(val_df) // batch_size,
                    epochs=50,callbacks=callbacks)
# Out:
# Epoch 1/50
# 2024-01-19 10:16:17.509564: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 233/233 [==============================] - ETA: 0s - loss: 0.4642 - iou_score: 0.3175 - dice_coeff: 0.5558 - precision: 0.5673 - recall: 0.5946 - sensitivity: 0.6377 - specificity: 0.9865 - auc: 0.8779
# Epoch 1: val_loss improved from inf to 1.10418, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 93s 206ms/step - loss: 0.4642 - iou_score: 0.3175 - dice_coeff: 0.5558 - precision: 0.5673 - recall: 0.5946 - sensitivity: 0.6377 - specificity: 0.9865 - auc: 0.8779 - val_loss: 1.1042 - val_iou_score: 4.2249e-07 - val_dice_coeff: 2.1435e-07 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 2/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3551 - iou_score: 0.4187 - dice_coeff: 0.6668 - precision: 0.7805 - recall: 0.6516 - sensitivity: 0.6907 - specificity: 0.9946 - auc: 0.8972
# Epoch 2: val_loss improved from 1.10418 to 1.10043, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 179ms/step - loss: 0.3551 - iou_score: 0.4187 - dice_coeff: 0.6668 - precision: 0.7805 - recall: 0.6516 - sensitivity: 0.6907 - specificity: 0.9946 - auc: 0.8972 - val_loss: 1.1004 - val_iou_score: 1.0015e-06 - val_dice_coeff: 1.2913e-06 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_auc: 0.5000 - lr: 1.0000e-04
# Epoch 3/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3286 - iou_score: 0.4419 - dice_coeff: 0.6917 - precision: 0.7949 - recall: 0.6775 - sensitivity: 0.7097 - specificity: 0.9948 - auc: 0.9061
# Epoch 3: val_loss improved from 1.10043 to 1.05703, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 181ms/step - loss: 0.3286 - iou_score: 0.4419 - dice_coeff: 0.6917 - precision: 0.7949 - recall: 0.6775 - sensitivity: 0.7097 - specificity: 0.9948 - auc: 0.9061 - val_loss: 1.0570 - val_iou_score: 3.2426e-04 - val_dice_coeff: 7.4809e-04 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - val_auc: 0.5026 - lr: 1.0000e-04
# Epoch 4/50
# 233/233 [==============================] - ETA: 0s - loss: 0.3076 - iou_score: 0.4626 - dice_coeff: 0.7094 - precision: 0.8102 - recall: 0.7007 - sensitivity: 0.7114 - specificity: 0.9951 - auc: 0.9229
# Epoch 4: val_loss improved from 1.05703 to 0.88297, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 179ms/step - loss: 0.3076 - iou_score: 0.4626 - dice_coeff: 0.7094 - precision: 0.8102 - recall: 0.7007 - sensitivity: 0.7114 - specificity: 0.9951 - auc: 0.9229 - val_loss: 0.8830 - val_iou_score: 0.0550 - val_dice_coeff: 0.1679 - val_precision: 0.9610 - val_recall: 0.1301 - val_sensitivity: 0.1003 - val_specificity: 0.9999 - val_auc: 0.6419 - lr: 1.0000e-04
# Epoch 5/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2917 - iou_score: 0.4774 - dice_coeff: 0.7245 - precision: 0.8088 - recall: 0.7238 - sensitivity: 0.7346 - specificity: 0.9949 - auc: 0.9298
# Epoch 5: val_loss improved from 0.88297 to 0.35779, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2917 - iou_score: 0.4774 - dice_coeff: 0.7245 - precision: 0.8088 - recall: 0.7238 - sensitivity: 0.7346 - specificity: 0.9949 - auc: 0.9298 - val_loss: 0.3578 - val_iou_score: 0.3788 - val_dice_coeff: 0.6577 - val_precision: 0.8346 - val_recall: 0.6127 - val_sensitivity: 0.5901 - val_specificity: 0.9966 - val_auc: 0.9116 - lr: 1.0000e-04
# Epoch 6/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2981 - iou_score: 0.4797 - dice_coeff: 0.7187 - precision: 0.8050 - recall: 0.7274 - sensitivity: 0.7250 - specificity: 0.9949 - auc: 0.9224
# Epoch 6: val_loss improved from 0.35779 to 0.28422, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2981 - iou_score: 0.4797 - dice_coeff: 0.7187 - precision: 0.8050 - recall: 0.7274 - sensitivity: 0.7250 - specificity: 0.9949 - auc: 0.9224 - val_loss: 0.2842 - val_iou_score: 0.4749 - val_dice_coeff: 0.7294 - val_precision: 0.7720 - val_recall: 0.8259 - val_sensitivity: 0.7626 - val_specificity: 0.9931 - val_auc: 0.9582 - lr: 1.0000e-04
# Epoch 7/50
# 233/233 [==============================] - ETA: 0s - loss: 0.
50
# 233/233 [==============================] - ETA: 0s - loss: 0.2252 - iou_score: 0.5622 - dice_coeff: 0.7866 - precision: 0.8400 - recall: 0.8170 - sensitivity: 0.7906 - specificity: 0.9953 - auc: 0.9509
# Epoch 21: val_loss did not improve from 0.26190
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2252 - iou_score: 0.5622 - dice_coeff: 0.7866 - precision: 0.8400 - recall: 0.8170 - sensitivity: 0.7906 - specificity: 0.9953 - auc: 0.9509 - val_loss: 0.2792 - val_iou_score: 0.4687 - val_dice_coeff: 0.7336 - val_precision: 0.7740 - val_recall: 0.8352 - val_sensitivity: 0.7695 - val_specificity: 0.9931 - val_auc: 0.9494 - lr: 1.0000e-04
# Epoch 22/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2229 - iou_score: 0.5714 - dice_coeff: 0.7886 - precision: 0.8393 - recall: 0.8188 - sensitivity: 0.7935 - specificity: 0.9953 - auc: 0.9529
# Epoch 22: val_loss improved from 0.26190 to 0.25994, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2229 - iou_score: 0.5714 - dice_coeff: 0.7886 - precision: 0.8393 - recall: 0.8188 - sensitivity: 0.7935 - specificity: 0.9953 - auc: 0.9529 - val_loss: 0.2599 - val_iou_score: 0.5084 - val_dice_coeff: 0.7515 - val_precision: 0.7860 - val_recall: 0.8460 - val_sensitivity: 0.7877 - val_specificity: 0.9935 - val_auc: 0.9593 - lr: 1.0000e-04
# Epoch 23/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2209 - iou_score: 0.5784 - dice_coeff: 0.7901 - precision: 0.8456 - recall: 0.8243 - sensitivity: 0.7942 - specificity: 0.9955 - auc: 0.9548
# Epoch 23: val_loss did not improve from 0.25994
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2209 - iou_score: 0.5784 - dice_coeff: 0.7901 - precision: 0.8456 - recall: 0.8243 - sensitivity: 0.7942 - specificity: 0.9955 - auc: 0.9548 - val_loss: 0.2646 - val_iou_score: 0.5019 - val_dice_coeff: 0.7480 - val_precision: 0.7627 - val_recall: 0.8550 - val_sensitivity: 0.7979 - val_specificity: 0.9925 - val_auc: 0.9591 - lr: 1.0000e-04
# Epoch 24/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2202 - iou_score: 0.5861 - dice_coeff: 0.7907 - precision: 0.8470 - recall: 0.8248 - sensitivity: 0.7919 - specificity: 0.9955 - auc: 0.9551
# Epoch 24: val_loss did not improve from 0.25994
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2202 - iou_score: 0.5861 - dice_coeff: 0.7907 - precision: 0.8470 - recall: 0.8248 - sensitivity: 0.7919 - specificity: 0.9955 - auc: 0.9551 - val_loss: 0.2842 - val_iou_score: 0.4916 - val_dice_coeff: 0.7284 - val_precision: 0.7700 - val_recall: 0.8211 - val_sensitivity: 0.7667 - val_specificity: 0.9931 - val_auc: 0.9478 - lr: 1.0000e-04
# Epoch 25/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2111 - iou_score: 0.5839 - dice_coeff: 0.7996 - precision: 0.8467 - recall: 0.8268 - sensitivity: 0.8001 - specificity: 0.9955 - auc: 0.9555
# Epoch 25: val_loss improved from 0.25994 to 0.25809, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2111 - iou_score: 0.5839 - dice_coeff: 0.7996 - precision: 0.8467 - recall: 0.8268 - sensitivity: 0.8001 - specificity: 0.9955 - auc: 0.9555 - val_loss: 0.2581 - val_iou_score: 0.5065 - val_dice_coeff: 0.7538 - val_precision: 0.7855 - val_recall: 0.8468 - val_sensitivity: 0.7795 - val_specificity: 0.9934 - val_auc: 0.9559 - lr: 1.0000e-04
# Epoch 26/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2190 - iou_score: 0.5760 - dice_coeff: 0.7919 - precision: 0.8455 - recall: 0.8271 - sensitivity: 0.7982 - specificity: 0.9954 - auc: 0.9561
# Epoch 26: val_loss did not improve from 0.25809
# 233/233 [==============================] - 41s 178ms/step - loss: 0.2190 - iou_score: 0.5760 - dice_coeff: 0.7919 - precision: 0.8455 - recall: 0.8271 - sensitivity: 0.7982 - specificity: 0.9954 - auc: 0.9561 - val_loss: 0.3189 - val_iou_score: 0.4452 - val_dice_coeff: 0.6973 - val_precision: 0.6753 - val_recall: 0.8868 - val_sensitivity: 0.8321 - val_specificity: 0.9880 - val_auc: 0.9671 - lr: 1.0000e-04
# Epoch 27/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2114 - iou_score: 0.5878 - dice_coeff: 0.7996 - precision: 0.8452 - recall: 0.8234 - sensitivity: 0.8035 - specificity: 0.9955 - auc: 0.9538
# Epoch 27: val_loss did not improve from 0.25809
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2114 - iou_score: 0.5878 - dice_coeff: 0.7996 - precision: 0.8452 - recall: 0.8234 - sensitivity: 0.8035 - specificity: 0.9955 - auc: 0.9538 - val_loss: 0.2670 - val_iou_score: 0.4922 - val_dice_coeff: 0.7449 - val_precision: 0.8037 - val_recall: 0.8277 - val_sensitivity: 0.7530 - val_specificity: 0.9943 - val_auc: 0.9499 - lr: 1.0000e-04
# Epoch 28/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2089 - iou_score: 0.5931 - dice_coeff: 0.8016 - precision: 0.8491 - recall: 0.8314 - sensitivity: 0.8021 - specificity: 0.9955 - auc: 0.9579
# Epoch 28: val_loss did not improve from 0.25809
# 233/233 [==============================] - 42s 178ms/step - loss: 0.2089 - iou_score: 0.5931 - dice_coeff: 0.8016 - precision: 0.8491 - recall: 0.8314 - sensitivity: 0.8021 - specificity: 0.9955 - auc: 0.9579 - val_loss: 0.2668 - val_iou_score: 0.5008 - val_dice_coeff: 0.7445 - val_precision: 0.8074 - val_recall: 0.8264 - val_sensitivity: 0.7483 - val_specificity: 0.9944 - val_auc: 0.9488 - lr: 1.0000e-04
# Epoch 29/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2129 - iou_score: 0.5937 - dice_coeff: 0.7975 - precision: 0.8461 - recall: 0.8280 - sensitivity: 0.8018 - specificity: 0.9955 - auc: 0.9552
# Epoch 29: val_loss did not improve from 0.25809
# 233/233 [==============================] - 42s 178ms/step - loss: 0.2129 - iou_score: 0.5937 - dice_coeff: 0.7975 - precision: 0.8461 - recall: 0.8280 - sensitivity: 0.8018 - specificity: 0.9955 - auc: 0.9552 - val_loss: 0.2768 - val_iou_score: 0.4822 - val_dice_coeff: 0.7383 - val_precision: 0.7668 - val_recall: 0.8418 - val_sensitivity: 0.7519 - val_specificity: 0.9927 - val_auc: 0.9456 - lr: 1.0000e-04
# Epoch 30/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2073 - iou_score: 0.5979 - dice_coeff: 0.8031 - precision: 0.8482 - recall: 0.8343 - sensitivity: 0.8064 - specificity: 0.9955 - auc: 0.9576
# Epoch 30: val_loss improved from 0.25809 to 0.25805, saving model to /kaggle/working/WNet_maxpool_fine_tune.h5
# 233/233 [==============================] - 42s 181ms/step - loss: 0.2073 - iou_score: 0.5979 - dice_coeff: 0.8031 - precision: 0.8482 - recall: 0.8343 - sensitivity: 0.8064 - specificity: 0.9955 - auc: 0.9576 - val_loss: 0.2580 - val_iou_score: 0.5190 - val_dice_coeff: 0.7543 - val_precision: 0.8215 - val_recall: 0.8123 - val_sensitivity: 0.7559 - val_specificity: 0.9950 - val_auc: 0.9425 - lr: 1.0000e-04
# Epoch 31/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2023 - iou_score: 0.6026 - dice_coeff: 0.8080 - precision: 0.8531 - recall: 0.8361 - sensitivity: 0.8085 - specificity: 0.9956 - auc: 0.9577
# Epoch 31: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 178ms/step - loss: 0.2023 - iou_score: 0.6026 - dice_coeff: 0.8080 - precision: 0.8531 - recall: 0.8361 - sensitivity: 0.8085 - specificity: 0.9956 - auc: 0.9577 - val_loss: 0.2664 - val_iou_score: 0.5041 - val_dice_coeff: 0.7457 - val_precision: 0.7654 - val_recall: 0.8602 - val_sensitivity: 0.8125 - val_specificity: 0.9925 - val_auc: 0.9611 - lr: 1.0000e-04
# Epoch 32/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2103 - iou_score: 0.5915 - dice_coeff: 0.8005 - precision: 0.8500 - recall: 0.8259 - sensitivity: 0.8057 - specificity: 0.9956 - auc: 0.9554
# Epoch 32: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2103 - iou_score: 0.5915 - dice_coeff: 0.8005 - precision: 0.8500 - recall: 0.8259 - sensitivity: 0.8057 - specificity: 0.9956 - auc: 0.9554 - val_loss: 0.3274 - val_iou_score: 0.4613 - val_dice_coeff: 0.6908 - val_precision: 0.7013 - val_recall: 0.7886 - val_sensitivity: 0.7873 - val_specificity: 0.9906 - val_auc: 0.9309 - lr: 1.0000e-04
# Epoch 33/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2132 - iou_score: 0.5860 - dice_coeff: 0.7995 - precision: 0.8405 - recall: 0.7993 - sensitivity: 0.8006 - specificity: 0.9954 - auc: 0.9432
# Epoch 33: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2132 - iou_score: 0.5860 - dice_coeff: 0.7995 - precision: 0.8405 - recall: 0.7993 - sensitivity: 0.8006 - specificity: 0.9954 - auc: 0.9432 - val_loss: 0.2683 - val_iou_score: 0.4921 - val_dice_coeff: 0.7448 - val_precision: 0.7840 - val_recall: 0.8395 - val_sensitivity: 0.7811 - val_specificity: 0.9935 - val_auc: 0.9493 - lr: 1.0000e-04
# Epoch 34/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2003 - iou_score: 0.6033 - dice_coeff: 0.8102 - precision: 0.8520 - recall: 0.8376 - sensitivity: 0.8124 - specificity: 0.9956 - auc: 0.9578
# Epoch 34: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 179ms/step - loss: 0.2003 - iou_score: 0.6033 - dice_coeff: 0.8102 - precision: 0.8520 - recall: 0.8376 - sensitivity: 0.8124 - specificity: 0.9956 - auc: 0.9578 - val_loss: 0.2614 - val_iou_score: 0.4854 - val_dice_coeff: 0.7517 - val_precision: 0.7899 - val_recall: 0.8364 - val_sensitivity: 0.7630 - val_specificity: 0.9937 - val_auc: 0.9466 - lr: 1.0000e-04
# Epoch 35/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2034 - iou_score: 0.6057 - dice_coeff: 0.8071 - precision: 0.8513 - recall: 0.8299 - sensitivity: 0.8069 - specificity: 0.9956 - auc: 0.9571
# Epoch 35: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 178ms/step - loss: 0.2034 - iou_score: 0.6057 - dice_coeff: 0.8071 - precision: 0.8513 - recall: 0.8299 - sensitivity: 0.8069 - specificity: 0.9956 - auc: 0.9571 - val_loss: 0.2764 - val_iou_score: 0.4818 - val_dice_coeff: 0.7376 - val_precision: 0.7683 - val_recall: 0.8473 - val_sensitivity: 0.7969 - val_specificity: 0.9928 - val_auc: 0.9537 - lr: 1.0000e-04
# Epoch 36/50
# 233/233 [==============================] - ETA: 0s - loss: 0.2019 - iou_score: 0.6034 - dice_coeff: 0.8085 - precision: 0.8524 - recall: 0.8363 - sensitivity: 0.8095 - specificity: 0.9956 - auc: 0.9583
# Epoch 36: val_loss did not improve from 0.25805
# 233/233 [==============================] - 42s 180ms/step - loss: 0.2019 - iou_score: 0.6034 - dice_coeff: 0.8085 - precision: 0.8524 - recall: 0.8363 - sensitivity: 0.8095 - specificity: 0.9956 - auc: 0.9583 - val_loss: 0.2632 - val_iou_score: 0.4998 - val_dice_coeff: 0.7497 - val_precision: 0.8636 - val_recall: 0.7692 - val_sensitivity: 0.7080 - val_specificity: 0.9966 - val_auc: 0.9228 - lr: 1.0000e-04
# Epoch 36: early stopping

# %%
# Save the final trained model
model.save('final_model_fine_tuned.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from matplotlib import pyplot as plt
history = pd.read_csv('/kaggle/working/training_log_WCE_segmentation', sep=',', engine='python')

#history= history

############### ########## ####### #######

iou_score=history['iou_score']
val_iou_score=history['val_iou_score']

loss=history['loss']
val_loss=history['val_loss']

train_dice=history['dice_coeff']
val_dice=history['val_dice_coeff']


epoch = np.arange(len(loss))

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
plt.subplots_adjust(wspace=0.3)  # Adjust the space between subplots

# Plot 1: Loss
axes[0].plot(epoch, loss, 'b', label='Training Loss', linewidth=1.5)
axes[0].plot(epoch, val_loss, 'r', label='Validation Loss', linewidth=1.5)
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training and Validation Loss')
axes[0].legend()

# Plot 2: IOU Scores
axes[1].plot(epoch, iou_score, 'b', label='Training IOU', linewidth=1.5)
axes[1].plot(epoch, val_iou_score, 'r', label='Validation IOU', linewidth=1.5)
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('IOU Score')
axes[1].set_title('Training and Validation IOU Score')
axes[1].legend()

# Plot 3: Dice Coefficients
axes[2].plot(epoch, train_dice, 'b', label='Training Dice Coeff', linewidth=1.5)
axes[2].plot(epoch, val_dice, 'r', label='Validation Dice Coeff', linewidth=1.5)
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Dice Coefficient')
axes[2].set_title('Training and Validation Dice Coefficient')
axes[2].legend()



# Customize tick marks and labels
for ax in axes:
    ax.grid(True)
    ax.set_xticks(np.arange(0, len(epoch), 5))  # Adjust the x-axis ticks
    ax.set_yticks(np.arange(0, 1.1, 0.1))  # Adjust the y-axis ticks
    ax.grid(which='both', linestyle='--', linewidth=0.5)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepring Testing Data

# %%
import os
import pandas as pd
from tqdm import tqdm

def read_patch_paths(image_folder, mask_folder):
    image_paths = []
    mask_paths = []

    # Get a list of image patch files in the folder
    image_files = os.listdir(image_folder)

    # Assuming the file names are the same in the mask folder
    for file_name in tqdm(image_files):
        image_path = os.path.join(image_folder, file_name)
        mask_path = os.path.join(mask_folder, file_name)

        # Check if both image and mask paths exist
        if os.path.exists(image_path) and os.path.exists(mask_path):
            image_paths.append(image_path)
            mask_paths.append(mask_path)

    # Create a DataFrame
    df = pd.DataFrame({'Image': image_paths, 'Mask': mask_paths})
    return df

# Specify the paths to the image and mask patch folders
image_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/image_patches_512_no_overlap"
mask_patch_folder = "/kaggle/input/testing-patches-he-512-idrid/HE_patches_test/mask_patches_512_no_overlap"

# Read patch paths and create a DataFrame
df_patches_test = read_patch_paths(image_patch_folder, mask_patch_folder)
# Out:
# 100%|██████████| 456/456 [00:01<00:00, 394.71it/s]

# %%
import cv2
import numpy as np
import albumentations as A
from tensorflow.keras.utils import Sequence
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
def apply_clahe(image):
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    cl = clahe.apply(l)
    limg = cv2.merge((cl, a, b))
    clahe_image = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
    return clahe_image

class CustomDataGenerator(Sequence):
    def __init__(self, df, batch_size, image_size, shuffle=True):
        self.df = df
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.transform = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            #A.RandomBrightnessContrast(p=0.2),
            #A.Rotate(limit=10, p=0.3)
        ])

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __getitem__(self, index):
        batch_df = self.df[index * self.batch_size : (index + 1) * self.batch_size]

        images = []
        masks = []

        for i, row in batch_df.iterrows():

            image = cv2.imread(row['Image'], cv2.IMREAD_COLOR)
            image = apply_clahe(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, self.image_size)
            #shape = image.shape
            #image = scaler.fit_transform(image.reshape(-1, shape[-1])).reshape(shape)
            image = image/np.max(image)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            mask_path = row['Mask']
            if mask_path:
                mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                mask = cv2.resize(mask, self.image_size)
                mask=mask>0
    

            augmented = self.transform(image=image, mask=mask)
            images.append(augmented['image'])
            masks.append(augmented['mask'])
            #images.append(image)
            #masks.append(mask)
        
                

        #images = np.expand_dims(np.array(images, dtype=np.float32), axis=-1)
        images = np.array(images, dtype=np.float32)
        masks = np.expand_dims(np.array(masks, dtype=np.float32), axis=-1)
        return  images, masks

# Example usage of the CustomDataGenerator
test_generator = CustomDataGenerator(df_patches_test, batch_size=16, image_size=(256, 256), shuffle=False)

# %%
results = model.evaluate(test_generator)
# Out:
# 29/29 [==============================] - 18s 462ms/step - loss: 0.2286 - iou_score: 0.4931 - dice_coeff: 0.7878 - precision: 0.8352 - recall: 0.7824 - sensitivity: 0.7678 - specificity: 0.9948 - auc: 0.9301

# %%
# !zip -r weights_WNet_Res50_AT_CL.zip /kaggle/working/WNet_maxpool_fine_tune.h5

# %%
from IPython.display import FileLink
FileLink(r'weights_WNet_Res50_AT_CL.zip')
